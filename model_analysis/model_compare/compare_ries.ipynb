# %%
import pandas as pd
import numpy as np
from scipy.stats import kruskal
import scikit_posthocs as sp
import matplotlib.pyplot as plt
import seaborn as sns
from utils.ci import bootstrap_ci
from utils.visulize import visulize_circles, visulize_letters, plot_grouped_bar_with_ci
from utils.grouping import get_group_labels

# %%
# load data
df = pd.read_csv('./summary_results.csv')
dataset_name = "RIES"  # Change to 'CF', 'CON', etc., for other comparisons
df = df[df['dataset'] == dataset_name].copy()

# ensure df has 240 rows excluding the title row
assert df.shape[0] == 240, f"Expected 240 rows, but got {df.shape[0]} rows."

# %%
print(df.columns)
metric_names = ['accuracy', 'f1_score', 'precision', 'recall', 'roc_auc']
models = df['model'].unique()
# Out:
# Index(['dataset', 'seed', 'model', 'accuracy', 'f1_score', 'precision',
#        'recall', 'roc_auc'],
#       dtype='object')

# %%
models
# Out:
# array(['logistic', 'randomforest', 'svm', 'lstm-features', 'lstm',
#        'lstmfcn-features', 'lstmfcn', 'vivit'], dtype=object)

# %%
# Run analysis per metric
posthoc_results = {}
for metric in metric_names:
    print(f"\n===== {metric.upper()} =====")
    data_by_model = [df[df['model'] == m][metric] for m in models]

    # Kruskal-Wallis test
    H, p = kruskal(*data_by_model)
    print(f"Kruskal-Wallis: H = {H:.3f}, p = {p:.4f}")
    
    # Post-hoc test if significant
    if p < 0.05:
        posthoc = sp.posthoc_dunn(df, val_col=metric, group_col='model', p_adjust='holm')
        posthoc_results[metric] = posthoc
        print("\nPost-hoc Dunn’s test (Holm-corrected):")
        print(posthoc)

        sig_plot = posthoc.apply(lambda x: x < 0.05).astype(int)
        # Plotting the significance matrix
        plt.figure(figsize=(10, 8))
        sns.heatmap(sig_plot.loc[models, models], annot=True, cmap='coolwarm', cbar=False)
        plt.title(f"Post-hoc Dunn's test significance matrix for {metric}")
    else:
        print("No statistically significant difference among models.")
# Out:
# ===== ACCURACY =====
# Kruskal-Wallis: H = 92.653, p = 0.0000
#
# Post-hoc Dunn’s test (Holm-corrected):
#                       logistic          lstm  lstm-features       lstmfcn  \
# logistic          1.000000e+00  1.000000e+00   1.000000e+00  1.000000e+00
# lstm              1.000000e+00  1.000000e+00   1.000000e+00  1.000000e+00
# lstm-features     1.000000e+00  1.000000e+00   1.000000e+00  1.000000e+00
# lstmfcn           1.000000e+00  1.000000e+00   1.000000e+00  1.000000e+00
# lstmfcn-features  1.000000e+00  1.000000e+00   1.000000e+00  1.000000e+00
# randomforest      1.206633e-01  1.000000e+00   1.000000e+00  1.000000e+00
# svm               3.918367e-14  5.063926e-10   5.075908e-11  2.448656e-09
# vivit             1.000000e+00  1.000000e+00   1.000000e+00  1.000000e+00
#
#                   lstmfcn-features  randomforest           svm         vivit
# logistic              1.000000e+00      0.120663  3.918367e-14  1.000000e+00
# lstm                  1.000000e+00      1.000000  5.063926e-10  1.000000e+00
# lstm-features         1.000000e+00      1.000000  5.075908e-11  1.000000e+00
# lstmfcn               1.000000e+00      1.000000  2.448656e-09  1.000000e+00
# lstmfcn-features      1.000000e+00      1.000000  2.448656e-09  1.000000e+00
# randomforest          1.000000e+00      1.000000  3.861156e-06  1.298156e-01
# svm                   2.448656e-09      0.000004  1.000000e+00  5.223360e-14
# vivit                 1.000000e+00      0.129816  5.223360e-14  1.000000e+00
#
# ===== F1_SCORE =====
# Kruskal-Wallis: H = 78.983, p = 0.0000
#
# Post-hoc Dunn’s test (Holm-corrected):
#                       logistic      lstm  lstm-features       lstmfcn  \
# logistic          1.000000e+00  0.000192       0.000042  4.057912e-07
# lstm              1.923026e-04  1.000000       1.000000  1.000000e+00
# lstm-features     4.160731e-05  1.000000       1.000000  1.000000e+00
# lstmfcn           4.057912e-07  1.000000       1.000000  1.000000e+00
# lstmfcn-features  3.266442e-06  1.000000       1.000000  1.000000e+00
# randomforest      3.200284e-02  1.000000       0.922641  1.641382e-01
# svm               3.325257e-14  0.007801       0.024580  2.476824e-01
# vivit             1.412152e-01  0.643782       0.353733  3.923312e-02
#
#                   lstmfcn-features  randomforest           svm     vivit
# logistic                  0.000003      0.032003  3.325257e-14  0.141215
# lstm                      1.000000      1.000000  7.801312e-03  0.643782
# lstm-features             1.000000      0.922641  2.457992e-02  0.353733
# lstmfcn                   1.000000      0.164138  2.476824e-01  0.039233
# lstmfcn-features          1.000000      0.358549  1.083858e-01  0.117342
# randomforest              0.358549      1.000000  2.749156e-05  1.000000
# svm                       0.108386      0.000027  1.000000e+00  0.000002
# vivit                     0.117342      1.000000  1.646884e-06  1.000000
#
# ===== PRECISION =====
# Kruskal-Wallis: H = 126.578, p = 0.0000
#
# Post-hoc Dunn’s test (Holm-corrected):
#                   logistic          lstm  lstm-features       lstmfcn  \
# logistic          1.000000  3.043772e-03   9.450933e-04  4.550327e-05
# lstm              0.003044  1.000000e+00   1.000000e+00  1.000000e+00
# lstm-features     0.000945  1.000000e+00   1.000000e+00  1.000000e+00
# lstmfcn           0.000046  1.000000e+00   1.000000e+00  1.000000e+00
# lstmfcn-features  0.000485  1.000000e+00   1.000000e+00  1.000000e+00
# randomforest      1.000000  3.043772e-03   9.450933e-04  4.550327e-05
# svm               0.001946  9.243966e-13   6.548865e-14  2.019556e-16
# vivit             0.023522  1.000000e+00   1.000000e+00  1.000000e+00
#
#                   lstmfcn-features  randomforest           svm         vivit
# logistic              4.849050e-04      1.000000  1.945667e-03  2.352208e-02
# lstm                  1.000000e+00      0.003044  9.243966e-13  1.000000e+00
# lstm-features         1.000000e+00      0.000945  6.548865e-14  1.000000e+00
# lstmfcn               1.000000e+00      0.000046  2.019556e-16  1.000000e+00
# lstmfcn-features      1.000000e+00      0.000485  1.630218e-14  1.000000e+00
# randomforest          4.849050e-04      1.000000  1.945667e-03  2.352208e-02
# svm                   1.630218e-14      0.001946  1.000000e+00  7.303774e-11
# vivit                 1.000000e+00      0.023522  7.303774e-11  1.000000e+00
#
# ===== RECALL =====
# Kruskal-Wallis: H = 153.880, p = 0.0000
#
# Post-hoc Dunn’s test (Holm-corrected):
#                       logistic          lstm  lstm-features       lstmfcn  \
# logistic          1.000000e+00  5.337283e-06   5.678844e-07  2.880306e-09
# lstm              5.337283e-06  1.000000e+00   1.000000e+00  1.000000e+00
# lstm-features     5.678844e-07  1.000000e+00   1.000000e+00  1.000000e+00
# lstmfcn           2.880306e-09  1.000000e+00   1.000000e+00  1.000000e+00
# lstmfcn-features  6.468739e-08  1.000000e+00   1.000000e+00  1.000000e+00
# randomforest      1.000000e+00  2.392688e-03   4.577655e-04  7.573303e-06
# svm               6.004626e-02  5.089706e-14   1.611782e-15  7.368724e-19
# vivit             6.004626e-02  1.539000e-01   6.004626e-02  3.285750e-03
#
#                   lstmfcn-features  randomforest           svm         vivit
# logistic              6.468739e-08      1.000000  6.004626e-02  6.004626e-02
# lstm                  1.000000e+00      0.002393  5.089706e-14  1.539000e-01
# lstm-features         1.000000e+00      0.000458  1.611782e-15  6.004626e-02
# lstmfcn               1.000000e+00      0.000008  7.368724e-19  3.285750e-03
# lstmfcn-features      1.000000e+00      0.000087  6.528712e-17  1.906181e-02
# randomforest          8.675108e-05      1.000000  5.017413e-04  1.000000e+00
# svm                   6.528712e-17      0.000502  1.000000e+00  5.843574e-07
# vivit                 1.906181e-02      1.000000  5.843574e-07  1.000000e+00
#
# ===== ROC_AUC =====
# Kruskal-Wallis: H = 134.469, p = 0.0000
#
# Post-hoc Dunn’s test (Holm-corrected):
#                       logistic          lstm  lstm-features       lstmfcn  \
# logistic          1.000000e+00  1.305784e-10   2.266553e-01  4.178219e-03
# lstm              1.305784e-10  1.000000e+00   8.044939e-05  1.548194e-02
# lstm-features     2.266553e-01  8.044939e-05   1.000000e+00  1.000000e+00
# lstmfcn           4.178219e-03  1.548194e-02   1.000000e+00  1.000000e+00
# lstmfcn-features  4.464986e-03  1.501460e-02   1.000000e+00  1.000000e+00
# randomforest      6.587813e-03  4.968791e-24   1.362392e-07  1.470621e-11
# svm               1.312055e-01  2.318627e-04   1.000000e+00  1.000000e+00
# vivit             1.000000e+00  1.349097e-09   4.257643e-01  1.278027e-02
#
#                   lstmfcn-features  randomforest           svm         vivit
# logistic              4.464986e-03  6.587813e-03  1.312055e-01  1.000000e+00
# lstm                  1.501460e-02  4.968791e-24  2.318627e-04  1.349097e-09
# lstm-features         1.000000e+00  1.362392e-07  1.000000e+00  4.257643e-01
# lstmfcn               1.000000e+00  1.470621e-11  1.000000e+00  1.278027e-02
# lstmfcn-features      1.000000e+00  1.785570e-11  1.000000e+00  1.335831e-02
# randomforest          1.785570e-11  1.000000e+00  3.400013e-08  1.998244e-03
# svm                   1.000000e+00  3.400013e-08  1.000000e+00  2.711712e-01
# vivit                 1.335831e-02  1.998244e-03  2.711712e-01  1.000000e+00

# %%
group_labels_per_metric = get_group_labels(posthoc_results, alpha=0.05)
print(group_labels_per_metric)
# Out:
# {'accuracy': {'logistic': 'A', 'lstm': 'A', 'lstm-features': 'A', 'lstmfcn': 'A', 'lstmfcn-features': 'A', 'randomforest': 'A', 'vivit': 'A', 'svm': 'B'}, 'f1_score': {'lstm': 'A', 'lstm-features': 'A', 'lstmfcn-features': 'A', 'randomforest': 'A', 'vivit': 'A', 'lstmfcn': 'B', 'svm': 'C', 'logistic': 'D'}, 'precision': {'lstm': 'A', 'lstm-features': 'A', 'lstmfcn': 'A', 'lstmfcn-features': 'A', 'vivit': 'A', 'logistic': 'B', 'randomforest': 'B', 'svm': 'C'}, 'recall': {'lstm': 'A', 'lstm-features': 'A', 'lstmfcn': 'A', 'lstmfcn-features': 'A', 'logistic': 'B', 'randomforest': 'B', 'vivit': 'B', 'svm': 'C'}, 'roc_auc': {'lstm-features': 'A', 'lstmfcn': 'A', 'lstmfcn-features': 'A', 'svm': 'A', 'logistic': 'B', 'vivit': 'B', 'randomforest': 'C', 'lstm': 'D'}}

# %%
visulize_letters(models, df, group_labels_per_metric)

# %%
plot_grouped_bar_with_ci(models, df, group_labels_per_metric, cultivar='Riesling')
# Out:
# Model: logistic, Metric: accuracy, Mean: 0.7599999999999999, CI: [0.7578571428571428, 0.7616726190476191]
# Model: randomforest, Metric: accuracy, Mean: 0.7521428571428569, CI: [0.7480892857142855, 0.7564285714285713]
# Model: svm, Metric: accuracy, Mean: 0.715, CI: [0.7123809523809523, 0.7178571428571429]
# Model: lstm, Metric: accuracy, Mean: 0.7576190476190476, CI: [0.7547619047619045, 0.7604761904761902]
# Model: lstm-features, Metric: accuracy, Mean: 0.7576190476190476, CI: [0.752857142857143, 0.7616726190476191]
# Model: lstmfcn, Metric: accuracy, Mean: 0.7573809523809523, CI: [0.7554761904761904, 0.7592857142857141]
# Model: lstmfcn-features, Metric: accuracy, Mean: 0.757142857142857, CI: [0.7554761904761904, 0.7588095238095235]
# Model: vivit, Metric: accuracy, Mean: 0.7604761904761903, CI: [0.7550000000000001, 0.7654761904761905]
# Model: logistic, Metric: f1_score, Mean: 0.7761900592245312, CI: [0.7743388459601122, 0.7777612569581154]
# Model: randomforest, Metric: f1_score, Mean: 0.7675917713671697, CI: [0.7624204127605257, 0.7720566923509722]
# Model: svm, Metric: f1_score, Mean: 0.7559499144337904, CI: [0.7536546399579234, 0.7583501437415507]
# Model: lstm, Metric: f1_score, Mean: 0.7644962542856608, CI: [0.7614814931031948, 0.7673533641029895]
# Model: lstm-features, Metric: f1_score, Mean: 0.7641062454657105, CI: [0.7610617260974138, 0.7672806098471309]
# Model: lstmfcn, Metric: f1_score, Mean: 0.7620082146112938, CI: [0.7596347712576481, 0.7644308571876588]
# Model: lstmfcn-features, Metric: f1_score, Mean: 0.7628564802387593, CI: [0.7611436683550608, 0.7646232607126271]
# Model: vivit, Metric: f1_score, Mean: 0.7710645461123823, CI: [0.7657404404783837, 0.7762657732765412]
# Model: logistic, Metric: precision, Mean: 0.7272411802871338, CI: [0.7243211471989454, 0.7297775358841339]
# Model: randomforest, Metric: precision, Mean: 0.723449707560547, CI: [0.7161981490549003, 0.7314580443051205]
# Model: svm, Metric: precision, Mean: 0.6610330825992015, CI: [0.6584224041950066, 0.6635896439241751]
# Model: lstm, Metric: precision, Mean: 0.7437331922043445, CI: [0.7390125013094105, 0.7489720354958148]
# Model: lstm-features, Metric: precision, Mean: 0.7451820125874388, CI: [0.737439436440461, 0.7523670940863463]
# Model: lstmfcn, Metric: precision, Mean: 0.7478776955288493, CI: [0.7445680185325386, 0.7515526449750788]
# Model: lstmfcn-features, Metric: precision, Mean: 0.7455246255267728, CI: [0.7421312622095394, 0.749175558538819]
# Model: vivit, Metric: precision, Mean: 0.7387528083831145, CI: [0.7320204151082765, 0.7451882139943914]
# Model: logistic, Metric: recall, Mean: 0.8323809523809522, CI: [0.8285714285714285, 0.836190476190476]
# Model: randomforest, Metric: recall, Mean: 0.82, CI: [0.802845238095238, 0.8338095238095237]
# Model: svm, Metric: recall, Mean: 0.8828571428571427, CI: [0.8780952380952379, 0.8880952380952379]
# Model: lstm, Metric: recall, Mean: 0.7871428571428573, CI: [0.7795238095238095, 0.7947619047619046]
# Model: lstm-features, Metric: recall, Mean: 0.7847619047619048, CI: [0.7790476190476191, 0.7909523809523811]
# Model: lstmfcn, Metric: recall, Mean: 0.777142857142857, CI: [0.7714285714285711, 0.7842857142857141]
# Model: lstmfcn-features, Metric: recall, Mean: 0.7814285714285713, CI: [0.7757142857142856, 0.787154761904762]
# Model: vivit, Metric: recall, Mean: 0.807142857142857, CI: [0.7976190476190474, 0.8166666666666665]
# Model: logistic, Metric: roc_auc, Mean: 0.82921768707483, CI: [0.8288979591836737, 0.8295238095238096]
# Model: randomforest, Metric: roc_auc, Mean: 0.8110952380952381, CI: [0.8097005102040816, 0.8125034013605442]
# Model: svm, Metric: roc_auc, Mean: 0.8314523809523809, CI: [0.8310167517006802, 0.8318778061224491]
# Model: lstm, Metric: roc_auc, Mean: 0.83743537414966, CI: [0.8362243197278912, 0.8386054421768706]
# Model: lstm-features, Metric: roc_auc, Mean: 0.8310204081632653, CI: [0.8292105442176871, 0.8326530612244897]
# Model: lstmfcn, Metric: roc_auc, Mean: 0.8324829931972787, CI: [0.8315714285714286, 0.8333403061224488]
# Model: lstmfcn-features, Metric: roc_auc, Mean: 0.8325442176870748, CI: [0.8315574829931972, 0.833530612244898]
# Model: vivit, Metric: roc_auc, Mean: 0.8236734693877552, CI: [0.8178431972789115, 0.83008962585034]

# %%
# change the col and row names to these model names
model_names = {
    'logistic': 'Logistic Regression',
    'randomforest': 'Random Forest',
    'svm': 'SVM',
    'lstm-features': 'Hybrid LSTM',
    'lstm': 'LSTM',
    'lstmfcn-features': 'Hybrid LSTM-FCN',
    'lstmfcn': 'LSTM-FCN',
    'vivit': 'ViVit',
}
# set the ordering for the col and row names
model_order = [
    'logistic',
    'randomforest',
    'svm',
    'lstm',
    'lstm-features',
    'lstmfcn',
    'lstmfcn-features',
    'vivit',
]

# for all values in posthoc_results, only remain 3 digits
# e.g. 0.123456 -> 0.123; 1.0 -> 1.00; 0.01123121e-05 -> 0.01e-05； 1 -> 1.00
# store each metric's posthoc result to a csv file
def fmt_three_digits(x):
    # Leave non-numerics (e.g., "ns", "-") alone
    if isinstance(x, (np.integer, int, np.floating, float)):
        s = f"{float(x):.3g}"  # 3 significant digits; uses sci-notation when appropriate
        # If not scientific and no decimal point, pad to .00 (e.g., 1 -> 1.00)
        if 'e' not in s and '.' not in s:
            s = s + '.00'
        return s
    return x


for metric, df in posthoc_results.items():
    # 1) format numbers
    df = df.applymap(fmt_three_digits)

    # 2) rename rows/cols to pretty names
    df = df.rename(index=model_names, columns=model_names)

    # 3) order rows/cols safely (keep only those present)
    desired_idx = [model_names[m] for m in model_order if model_names.get(m) in df.index]
    desired_cols = [model_names[m] for m in model_order if model_names.get(m) in df.columns]
    df = df.loc[desired_idx, desired_cols]

    # 4) save
    df.to_csv(f'./tables/posthoc_dunn_{dataset_name}_{metric}.csv')
# Out:
# C:\Users\Mud\AppData\Local\Temp\ipykernel_52636\631486915.py:40: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(fmt_three_digits)
# C:\Users\Mud\AppData\Local\Temp\ipykernel_52636\631486915.py:40: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(fmt_three_digits)
# C:\Users\Mud\AppData\Local\Temp\ipykernel_52636\631486915.py:40: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(fmt_three_digits)
# C:\Users\Mud\AppData\Local\Temp\ipykernel_52636\631486915.py:40: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(fmt_three_digits)
# C:\Users\Mud\AppData\Local\Temp\ipykernel_52636\631486915.py:40: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(fmt_three_digits)
