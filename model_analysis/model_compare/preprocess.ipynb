# %%
import pandas as pd

# %%
# load data
df1 = pd.read_csv(r"C:\Users\Mud\Desktop\2ndPaper\traditional_ml\pipelines\summary_results.csv")  # conventional models
df2 = pd.read_csv(r"C:\Users\Mud\Desktop\2ndPaper\lstm\pipelines\summary_results_new.csv")          # lstm variants
df3 = pd.read_csv(r"C:\Users\Mud\Desktop\2ndPaper\transformer\summary_results.csv")         # vivit
df3['model'] = 'vivit'


df = pd.concat([df1, df2, df3], ignore_index=True)

# Drop only the columns that exist in the dataframe
columns_to_drop = ['Best Parameters', 'TN', 'FP', 'FN', 'TP', 'run_name', 'features', 'batch_size', 'learning_rate']
df.drop(columns=[col for col in columns_to_drop if col in df.columns], inplace=True)

df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")

# %%
# store the df into csv file
df.to_csv('./summary_results_new.csv', index=False)
