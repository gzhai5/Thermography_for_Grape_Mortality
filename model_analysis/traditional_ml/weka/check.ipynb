# %%
import numpy as np

# %%
X_train = np.load(f'../../data-preprocess/data-split/data/features/train/X_train.npy', allow_pickle=True)
y_train = np.load(f'../../data-preprocess/data-split/data/features/train/y_train.npy', allow_pickle=True)
X_test = np.load(f'../../data-preprocess/data-split/data/features/test/X_test.npy', allow_pickle=True)
y_test = np.load(f'../../data-preprocess/data-split/data/features/test/y_test.npy', allow_pickle=True)

# %%
# see what is inside test labels, count of 0 and 1
unique, counts = np.unique(y_test, return_counts=True)
print(dict(zip(unique, counts)))
# Out:
# {0: 280, 1: 280}

# %%
# see what is inside train labels, count of 0 and 1
unique, counts = np.unique(y_train, return_counts=True)
print(dict(zip(unique, counts)))
# Out:
# {0: 694, 1: 1529}

# %%
# see what is one feature looks like
print(X_train[0])
# Out:
# {'pc0': -1320.5068446619284, 'pc1': 47.46269889751666, 'pc2': 39.9311463643831, 'rising_waveform': 0.9653721900282748, 'falling_waveform': 0.5479591836734714, 'peak_temperature': 260.6504913076342, 'cultivar': 1}

# %%
# see if the label data is balanced in cultivars, cultivar data is 1,2,3,4 in feature data
cultivars = np.array([x['cultivar'] for x in X_test])
unique, counts = np.unique(cultivars, return_counts=True)
print(dict(zip(unique, counts)))
# Out:
# {1: 140, 2: 140, 3: 140, 4: 140}
