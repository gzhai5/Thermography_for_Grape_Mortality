# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import accuracy_score, roc_auc_score, recall_score, precision_score, f1_score
from sklearn.metrics import confusion_matrix, precision_recall_fscore_support
import seaborn as sns
from collections import Counter
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau
from model.lstmfcn import generate_lstmfcn
from model.fcn import generate_fcn
from model.lstm import generate_lstm
from utils.class_weight import compute_class_weight
import tensorflow as tf
import random as python_random

# %%
# # load the data
X_test_time = np.load('../data-preprocess/data-split/data/mean-time-series/test/X_test.npy')
y_test = np.load('../data-preprocess/data-split/data/features/test/y_test.npy')
X_train_time = np.load('../data-preprocess/data-split/data/mean-time-series/train/X_train.npy')
y_train = np.load('../data-preprocess/data-split/data/features/train/y_train.npy')
X_test_features = np.load('../data-preprocess/data-split/data/features/test/X_test.npy', allow_pickle=True)
X_train_features = np.load('../data-preprocess/data-split/data/features/train/X_train.npy', allow_pickle=True)

# # load fake data
#X_train = np.load('./fake/train/X_train.npy')
#y_train = np.load('./fake/train/y_train.npy')
#X_test = np.load('./fake/test/X_test.npy')
#y_test = np.load('./fake/test/y_test.npy')


print('X_train of time series shape:', X_train_time.shape)
print('X_test of time series shape:', X_test_time.shape)
print('X_train of features shape:', X_train_features.shape)
print('X_test of features shape:', X_test_features.shape)
print('y_train shape:', y_train.shape)
print('y_test shape:', y_test.shape)
# Out:
# X_train of time series shape: (2223, 600)
# X_test of time series shape: (560, 600)
# X_train of features shape: (2223,)
# X_test of features shape: (560,)
# y_train shape: (2223,)
# y_test shape: (560,)

# %%
def reset_random_seeds(seed=42):
   np.random.seed(seed)
   python_random.seed(seed)
   tf.random.set_seed(seed)

reset_random_seeds()

# %%
# normalize the data to have same starting pt for all time series
# input shape: (n_samples, n_timepoints), want each samples - its mean of 0-30th timepts
def normalize_curves_mean_method(unnormalized_datas):
    normalized_datas = []
    for unnormalized_data in unnormalized_datas:
        mean = np.mean(unnormalized_data[:30])
        normalized_data = unnormalized_data - mean
        normalized_datas.append(normalized_data)
    normalized_datas = np.array(normalized_datas)
    assert normalized_datas.shape == unnormalized_datas.shape
    return normalized_datas

# normalize the data using z-score, have mean 0 and std 1
def normalize_curves_zscore(unnormalized_datas):
    normalized_datas = []
    for unnormalized_data in unnormalized_datas:
        mean = np.mean(unnormalized_data)
        std = np.std(unnormalized_data)
        normalized_data = (unnormalized_data - mean) / std
        normalized_datas.append(normalized_data)
    normalized_datas = np.array(normalized_datas)
    assert normalized_datas.shape == unnormalized_datas.shape
    return normalized_datas


# apply ln() to the time series data
def apply_ln_to_curves(datas):
    ln_datas = []
    for data in datas:
        ln_data = np.log(data)
        ln_datas.append(ln_data)
    ln_datas = np.array(ln_datas)
    assert ln_datas.shape == datas.shape
    return ln_datas


# split the time series data into wanted time points
def split_time_series(datas, start, end):
    datas = datas[:, start:end]
    return datas


# plot the time series data, randomly picked n samples, different colors represent different classes
def plot_random_time_series(datas, n, labels):
    for i in range(n):
        idx = np.random.randint(datas.shape[0])
        plt.plot(datas[idx], color = 'blue' if labels[idx] == 1 else 'red', alpha = 0.2)
    plt.show()


X_train_time = normalize_curves_mean_method(X_train_time)
X_test_time = normalize_curves_mean_method(X_test_time)
plot_random_time_series(X_train_time, 100, y_train)

# %%
# normalize the features data
X_train_features = pd.DataFrame.from_records(X_train_features.flatten())
X_test_features = pd.DataFrame.from_records(X_test_features.flatten())
print(X_train_features.head(1))

scaler = StandardScaler()
features = X_train_features.columns
X_train_features[features] = scaler.fit_transform(X_train_features[features])
X_test_features[features] = scaler.transform(X_test_features[features])
print(X_train_features.head(1))
# Out:
#            pc0        pc1        pc2  rising_waveform  falling_waveform  \
# 0 -1320.506845  47.462699  39.931146         0.965372          0.547959
#
#    peak_temperature  cultivar
# 0        260.650491         1
#         pc0       pc1       pc2  rising_waveform  falling_waveform  \
# 0 -1.100143  0.143025  0.333856        -1.146425         -1.244999
#
#    peak_temperature  cultivar
# 0         -1.146425  -1.35422

# %%
# normalize the time series data
# compute mean & std of the training set, then normalize the whole dataset using z-normalization
mean = np.mean(X_train_time)
std = np.std(X_train_time)
X_train_time = (X_train_time - mean) / std
X_test_time = (X_test_time - mean) / std

# %%
# Ensure data is shaped correctly
X_train_time = X_train_time.reshape(-1, 1, 600)  # Convert to (samples, 1, timesteps)
X_test_time = X_test_time.reshape(-1, 1, 600)
y_train = y_train.reshape(-1, 1)  # Ensure labels are in shape (samples, 1)
y_test = y_test.reshape(-1, 1)
X_train_features = X_train_features.values
X_test_features = X_test_features.values

print('X_train shape of time series:', X_train_time.shape)
print('y_train shape:', y_train.shape)
print('X_test shape of time series:', X_test_time.shape)
print('y_test shape:', y_test.shape)
print('X_train shape of features:', X_train_features.shape)
print('X_test shape of features:', X_test_features.shape)
# Out:
# X_train shape of time series: (2223, 1, 600)
# y_train shape: (2223, 1)
# X_test shape of time series: (560, 1, 600)
# y_test shape: (560, 1)
# X_train shape of features: (2223, 7)
# X_test shape of features: (560, 7)

# %%
# Train final model on full training data# Initialize model
final_model = generate_lstm(feature_input_accept=True, dropout=0.0)
class_weights = compute_class_weight(y_train)
print('class_weights:', class_weights)
reduce_lr = ReduceLROnPlateau(monitor='loss', patience=15, mode='auto',
    factor=1. / np.cbrt(2), cooldown=0, min_lr=5e-7, verbose=2)
final_model.compile(optimizer=Adam(learning_rate=8e-6), loss='binary_crossentropy', metrics=['accuracy'])

# split the data into training and validation set
X_train_time, X_val_time, X_train_features, X_val_features, y_train, y_val = train_test_split(
    X_train_time, X_train_features, y_train, test_size=0.2, random_state=42)
print('X_train shape of time series:', X_train_time.shape)
print('y_train shape:', y_train.shape)
print('X_val shape of time series:', X_val_time.shape)
print('y_val shape:', y_val.shape)
print('X_train shape of features:', X_train_features.shape)
print('X_val shape of features:', X_val_features.shape)

# Train model
history = final_model.fit(
    [X_train_time, X_train_features], y_train,
    validation_data=([X_val_time, X_val_features], y_val),
    callbacks=[reduce_lr],
    epochs=1100, batch_size=16, class_weight={0: class_weights[0], 1: class_weights[1]},
    verbose=1
)

# Predict on test set
y_pred_prob = final_model.predict([X_test_time, X_test_features])
y_pred = (y_pred_prob > 0.5).astype(int)

# Calculate metrics
accuracy = accuracy_score(y_test, y_pred)
precision, recall, f1, _ = precision_recall_fscore_support(y_test, y_pred, average='binary')
roc_auc = roc_auc_score(y_test, y_pred_prob)
conf_matrix = confusion_matrix(y_test, y_pred)

# plot the metrics
print(f"Test Accuracy: {accuracy:.4f}")
print(f"Test F1 Score: {f1:.4f}")
print(f"Test Precision: {precision:.4f}")
print(f"Test Recall: {recall:.4f}")
print(f"Test ROC AUC Score: {roc_auc:.4f}")
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Dead', 'Alive'], yticklabels=['Dead', 'Alive'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()


# plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.figure(figsize=(10, 7))
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.figure(figsize=(10, 7))
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# class_weights: [1.60158501 0.72694572]
# X_train shape of time series: (1778, 1, 600)
# y_train shape: (1778, 1)
# X_val shape of time series: (445, 1, 600)
# y_val shape: (445, 1)
# X_train shape of features: (1778, 7)
# X_val shape of features: (445, 7)
# Epoch 1/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6471 - loss: 0.7353 - val_accuracy: 0.6517 - val_loss: 0.6527 - learning_rate: 8.0000e-06
# Epoch 2/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 933us/step - accuracy: 0.6374 - loss: 0.7262 - val_accuracy: 0.6584 - val_loss: 0.6432 - learning_rate: 8.0000e-06
# Epoch 3/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 973us/step - accuracy: 0.6757 - loss: 0.6909 - val_accuracy: 0.6742 - val_loss: 0.6345 - learning_rate: 8.0000e-06
# Epoch 4/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 866us/step - accuracy: 0.6937 - loss: 0.6778 - val_accuracy: 0.7034 - val_loss: 0.6268 - learning_rate: 8.0000e-06
# Epoch 5/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 893us/step - accuracy: 0.7042 - loss: 0.6560 - val_accuracy: 0.7191 - val_loss: 0.6198 - learning_rate: 8.0000e-06
# Epoch 6/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 948us/step - accuracy: 0.7202 - loss: 0.6449 - val_accuracy: 0.7393 - val_loss: 0.6134 - learning_rate: 8.0000e-06
# Epoch 7/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 889us/step - accuracy: 0.7168 - loss: 0.6377 - val_accuracy: 0.7303 - val_loss: 0.6068 - learning_rate: 8.0000e-06
# Epoch 8/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 847us/step - accuracy: 0.7350 - loss: 0.6224 - val_accuracy: 0.7393 - val_loss: 0.6007 - learning_rate: 8.0000e-06
# Epoch 9/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 847us/step - accuracy: 0.7182 - loss: 0.6179 - val_accuracy: 0.7258 - val_loss: 0.5954 - learning_rate: 8.0000e-06
# Epoch 10/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 838us/step - accuracy: 0.7232 - loss: 0.6105 - val_accuracy: 0.7236 - val_loss: 0.5909 - learning_rate: 8.0000e-06
# Epoch 11/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step - accuracy: 0.7150 - loss: 0.6118 - val_accuracy: 0.7191 - val_loss: 0.5869 - learning_rate: 8.0000e-06
# Epoch 12/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - accuracy: 0.7337 - loss: 0.5951 - val_accuracy: 0.7169 - val_loss: 0.5829 - learning_rate: 8.0000e-06
# Epoch 13/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 894us/step - accuracy: 0.7237 - loss: 0.5927 - val_accuracy: 0.7169 - val_loss: 0.5798 - learning_rate: 8.0000e-06
# Epoch 14/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 856us/step - accuracy: 0.7284 - loss: 0.5903 - val_accuracy: 0.7146 - val_loss: 0.5772 - learning_rate: 8.0000e-06
# Epoch 15/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 906us/step - accuracy: 0.7198 - loss: 0.5874 - val_accuracy: 0.7191 - val_loss: 0.5754 - learning_rate: 8.0000e-06
# Epoch 16/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 947us/step - accuracy: 0.7220 - loss: 0.5833 - val_accuracy: 0.7213 - val_loss: 0.5735 - learning_rate: 8.0000e-06
# Epoch 17/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 929us/step - accuracy: 0.7200 - loss: 0.5833 - val_accuracy: 0.7146 - val_loss: 0.5720 - learning_rate: 8.0000e-06
# Epoch 18/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 893us/step - accuracy: 0.7221 - loss: 0.5838 - val_accuracy: 0.7146 - val_loss: 0.5706 - learning_rate: 8.0000e-06
# Epoch 19/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 865us/step - accuracy: 0.7277 - loss: 0.5743 - val_accuracy: 0.7124 - val_loss: 0.5695 - learning_rate: 8.0000e-06
# Epoch 20/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step - accuracy: 0.7256 - loss: 0.5770 - val_accuracy: 0.7101 - val_loss: 0.5686 - learning_rate: 8.0000e-06
# Epoch 21/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 894us/step - accuracy: 0.7274 - loss: 0.5762 - val_accuracy: 0.7056 - val_loss: 0.5677 - learning_rate: 8.0000e-06
# Epoch 22/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step - accuracy: 0.7273 - loss: 0.5735 - val_accuracy: 0.7079 - val_loss: 0.5670 - learning_rate: 8.0000e-06
# Epoch 23/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 940us/step - accuracy: 0.7224 - loss: 0.5749 - val_accuracy: 0.7056 - val_loss: 0.5666 - learning_rate: 8.0000e-06
# Epoch 24/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 847us/step - accuracy: 0.7273 - loss: 0.5756 - val_accuracy: 0.7056 - val_loss: 0.5661 - learning_rate: 8.0000e-06
# Epoch 25/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 840us/step - accuracy: 0.7312 - loss: 0.5690 - val_accuracy: 0.7056 - val_loss: 0.5655 - learning_rate: 8.0000e-06
# Epoch 26/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 847us/step - accuracy: 0.7283 - loss: 0.5723 - val_accuracy: 0.7056 - val_loss: 0.5651 - learning_rate: 8.0000e-06
# Epoch 27/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 829us/step - accuracy: 0.7320 - loss: 0.5712 - val_accuracy: 0.7056 - val_loss: 0.5646 - learning_rate: 8.0000e-06
# Epoch 28/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 829us/step - accuracy: 0.7266 - loss: 0.5665 - val_accuracy: 0.7056 - val_loss: 0.5645 - learning_rate: 8.0000e-06
# Epoch 29/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 839us/step - accuracy: 0.7254 - loss: 0.5644 - val_accuracy: 0.7079 - val_loss: 0.5642 - learning_rate: 8.0000e-06
# Epoch 30/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 830us/step - accuracy: 0.7335 - loss: 0.5644 - val_accuracy: 0.7079 - val_loss: 0.5640 - learning_rate: 8.0000e-06
# Epoch 31/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 912us/step - accuracy: 0.7335 - loss: 0.5667 - val_accuracy: 0.7079 - val_loss: 0.5639 - learning_rate: 8.0000e-06
# Epoch 32/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step - accuracy: 0.7349 - loss: 0.5596 - val_accuracy: 0.7079 - val_loss: 0.5634 - learning_rate: 8.0000e-06
# Epoch 33/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 847us/step - accuracy: 0.7243 - loss: 0.5629 - val_accuracy: 0.7101 - val_loss: 0.5629 - learning_rate: 8.0000e-06
# Epoch 34/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 862us/step - accuracy: 0.7271 - loss: 0.5673 - val_accuracy: 0.7101 - val_loss: 0.5632 - learning_rate: 8.0000e-06
# Epoch 35/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step - accuracy: 0.7264 - loss: 0.5609 - val_accuracy: 0.7101 - val_loss: 0.5632 - learning_rate: 8.0000e-06
# Epoch 36/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step - accuracy: 0.7335 - loss: 0.5610 - val_accuracy: 0.7101 - val_loss: 0.5631 - learning_rate: 8.0000e-06
# Epoch 37/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 841us/step - accuracy: 0.7301 - loss: 0.5618 - val_accuracy: 0.7101 - val_loss: 0.5630 - learning_rate: 8.0000e-06
# Epoch 38/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 842us/step - accuracy: 0.7334 - loss: 0.5572 - val_accuracy: 0.7124 - val_loss: 0.5629 - learning_rate: 8.0000e-06
# Epoch 39/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step - accuracy: 0.7404 - loss: 0.5593 - val_accuracy: 0.7124 - val_loss: 0.5632 - learning_rate: 8.0000e-06
# Epoch 40/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - accuracy: 0.7307 - loss: 0.5575 - val_accuracy: 0.7124 - val_loss: 0.5631 - learning_rate: 8.0000e-06
# Epoch 41/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 893us/step - accuracy: 0.7212 - loss: 0.5572 - val_accuracy: 0.7124 - val_loss: 0.5628 - learning_rate: 8.0000e-06
# Epoch 42/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 849us/step - accuracy: 0.7344 - loss: 0.5572 - val_accuracy: 0.7124 - val_loss: 0.5627 - learning_rate: 8.0000e-06
# Epoch 43/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 864us/step - accuracy: 0.7370 - loss: 0.5542 - val_accuracy: 0.7101 - val_loss: 0.5626 - learning_rate: 8.0000e-06
# Epoch 44/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 830us/step - accuracy: 0.7360 - loss: 0.5621 - val_accuracy: 0.7101 - val_loss: 0.5629 - learning_rate: 8.0000e-06
# Epoch 45/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 838us/step - accuracy: 0.7263 - loss: 0.5567 - val_accuracy: 0.7169 - val_loss: 0.5627 - learning_rate: 8.0000e-06
# Epoch 46/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 859us/step - accuracy: 0.7297 - loss: 0.5553 - val_accuracy: 0.7169 - val_loss: 0.5625 - learning_rate: 8.0000e-06
# Epoch 47/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step - accuracy: 0.7334 - loss: 0.5566 - val_accuracy: 0.7169 - val_loss: 0.5622 - learning_rate: 8.0000e-06
# Epoch 48/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step - accuracy: 0.7310 - loss: 0.5561 - val_accuracy: 0.7191 - val_loss: 0.5623 - learning_rate: 8.0000e-06
# Epoch 49/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 829us/step - accuracy: 0.7385 - loss: 0.5532 - val_accuracy: 0.7169 - val_loss: 0.5625 - learning_rate: 8.0000e-06
# Epoch 50/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step - accuracy: 0.7340 - loss: 0.5533 - val_accuracy: 0.7169 - val_loss: 0.5623 - learning_rate: 8.0000e-06
# Epoch 51/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 824us/step - accuracy: 0.7469 - loss: 0.5551 - val_accuracy: 0.7191 - val_loss: 0.5622 - learning_rate: 8.0000e-06
# Epoch 52/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 845us/step - accuracy: 0.7286 - loss: 0.5573 - val_accuracy: 0.7191 - val_loss: 0.5619 - learning_rate: 8.0000e-06
# Epoch 53/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step - accuracy: 0.7310 - loss: 0.5540 - val_accuracy: 0.7191 - val_loss: 0.5621 - learning_rate: 8.0000e-06
# Epoch 54/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 957us/step - accuracy: 0.7412 - loss: 0.5516 - val_accuracy: 0.7191 - val_loss: 0.5620 - learning_rate: 8.0000e-06
# Epoch 55/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step - accuracy: 0.7332 - loss: 0.5590 - val_accuracy: 0.7191 - val_loss: 0.5624 - learning_rate: 8.0000e-06
# Epoch 56/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 867us/step - accuracy: 0.7345 - loss: 0.5530 - val_accuracy: 0.7169 - val_loss: 0.5626 - learning_rate: 8.0000e-06
# Epoch 57/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 875us/step - accuracy: 0.7380 - loss: 0.5502 - val_accuracy: 0.7169 - val_loss: 0.5627 - learning_rate: 8.0000e-06
# Epoch 58/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 866us/step - accuracy: 0.7407 - loss: 0.5469 - val_accuracy: 0.7146 - val_loss: 0.5628 - learning_rate: 8.0000e-06
# Epoch 59/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step - accuracy: 0.7374 - loss: 0.5515 - val_accuracy: 0.7146 - val_loss: 0.5627 - learning_rate: 8.0000e-06
# Epoch 60/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 856us/step - accuracy: 0.7413 - loss: 0.5520 - val_accuracy: 0.7124 - val_loss: 0.5631 - learning_rate: 8.0000e-06
# Epoch 61/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 945us/step - accuracy: 0.7321 - loss: 0.5517 - val_accuracy: 0.7124 - val_loss: 0.5632 - learning_rate: 8.0000e-06
# Epoch 62/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step - accuracy: 0.7364 - loss: 0.5476 - val_accuracy: 0.7124 - val_loss: 0.5628 - learning_rate: 8.0000e-06
# Epoch 63/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step - accuracy: 0.7348 - loss: 0.5493 - val_accuracy: 0.7124 - val_loss: 0.5627 - learning_rate: 8.0000e-06
# Epoch 64/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 856us/step - accuracy: 0.7433 - loss: 0.5488 - val_accuracy: 0.7124 - val_loss: 0.5629 - learning_rate: 8.0000e-06
# Epoch 65/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 856us/step - accuracy: 0.7358 - loss: 0.5492 - val_accuracy: 0.7124 - val_loss: 0.5627 - learning_rate: 8.0000e-06
# Epoch 66/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step - accuracy: 0.7392 - loss: 0.5520 - val_accuracy: 0.7124 - val_loss: 0.5627 - learning_rate: 8.0000e-06
# Epoch 67/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 845us/step - accuracy: 0.7385 - loss: 0.5523 - val_accuracy: 0.7124 - val_loss: 0.5627 - learning_rate: 8.0000e-06
# Epoch 68/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - accuracy: 0.7413 - loss: 0.5481 - val_accuracy: 0.7124 - val_loss: 0.5625 - learning_rate: 8.0000e-06
# Epoch 69/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 867us/step - accuracy: 0.7369 - loss: 0.5488 - val_accuracy: 0.7124 - val_loss: 0.5628 - learning_rate: 8.0000e-06
# Epoch 70/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - accuracy: 0.7436 - loss: 0.5510 - val_accuracy: 0.7146 - val_loss: 0.5630 - learning_rate: 8.0000e-06
# Epoch 71/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 872us/step - accuracy: 0.7503 - loss: 0.5406 - val_accuracy: 0.7146 - val_loss: 0.5629 - learning_rate: 8.0000e-06
# Epoch 72/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 883us/step - accuracy: 0.7466 - loss: 0.5411 - val_accuracy: 0.7146 - val_loss: 0.5626 - learning_rate: 8.0000e-06
# Epoch 73/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 875us/step - accuracy: 0.7395 - loss: 0.5454 - val_accuracy: 0.7146 - val_loss: 0.5627 - learning_rate: 8.0000e-06
# Epoch 74/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step - accuracy: 0.7425 - loss: 0.5466 - val_accuracy: 0.7169 - val_loss: 0.5627 - learning_rate: 8.0000e-06
# Epoch 75/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 906us/step - accuracy: 0.7408 - loss: 0.5432 - val_accuracy: 0.7169 - val_loss: 0.5626 - learning_rate: 8.0000e-06
# Epoch 76/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - accuracy: 0.7348 - loss: 0.5461 - val_accuracy: 0.7213 - val_loss: 0.5621 - learning_rate: 8.0000e-06
# Epoch 77/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 866us/step - accuracy: 0.7488 - loss: 0.5440 - val_accuracy: 0.7213 - val_loss: 0.5624 - learning_rate: 8.0000e-06
# Epoch 78/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 857us/step - accuracy: 0.7418 - loss: 0.5420 - val_accuracy: 0.7213 - val_loss: 0.5623 - learning_rate: 8.0000e-06
# Epoch 79/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 838us/step - accuracy: 0.7405 - loss: 0.5453 - val_accuracy: 0.7213 - val_loss: 0.5626 - learning_rate: 8.0000e-06
# Epoch 80/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 839us/step - accuracy: 0.7324 - loss: 0.5427 - val_accuracy: 0.7213 - val_loss: 0.5622 - learning_rate: 8.0000e-06
# Epoch 81/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 820us/step - accuracy: 0.7392 - loss: 0.5401 - val_accuracy: 0.7213 - val_loss: 0.5623 - learning_rate: 8.0000e-06
# Epoch 82/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 820us/step - accuracy: 0.7415 - loss: 0.5386 - val_accuracy: 0.7213 - val_loss: 0.5620 - learning_rate: 8.0000e-06
# Epoch 83/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 888us/step - accuracy: 0.7365 - loss: 0.5457 - val_accuracy: 0.7213 - val_loss: 0.5625 - learning_rate: 8.0000e-06
# Epoch 84/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 843us/step - accuracy: 0.7421 - loss: 0.5454 - val_accuracy: 0.7213 - val_loss: 0.5622 - learning_rate: 8.0000e-06
# Epoch 85/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 847us/step - accuracy: 0.7397 - loss: 0.5459 - val_accuracy: 0.7236 - val_loss: 0.5622 - learning_rate: 8.0000e-06
# Epoch 86/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 833us/step - accuracy: 0.7508 - loss: 0.5398 - val_accuracy: 0.7213 - val_loss: 0.5624 - learning_rate: 8.0000e-06
# Epoch 87/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 852us/step - accuracy: 0.7463 - loss: 0.5440 - val_accuracy: 0.7236 - val_loss: 0.5624 - learning_rate: 8.0000e-06
# Epoch 88/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 836us/step - accuracy: 0.7444 - loss: 0.5420 - val_accuracy: 0.7236 - val_loss: 0.5624 - learning_rate: 8.0000e-06
# Epoch 89/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step - accuracy: 0.7420 - loss: 0.5469 - val_accuracy: 0.7236 - val_loss: 0.5624 - learning_rate: 8.0000e-06
# Epoch 90/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 931us/step - accuracy: 0.7481 - loss: 0.5426 - val_accuracy: 0.7236 - val_loss: 0.5624 - learning_rate: 8.0000e-06
# Epoch 91/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 866us/step - accuracy: 0.7355 - loss: 0.5446 - val_accuracy: 0.7236 - val_loss: 0.5620 - learning_rate: 8.0000e-06
# Epoch 92/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step - accuracy: 0.7447 - loss: 0.5440 - val_accuracy: 0.7236 - val_loss: 0.5620 - learning_rate: 8.0000e-06
# Epoch 93/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step - accuracy: 0.7486 - loss: 0.5425 - val_accuracy: 0.7236 - val_loss: 0.5620 - learning_rate: 8.0000e-06
# Epoch 94/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 842us/step - accuracy: 0.7504 - loss: 0.5446 - val_accuracy: 0.7236 - val_loss: 0.5620 - learning_rate: 8.0000e-06
# Epoch 95/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - accuracy: 0.7431 - loss: 0.5385 - val_accuracy: 0.7236 - val_loss: 0.5621 - learning_rate: 8.0000e-06
# Epoch 96/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 842us/step - accuracy: 0.7399 - loss: 0.5414 - val_accuracy: 0.7236 - val_loss: 0.5624 - learning_rate: 8.0000e-06
# Epoch 97/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - accuracy: 0.7440 - loss: 0.5403 - val_accuracy: 0.7236 - val_loss: 0.5618 - learning_rate: 8.0000e-06
# Epoch 98/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - accuracy: 0.7446 - loss: 0.5424 - val_accuracy: 0.7236 - val_loss: 0.5618 - learning_rate: 8.0000e-06
# Epoch 99/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 843us/step - accuracy: 0.7559 - loss: 0.5414 - val_accuracy: 0.7236 - val_loss: 0.5616 - learning_rate: 8.0000e-06
# Epoch 100/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 842us/step - accuracy: 0.7383 - loss: 0.5425 - val_accuracy: 0.7236 - val_loss: 0.5612 - learning_rate: 8.0000e-06
# Epoch 101/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 842us/step - accuracy: 0.7401 - loss: 0.5363 - val_accuracy: 0.7236 - val_loss: 0.5611 - learning_rate: 8.0000e-06
# Epoch 102/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 842us/step - accuracy: 0.7452 - loss: 0.5424 - val_accuracy: 0.7236 - val_loss: 0.5615 - learning_rate: 8.0000e-06
# Epoch 103/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 855us/step - accuracy: 0.7484 - loss: 0.5425 - val_accuracy: 0.7236 - val_loss: 0.5617 - learning_rate: 8.0000e-06
# Epoch 104/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 942us/step - accuracy: 0.7375 - loss: 0.5410 - val_accuracy: 0.7236 - val_loss: 0.5616 - learning_rate: 8.0000e-06
# Epoch 105/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step - accuracy: 0.7408 - loss: 0.5414 - val_accuracy: 0.7236 - val_loss: 0.5615 - learning_rate: 8.0000e-06
# Epoch 106/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step - accuracy: 0.7545 - loss: 0.5377 - val_accuracy: 0.7236 - val_loss: 0.5617 - learning_rate: 8.0000e-06
# Epoch 107/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step - accuracy: 0.7454 - loss: 0.5397 - val_accuracy: 0.7258 - val_loss: 0.5613 - learning_rate: 8.0000e-06
# Epoch 108/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step - accuracy: 0.7516 - loss: 0.5393 - val_accuracy: 0.7258 - val_loss: 0.5613 - learning_rate: 8.0000e-06
# Epoch 109/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 907us/step - accuracy: 0.7530 - loss: 0.5411 - val_accuracy: 0.7258 - val_loss: 0.5614 - learning_rate: 8.0000e-06
# Epoch 110/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 951us/step - accuracy: 0.7445 - loss: 0.5412 - val_accuracy: 0.7281 - val_loss: 0.5611 - learning_rate: 8.0000e-06
# Epoch 111/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step - accuracy: 0.7387 - loss: 0.5374 - val_accuracy: 0.7281 - val_loss: 0.5611 - learning_rate: 8.0000e-06
# Epoch 112/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step - accuracy: 0.7500 - loss: 0.5370 - val_accuracy: 0.7281 - val_loss: 0.5609 - learning_rate: 8.0000e-06
# Epoch 113/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - accuracy: 0.7477 - loss: 0.5368 - val_accuracy: 0.7281 - val_loss: 0.5607 - learning_rate: 8.0000e-06
# Epoch 114/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 857us/step - accuracy: 0.7417 - loss: 0.5437 - val_accuracy: 0.7281 - val_loss: 0.5610 - learning_rate: 8.0000e-06
# Epoch 115/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step - accuracy: 0.7511 - loss: 0.5366 - val_accuracy: 0.7281 - val_loss: 0.5611 - learning_rate: 8.0000e-06
# Epoch 116/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 842us/step - accuracy: 0.7441 - loss: 0.5393 - val_accuracy: 0.7281 - val_loss: 0.5612 - learning_rate: 8.0000e-06
# Epoch 117/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step - accuracy: 0.7469 - loss: 0.5437 - val_accuracy: 0.7281 - val_loss: 0.5611 - learning_rate: 8.0000e-06
# Epoch 118/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 842us/step - accuracy: 0.7460 - loss: 0.5398 - val_accuracy: 0.7281 - val_loss: 0.5610 - learning_rate: 8.0000e-06
# Epoch 119/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - accuracy: 0.7427 - loss: 0.5414 - val_accuracy: 0.7281 - val_loss: 0.5607 - learning_rate: 8.0000e-06
# Epoch 120/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 842us/step - accuracy: 0.7431 - loss: 0.5383 - val_accuracy: 0.7281 - val_loss: 0.5604 - learning_rate: 8.0000e-06
# Epoch 121/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 838us/step - accuracy: 0.7508 - loss: 0.5376 - val_accuracy: 0.7281 - val_loss: 0.5611 - learning_rate: 8.0000e-06
# Epoch 122/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step - accuracy: 0.7527 - loss: 0.5380 - val_accuracy: 0.7281 - val_loss: 0.5612 - learning_rate: 8.0000e-06
# Epoch 123/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 942us/step - accuracy: 0.7467 - loss: 0.5367 - val_accuracy: 0.7281 - val_loss: 0.5610 - learning_rate: 8.0000e-06
# Epoch 124/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step - accuracy: 0.7504 - loss: 0.5361 - val_accuracy: 0.7281 - val_loss: 0.5608 - learning_rate: 8.0000e-06
# Epoch 125/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 843us/step - accuracy: 0.7525 - loss: 0.5374 - val_accuracy: 0.7281 - val_loss: 0.5605 - learning_rate: 8.0000e-06
# Epoch 126/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 842us/step - accuracy: 0.7455 - loss: 0.5345 - val_accuracy: 0.7281 - val_loss: 0.5606 - learning_rate: 8.0000e-06
# Epoch 127/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step - accuracy: 0.7636 - loss: 0.5330 - val_accuracy: 0.7281 - val_loss: 0.5602 - learning_rate: 8.0000e-06
# Epoch 128/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 866us/step - accuracy: 0.7410 - loss: 0.5353 - val_accuracy: 0.7303 - val_loss: 0.5601 - learning_rate: 8.0000e-06
# Epoch 129/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step - accuracy: 0.7462 - loss: 0.5354 - val_accuracy: 0.7303 - val_loss: 0.5604 - learning_rate: 8.0000e-06
# Epoch 130/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 966us/step - accuracy: 0.7528 - loss: 0.5357 - val_accuracy: 0.7303 - val_loss: 0.5603 - learning_rate: 8.0000e-06
# Epoch 131/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step - accuracy: 0.7419 - loss: 0.5364 - val_accuracy: 0.7303 - val_loss: 0.5602 - learning_rate: 8.0000e-06
# Epoch 132/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step - accuracy: 0.7464 - loss: 0.5398 - val_accuracy: 0.7303 - val_loss: 0.5602 - learning_rate: 8.0000e-06
# Epoch 133/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step - accuracy: 0.7486 - loss: 0.5348 - val_accuracy: 0.7303 - val_loss: 0.5597 - learning_rate: 8.0000e-06
# Epoch 134/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step - accuracy: 0.7502 - loss: 0.5292 - val_accuracy: 0.7303 - val_loss: 0.5595 - learning_rate: 8.0000e-06
# Epoch 135/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 824us/step - accuracy: 0.7486 - loss: 0.5368 - val_accuracy: 0.7303 - val_loss: 0.5596 - learning_rate: 8.0000e-06
# Epoch 136/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 933us/step - accuracy: 0.7525 - loss: 0.5333 - val_accuracy: 0.7303 - val_loss: 0.5597 - learning_rate: 8.0000e-06
# Epoch 137/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 842us/step - accuracy: 0.7461 - loss: 0.5404 - val_accuracy: 0.7303 - val_loss: 0.5599 - learning_rate: 8.0000e-06
# Epoch 138/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 852us/step - accuracy: 0.7491 - loss: 0.5326 - val_accuracy: 0.7303 - val_loss: 0.5597 - learning_rate: 8.0000e-06
# Epoch 139/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - accuracy: 0.7466 - loss: 0.5333 - val_accuracy: 0.7303 - val_loss: 0.5601 - learning_rate: 8.0000e-06
# Epoch 140/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - accuracy: 0.7386 - loss: 0.5355 - val_accuracy: 0.7303 - val_loss: 0.5597 - learning_rate: 8.0000e-06
# Epoch 141/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 842us/step - accuracy: 0.7488 - loss: 0.5376 - val_accuracy: 0.7326 - val_loss: 0.5593 - learning_rate: 8.0000e-06
# Epoch 142/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 930us/step - accuracy: 0.7553 - loss: 0.5351 - val_accuracy: 0.7303 - val_loss: 0.5599 - learning_rate: 8.0000e-06
# Epoch 143/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 833us/step - accuracy: 0.7490 - loss: 0.5374 - val_accuracy: 0.7303 - val_loss: 0.5596 - learning_rate: 8.0000e-06
# Epoch 144/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step - accuracy: 0.7479 - loss: 0.5350 - val_accuracy: 0.7326 - val_loss: 0.5592 - learning_rate: 8.0000e-06
# Epoch 145/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - accuracy: 0.7449 - loss: 0.5346 - val_accuracy: 0.7326 - val_loss: 0.5590 - learning_rate: 8.0000e-06
# Epoch 146/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 862us/step - accuracy: 0.7473 - loss: 0.5296 - val_accuracy: 0.7326 - val_loss: 0.5585 - learning_rate: 8.0000e-06
# Epoch 147/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - accuracy: 0.7516 - loss: 0.5369 - val_accuracy: 0.7326 - val_loss: 0.5581 - learning_rate: 8.0000e-06
# Epoch 148/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 942us/step - accuracy: 0.7493 - loss: 0.5396 - val_accuracy: 0.7326 - val_loss: 0.5582 - learning_rate: 8.0000e-06
# Epoch 149/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - accuracy: 0.7566 - loss: 0.5298 - val_accuracy: 0.7326 - val_loss: 0.5582 - learning_rate: 8.0000e-06
# Epoch 150/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - accuracy: 0.7521 - loss: 0.5391 - val_accuracy: 0.7326 - val_loss: 0.5582 - learning_rate: 8.0000e-06
# Epoch 151/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 864us/step - accuracy: 0.7484 - loss: 0.5367 - val_accuracy: 0.7303 - val_loss: 0.5588 - learning_rate: 8.0000e-06
# Epoch 152/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step - accuracy: 0.7536 - loss: 0.5297 - val_accuracy: 0.7303 - val_loss: 0.5590 - learning_rate: 8.0000e-06
# Epoch 153/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step - accuracy: 0.7505 - loss: 0.5351 - val_accuracy: 0.7303 - val_loss: 0.5585 - learning_rate: 8.0000e-06
# Epoch 154/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 933us/step - accuracy: 0.7576 - loss: 0.5335 - val_accuracy: 0.7303 - val_loss: 0.5585 - learning_rate: 8.0000e-06
# Epoch 155/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step - accuracy: 0.7548 - loss: 0.5297 - val_accuracy: 0.7281 - val_loss: 0.5587 - learning_rate: 8.0000e-06
# Epoch 156/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - accuracy: 0.7472 - loss: 0.5356 - val_accuracy: 0.7281 - val_loss: 0.5588 - learning_rate: 8.0000e-06
# Epoch 157/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 878us/step - accuracy: 0.7517 - loss: 0.5340 - val_accuracy: 0.7281 - val_loss: 0.5589 - learning_rate: 8.0000e-06
# Epoch 158/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step - accuracy: 0.7622 - loss: 0.5340 - val_accuracy: 0.7281 - val_loss: 0.5585 - learning_rate: 8.0000e-06
# Epoch 159/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 933us/step - accuracy: 0.7537 - loss: 0.5356 - val_accuracy: 0.7281 - val_loss: 0.5586 - learning_rate: 8.0000e-06
# Epoch 160/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 857us/step - accuracy: 0.7601 - loss: 0.5330 - val_accuracy: 0.7281 - val_loss: 0.5587 - learning_rate: 8.0000e-06
# Epoch 161/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 888us/step - accuracy: 0.7499 - loss: 0.5369 - val_accuracy: 0.7281 - val_loss: 0.5587 - learning_rate: 8.0000e-06
# Epoch 162/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - accuracy: 0.7482 - loss: 0.5373 - val_accuracy: 0.7281 - val_loss: 0.5585 - learning_rate: 8.0000e-06
# Epoch 163/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 852us/step - accuracy: 0.7511 - loss: 0.5306 - val_accuracy: 0.7281 - val_loss: 0.5587 - learning_rate: 8.0000e-06
# Epoch 164/1100
#  53/112 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step - accuracy: 0.7525 - loss: 0.5285
# Epoch 164: ReduceLROnPlateau reducing learning rate to 6.34960419184159e-06.
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7509 - loss: 0.5345 - val_accuracy: 0.7281 - val_loss: 0.5586 - learning_rate: 8.0000e-06
# Epoch 165/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step - accuracy: 0.7569 - loss: 0.5315 - val_accuracy: 0.7281 - val_loss: 0.5582 - learning_rate: 6.3496e-06
# Epoch 166/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - accuracy: 0.7529 - loss: 0.5306 - val_accuracy: 0.7281 - val_loss: 0.5579 - learning_rate: 6.3496e-06
# Epoch 167/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step - accuracy: 0.7575 - loss: 0.5346 - val_accuracy: 0.7281 - val_loss: 0.5579 - learning_rate: 6.3496e-06
# Epoch 168/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 888us/step - accuracy: 0.7514 - loss: 0.5324 - val_accuracy: 0.7281 - val_loss: 0.5579 - learning_rate: 6.3496e-06
# Epoch 169/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 996us/step - accuracy: 0.7522 - loss: 0.5327 - val_accuracy: 0.7281 - val_loss: 0.5581 - learning_rate: 6.3496e-06
# Epoch 170/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - accuracy: 0.7586 - loss: 0.5313 - val_accuracy: 0.7303 - val_loss: 0.5580 - learning_rate: 6.3496e-06
# Epoch 171/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step - accuracy: 0.7452 - loss: 0.5358 - val_accuracy: 0.7303 - val_loss: 0.5580 - learning_rate: 6.3496e-06
# Epoch 172/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 842us/step - accuracy: 0.7486 - loss: 0.5330 - val_accuracy: 0.7326 - val_loss: 0.5575 - learning_rate: 6.3496e-06
# Epoch 173/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - accuracy: 0.7497 - loss: 0.5353 - val_accuracy: 0.7326 - val_loss: 0.5573 - learning_rate: 6.3496e-06
# Epoch 174/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.7544 - loss: 0.5309 - val_accuracy: 0.7326 - val_loss: 0.5571 - learning_rate: 6.3496e-06
# Epoch 175/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 867us/step - accuracy: 0.7473 - loss: 0.5373 - val_accuracy: 0.7326 - val_loss: 0.5574 - learning_rate: 6.3496e-06
# Epoch 176/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 842us/step - accuracy: 0.7549 - loss: 0.5324 - val_accuracy: 0.7326 - val_loss: 0.5575 - learning_rate: 6.3496e-06
# Epoch 177/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - accuracy: 0.7526 - loss: 0.5335 - val_accuracy: 0.7326 - val_loss: 0.5575 - learning_rate: 6.3496e-06
# Epoch 178/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - accuracy: 0.7417 - loss: 0.5337 - val_accuracy: 0.7303 - val_loss: 0.5570 - learning_rate: 6.3496e-06
# Epoch 179/1100
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 923us/step - accuracy: 0.7515 - loss: 0.5262
# Epoch 179: ReduceLROnPlateau reducing learning rate to 5.039684085285258e-06.
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7515 - loss: 0.5263 - val_accuracy: 0.7303 - val_loss: 0.5571 - learning_rate: 6.3496e-06
# Epoch 180/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 856us/step - accuracy: 0.7627 - loss: 0.5298 - val_accuracy: 0.7326 - val_loss: 0.5574 - learning_rate: 5.0397e-06
# Epoch 181/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 833us/step - accuracy: 0.7598 - loss: 0.5334 - val_accuracy: 0.7326 - val_loss: 0.5574 - learning_rate: 5.0397e-06
# Epoch 182/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step - accuracy: 0.7479 - loss: 0.5338 - val_accuracy: 0.7326 - val_loss: 0.5576 - learning_rate: 5.0397e-06
# Epoch 183/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 830us/step - accuracy: 0.7575 - loss: 0.5323 - val_accuracy: 0.7303 - val_loss: 0.5572 - learning_rate: 5.0397e-06
# Epoch 184/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 924us/step - accuracy: 0.7589 - loss: 0.5238 - val_accuracy: 0.7303 - val_loss: 0.5568 - learning_rate: 5.0397e-06
# Epoch 185/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 839us/step - accuracy: 0.7607 - loss: 0.5358 - val_accuracy: 0.7326 - val_loss: 0.5565 - learning_rate: 5.0397e-06
# Epoch 186/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step - accuracy: 0.7523 - loss: 0.5310 - val_accuracy: 0.7303 - val_loss: 0.5566 - learning_rate: 5.0397e-06
# Epoch 187/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 852us/step - accuracy: 0.7535 - loss: 0.5296 - val_accuracy: 0.7326 - val_loss: 0.5565 - learning_rate: 5.0397e-06
# Epoch 188/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step - accuracy: 0.7545 - loss: 0.5272 - val_accuracy: 0.7326 - val_loss: 0.5564 - learning_rate: 5.0397e-06
# Epoch 189/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 960us/step - accuracy: 0.7591 - loss: 0.5312 - val_accuracy: 0.7303 - val_loss: 0.5565 - learning_rate: 5.0397e-06
# Epoch 190/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 843us/step - accuracy: 0.7561 - loss: 0.5289 - val_accuracy: 0.7303 - val_loss: 0.5568 - learning_rate: 5.0397e-06
# Epoch 191/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 843us/step - accuracy: 0.7535 - loss: 0.5337 - val_accuracy: 0.7303 - val_loss: 0.5568 - learning_rate: 5.0397e-06
# Epoch 192/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - accuracy: 0.7507 - loss: 0.5334 - val_accuracy: 0.7303 - val_loss: 0.5569 - learning_rate: 5.0397e-06
# Epoch 193/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 919us/step - accuracy: 0.7507 - loss: 0.5315 - val_accuracy: 0.7303 - val_loss: 0.5567 - learning_rate: 5.0397e-06
# Epoch 194/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step - accuracy: 0.7536 - loss: 0.5281 - val_accuracy: 0.7303 - val_loss: 0.5567 - learning_rate: 5.0397e-06
# Epoch 195/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 852us/step - accuracy: 0.7517 - loss: 0.5311 - val_accuracy: 0.7326 - val_loss: 0.5566 - learning_rate: 5.0397e-06
# Epoch 196/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 857us/step - accuracy: 0.7552 - loss: 0.5312 - val_accuracy: 0.7303 - val_loss: 0.5569 - learning_rate: 5.0397e-06
# Epoch 197/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 852us/step - accuracy: 0.7543 - loss: 0.5329 - val_accuracy: 0.7326 - val_loss: 0.5565 - learning_rate: 5.0397e-06
# Epoch 198/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 973us/step - accuracy: 0.7595 - loss: 0.5326 - val_accuracy: 0.7326 - val_loss: 0.5565 - learning_rate: 5.0397e-06
# Epoch 199/1100
#  84/112 ━━━━━━━━━━━━━━━━━━━━ 0s 609us/step - accuracy: 0.7591 - loss: 0.5261
# Epoch 199: ReduceLROnPlateau reducing learning rate to 4.000000088243381e-06.
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 842us/step - accuracy: 0.7580 - loss: 0.5292 - val_accuracy: 0.7326 - val_loss: 0.5563 - learning_rate: 5.0397e-06
# Epoch 200/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - accuracy: 0.7534 - loss: 0.5299 - val_accuracy: 0.7326 - val_loss: 0.5565 - learning_rate: 4.0000e-06
# Epoch 201/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 994us/step - accuracy: 0.7604 - loss: 0.5327 - val_accuracy: 0.7326 - val_loss: 0.5565 - learning_rate: 4.0000e-06
# Epoch 202/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 937us/step - accuracy: 0.7507 - loss: 0.5287 - val_accuracy: 0.7326 - val_loss: 0.5566 - learning_rate: 4.0000e-06
# Epoch 203/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - accuracy: 0.7536 - loss: 0.5307 - val_accuracy: 0.7326 - val_loss: 0.5564 - learning_rate: 4.0000e-06
# Epoch 204/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step - accuracy: 0.7543 - loss: 0.5288 - val_accuracy: 0.7326 - val_loss: 0.5562 - learning_rate: 4.0000e-06
# Epoch 205/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 849us/step - accuracy: 0.7580 - loss: 0.5303 - val_accuracy: 0.7326 - val_loss: 0.5561 - learning_rate: 4.0000e-06
# Epoch 206/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step - accuracy: 0.7581 - loss: 0.5265 - val_accuracy: 0.7326 - val_loss: 0.5563 - learning_rate: 4.0000e-06
# Epoch 207/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 854us/step - accuracy: 0.7561 - loss: 0.5292 - val_accuracy: 0.7326 - val_loss: 0.5566 - learning_rate: 4.0000e-06
# Epoch 208/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 824us/step - accuracy: 0.7526 - loss: 0.5298 - val_accuracy: 0.7326 - val_loss: 0.5564 - learning_rate: 4.0000e-06
# Epoch 209/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step - accuracy: 0.7586 - loss: 0.5265 - val_accuracy: 0.7326 - val_loss: 0.5563 - learning_rate: 4.0000e-06
# Epoch 210/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 856us/step - accuracy: 0.7579 - loss: 0.5342 - val_accuracy: 0.7326 - val_loss: 0.5562 - learning_rate: 4.0000e-06
# Epoch 211/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 924us/step - accuracy: 0.7649 - loss: 0.5261 - val_accuracy: 0.7326 - val_loss: 0.5559 - learning_rate: 4.0000e-06
# Epoch 212/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 847us/step - accuracy: 0.7483 - loss: 0.5281 - val_accuracy: 0.7326 - val_loss: 0.5559 - learning_rate: 4.0000e-06
# Epoch 213/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 834us/step - accuracy: 0.7653 - loss: 0.5279 - val_accuracy: 0.7326 - val_loss: 0.5557 - learning_rate: 4.0000e-06
# Epoch 214/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step - accuracy: 0.7566 - loss: 0.5309 - val_accuracy: 0.7326 - val_loss: 0.5557 - learning_rate: 4.0000e-06
# Epoch 215/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step - accuracy: 0.7588 - loss: 0.5294 - val_accuracy: 0.7326 - val_loss: 0.5560 - learning_rate: 4.0000e-06
# Epoch 216/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 875us/step - accuracy: 0.7595 - loss: 0.5272 - val_accuracy: 0.7326 - val_loss: 0.5558 - learning_rate: 4.0000e-06
# Epoch 217/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 852us/step - accuracy: 0.7598 - loss: 0.5303 - val_accuracy: 0.7326 - val_loss: 0.5559 - learning_rate: 4.0000e-06
# Epoch 218/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 852us/step - accuracy: 0.7530 - loss: 0.5298 - val_accuracy: 0.7326 - val_loss: 0.5559 - learning_rate: 4.0000e-06
# Epoch 219/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 890us/step - accuracy: 0.7555 - loss: 0.5312 - val_accuracy: 0.7326 - val_loss: 0.5561 - learning_rate: 4.0000e-06
# Epoch 220/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 942us/step - accuracy: 0.7563 - loss: 0.5278 - val_accuracy: 0.7326 - val_loss: 0.5561 - learning_rate: 4.0000e-06
# Epoch 221/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step - accuracy: 0.7536 - loss: 0.5296 - val_accuracy: 0.7326 - val_loss: 0.5561 - learning_rate: 4.0000e-06
# Epoch 222/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 888us/step - accuracy: 0.7592 - loss: 0.5304 - val_accuracy: 0.7326 - val_loss: 0.5561 - learning_rate: 4.0000e-06
# Epoch 223/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - accuracy: 0.7574 - loss: 0.5242 - val_accuracy: 0.7326 - val_loss: 0.5557 - learning_rate: 4.0000e-06
# Epoch 224/1100
#  77/112 ━━━━━━━━━━━━━━━━━━━━ 0s 665us/step - accuracy: 0.7558 - loss: 0.5191
# Epoch 224: ReduceLROnPlateau reducing learning rate to 3.174802095920795e-06.
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 888us/step - accuracy: 0.7529 - loss: 0.5253 - val_accuracy: 0.7326 - val_loss: 0.5558 - learning_rate: 4.0000e-06
# Epoch 225/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - accuracy: 0.7546 - loss: 0.5273 - val_accuracy: 0.7326 - val_loss: 0.5555 - learning_rate: 3.1748e-06
# Epoch 226/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 847us/step - accuracy: 0.7592 - loss: 0.5273 - val_accuracy: 0.7326 - val_loss: 0.5555 - learning_rate: 3.1748e-06
# Epoch 227/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 824us/step - accuracy: 0.7591 - loss: 0.5262 - val_accuracy: 0.7326 - val_loss: 0.5558 - learning_rate: 3.1748e-06
# Epoch 228/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 833us/step - accuracy: 0.7607 - loss: 0.5272 - val_accuracy: 0.7326 - val_loss: 0.5558 - learning_rate: 3.1748e-06
# Epoch 229/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 833us/step - accuracy: 0.7535 - loss: 0.5261 - val_accuracy: 0.7326 - val_loss: 0.5559 - learning_rate: 3.1748e-06
# Epoch 230/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 942us/step - accuracy: 0.7568 - loss: 0.5286 - val_accuracy: 0.7326 - val_loss: 0.5558 - learning_rate: 3.1748e-06
# Epoch 231/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step - accuracy: 0.7555 - loss: 0.5294 - val_accuracy: 0.7326 - val_loss: 0.5557 - learning_rate: 3.1748e-06
# Epoch 232/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - accuracy: 0.7647 - loss: 0.5250 - val_accuracy: 0.7326 - val_loss: 0.5556 - learning_rate: 3.1748e-06
# Epoch 233/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step - accuracy: 0.7584 - loss: 0.5248 - val_accuracy: 0.7326 - val_loss: 0.5557 - learning_rate: 3.1748e-06
# Epoch 234/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step - accuracy: 0.7602 - loss: 0.5322 - val_accuracy: 0.7326 - val_loss: 0.5556 - learning_rate: 3.1748e-06
# Epoch 235/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - accuracy: 0.7577 - loss: 0.5253 - val_accuracy: 0.7326 - val_loss: 0.5555 - learning_rate: 3.1748e-06
# Epoch 236/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 852us/step - accuracy: 0.7504 - loss: 0.5294 - val_accuracy: 0.7326 - val_loss: 0.5558 - learning_rate: 3.1748e-06
# Epoch 237/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - accuracy: 0.7535 - loss: 0.5297 - val_accuracy: 0.7326 - val_loss: 0.5556 - learning_rate: 3.1748e-06
# Epoch 238/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 872us/step - accuracy: 0.7474 - loss: 0.5264 - val_accuracy: 0.7326 - val_loss: 0.5556 - learning_rate: 3.1748e-06
# Epoch 239/1100
#  79/112 ━━━━━━━━━━━━━━━━━━━━ 0s 642us/step - accuracy: 0.7640 - loss: 0.5256
# Epoch 239: ReduceLROnPlateau reducing learning rate to 2.519842042642629e-06.
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 965us/step - accuracy: 0.7604 - loss: 0.5302 - val_accuracy: 0.7326 - val_loss: 0.5556 - learning_rate: 3.1748e-06
# Epoch 240/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - accuracy: 0.7611 - loss: 0.5305 - val_accuracy: 0.7326 - val_loss: 0.5556 - learning_rate: 2.5198e-06
# Epoch 241/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step - accuracy: 0.7629 - loss: 0.5293 - val_accuracy: 0.7326 - val_loss: 0.5553 - learning_rate: 2.5198e-06
# Epoch 242/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step - accuracy: 0.7561 - loss: 0.5309 - val_accuracy: 0.7326 - val_loss: 0.5554 - learning_rate: 2.5198e-06
# Epoch 243/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step - accuracy: 0.7680 - loss: 0.5288 - val_accuracy: 0.7326 - val_loss: 0.5555 - learning_rate: 2.5198e-06
# Epoch 244/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step - accuracy: 0.7591 - loss: 0.5299 - val_accuracy: 0.7326 - val_loss: 0.5555 - learning_rate: 2.5198e-06
# Epoch 245/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 855us/step - accuracy: 0.7504 - loss: 0.5319 - val_accuracy: 0.7326 - val_loss: 0.5555 - learning_rate: 2.5198e-06
# Epoch 246/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 833us/step - accuracy: 0.7598 - loss: 0.5277 - val_accuracy: 0.7326 - val_loss: 0.5554 - learning_rate: 2.5198e-06
# Epoch 247/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 847us/step - accuracy: 0.7579 - loss: 0.5276 - val_accuracy: 0.7326 - val_loss: 0.5555 - learning_rate: 2.5198e-06
# Epoch 248/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step - accuracy: 0.7614 - loss: 0.5259 - val_accuracy: 0.7326 - val_loss: 0.5555 - learning_rate: 2.5198e-06
# Epoch 249/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 833us/step - accuracy: 0.7633 - loss: 0.5293 - val_accuracy: 0.7326 - val_loss: 0.5554 - learning_rate: 2.5198e-06
# Epoch 250/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 843us/step - accuracy: 0.7610 - loss: 0.5266 - val_accuracy: 0.7348 - val_loss: 0.5553 - learning_rate: 2.5198e-06
# Epoch 251/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - accuracy: 0.7600 - loss: 0.5266 - val_accuracy: 0.7348 - val_loss: 0.5552 - learning_rate: 2.5198e-06
# Epoch 252/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step - accuracy: 0.7639 - loss: 0.5298 - val_accuracy: 0.7348 - val_loss: 0.5551 - learning_rate: 2.5198e-06
# Epoch 253/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 951us/step - accuracy: 0.7610 - loss: 0.5348 - val_accuracy: 0.7348 - val_loss: 0.5551 - learning_rate: 2.5198e-06
# Epoch 254/1100
#  81/112 ━━━━━━━━━━━━━━━━━━━━ 0s 625us/step - accuracy: 0.7533 - loss: 0.5263
# Epoch 254: ReduceLROnPlateau reducing learning rate to 2.0000000441216903e-06.
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step - accuracy: 0.7524 - loss: 0.5307 - val_accuracy: 0.7348 - val_loss: 0.5551 - learning_rate: 2.5198e-06
# Epoch 255/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 833us/step - accuracy: 0.7635 - loss: 0.5292 - val_accuracy: 0.7348 - val_loss: 0.5550 - learning_rate: 2.0000e-06
# Epoch 256/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step - accuracy: 0.7587 - loss: 0.5313 - val_accuracy: 0.7348 - val_loss: 0.5551 - learning_rate: 2.0000e-06
# Epoch 257/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 933us/step - accuracy: 0.7569 - loss: 0.5270 - val_accuracy: 0.7348 - val_loss: 0.5551 - learning_rate: 2.0000e-06
# Epoch 258/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step - accuracy: 0.7616 - loss: 0.5251 - val_accuracy: 0.7348 - val_loss: 0.5551 - learning_rate: 2.0000e-06
# Epoch 259/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 852us/step - accuracy: 0.7562 - loss: 0.5252 - val_accuracy: 0.7348 - val_loss: 0.5551 - learning_rate: 2.0000e-06
# Epoch 260/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 852us/step - accuracy: 0.7552 - loss: 0.5317 - val_accuracy: 0.7348 - val_loss: 0.5550 - learning_rate: 2.0000e-06
# Epoch 261/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7569 - loss: 0.5278 - val_accuracy: 0.7348 - val_loss: 0.5550 - learning_rate: 2.0000e-06
# Epoch 262/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step - accuracy: 0.7583 - loss: 0.5301 - val_accuracy: 0.7348 - val_loss: 0.5551 - learning_rate: 2.0000e-06
# Epoch 263/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 838us/step - accuracy: 0.7534 - loss: 0.5262 - val_accuracy: 0.7348 - val_loss: 0.5552 - learning_rate: 2.0000e-06
# Epoch 264/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 833us/step - accuracy: 0.7528 - loss: 0.5270 - val_accuracy: 0.7348 - val_loss: 0.5550 - learning_rate: 2.0000e-06
# Epoch 265/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 852us/step - accuracy: 0.7598 - loss: 0.5282 - val_accuracy: 0.7348 - val_loss: 0.5549 - learning_rate: 2.0000e-06
# Epoch 266/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 852us/step - accuracy: 0.7617 - loss: 0.5303 - val_accuracy: 0.7348 - val_loss: 0.5549 - learning_rate: 2.0000e-06
# Epoch 267/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 825us/step - accuracy: 0.7537 - loss: 0.5263 - val_accuracy: 0.7348 - val_loss: 0.5549 - learning_rate: 2.0000e-06
# Epoch 268/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 833us/step - accuracy: 0.7608 - loss: 0.5249 - val_accuracy: 0.7348 - val_loss: 0.5548 - learning_rate: 2.0000e-06
# Epoch 269/1100
#  84/112 ━━━━━━━━━━━━━━━━━━━━ 0s 602us/step - accuracy: 0.7505 - loss: 0.5264
# Epoch 269: ReduceLROnPlateau reducing learning rate to 1.5874010479603974e-06.
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step - accuracy: 0.7505 - loss: 0.5301 - val_accuracy: 0.7348 - val_loss: 0.5548 - learning_rate: 2.0000e-06
# Epoch 270/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step - accuracy: 0.7650 - loss: 0.5216 - val_accuracy: 0.7348 - val_loss: 0.5547 - learning_rate: 1.5874e-06
# Epoch 271/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 852us/step - accuracy: 0.7597 - loss: 0.5275 - val_accuracy: 0.7348 - val_loss: 0.5547 - learning_rate: 1.5874e-06
# Epoch 272/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 824us/step - accuracy: 0.7531 - loss: 0.5274 - val_accuracy: 0.7348 - val_loss: 0.5548 - learning_rate: 1.5874e-06
# Epoch 273/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step - accuracy: 0.7549 - loss: 0.5273 - val_accuracy: 0.7348 - val_loss: 0.5548 - learning_rate: 1.5874e-06
# Epoch 274/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 949us/step - accuracy: 0.7601 - loss: 0.5278 - val_accuracy: 0.7348 - val_loss: 0.5546 - learning_rate: 1.5874e-06
# Epoch 275/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step - accuracy: 0.7537 - loss: 0.5257 - val_accuracy: 0.7348 - val_loss: 0.5546 - learning_rate: 1.5874e-06
# Epoch 276/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 875us/step - accuracy: 0.7608 - loss: 0.5282 - val_accuracy: 0.7348 - val_loss: 0.5547 - learning_rate: 1.5874e-06
# Epoch 277/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step - accuracy: 0.7603 - loss: 0.5240 - val_accuracy: 0.7348 - val_loss: 0.5547 - learning_rate: 1.5874e-06
# Epoch 278/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step - accuracy: 0.7565 - loss: 0.5257 - val_accuracy: 0.7348 - val_loss: 0.5548 - learning_rate: 1.5874e-06
# Epoch 279/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 852us/step - accuracy: 0.7516 - loss: 0.5229 - val_accuracy: 0.7348 - val_loss: 0.5548 - learning_rate: 1.5874e-06
# Epoch 280/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step - accuracy: 0.7715 - loss: 0.5232 - val_accuracy: 0.7348 - val_loss: 0.5547 - learning_rate: 1.5874e-06
# Epoch 281/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 842us/step - accuracy: 0.7487 - loss: 0.5324 - val_accuracy: 0.7371 - val_loss: 0.5547 - learning_rate: 1.5874e-06
# Epoch 282/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 924us/step - accuracy: 0.7554 - loss: 0.5237 - val_accuracy: 0.7371 - val_loss: 0.5546 - learning_rate: 1.5874e-06
# Epoch 283/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 833us/step - accuracy: 0.7521 - loss: 0.5250 - val_accuracy: 0.7371 - val_loss: 0.5545 - learning_rate: 1.5874e-06
# Epoch 284/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 852us/step - accuracy: 0.7564 - loss: 0.5299 - val_accuracy: 0.7371 - val_loss: 0.5545 - learning_rate: 1.5874e-06
# Epoch 285/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 833us/step - accuracy: 0.7600 - loss: 0.5278 - val_accuracy: 0.7371 - val_loss: 0.5544 - learning_rate: 1.5874e-06
# Epoch 286/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 888us/step - accuracy: 0.7573 - loss: 0.5275 - val_accuracy: 0.7371 - val_loss: 0.5545 - learning_rate: 1.5874e-06
# Epoch 287/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 842us/step - accuracy: 0.7645 - loss: 0.5287 - val_accuracy: 0.7371 - val_loss: 0.5546 - learning_rate: 1.5874e-06
# Epoch 288/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 824us/step - accuracy: 0.7534 - loss: 0.5286 - val_accuracy: 0.7371 - val_loss: 0.5546 - learning_rate: 1.5874e-06
# Epoch 289/1100
# ...
# Epoch 1004/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 766us/step - accuracy: 0.7574 - loss: 0.5265 - val_accuracy: 0.7393 - val_loss: 0.5526 - learning_rate: 5.0000e-07
# Epoch 1005/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step - accuracy: 0.7529 - loss: 0.5260 - val_accuracy: 0.7393 - val_loss: 0.5526 - learning_rate: 5.0000e-07
# Epoch 1006/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 855us/step - accuracy: 0.7566 - loss: 0.5229 - val_accuracy: 0.7393 - val_loss: 0.5526 - learning_rate: 5.0000e-07
# Epoch 1007/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step - accuracy: 0.7595 - loss: 0.5239 - val_accuracy: 0.7393 - val_loss: 0.5526 - learning_rate: 5.0000e-07
# Epoch 1008/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 787us/step - accuracy: 0.7587 - loss: 0.5227 - val_accuracy: 0.7393 - val_loss: 0.5526 - learning_rate: 5.0000e-07
# Epoch 1009/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 776us/step - accuracy: 0.7682 - loss: 0.5245 - val_accuracy: 0.7393 - val_loss: 0.5527 - learning_rate: 5.0000e-07
# Epoch 1010/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step - accuracy: 0.7586 - loss: 0.5231 - val_accuracy: 0.7393 - val_loss: 0.5526 - learning_rate: 5.0000e-07
# Epoch 1011/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 864us/step - accuracy: 0.7569 - loss: 0.5242 - val_accuracy: 0.7393 - val_loss: 0.5526 - learning_rate: 5.0000e-07
# Epoch 1012/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 766us/step - accuracy: 0.7544 - loss: 0.5243 - val_accuracy: 0.7393 - val_loss: 0.5526 - learning_rate: 5.0000e-07
# Epoch 1013/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 776us/step - accuracy: 0.7618 - loss: 0.5204 - val_accuracy: 0.7393 - val_loss: 0.5526 - learning_rate: 5.0000e-07
# Epoch 1014/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 766us/step - accuracy: 0.7514 - loss: 0.5238 - val_accuracy: 0.7393 - val_loss: 0.5525 - learning_rate: 5.0000e-07
# Epoch 1015/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 771us/step - accuracy: 0.7644 - loss: 0.5256 - val_accuracy: 0.7393 - val_loss: 0.5526 - learning_rate: 5.0000e-07
# Epoch 1016/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 802us/step - accuracy: 0.7666 - loss: 0.5235 - val_accuracy: 0.7393 - val_loss: 0.5526 - learning_rate: 5.0000e-07
# Epoch 1017/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 843us/step - accuracy: 0.7663 - loss: 0.5222 - val_accuracy: 0.7393 - val_loss: 0.5526 - learning_rate: 5.0000e-07
# Epoch 1018/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 785us/step - accuracy: 0.7609 - loss: 0.5218 - val_accuracy: 0.7393 - val_loss: 0.5526 - learning_rate: 5.0000e-07
# Epoch 1019/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 824us/step - accuracy: 0.7551 - loss: 0.5265 - val_accuracy: 0.7393 - val_loss: 0.5526 - learning_rate: 5.0000e-07
# Epoch 1020/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 951us/step - accuracy: 0.7625 - loss: 0.5259 - val_accuracy: 0.7393 - val_loss: 0.5525 - learning_rate: 5.0000e-07
# Epoch 1021/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 788us/step - accuracy: 0.7573 - loss: 0.5244 - val_accuracy: 0.7393 - val_loss: 0.5525 - learning_rate: 5.0000e-07
# Epoch 1022/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 788us/step - accuracy: 0.7603 - loss: 0.5268 - val_accuracy: 0.7393 - val_loss: 0.5526 - learning_rate: 5.0000e-07
# Epoch 1023/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 759us/step - accuracy: 0.7599 - loss: 0.5251 - val_accuracy: 0.7393 - val_loss: 0.5526 - learning_rate: 5.0000e-07
# Epoch 1024/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 846us/step - accuracy: 0.7606 - loss: 0.5229 - val_accuracy: 0.7393 - val_loss: 0.5526 - learning_rate: 5.0000e-07
# Epoch 1025/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 758us/step - accuracy: 0.7580 - loss: 0.5224 - val_accuracy: 0.7393 - val_loss: 0.5526 - learning_rate: 5.0000e-07
# Epoch 1026/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step - accuracy: 0.7584 - loss: 0.5282 - val_accuracy: 0.7393 - val_loss: 0.5526 - learning_rate: 5.0000e-07
# Epoch 1027/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 776us/step - accuracy: 0.7576 - loss: 0.5238 - val_accuracy: 0.7393 - val_loss: 0.5526 - learning_rate: 5.0000e-07
# Epoch 1028/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 758us/step - accuracy: 0.7590 - loss: 0.5274 - val_accuracy: 0.7393 - val_loss: 0.5526 - learning_rate: 5.0000e-07
# Epoch 1029/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 833us/step - accuracy: 0.7659 - loss: 0.5219 - val_accuracy: 0.7393 - val_loss: 0.5526 - learning_rate: 5.0000e-07
# Epoch 1030/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step - accuracy: 0.7602 - loss: 0.5255 - val_accuracy: 0.7393 - val_loss: 0.5525 - learning_rate: 5.0000e-07
# Epoch 1031/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step - accuracy: 0.7625 - loss: 0.5241 - val_accuracy: 0.7393 - val_loss: 0.5525 - learning_rate: 5.0000e-07
# Epoch 1032/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - accuracy: 0.7607 - loss: 0.5249 - val_accuracy: 0.7393 - val_loss: 0.5525 - learning_rate: 5.0000e-07
# Epoch 1033/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 767us/step - accuracy: 0.7585 - loss: 0.5244 - val_accuracy: 0.7393 - val_loss: 0.5525 - learning_rate: 5.0000e-07
# Epoch 1034/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 856us/step - accuracy: 0.7626 - loss: 0.5242 - val_accuracy: 0.7393 - val_loss: 0.5525 - learning_rate: 5.0000e-07
# Epoch 1035/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 757us/step - accuracy: 0.7570 - loss: 0.5262 - val_accuracy: 0.7393 - val_loss: 0.5525 - learning_rate: 5.0000e-07
# Epoch 1036/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 762us/step - accuracy: 0.7625 - loss: 0.5236 - val_accuracy: 0.7393 - val_loss: 0.5526 - learning_rate: 5.0000e-07
# Epoch 1037/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 820us/step - accuracy: 0.7628 - loss: 0.5250 - val_accuracy: 0.7393 - val_loss: 0.5526 - learning_rate: 5.0000e-07
# Epoch 1038/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7552 - loss: 0.5271 - val_accuracy: 0.7393 - val_loss: 0.5526 - learning_rate: 5.0000e-07
# Epoch 1039/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 840us/step - accuracy: 0.7642 - loss: 0.5239 - val_accuracy: 0.7393 - val_loss: 0.5526 - learning_rate: 5.0000e-07
# Epoch 1040/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 820us/step - accuracy: 0.7616 - loss: 0.5261 - val_accuracy: 0.7393 - val_loss: 0.5526 - learning_rate: 5.0000e-07
# Epoch 1041/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 803us/step - accuracy: 0.7578 - loss: 0.5267 - val_accuracy: 0.7393 - val_loss: 0.5525 - learning_rate: 5.0000e-07
# Epoch 1042/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 823us/step - accuracy: 0.7586 - loss: 0.5273 - val_accuracy: 0.7393 - val_loss: 0.5526 - learning_rate: 5.0000e-07
# Epoch 1043/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 839us/step - accuracy: 0.7531 - loss: 0.5245 - val_accuracy: 0.7393 - val_loss: 0.5525 - learning_rate: 5.0000e-07
# Epoch 1044/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 829us/step - accuracy: 0.7588 - loss: 0.5247 - val_accuracy: 0.7393 - val_loss: 0.5526 - learning_rate: 5.0000e-07
# Epoch 1045/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 838us/step - accuracy: 0.7559 - loss: 0.5247 - val_accuracy: 0.7393 - val_loss: 0.5526 - learning_rate: 5.0000e-07
# Epoch 1046/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 820us/step - accuracy: 0.7673 - loss: 0.5230 - val_accuracy: 0.7393 - val_loss: 0.5526 - learning_rate: 5.0000e-07
# Epoch 1047/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step - accuracy: 0.7638 - loss: 0.5234 - val_accuracy: 0.7393 - val_loss: 0.5525 - learning_rate: 5.0000e-07
# Epoch 1048/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 797us/step - accuracy: 0.7592 - loss: 0.5254 - val_accuracy: 0.7393 - val_loss: 0.5526 - learning_rate: 5.0000e-07
# Epoch 1049/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 776us/step - accuracy: 0.7615 - loss: 0.5257 - val_accuracy: 0.7393 - val_loss: 0.5525 - learning_rate: 5.0000e-07
# Epoch 1050/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 776us/step - accuracy: 0.7664 - loss: 0.5237 - val_accuracy: 0.7393 - val_loss: 0.5525 - learning_rate: 5.0000e-07
# Epoch 1051/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 767us/step - accuracy: 0.7536 - loss: 0.5262 - val_accuracy: 0.7393 - val_loss: 0.5525 - learning_rate: 5.0000e-07
# Epoch 1052/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step - accuracy: 0.7635 - loss: 0.5253 - val_accuracy: 0.7393 - val_loss: 0.5525 - learning_rate: 5.0000e-07
# Epoch 1053/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step - accuracy: 0.7548 - loss: 0.5219 - val_accuracy: 0.7393 - val_loss: 0.5525 - learning_rate: 5.0000e-07
# Epoch 1054/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 766us/step - accuracy: 0.7578 - loss: 0.5195 - val_accuracy: 0.7393 - val_loss: 0.5524 - learning_rate: 5.0000e-07
# Epoch 1055/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 788us/step - accuracy: 0.7545 - loss: 0.5263 - val_accuracy: 0.7393 - val_loss: 0.5524 - learning_rate: 5.0000e-07
# Epoch 1056/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 779us/step - accuracy: 0.7646 - loss: 0.5222 - val_accuracy: 0.7393 - val_loss: 0.5524 - learning_rate: 5.0000e-07
# Epoch 1057/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step - accuracy: 0.7619 - loss: 0.5251 - val_accuracy: 0.7393 - val_loss: 0.5525 - learning_rate: 5.0000e-07
# Epoch 1058/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 793us/step - accuracy: 0.7613 - loss: 0.5217 - val_accuracy: 0.7393 - val_loss: 0.5525 - learning_rate: 5.0000e-07
# Epoch 1059/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 793us/step - accuracy: 0.7607 - loss: 0.5186 - val_accuracy: 0.7393 - val_loss: 0.5525 - learning_rate: 5.0000e-07
# Epoch 1060/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 779us/step - accuracy: 0.7498 - loss: 0.5241 - val_accuracy: 0.7393 - val_loss: 0.5525 - learning_rate: 5.0000e-07
# Epoch 1061/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 833us/step - accuracy: 0.7619 - loss: 0.5313 - val_accuracy: 0.7393 - val_loss: 0.5525 - learning_rate: 5.0000e-07
# Epoch 1062/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step - accuracy: 0.7598 - loss: 0.5191 - val_accuracy: 0.7393 - val_loss: 0.5525 - learning_rate: 5.0000e-07
# Epoch 1063/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step - accuracy: 0.7582 - loss: 0.5235 - val_accuracy: 0.7393 - val_loss: 0.5525 - learning_rate: 5.0000e-07
# Epoch 1064/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 779us/step - accuracy: 0.7596 - loss: 0.5282 - val_accuracy: 0.7393 - val_loss: 0.5525 - learning_rate: 5.0000e-07
# Epoch 1065/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 768us/step - accuracy: 0.7558 - loss: 0.5223 - val_accuracy: 0.7393 - val_loss: 0.5525 - learning_rate: 5.0000e-07
# Epoch 1066/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step - accuracy: 0.7638 - loss: 0.5256 - val_accuracy: 0.7416 - val_loss: 0.5525 - learning_rate: 5.0000e-07
# Epoch 1067/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 767us/step - accuracy: 0.7605 - loss: 0.5205 - val_accuracy: 0.7416 - val_loss: 0.5525 - learning_rate: 5.0000e-07
# Epoch 1068/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step - accuracy: 0.7565 - loss: 0.5266 - val_accuracy: 0.7416 - val_loss: 0.5525 - learning_rate: 5.0000e-07
# Epoch 1069/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 788us/step - accuracy: 0.7624 - loss: 0.5265 - val_accuracy: 0.7393 - val_loss: 0.5525 - learning_rate: 5.0000e-07
# Epoch 1070/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 893us/step - accuracy: 0.7595 - loss: 0.5257 - val_accuracy: 0.7416 - val_loss: 0.5525 - learning_rate: 5.0000e-07
# Epoch 1071/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step - accuracy: 0.7588 - loss: 0.5248 - val_accuracy: 0.7416 - val_loss: 0.5525 - learning_rate: 5.0000e-07
# Epoch 1072/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 766us/step - accuracy: 0.7571 - loss: 0.5248 - val_accuracy: 0.7393 - val_loss: 0.5524 - learning_rate: 5.0000e-07
# Epoch 1073/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 794us/step - accuracy: 0.7593 - loss: 0.5251 - val_accuracy: 0.7393 - val_loss: 0.5524 - learning_rate: 5.0000e-07
# Epoch 1074/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 793us/step - accuracy: 0.7644 - loss: 0.5249 - val_accuracy: 0.7416 - val_loss: 0.5524 - learning_rate: 5.0000e-07
# Epoch 1075/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 917us/step - accuracy: 0.7580 - loss: 0.5251 - val_accuracy: 0.7393 - val_loss: 0.5524 - learning_rate: 5.0000e-07
# Epoch 1076/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 793us/step - accuracy: 0.7609 - loss: 0.5249 - val_accuracy: 0.7416 - val_loss: 0.5524 - learning_rate: 5.0000e-07
# Epoch 1077/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step - accuracy: 0.7661 - loss: 0.5246 - val_accuracy: 0.7416 - val_loss: 0.5524 - learning_rate: 5.0000e-07
# Epoch 1078/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step - accuracy: 0.7553 - loss: 0.5185 - val_accuracy: 0.7416 - val_loss: 0.5524 - learning_rate: 5.0000e-07
# Epoch 1079/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 804us/step - accuracy: 0.7644 - loss: 0.5253 - val_accuracy: 0.7416 - val_loss: 0.5524 - learning_rate: 5.0000e-07
# Epoch 1080/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 807us/step - accuracy: 0.7552 - loss: 0.5224 - val_accuracy: 0.7393 - val_loss: 0.5523 - learning_rate: 5.0000e-07
# Epoch 1081/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 788us/step - accuracy: 0.7587 - loss: 0.5233 - val_accuracy: 0.7393 - val_loss: 0.5523 - learning_rate: 5.0000e-07
# Epoch 1082/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 776us/step - accuracy: 0.7668 - loss: 0.5241 - val_accuracy: 0.7393 - val_loss: 0.5523 - learning_rate: 5.0000e-07
# Epoch 1083/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 784us/step - accuracy: 0.7622 - loss: 0.5226 - val_accuracy: 0.7393 - val_loss: 0.5523 - learning_rate: 5.0000e-07
# Epoch 1084/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step - accuracy: 0.7575 - loss: 0.5251 - val_accuracy: 0.7393 - val_loss: 0.5523 - learning_rate: 5.0000e-07
# Epoch 1085/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7575 - loss: 0.5275 - val_accuracy: 0.7416 - val_loss: 0.5523 - learning_rate: 5.0000e-07
# Epoch 1086/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7658 - loss: 0.5239 - val_accuracy: 0.7416 - val_loss: 0.5523 - learning_rate: 5.0000e-07
# Epoch 1087/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7585 - loss: 0.5196 - val_accuracy: 0.7416 - val_loss: 0.5523 - learning_rate: 5.0000e-07
# Epoch 1088/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7667 - loss: 0.5210 - val_accuracy: 0.7416 - val_loss: 0.5523 - learning_rate: 5.0000e-07
# Epoch 1089/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7631 - loss: 0.5218 - val_accuracy: 0.7416 - val_loss: 0.5523 - learning_rate: 5.0000e-07
# Epoch 1090/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7623 - loss: 0.5241 - val_accuracy: 0.7416 - val_loss: 0.5523 - learning_rate: 5.0000e-07
# Epoch 1091/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7574 - loss: 0.5194 - val_accuracy: 0.7416 - val_loss: 0.5524 - learning_rate: 5.0000e-07
# Epoch 1092/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7531 - loss: 0.5262 - val_accuracy: 0.7393 - val_loss: 0.5524 - learning_rate: 5.0000e-07
# Epoch 1093/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7591 - loss: 0.5271 - val_accuracy: 0.7393 - val_loss: 0.5524 - learning_rate: 5.0000e-07
# Epoch 1094/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7690 - loss: 0.5244 - val_accuracy: 0.7393 - val_loss: 0.5524 - learning_rate: 5.0000e-07
# Epoch 1095/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7549 - loss: 0.5256 - val_accuracy: 0.7393 - val_loss: 0.5524 - learning_rate: 5.0000e-07
# Epoch 1096/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7507 - loss: 0.5255 - val_accuracy: 0.7393 - val_loss: 0.5524 - learning_rate: 5.0000e-07
# Epoch 1097/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7629 - loss: 0.5223 - val_accuracy: 0.7393 - val_loss: 0.5524 - learning_rate: 5.0000e-07
# Epoch 1098/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7636 - loss: 0.5249 - val_accuracy: 0.7393 - val_loss: 0.5524 - learning_rate: 5.0000e-07
# Epoch 1099/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7549 - loss: 0.5262 - val_accuracy: 0.7393 - val_loss: 0.5524 - learning_rate: 5.0000e-07
# Epoch 1100/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7586 - loss: 0.5242 - val_accuracy: 0.7393 - val_loss: 0.5523 - learning_rate: 5.0000e-07
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Test Accuracy: 0.7250
# Test F1 Score: 0.7308
# Test Precision: 0.7158
# Test Recall: 0.7464
# Test ROC AUC Score: 0.8053
