# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import accuracy_score, roc_auc_score, recall_score, precision_score, f1_score
from sklearn.metrics import confusion_matrix, precision_recall_fscore_support
import seaborn as sns
from collections import Counter
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau
from model.lstmfcn import generate_lstmfcn
from model.fcn import generate_fcn
from model.lstm import generate_lstm
from utils.class_weight import compute_class_weight
import tensorflow as tf
import random as python_random

# %%
# # load the data
X_test_time = np.load('../data-preprocess/data-split/data/mean-time-series/test/X_test.npy')
y_test = np.load('../data-preprocess/data-split/data/features/test/y_test.npy')
X_train_time = np.load('../data-preprocess/data-split/data/mean-time-series/train/X_train.npy')
y_train = np.load('../data-preprocess/data-split/data/features/train/y_train.npy')
X_test_features = np.load('../data-preprocess/data-split/data/features/test/X_test.npy', allow_pickle=True)
X_train_features = np.load('../data-preprocess/data-split/data/features/train/X_train.npy', allow_pickle=True)

# # load fake data
#X_train = np.load('./fake/train/X_train.npy')
#y_train = np.load('./fake/train/y_train.npy')
#X_test = np.load('./fake/test/X_test.npy')
#y_test = np.load('./fake/test/y_test.npy')


print('X_train of time series shape:', X_train_time.shape)
print('X_test of time series shape:', X_test_time.shape)
print('X_train of features shape:', X_train_features.shape)
print('X_test of features shape:', X_test_features.shape)
print('y_train shape:', y_train.shape)
print('y_test shape:', y_test.shape)
# Out:
# X_train of time series shape: (2223, 600)
# X_test of time series shape: (560, 600)
# X_train of features shape: (2223,)
# X_test of features shape: (560,)
# y_train shape: (2223,)
# y_test shape: (560,)

# %%
def reset_random_seeds(seed=42):
   np.random.seed(seed)
   python_random.seed(seed)
   tf.random.set_seed(seed)

reset_random_seeds()

# %%
# normalize the data to have same starting pt for all time series
# input shape: (n_samples, n_timepoints), want each samples - its mean of 0-30th timepts
def normalize_curves_mean_method(unnormalized_datas):
    normalized_datas = []
    for unnormalized_data in unnormalized_datas:
        mean = np.mean(unnormalized_data[:30])
        normalized_data = unnormalized_data - mean
        normalized_datas.append(normalized_data)
    normalized_datas = np.array(normalized_datas)
    assert normalized_datas.shape == unnormalized_datas.shape
    return normalized_datas

# normalize the data using z-score, have mean 0 and std 1
def normalize_curves_zscore(unnormalized_datas):
    normalized_datas = []
    for unnormalized_data in unnormalized_datas:
        mean = np.mean(unnormalized_data)
        std = np.std(unnormalized_data)
        normalized_data = (unnormalized_data - mean) / std
        normalized_datas.append(normalized_data)
    normalized_datas = np.array(normalized_datas)
    assert normalized_datas.shape == unnormalized_datas.shape
    return normalized_datas


# apply ln() to the time series data
def apply_ln_to_curves(datas):
    ln_datas = []
    for data in datas:
        ln_data = np.log(data)
        ln_datas.append(ln_data)
    ln_datas = np.array(ln_datas)
    assert ln_datas.shape == datas.shape
    return ln_datas


# split the time series data into wanted time points
def split_time_series(datas, start, end):
    datas = datas[:, start:end]
    return datas


# plot the time series data, randomly picked n samples, different colors represent different classes
def plot_random_time_series(datas, n, labels):
    for i in range(n):
        idx = np.random.randint(datas.shape[0])
        plt.plot(datas[idx], color = 'blue' if labels[idx] == 1 else 'red', alpha = 0.2)
    plt.show()


X_train_time = normalize_curves_mean_method(X_train_time)
X_test_time = normalize_curves_mean_method(X_test_time)
plot_random_time_series(X_train_time, 100, y_train)

# %%
# normalize the features data
X_train_features = pd.DataFrame.from_records(X_train_features.flatten())
X_test_features = pd.DataFrame.from_records(X_test_features.flatten())
print(X_train_features.head(1))

scaler = StandardScaler()
features = X_train_features.columns
X_train_features[features] = scaler.fit_transform(X_train_features[features])
X_test_features[features] = scaler.transform(X_test_features[features])
print(X_train_features.head(1))
# Out:
#            pc0        pc1        pc2  rising_waveform  falling_waveform  \
# 0 -1320.506845  47.462699  39.931146         0.965372          0.547959
#
#    peak_temperature  cultivar
# 0        260.650491         1
#         pc0       pc1       pc2  rising_waveform  falling_waveform  \
# 0 -1.100143  0.143025  0.333856        -1.146425         -1.244999
#
#    peak_temperature  cultivar
# 0         -1.146425  -1.35422

# %%
# normalize the time series data
# compute mean & std of the training set, then normalize the whole dataset using z-normalization
mean = np.mean(X_train_time)
std = np.std(X_train_time)
X_train_time = (X_train_time - mean) / std
X_test_time = (X_test_time - mean) / std

# %%
# Ensure data is shaped correctly
X_train_time = X_train_time.reshape(-1, 1, 600)  # Convert to (samples, 1, timesteps)
X_test_time = X_test_time.reshape(-1, 1, 600)
y_train = y_train.reshape(-1, 1)  # Ensure labels are in shape (samples, 1)
y_test = y_test.reshape(-1, 1)
X_train_features = X_train_features.values
X_test_features = X_test_features.values

print('X_train shape of time series:', X_train_time.shape)
print('y_train shape:', y_train.shape)
print('X_test shape of time series:', X_test_time.shape)
print('y_test shape:', y_test.shape)
print('X_train shape of features:', X_train_features.shape)
print('X_test shape of features:', X_test_features.shape)
# Out:
# X_train shape of time series: (2223, 1, 600)
# y_train shape: (2223, 1)
# X_test shape of time series: (560, 1, 600)
# y_test shape: (560, 1)
# X_train shape of features: (2223, 7)
# X_test shape of features: (560, 7)

# %%
# Train final model on full training data# Initialize model
final_model = generate_lstmfcn(feature_input_accept=True, dropout=0.0)
class_weights = compute_class_weight(y_train)
print('class_weights:', class_weights)
reduce_lr = ReduceLROnPlateau(monitor='loss', patience=15, mode='auto',
    factor=1. / np.cbrt(2), cooldown=0, min_lr=1e-6, verbose=2)
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=20, verbose=1, mode='min', restore_best_weights=True)
final_model.compile(optimizer=Adam(learning_rate=5e-6), loss='binary_crossentropy', metrics=['accuracy'])

# split the data into training and validation set
X_train_time, X_val_time, X_train_features, X_val_features, y_train, y_val = train_test_split(
    X_train_time, X_train_features, y_train, test_size=0.2, random_state=42)
print('X_train shape of time series:', X_train_time.shape)
print('y_train shape:', y_train.shape)
print('X_val shape of time series:', X_val_time.shape)
print('y_val shape:', y_val.shape)
print('X_train shape of features:', X_train_features.shape)
print('X_val shape of features:', X_val_features.shape)

# Train model
history = final_model.fit(
    [X_train_time, X_train_features], y_train,
    validation_data=([X_val_time, X_val_features], y_val),
    callbacks=[reduce_lr],
    shuffle=True,
    epochs=200, batch_size=16, class_weight={0: class_weights[0], 1: class_weights[1]},
    verbose=1
)

# Predict on test set
y_pred_prob = final_model.predict([X_test_time, X_test_features])
y_pred = (y_pred_prob > 0.5).astype(int)

# Calculate metrics
accuracy = accuracy_score(y_test, y_pred)
precision, recall, f1, _ = precision_recall_fscore_support(y_test, y_pred, average='binary')
roc_auc = roc_auc_score(y_test, y_pred_prob)
conf_matrix = confusion_matrix(y_test, y_pred)

# plot the metrics
print(f"Test Accuracy: {accuracy:.4f}")
print(f"Test F1 Score: {f1:.4f}")
print(f"Test Precision: {precision:.4f}")
print(f"Test Recall: {recall:.4f}")
print(f"Test ROC AUC Score: {roc_auc:.4f}")
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Dead', 'Alive'], yticklabels=['Dead', 'Alive'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()


# plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.figure(figsize=(10, 7))
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.figure(figsize=(10, 7))
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# class_weights: [1.60158501 0.72694572]
# X_train shape of time series: (1778, 1, 600)
# y_train shape: (1778, 1)
# X_val shape of time series: (445, 1, 600)
# y_val shape: (445, 1)
# X_train shape of features: (1778, 7)
# X_val shape of features: (445, 7)
# Epoch 1/200
# 112/112 [==============================] - 7s 50ms/step - loss: 0.8620 - accuracy: 0.6850 - val_loss: 0.6507 - val_accuracy: 0.6989 - lr: 5.0000e-06
# Epoch 2/200
# 112/112 [==============================] - 5s 48ms/step - loss: 0.7074 - accuracy: 0.6974 - val_loss: 0.5882 - val_accuracy: 0.7528 - lr: 5.0000e-06
# Epoch 3/200
# 112/112 [==============================] - 5s 47ms/step - loss: 0.6444 - accuracy: 0.7424 - val_loss: 0.5653 - val_accuracy: 0.7438 - lr: 5.0000e-06
# Epoch 4/200
# 112/112 [==============================] - 5s 47ms/step - loss: 0.6178 - accuracy: 0.7469 - val_loss: 0.5643 - val_accuracy: 0.7393 - lr: 5.0000e-06
# Epoch 5/200
# 112/112 [==============================] - 5s 48ms/step - loss: 0.6020 - accuracy: 0.7413 - val_loss: 0.5603 - val_accuracy: 0.7348 - lr: 5.0000e-06
# Epoch 6/200
# 112/112 [==============================] - 5s 48ms/step - loss: 0.5982 - accuracy: 0.7317 - val_loss: 0.5609 - val_accuracy: 0.7281 - lr: 5.0000e-06
# Epoch 7/200
# 112/112 [==============================] - 5s 48ms/step - loss: 0.5892 - accuracy: 0.7283 - val_loss: 0.5702 - val_accuracy: 0.7236 - lr: 5.0000e-06
# Epoch 8/200
# 112/112 [==============================] - 5s 49ms/step - loss: 0.5927 - accuracy: 0.7278 - val_loss: 0.5695 - val_accuracy: 0.7213 - lr: 5.0000e-06
# Epoch 9/200
# 112/112 [==============================] - 8s 70ms/step - loss: 0.5913 - accuracy: 0.7210 - val_loss: 0.5666 - val_accuracy: 0.7191 - lr: 5.0000e-06
# Epoch 10/200
# 112/112 [==============================] - 7s 63ms/step - loss: 0.5826 - accuracy: 0.7283 - val_loss: 0.5780 - val_accuracy: 0.7101 - lr: 5.0000e-06
# Epoch 11/200
# 112/112 [==============================] - 7s 65ms/step - loss: 0.5814 - accuracy: 0.7267 - val_loss: 0.5830 - val_accuracy: 0.7124 - lr: 5.0000e-06
# Epoch 12/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5765 - accuracy: 0.7261 - val_loss: 0.5761 - val_accuracy: 0.7124 - lr: 5.0000e-06
# Epoch 13/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5776 - accuracy: 0.7312 - val_loss: 0.5752 - val_accuracy: 0.7146 - lr: 5.0000e-06
# Epoch 14/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5832 - accuracy: 0.7312 - val_loss: 0.5807 - val_accuracy: 0.7146 - lr: 5.0000e-06
# Epoch 15/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5789 - accuracy: 0.7261 - val_loss: 0.5830 - val_accuracy: 0.7079 - lr: 5.0000e-06
# Epoch 16/200
# 112/112 [==============================] - 7s 65ms/step - loss: 0.5761 - accuracy: 0.7261 - val_loss: 0.5719 - val_accuracy: 0.7146 - lr: 5.0000e-06
# Epoch 17/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5755 - accuracy: 0.7255 - val_loss: 0.5780 - val_accuracy: 0.7079 - lr: 5.0000e-06
# Epoch 18/200
# 112/112 [==============================] - 7s 65ms/step - loss: 0.5754 - accuracy: 0.7289 - val_loss: 0.5702 - val_accuracy: 0.7191 - lr: 5.0000e-06
# Epoch 19/200
# 112/112 [==============================] - 7s 65ms/step - loss: 0.5790 - accuracy: 0.7227 - val_loss: 0.5685 - val_accuracy: 0.7146 - lr: 5.0000e-06
# Epoch 20/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5754 - accuracy: 0.7210 - val_loss: 0.5763 - val_accuracy: 0.7079 - lr: 5.0000e-06
# Epoch 21/200
# 112/112 [==============================] - 7s 65ms/step - loss: 0.5694 - accuracy: 0.7227 - val_loss: 0.5791 - val_accuracy: 0.7079 - lr: 5.0000e-06
# Epoch 22/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5713 - accuracy: 0.7289 - val_loss: 0.5785 - val_accuracy: 0.7101 - lr: 5.0000e-06
# Epoch 23/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5713 - accuracy: 0.7289 - val_loss: 0.5710 - val_accuracy: 0.7124 - lr: 5.0000e-06
# Epoch 24/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5714 - accuracy: 0.7188 - val_loss: 0.5707 - val_accuracy: 0.7079 - lr: 5.0000e-06
# Epoch 25/200
# 112/112 [==============================] - 8s 67ms/step - loss: 0.5785 - accuracy: 0.7177 - val_loss: 0.5785 - val_accuracy: 0.7034 - lr: 5.0000e-06
# Epoch 26/200
# 112/112 [==============================] - 7s 65ms/step - loss: 0.5743 - accuracy: 0.7385 - val_loss: 0.5712 - val_accuracy: 0.7101 - lr: 5.0000e-06
# Epoch 27/200
# 112/112 [==============================] - 7s 64ms/step - loss: 0.5746 - accuracy: 0.7261 - val_loss: 0.5725 - val_accuracy: 0.7101 - lr: 5.0000e-06
# Epoch 28/200
# 112/112 [==============================] - 7s 64ms/step - loss: 0.5681 - accuracy: 0.7109 - val_loss: 0.5811 - val_accuracy: 0.6989 - lr: 5.0000e-06
# Epoch 29/200
# 112/112 [==============================] - 7s 64ms/step - loss: 0.5691 - accuracy: 0.7188 - val_loss: 0.5667 - val_accuracy: 0.7146 - lr: 5.0000e-06
# Epoch 30/200
# 112/112 [==============================] - 7s 65ms/step - loss: 0.5711 - accuracy: 0.7255 - val_loss: 0.5684 - val_accuracy: 0.7124 - lr: 5.0000e-06
# Epoch 31/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5723 - accuracy: 0.7267 - val_loss: 0.5662 - val_accuracy: 0.7169 - lr: 5.0000e-06
# Epoch 32/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5689 - accuracy: 0.7289 - val_loss: 0.5632 - val_accuracy: 0.7169 - lr: 5.0000e-06
# Epoch 33/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5717 - accuracy: 0.7216 - val_loss: 0.5710 - val_accuracy: 0.7101 - lr: 5.0000e-06
# Epoch 34/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5601 - accuracy: 0.7357 - val_loss: 0.5780 - val_accuracy: 0.6966 - lr: 5.0000e-06
# Epoch 35/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5668 - accuracy: 0.7278 - val_loss: 0.5717 - val_accuracy: 0.7011 - lr: 5.0000e-06
# Epoch 36/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5640 - accuracy: 0.7205 - val_loss: 0.5785 - val_accuracy: 0.7011 - lr: 5.0000e-06
# Epoch 37/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5774 - accuracy: 0.7233 - val_loss: 0.5646 - val_accuracy: 0.7124 - lr: 5.0000e-06
# Epoch 38/200
# 112/112 [==============================] - 7s 65ms/step - loss: 0.5698 - accuracy: 0.7345 - val_loss: 0.5718 - val_accuracy: 0.7034 - lr: 5.0000e-06
# Epoch 39/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5664 - accuracy: 0.7300 - val_loss: 0.5776 - val_accuracy: 0.6966 - lr: 5.0000e-06
# Epoch 40/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5697 - accuracy: 0.7317 - val_loss: 0.5677 - val_accuracy: 0.7079 - lr: 5.0000e-06
# Epoch 41/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5654 - accuracy: 0.7317 - val_loss: 0.5671 - val_accuracy: 0.7124 - lr: 5.0000e-06
# Epoch 42/200
# 112/112 [==============================] - 7s 65ms/step - loss: 0.5657 - accuracy: 0.7368 - val_loss: 0.5645 - val_accuracy: 0.7146 - lr: 5.0000e-06
# Epoch 43/200
# 112/112 [==============================] - 7s 65ms/step - loss: 0.5655 - accuracy: 0.7278 - val_loss: 0.5614 - val_accuracy: 0.7146 - lr: 5.0000e-06
# Epoch 44/200
# 112/112 [==============================] - 7s 65ms/step - loss: 0.5649 - accuracy: 0.7323 - val_loss: 0.5785 - val_accuracy: 0.6989 - lr: 5.0000e-06
# Epoch 45/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5613 - accuracy: 0.7402 - val_loss: 0.5608 - val_accuracy: 0.7213 - lr: 5.0000e-06
# Epoch 46/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5655 - accuracy: 0.7289 - val_loss: 0.5626 - val_accuracy: 0.7146 - lr: 5.0000e-06
# Epoch 47/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5659 - accuracy: 0.7244 - val_loss: 0.5612 - val_accuracy: 0.7124 - lr: 5.0000e-06
# Epoch 48/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5700 - accuracy: 0.7222 - val_loss: 0.5651 - val_accuracy: 0.7079 - lr: 5.0000e-06
# Epoch 49/200
# 111/112 [============================>.] - ETA: 0s - loss: 0.5648 - accuracy: 0.7241
# Epoch 49: ReduceLROnPlateau reducing learning rate to 3.968502529667691e-06.
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5655 - accuracy: 0.7233 - val_loss: 0.5753 - val_accuracy: 0.7011 - lr: 5.0000e-06
# Epoch 50/200
# 112/112 [==============================] - 8s 67ms/step - loss: 0.5652 - accuracy: 0.7328 - val_loss: 0.5713 - val_accuracy: 0.7056 - lr: 3.9685e-06
# Epoch 51/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5574 - accuracy: 0.7385 - val_loss: 0.5699 - val_accuracy: 0.7079 - lr: 3.9685e-06
# Epoch 52/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5632 - accuracy: 0.7340 - val_loss: 0.5608 - val_accuracy: 0.7169 - lr: 3.9685e-06
# Epoch 53/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5597 - accuracy: 0.7328 - val_loss: 0.5568 - val_accuracy: 0.7191 - lr: 3.9685e-06
# Epoch 54/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5619 - accuracy: 0.7340 - val_loss: 0.5540 - val_accuracy: 0.7213 - lr: 3.9685e-06
# Epoch 55/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5645 - accuracy: 0.7261 - val_loss: 0.5647 - val_accuracy: 0.7124 - lr: 3.9685e-06
# Epoch 56/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5556 - accuracy: 0.7413 - val_loss: 0.5576 - val_accuracy: 0.7169 - lr: 3.9685e-06
# Epoch 57/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5590 - accuracy: 0.7390 - val_loss: 0.5634 - val_accuracy: 0.7101 - lr: 3.9685e-06
# Epoch 58/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5591 - accuracy: 0.7345 - val_loss: 0.5651 - val_accuracy: 0.7101 - lr: 3.9685e-06
# Epoch 59/200
# 112/112 [==============================] - 7s 67ms/step - loss: 0.5580 - accuracy: 0.7463 - val_loss: 0.5677 - val_accuracy: 0.7079 - lr: 3.9685e-06
# Epoch 60/200
# 112/112 [==============================] - 7s 67ms/step - loss: 0.5615 - accuracy: 0.7295 - val_loss: 0.5647 - val_accuracy: 0.7124 - lr: 3.9685e-06
# Epoch 61/200
# 112/112 [==============================] - 7s 67ms/step - loss: 0.5611 - accuracy: 0.7323 - val_loss: 0.5551 - val_accuracy: 0.7169 - lr: 3.9685e-06
# Epoch 62/200
# 112/112 [==============================] - 7s 67ms/step - loss: 0.5547 - accuracy: 0.7413 - val_loss: 0.5581 - val_accuracy: 0.7191 - lr: 3.9685e-06
# Epoch 63/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5629 - accuracy: 0.7357 - val_loss: 0.5576 - val_accuracy: 0.7169 - lr: 3.9685e-06
# Epoch 64/200
# 112/112 [==============================] - 7s 64ms/step - loss: 0.5565 - accuracy: 0.7396 - val_loss: 0.5651 - val_accuracy: 0.7101 - lr: 3.9685e-06
# Epoch 65/200
# 112/112 [==============================] - 7s 64ms/step - loss: 0.5551 - accuracy: 0.7317 - val_loss: 0.5554 - val_accuracy: 0.7169 - lr: 3.9685e-06
# Epoch 66/200
# 112/112 [==============================] - 7s 64ms/step - loss: 0.5597 - accuracy: 0.7345 - val_loss: 0.5513 - val_accuracy: 0.7236 - lr: 3.9685e-06
# Epoch 67/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5634 - accuracy: 0.7193 - val_loss: 0.5560 - val_accuracy: 0.7213 - lr: 3.9685e-06
# Epoch 68/200
# 112/112 [==============================] - 7s 67ms/step - loss: 0.5668 - accuracy: 0.7255 - val_loss: 0.5547 - val_accuracy: 0.7169 - lr: 3.9685e-06
# Epoch 69/200
# 112/112 [==============================] - 7s 67ms/step - loss: 0.5619 - accuracy: 0.7278 - val_loss: 0.5612 - val_accuracy: 0.7169 - lr: 3.9685e-06
# Epoch 70/200
# 112/112 [==============================] - 7s 67ms/step - loss: 0.5572 - accuracy: 0.7379 - val_loss: 0.5597 - val_accuracy: 0.7146 - lr: 3.9685e-06
# Epoch 71/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5614 - accuracy: 0.7323 - val_loss: 0.5483 - val_accuracy: 0.7236 - lr: 3.9685e-06
# Epoch 72/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5602 - accuracy: 0.7413 - val_loss: 0.5668 - val_accuracy: 0.7056 - lr: 3.9685e-06
# Epoch 73/200
# 112/112 [==============================] - 8s 67ms/step - loss: 0.5578 - accuracy: 0.7430 - val_loss: 0.5552 - val_accuracy: 0.7213 - lr: 3.9685e-06
# Epoch 74/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5551 - accuracy: 0.7385 - val_loss: 0.5482 - val_accuracy: 0.7236 - lr: 3.9685e-06
# Epoch 75/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5596 - accuracy: 0.7312 - val_loss: 0.5568 - val_accuracy: 0.7191 - lr: 3.9685e-06
# Epoch 76/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5576 - accuracy: 0.7396 - val_loss: 0.5548 - val_accuracy: 0.7191 - lr: 3.9685e-06
# Epoch 77/200
# 111/112 [============================>.] - ETA: 0s - loss: 0.5567 - accuracy: 0.7370
# Epoch 77: ReduceLROnPlateau reducing learning rate to 3.1498024179533314e-06.
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5574 - accuracy: 0.7368 - val_loss: 0.5633 - val_accuracy: 0.7146 - lr: 3.9685e-06
# Epoch 78/200
# 112/112 [==============================] - 8s 68ms/step - loss: 0.5546 - accuracy: 0.7306 - val_loss: 0.5535 - val_accuracy: 0.7191 - lr: 3.1498e-06
# Epoch 79/200
# 112/112 [==============================] - 8s 67ms/step - loss: 0.5563 - accuracy: 0.7368 - val_loss: 0.5573 - val_accuracy: 0.7191 - lr: 3.1498e-06
# Epoch 80/200
# 112/112 [==============================] - 7s 67ms/step - loss: 0.5536 - accuracy: 0.7261 - val_loss: 0.5632 - val_accuracy: 0.7146 - lr: 3.1498e-06
# Epoch 81/200
# 112/112 [==============================] - 7s 67ms/step - loss: 0.5522 - accuracy: 0.7357 - val_loss: 0.5629 - val_accuracy: 0.7146 - lr: 3.1498e-06
# Epoch 82/200
# 112/112 [==============================] - 8s 67ms/step - loss: 0.5516 - accuracy: 0.7379 - val_loss: 0.5627 - val_accuracy: 0.7146 - lr: 3.1498e-06
# Epoch 83/200
# 112/112 [==============================] - 7s 67ms/step - loss: 0.5558 - accuracy: 0.7385 - val_loss: 0.5570 - val_accuracy: 0.7191 - lr: 3.1498e-06
# Epoch 84/200
# 112/112 [==============================] - 7s 67ms/step - loss: 0.5558 - accuracy: 0.7430 - val_loss: 0.5515 - val_accuracy: 0.7191 - lr: 3.1498e-06
# Epoch 85/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5544 - accuracy: 0.7492 - val_loss: 0.5583 - val_accuracy: 0.7169 - lr: 3.1498e-06
# Epoch 86/200
# 112/112 [==============================] - 8s 67ms/step - loss: 0.5601 - accuracy: 0.7418 - val_loss: 0.5583 - val_accuracy: 0.7169 - lr: 3.1498e-06
# Epoch 87/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5561 - accuracy: 0.7396 - val_loss: 0.5589 - val_accuracy: 0.7213 - lr: 3.1498e-06
# Epoch 88/200
# 112/112 [==============================] - 7s 67ms/step - loss: 0.5581 - accuracy: 0.7373 - val_loss: 0.5588 - val_accuracy: 0.7169 - lr: 3.1498e-06
# Epoch 89/200
# 112/112 [==============================] - 8s 67ms/step - loss: 0.5607 - accuracy: 0.7238 - val_loss: 0.5595 - val_accuracy: 0.7124 - lr: 3.1498e-06
# Epoch 90/200
# 112/112 [==============================] - 8s 68ms/step - loss: 0.5552 - accuracy: 0.7368 - val_loss: 0.5634 - val_accuracy: 0.7169 - lr: 3.1498e-06
# Epoch 91/200
# 112/112 [==============================] - 8s 67ms/step - loss: 0.5580 - accuracy: 0.7357 - val_loss: 0.5687 - val_accuracy: 0.7101 - lr: 3.1498e-06
# Epoch 92/200
# 112/112 [==============================] - 8s 67ms/step - loss: 0.5604 - accuracy: 0.7357 - val_loss: 0.5643 - val_accuracy: 0.7146 - lr: 3.1498e-06
# Epoch 93/200
# 112/112 [==============================] - 7s 67ms/step - loss: 0.5569 - accuracy: 0.7379 - val_loss: 0.5612 - val_accuracy: 0.7146 - lr: 3.1498e-06
# Epoch 94/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5528 - accuracy: 0.7368 - val_loss: 0.5570 - val_accuracy: 0.7191 - lr: 3.1498e-06
# Epoch 95/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5523 - accuracy: 0.7413 - val_loss: 0.5633 - val_accuracy: 0.7169 - lr: 3.1498e-06
# Epoch 96/200
# 112/112 [==============================] - 7s 65ms/step - loss: 0.5578 - accuracy: 0.7390 - val_loss: 0.5502 - val_accuracy: 0.7191 - lr: 3.1498e-06
# Epoch 97/200
# 111/112 [============================>.] - ETA: 0s - loss: 0.5554 - accuracy: 0.7376
# Epoch 97: ReduceLROnPlateau reducing learning rate to 2.499999919802159e-06.
# 112/112 [==============================] - 7s 65ms/step - loss: 0.5558 - accuracy: 0.7368 - val_loss: 0.5585 - val_accuracy: 0.7191 - lr: 3.1498e-06
# Epoch 98/200
# 112/112 [==============================] - 7s 67ms/step - loss: 0.5554 - accuracy: 0.7334 - val_loss: 0.5590 - val_accuracy: 0.7169 - lr: 2.5000e-06
# Epoch 99/200
# 112/112 [==============================] - 8s 68ms/step - loss: 0.5586 - accuracy: 0.7345 - val_loss: 0.5565 - val_accuracy: 0.7169 - lr: 2.5000e-06
# Epoch 100/200
# 112/112 [==============================] - 7s 65ms/step - loss: 0.5546 - accuracy: 0.7447 - val_loss: 0.5627 - val_accuracy: 0.7169 - lr: 2.5000e-06
# Epoch 101/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5510 - accuracy: 0.7362 - val_loss: 0.5699 - val_accuracy: 0.7101 - lr: 2.5000e-06
# Epoch 102/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5591 - accuracy: 0.7362 - val_loss: 0.5621 - val_accuracy: 0.7124 - lr: 2.5000e-06
# Epoch 103/200
# 112/112 [==============================] - 7s 65ms/step - loss: 0.5584 - accuracy: 0.7306 - val_loss: 0.5621 - val_accuracy: 0.7124 - lr: 2.5000e-06
# Epoch 104/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5580 - accuracy: 0.7402 - val_loss: 0.5592 - val_accuracy: 0.7146 - lr: 2.5000e-06
# Epoch 105/200
# 112/112 [==============================] - 8s 67ms/step - loss: 0.5607 - accuracy: 0.7357 - val_loss: 0.5632 - val_accuracy: 0.7146 - lr: 2.5000e-06
# Epoch 106/200
# 112/112 [==============================] - 7s 67ms/step - loss: 0.5522 - accuracy: 0.7407 - val_loss: 0.5598 - val_accuracy: 0.7124 - lr: 2.5000e-06
# Epoch 107/200
# 112/112 [==============================] - 7s 67ms/step - loss: 0.5487 - accuracy: 0.7435 - val_loss: 0.5610 - val_accuracy: 0.7169 - lr: 2.5000e-06
# Epoch 108/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5566 - accuracy: 0.7357 - val_loss: 0.5608 - val_accuracy: 0.7146 - lr: 2.5000e-06
# Epoch 109/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5461 - accuracy: 0.7452 - val_loss: 0.5596 - val_accuracy: 0.7124 - lr: 2.5000e-06
# Epoch 110/200
# 112/112 [==============================] - 8s 67ms/step - loss: 0.5570 - accuracy: 0.7357 - val_loss: 0.5641 - val_accuracy: 0.7124 - lr: 2.5000e-06
# Epoch 111/200
# 112/112 [==============================] - 8s 68ms/step - loss: 0.5506 - accuracy: 0.7435 - val_loss: 0.5573 - val_accuracy: 0.7146 - lr: 2.5000e-06
# Epoch 112/200
# 112/112 [==============================] - 7s 67ms/step - loss: 0.5543 - accuracy: 0.7396 - val_loss: 0.5582 - val_accuracy: 0.7146 - lr: 2.5000e-06
# Epoch 113/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5502 - accuracy: 0.7413 - val_loss: 0.5670 - val_accuracy: 0.7146 - lr: 2.5000e-06
# Epoch 114/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5554 - accuracy: 0.7334 - val_loss: 0.5593 - val_accuracy: 0.7146 - lr: 2.5000e-06
# Epoch 115/200
# 112/112 [==============================] - 7s 65ms/step - loss: 0.5550 - accuracy: 0.7418 - val_loss: 0.5618 - val_accuracy: 0.7169 - lr: 2.5000e-06
# Epoch 116/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5510 - accuracy: 0.7418 - val_loss: 0.5528 - val_accuracy: 0.7191 - lr: 2.5000e-06
# Epoch 117/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5521 - accuracy: 0.7379 - val_loss: 0.5551 - val_accuracy: 0.7213 - lr: 2.5000e-06
# Epoch 118/200
# 112/112 [==============================] - 7s 67ms/step - loss: 0.5516 - accuracy: 0.7407 - val_loss: 0.5520 - val_accuracy: 0.7213 - lr: 2.5000e-06
# Epoch 119/200
# 112/112 [==============================] - 8s 68ms/step - loss: 0.5489 - accuracy: 0.7413 - val_loss: 0.5518 - val_accuracy: 0.7191 - lr: 2.5000e-06
# Epoch 120/200
# 112/112 [==============================] - 7s 67ms/step - loss: 0.5519 - accuracy: 0.7418 - val_loss: 0.5516 - val_accuracy: 0.7169 - lr: 2.5000e-06
# Epoch 121/200
# 112/112 [==============================] - 8s 67ms/step - loss: 0.5512 - accuracy: 0.7497 - val_loss: 0.5562 - val_accuracy: 0.7146 - lr: 2.5000e-06
# Epoch 122/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5508 - accuracy: 0.7452 - val_loss: 0.5591 - val_accuracy: 0.7146 - lr: 2.5000e-06
# Epoch 123/200
# 112/112 [==============================] - 7s 67ms/step - loss: 0.5523 - accuracy: 0.7435 - val_loss: 0.5599 - val_accuracy: 0.7124 - lr: 2.5000e-06
# Epoch 124/200
# 111/112 [============================>.] - ETA: 0s - loss: 0.5489 - accuracy: 0.7337
# Epoch 124: ReduceLROnPlateau reducing learning rate to 1.9842512648338455e-06.
# 112/112 [==============================] - 7s 67ms/step - loss: 0.5491 - accuracy: 0.7334 - val_loss: 0.5615 - val_accuracy: 0.7124 - lr: 2.5000e-06
# Epoch 125/200
# 112/112 [==============================] - 8s 68ms/step - loss: 0.5548 - accuracy: 0.7340 - val_loss: 0.5585 - val_accuracy: 0.7146 - lr: 1.9843e-06
# Epoch 126/200
# 112/112 [==============================] - 8s 68ms/step - loss: 0.5520 - accuracy: 0.7373 - val_loss: 0.5552 - val_accuracy: 0.7191 - lr: 1.9843e-06
# Epoch 127/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5507 - accuracy: 0.7413 - val_loss: 0.5580 - val_accuracy: 0.7146 - lr: 1.9843e-06
# Epoch 128/200
# 112/112 [==============================] - 8s 67ms/step - loss: 0.5482 - accuracy: 0.7441 - val_loss: 0.5615 - val_accuracy: 0.7124 - lr: 1.9843e-06
# Epoch 129/200
# 112/112 [==============================] - 8s 68ms/step - loss: 0.5494 - accuracy: 0.7447 - val_loss: 0.5580 - val_accuracy: 0.7124 - lr: 1.9843e-06
# Epoch 130/200
# 112/112 [==============================] - 8s 68ms/step - loss: 0.5465 - accuracy: 0.7351 - val_loss: 0.5578 - val_accuracy: 0.7124 - lr: 1.9843e-06
# Epoch 131/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5524 - accuracy: 0.7435 - val_loss: 0.5585 - val_accuracy: 0.7124 - lr: 1.9843e-06
# Epoch 132/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5545 - accuracy: 0.7334 - val_loss: 0.5586 - val_accuracy: 0.7124 - lr: 1.9843e-06
# Epoch 133/200
# 112/112 [==============================] - 8s 67ms/step - loss: 0.5510 - accuracy: 0.7424 - val_loss: 0.5595 - val_accuracy: 0.7124 - lr: 1.9843e-06
# Epoch 134/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5504 - accuracy: 0.7458 - val_loss: 0.5630 - val_accuracy: 0.7101 - lr: 1.9843e-06
# Epoch 135/200
# 112/112 [==============================] - 7s 67ms/step - loss: 0.5546 - accuracy: 0.7413 - val_loss: 0.5550 - val_accuracy: 0.7169 - lr: 1.9843e-06
# Epoch 136/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5493 - accuracy: 0.7390 - val_loss: 0.5610 - val_accuracy: 0.7124 - lr: 1.9843e-06
# Epoch 137/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5491 - accuracy: 0.7413 - val_loss: 0.5544 - val_accuracy: 0.7169 - lr: 1.9843e-06
# Epoch 138/200
# 112/112 [==============================] - 7s 65ms/step - loss: 0.5527 - accuracy: 0.7402 - val_loss: 0.5549 - val_accuracy: 0.7146 - lr: 1.9843e-06
# Epoch 139/200
# 111/112 [============================>.] - ETA: 0s - loss: 0.5579 - accuracy: 0.7348
# Epoch 139: ReduceLROnPlateau reducing learning rate to 1.5749012089766657e-06.
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5577 - accuracy: 0.7351 - val_loss: 0.5560 - val_accuracy: 0.7169 - lr: 1.9843e-06
# Epoch 140/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5510 - accuracy: 0.7385 - val_loss: 0.5607 - val_accuracy: 0.7124 - lr: 1.5749e-06
# Epoch 141/200
# 112/112 [==============================] - 7s 65ms/step - loss: 0.5496 - accuracy: 0.7402 - val_loss: 0.5595 - val_accuracy: 0.7146 - lr: 1.5749e-06
# Epoch 142/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5583 - accuracy: 0.7413 - val_loss: 0.5528 - val_accuracy: 0.7213 - lr: 1.5749e-06
# Epoch 143/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5461 - accuracy: 0.7503 - val_loss: 0.5538 - val_accuracy: 0.7169 - lr: 1.5749e-06
# Epoch 144/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5483 - accuracy: 0.7480 - val_loss: 0.5600 - val_accuracy: 0.7101 - lr: 1.5749e-06
# Epoch 145/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5495 - accuracy: 0.7362 - val_loss: 0.5575 - val_accuracy: 0.7146 - lr: 1.5749e-06
# Epoch 146/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5497 - accuracy: 0.7413 - val_loss: 0.5572 - val_accuracy: 0.7169 - lr: 1.5749e-06
# Epoch 147/200
# 112/112 [==============================] - 7s 67ms/step - loss: 0.5545 - accuracy: 0.7289 - val_loss: 0.5551 - val_accuracy: 0.7191 - lr: 1.5749e-06
# Epoch 148/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5505 - accuracy: 0.7475 - val_loss: 0.5554 - val_accuracy: 0.7191 - lr: 1.5749e-06
# Epoch 149/200
# 112/112 [==============================] - 7s 67ms/step - loss: 0.5537 - accuracy: 0.7430 - val_loss: 0.5549 - val_accuracy: 0.7191 - lr: 1.5749e-06
# Epoch 150/200
# 112/112 [==============================] - 8s 67ms/step - loss: 0.5522 - accuracy: 0.7306 - val_loss: 0.5584 - val_accuracy: 0.7124 - lr: 1.5749e-06
# Epoch 151/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5578 - accuracy: 0.7396 - val_loss: 0.5488 - val_accuracy: 0.7213 - lr: 1.5749e-06
# Epoch 152/200
# 112/112 [==============================] - 8s 68ms/step - loss: 0.5509 - accuracy: 0.7497 - val_loss: 0.5540 - val_accuracy: 0.7169 - lr: 1.5749e-06
# Epoch 153/200
# 112/112 [==============================] - 8s 72ms/step - loss: 0.5482 - accuracy: 0.7435 - val_loss: 0.5567 - val_accuracy: 0.7146 - lr: 1.5749e-06
# Epoch 154/200
# 111/112 [============================>.] - ETA: 0s - loss: 0.5497 - accuracy: 0.7517
# Epoch 154: ReduceLROnPlateau reducing learning rate to 1.2499999599010794e-06.
# 112/112 [==============================] - 9s 76ms/step - loss: 0.5496 - accuracy: 0.7514 - val_loss: 0.5599 - val_accuracy: 0.7124 - lr: 1.5749e-06
# Epoch 155/200
# 112/112 [==============================] - 8s 71ms/step - loss: 0.5556 - accuracy: 0.7334 - val_loss: 0.5581 - val_accuracy: 0.7124 - lr: 1.2500e-06
# Epoch 156/200
# 112/112 [==============================] - 8s 71ms/step - loss: 0.5506 - accuracy: 0.7407 - val_loss: 0.5571 - val_accuracy: 0.7124 - lr: 1.2500e-06
# Epoch 157/200
# 112/112 [==============================] - 8s 71ms/step - loss: 0.5486 - accuracy: 0.7413 - val_loss: 0.5564 - val_accuracy: 0.7124 - lr: 1.2500e-06
# Epoch 158/200
# 112/112 [==============================] - 8s 69ms/step - loss: 0.5482 - accuracy: 0.7452 - val_loss: 0.5574 - val_accuracy: 0.7124 - lr: 1.2500e-06
# Epoch 159/200
# 112/112 [==============================] - 8s 68ms/step - loss: 0.5489 - accuracy: 0.7452 - val_loss: 0.5563 - val_accuracy: 0.7124 - lr: 1.2500e-06
# Epoch 160/200
# 112/112 [==============================] - 8s 68ms/step - loss: 0.5489 - accuracy: 0.7390 - val_loss: 0.5552 - val_accuracy: 0.7169 - lr: 1.2500e-06
# Epoch 161/200
# 112/112 [==============================] - 8s 69ms/step - loss: 0.5508 - accuracy: 0.7447 - val_loss: 0.5578 - val_accuracy: 0.7124 - lr: 1.2500e-06
# Epoch 162/200
# 112/112 [==============================] - 8s 69ms/step - loss: 0.5507 - accuracy: 0.7402 - val_loss: 0.5604 - val_accuracy: 0.7124 - lr: 1.2500e-06
# Epoch 163/200
# 112/112 [==============================] - 8s 71ms/step - loss: 0.5543 - accuracy: 0.7396 - val_loss: 0.5578 - val_accuracy: 0.7124 - lr: 1.2500e-06
# Epoch 164/200
# 112/112 [==============================] - 8s 70ms/step - loss: 0.5497 - accuracy: 0.7458 - val_loss: 0.5626 - val_accuracy: 0.7124 - lr: 1.2500e-06
# Epoch 165/200
# 112/112 [==============================] - 8s 67ms/step - loss: 0.5468 - accuracy: 0.7520 - val_loss: 0.5595 - val_accuracy: 0.7124 - lr: 1.2500e-06
# Epoch 166/200
# 112/112 [==============================] - 7s 65ms/step - loss: 0.5478 - accuracy: 0.7435 - val_loss: 0.5558 - val_accuracy: 0.7169 - lr: 1.2500e-06
# Epoch 167/200
# 112/112 [==============================] - 7s 63ms/step - loss: 0.5503 - accuracy: 0.7396 - val_loss: 0.5546 - val_accuracy: 0.7169 - lr: 1.2500e-06
# Epoch 168/200
# 112/112 [==============================] - 7s 63ms/step - loss: 0.5482 - accuracy: 0.7452 - val_loss: 0.5540 - val_accuracy: 0.7169 - lr: 1.2500e-06
# Epoch 169/200
# 111/112 [============================>.] - ETA: 0s - loss: 0.5527 - accuracy: 0.7387
# Epoch 169: ReduceLROnPlateau reducing learning rate to 1e-06.
# 112/112 [==============================] - 7s 65ms/step - loss: 0.5527 - accuracy: 0.7385 - val_loss: 0.5541 - val_accuracy: 0.7146 - lr: 1.2500e-06
# Epoch 170/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5436 - accuracy: 0.7396 - val_loss: 0.5563 - val_accuracy: 0.7124 - lr: 1.0000e-06
# Epoch 171/200
# 112/112 [==============================] - 7s 65ms/step - loss: 0.5511 - accuracy: 0.7441 - val_loss: 0.5518 - val_accuracy: 0.7146 - lr: 1.0000e-06
# Epoch 172/200
# 112/112 [==============================] - 7s 67ms/step - loss: 0.5562 - accuracy: 0.7385 - val_loss: 0.5536 - val_accuracy: 0.7191 - lr: 1.0000e-06
# Epoch 173/200
# 112/112 [==============================] - 7s 65ms/step - loss: 0.5468 - accuracy: 0.7435 - val_loss: 0.5585 - val_accuracy: 0.7124 - lr: 1.0000e-06
# Epoch 174/200
# 112/112 [==============================] - 7s 65ms/step - loss: 0.5497 - accuracy: 0.7463 - val_loss: 0.5570 - val_accuracy: 0.7124 - lr: 1.0000e-06
# Epoch 175/200
# 112/112 [==============================] - 7s 65ms/step - loss: 0.5487 - accuracy: 0.7334 - val_loss: 0.5582 - val_accuracy: 0.7124 - lr: 1.0000e-06
# Epoch 176/200
# 112/112 [==============================] - 7s 67ms/step - loss: 0.5443 - accuracy: 0.7430 - val_loss: 0.5565 - val_accuracy: 0.7124 - lr: 1.0000e-06
# Epoch 177/200
# 112/112 [==============================] - 8s 68ms/step - loss: 0.5448 - accuracy: 0.7503 - val_loss: 0.5574 - val_accuracy: 0.7124 - lr: 1.0000e-06
# Epoch 178/200
# 112/112 [==============================] - 7s 67ms/step - loss: 0.5497 - accuracy: 0.7328 - val_loss: 0.5543 - val_accuracy: 0.7169 - lr: 1.0000e-06
# Epoch 179/200
# 112/112 [==============================] - 7s 67ms/step - loss: 0.5462 - accuracy: 0.7385 - val_loss: 0.5552 - val_accuracy: 0.7124 - lr: 1.0000e-06
# Epoch 180/200
# 112/112 [==============================] - 8s 68ms/step - loss: 0.5486 - accuracy: 0.7345 - val_loss: 0.5572 - val_accuracy: 0.7124 - lr: 1.0000e-06
# Epoch 181/200
# 112/112 [==============================] - 8s 68ms/step - loss: 0.5494 - accuracy: 0.7413 - val_loss: 0.5564 - val_accuracy: 0.7124 - lr: 1.0000e-06
# Epoch 182/200
# 112/112 [==============================] - 7s 67ms/step - loss: 0.5473 - accuracy: 0.7441 - val_loss: 0.5576 - val_accuracy: 0.7124 - lr: 1.0000e-06
# Epoch 183/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5522 - accuracy: 0.7362 - val_loss: 0.5574 - val_accuracy: 0.7124 - lr: 1.0000e-06
# Epoch 184/200
# 112/112 [==============================] - 7s 67ms/step - loss: 0.5482 - accuracy: 0.7452 - val_loss: 0.5567 - val_accuracy: 0.7124 - lr: 1.0000e-06
# Epoch 185/200
# 112/112 [==============================] - 7s 67ms/step - loss: 0.5522 - accuracy: 0.7407 - val_loss: 0.5559 - val_accuracy: 0.7169 - lr: 1.0000e-06
# Epoch 186/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5513 - accuracy: 0.7390 - val_loss: 0.5517 - val_accuracy: 0.7124 - lr: 1.0000e-06
# Epoch 187/200
# 112/112 [==============================] - 7s 65ms/step - loss: 0.5418 - accuracy: 0.7542 - val_loss: 0.5543 - val_accuracy: 0.7191 - lr: 1.0000e-06
# Epoch 188/200
# 112/112 [==============================] - 7s 65ms/step - loss: 0.5523 - accuracy: 0.7368 - val_loss: 0.5547 - val_accuracy: 0.7169 - lr: 1.0000e-06
# Epoch 189/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5458 - accuracy: 0.7418 - val_loss: 0.5561 - val_accuracy: 0.7124 - lr: 1.0000e-06
# Epoch 190/200
# 112/112 [==============================] - 7s 65ms/step - loss: 0.5520 - accuracy: 0.7430 - val_loss: 0.5574 - val_accuracy: 0.7124 - lr: 1.0000e-06
# Epoch 191/200
# 112/112 [==============================] - 7s 65ms/step - loss: 0.5470 - accuracy: 0.7402 - val_loss: 0.5565 - val_accuracy: 0.7124 - lr: 1.0000e-06
# Epoch 192/200
# 112/112 [==============================] - 7s 65ms/step - loss: 0.5434 - accuracy: 0.7492 - val_loss: 0.5566 - val_accuracy: 0.7124 - lr: 1.0000e-06
# Epoch 193/200
# 112/112 [==============================] - 8s 67ms/step - loss: 0.5527 - accuracy: 0.7272 - val_loss: 0.5548 - val_accuracy: 0.7146 - lr: 1.0000e-06
# Epoch 194/200
# 112/112 [==============================] - 7s 65ms/step - loss: 0.5432 - accuracy: 0.7503 - val_loss: 0.5574 - val_accuracy: 0.7124 - lr: 1.0000e-06
# Epoch 195/200
# 112/112 [==============================] - 7s 65ms/step - loss: 0.5493 - accuracy: 0.7480 - val_loss: 0.5577 - val_accuracy: 0.7124 - lr: 1.0000e-06
# Epoch 196/200
# 112/112 [==============================] - 7s 65ms/step - loss: 0.5437 - accuracy: 0.7475 - val_loss: 0.5595 - val_accuracy: 0.7124 - lr: 1.0000e-06
# Epoch 197/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5483 - accuracy: 0.7430 - val_loss: 0.5564 - val_accuracy: 0.7124 - lr: 1.0000e-06
# Epoch 198/200
# 112/112 [==============================] - 7s 66ms/step - loss: 0.5490 - accuracy: 0.7278 - val_loss: 0.5551 - val_accuracy: 0.7169 - lr: 1.0000e-06
# Epoch 199/200
# 112/112 [==============================] - 8s 68ms/step - loss: 0.5524 - accuracy: 0.7351 - val_loss: 0.5534 - val_accuracy: 0.7146 - lr: 1.0000e-06
# Epoch 200/200
# 112/112 [==============================] - 8s 67ms/step - loss: 0.5553 - accuracy: 0.7317 - val_loss: 0.5535 - val_accuracy: 0.7146 - lr: 1.0000e-06
# 18/18 [==============================] - 1s 19ms/step
# Test Accuracy: 0.7214
# Test F1 Score: 0.7338
# Test Precision: 0.7026
# Test Recall: 0.7679
# Test ROC AUC Score: 0.7984
