# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import accuracy_score, roc_auc_score, recall_score, precision_score, f1_score
from sklearn.metrics import confusion_matrix, precision_recall_fscore_support
import seaborn as sns
from collections import Counter
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau
import sys
sys.path.append(r'C:\Users\Mud\Desktop\2ndPaper\lstm')
from model.lstmfcn import generate_lstmfcn
from model.fcn import generate_fcn
from model.lstm import generate_lstm
from utils.class_weight import compute_class_weight
import tensorflow as tf
import random as python_random

# %%
# load the data
X_test = np.load(r'C:\Users\Mud\Desktop\2ndPaper\lstm\cultivar-specific\data\ries\X_test_ries.npy')
y_test = np.load(r'C:\Users\Mud\Desktop\2ndPaper\lstm\cultivar-specific\data\ries\y_test_ries.npy')
X_train = np.load(r'C:\Users\Mud\Desktop\2ndPaper\lstm\cultivar-specific\data\ries\X_train_ries.npy')
y_train = np.load(r'C:\Users\Mud\Desktop\2ndPaper\lstm\cultivar-specific\data\ries\y_train_ries.npy')

# # load fake data
#X_train = np.load('./fake/train/X_train.npy')
#y_train = np.load('./fake/train/y_train.npy')
#X_test = np.load('./fake/test/X_test.npy')
#y_test = np.load('./fake/test/y_test.npy')


print('X_train shape:', X_train.shape)
print('y_train shape:', y_train.shape)
print('X_test shape:', X_test.shape)
print('y_test shape:', y_test.shape)
# Out:
# X_train shape: (540, 600)
# y_train shape: (540,)
# X_test shape: (140, 600)
# y_test shape: (140,)

# %%
def reset_random_seeds(seed=42):
   np.random.seed(seed)
   python_random.seed(seed)
   tf.random.set_seed(seed)

reset_random_seeds()

# %%
# normalize the data to have same starting pt for all time series
# input shape: (n_samples, n_timepoints), want each samples - its mean of 0-30th timepts
def normalize_curves_mean_method(unnormalized_datas):
    normalized_datas = []
    for unnormalized_data in unnormalized_datas:
        mean = np.mean(unnormalized_data[:30])
        normalized_data = unnormalized_data - mean
        normalized_datas.append(normalized_data)
    normalized_datas = np.array(normalized_datas)
    assert normalized_datas.shape == unnormalized_datas.shape
    return normalized_datas

# normalize the data using z-score, have mean 0 and std 1
def normalize_curves_zscore(unnormalized_datas):
    normalized_datas = []
    for unnormalized_data in unnormalized_datas:
        mean = np.mean(unnormalized_data)
        std = np.std(unnormalized_data)
        normalized_data = (unnormalized_data - mean) / std
        normalized_datas.append(normalized_data)
    normalized_datas = np.array(normalized_datas)
    assert normalized_datas.shape == unnormalized_datas.shape
    return normalized_datas


# apply ln() to the time series data
def apply_ln_to_curves(datas):
    ln_datas = []
    for data in datas:
        ln_data = np.log(data)
        ln_datas.append(ln_data)
    ln_datas = np.array(ln_datas)
    assert ln_datas.shape == datas.shape
    return ln_datas


# split the time series data into wanted time points
def split_time_series(datas, start, end):
    datas = datas[:, start:end]
    return datas


# plot the time series data, randomly picked n samples, different colors represent different classes
def plot_random_time_series(datas, n, labels):
    for i in range(n):
        idx = np.random.randint(datas.shape[0])
        plt.plot(datas[idx], color = 'blue' if labels[idx] == 1 else 'red', alpha = 0.2)
    plt.show()


X_train = normalize_curves_mean_method(X_train)
X_test = normalize_curves_mean_method(X_test)
plot_random_time_series(X_train, 100, y_train)
# X_train = normalize_curves_zscore(X_train)
# X_test = normalize_curves_zscore(X_test)
print('X_train shape:', X_train.shape)
print('X_train range:', np.min(X_train), np.max(X_train))
print('X_test shape:', X_test.shape)
print('X_test range:', np.min(X_test), np.max(X_test))
# Out:
# X_train shape: (540, 600)
# X_train range: -27.382237339377753 890.6585034013606
# X_test shape: (140, 600)
# X_test range: -33.20770975056621 708.0417989417983

# %%
# upsample the one class in the training set by given factor
# add some level of noise to the time series data with maintaining mean & std
# class_label: 1 is alive, 0 is dead
def data_augmentation(X_train, y_train, n_times, class_label=1, random_seed=42):
    np.random.seed(random_seed)
    X_train_augmented = X_train.copy()
    y_train_augmented = y_train.copy()
    for i in range(len(y_train)):
        if y_train[i] == class_label:
            for _ in range(n_times):
                X_train_augmented = np.concatenate((X_train_augmented, [X_train[i] + np.random.normal(0, 0.1, X_train[i].shape)]), axis=0)
                y_train_augmented = np.concatenate((y_train_augmented, [y_train[i]]), axis=0)
    return X_train_augmented, y_train_augmented



print('Before, Class ratio:', Counter(y_train))
#X_train, y_train = data_augmentation(X_train, y_train, 10, class_label=0)
#X_train, y_train = data_augmentation(X_train, y_train, 4, class_label=1)
print('After, Class ratio:', Counter(y_train))
# Out:
# Before, Class ratio: Counter({1: 395, 0: 145})
# After, Class ratio: Counter({1: 395, 0: 145})

# %%
# compute mean & std of the training set, then normalize the whole dataset using z-normalization
mean = np.mean(X_train)
std = np.std(X_train)
#X_train = (X_train - mean) / std
#X_test = (X_test - mean) / std

# %%
# Ensure data is shaped correctly
X_train = X_train.reshape(-1, 1, 600)  # Convert to (samples, 1, timesteps)
X_test = X_test.reshape(-1, 1, 600)
y_train = y_train.reshape(-1, 1)  # Ensure labels are in shape (samples, 1)
y_test = y_test.reshape(-1, 1)

print('X_train shape:', X_train.shape)
print('y_train shape:', y_train.shape)
print('X_test shape:', X_test.shape)
print('y_test shape:', y_test.shape)
# Out:
# X_train shape: (540, 1, 600)
# y_train shape: (540, 1)
# X_test shape: (140, 1, 600)
# y_test shape: (140, 1)

# %%
# Train final model on full training data# Initialize model
final_model = generate_lstmfcn(dropout=0.0)
class_weights = compute_class_weight(y_train)
print('class_weights:', class_weights)
reduce_lr = ReduceLROnPlateau(monitor='loss', patience=15, mode='auto',
    factor=1. / np.cbrt(2), cooldown=0, min_lr=1e-6, verbose=2)
final_model.compile(optimizer=Adam(learning_rate=5e-6), loss='binary_crossentropy', metrics=['accuracy'])

# split the data into training and validation set
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# Train model
history = final_model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    callbacks=[reduce_lr],
    epochs=200, batch_size=16, class_weight={0: class_weights[0], 1: class_weights[1]},
    verbose=1
)

# Predict on test set
y_pred_prob = final_model.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)

# Calculate metrics
accuracy = accuracy_score(y_test, y_pred)
precision, recall, f1, _ = precision_recall_fscore_support(y_test, y_pred, average='binary')
roc_auc = roc_auc_score(y_test, y_pred_prob)
conf_matrix = confusion_matrix(y_test, y_pred)

# plot the metrics
print(f"Test Accuracy: {accuracy:.4f}")
print(f"Test F1 Score: {f1:.4f}")
print(f"Test Precision: {precision:.4f}")
print(f"Test Recall: {recall:.4f}")
print(f"Test ROC AUC Score: {roc_auc:.4f}")
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Dead', 'Alive'], yticklabels=['Dead', 'Alive'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()


# plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.figure(figsize=(10, 7))
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.figure(figsize=(10, 7))
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# class_weights: [1.86206897 0.6835443 ]
# Epoch 1/200
# 27/27 [==============================] - 24s 277ms/step - loss: 0.7662 - accuracy: 0.7222 - val_loss: 0.8186 - val_accuracy: 0.7685 - lr: 5.0000e-06
# Epoch 2/200
# 27/27 [==============================] - 3s 125ms/step - loss: 0.7130 - accuracy: 0.7245 - val_loss: 0.6268 - val_accuracy: 0.7685 - lr: 5.0000e-06
# Epoch 3/200
# 27/27 [==============================] - 3s 122ms/step - loss: 0.6760 - accuracy: 0.7361 - val_loss: 0.6529 - val_accuracy: 0.7593 - lr: 5.0000e-06
# Epoch 4/200
# 27/27 [==============================] - 3s 121ms/step - loss: 0.6504 - accuracy: 0.7824 - val_loss: 0.6776 - val_accuracy: 0.5833 - lr: 5.0000e-06
# Epoch 5/200
# 27/27 [==============================] - 3s 125ms/step - loss: 0.6279 - accuracy: 0.7940 - val_loss: 0.6787 - val_accuracy: 0.5278 - lr: 5.0000e-06
# Epoch 6/200
# 27/27 [==============================] - 3s 124ms/step - loss: 0.6068 - accuracy: 0.7847 - val_loss: 0.6688 - val_accuracy: 0.5463 - lr: 5.0000e-06
# Epoch 7/200
# 27/27 [==============================] - 3s 123ms/step - loss: 0.5902 - accuracy: 0.7778 - val_loss: 0.6522 - val_accuracy: 0.6204 - lr: 5.0000e-06
# Epoch 8/200
# 27/27 [==============================] - 3s 126ms/step - loss: 0.5876 - accuracy: 0.7708 - val_loss: 0.6345 - val_accuracy: 0.6759 - lr: 5.0000e-06
# Epoch 9/200
# 27/27 [==============================] - 3s 123ms/step - loss: 0.5691 - accuracy: 0.7801 - val_loss: 0.6192 - val_accuracy: 0.6944 - lr: 5.0000e-06
# Epoch 10/200
# 27/27 [==============================] - 3s 121ms/step - loss: 0.5648 - accuracy: 0.7593 - val_loss: 0.5997 - val_accuracy: 0.7407 - lr: 5.0000e-06
# Epoch 11/200
# 27/27 [==============================] - 3s 123ms/step - loss: 0.5608 - accuracy: 0.7569 - val_loss: 0.5850 - val_accuracy: 0.7407 - lr: 5.0000e-06
# Epoch 12/200
# 27/27 [==============================] - 3s 118ms/step - loss: 0.5632 - accuracy: 0.7755 - val_loss: 0.5686 - val_accuracy: 0.7593 - lr: 5.0000e-06
# Epoch 13/200
# 27/27 [==============================] - 3s 122ms/step - loss: 0.5578 - accuracy: 0.7569 - val_loss: 0.5575 - val_accuracy: 0.7593 - lr: 5.0000e-06
# Epoch 14/200
# 27/27 [==============================] - 3s 127ms/step - loss: 0.5496 - accuracy: 0.7731 - val_loss: 0.5442 - val_accuracy: 0.7778 - lr: 5.0000e-06
# Epoch 15/200
# 27/27 [==============================] - 6s 219ms/step - loss: 0.5531 - accuracy: 0.7477 - val_loss: 0.5361 - val_accuracy: 0.7870 - lr: 5.0000e-06
# Epoch 16/200
# 27/27 [==============================] - 9s 350ms/step - loss: 0.5543 - accuracy: 0.7639 - val_loss: 0.5275 - val_accuracy: 0.7870 - lr: 5.0000e-06
# Epoch 17/200
# 27/27 [==============================] - 9s 352ms/step - loss: 0.5436 - accuracy: 0.7593 - val_loss: 0.5231 - val_accuracy: 0.7870 - lr: 5.0000e-06
# Epoch 18/200
# 27/27 [==============================] - 9s 341ms/step - loss: 0.5417 - accuracy: 0.7755 - val_loss: 0.5149 - val_accuracy: 0.8148 - lr: 5.0000e-06
# Epoch 19/200
# 27/27 [==============================] - 4s 138ms/step - loss: 0.5521 - accuracy: 0.7407 - val_loss: 0.5121 - val_accuracy: 0.8148 - lr: 5.0000e-06
# Epoch 20/200
# 27/27 [==============================] - 3s 121ms/step - loss: 0.5671 - accuracy: 0.7407 - val_loss: 0.5089 - val_accuracy: 0.8148 - lr: 5.0000e-06
# Epoch 21/200
# 27/27 [==============================] - 3s 124ms/step - loss: 0.5416 - accuracy: 0.7616 - val_loss: 0.5045 - val_accuracy: 0.8148 - lr: 5.0000e-06
# Epoch 22/200
# 27/27 [==============================] - 3s 125ms/step - loss: 0.5398 - accuracy: 0.7593 - val_loss: 0.5041 - val_accuracy: 0.8148 - lr: 5.0000e-06
# Epoch 23/200
# 27/27 [==============================] - 3s 116ms/step - loss: 0.5362 - accuracy: 0.7616 - val_loss: 0.5039 - val_accuracy: 0.8148 - lr: 5.0000e-06
# Epoch 24/200
# 27/27 [==============================] - 3s 124ms/step - loss: 0.5391 - accuracy: 0.7500 - val_loss: 0.5049 - val_accuracy: 0.8148 - lr: 5.0000e-06
# Epoch 25/200
# 27/27 [==============================] - 3s 123ms/step - loss: 0.5409 - accuracy: 0.7407 - val_loss: 0.5037 - val_accuracy: 0.8148 - lr: 5.0000e-06
# Epoch 26/200
# 27/27 [==============================] - 3s 116ms/step - loss: 0.5353 - accuracy: 0.7454 - val_loss: 0.5041 - val_accuracy: 0.8148 - lr: 5.0000e-06
# Epoch 27/200
# 27/27 [==============================] - 3s 120ms/step - loss: 0.5384 - accuracy: 0.7685 - val_loss: 0.5055 - val_accuracy: 0.8148 - lr: 5.0000e-06
# Epoch 28/200
# 27/27 [==============================] - 3s 121ms/step - loss: 0.5442 - accuracy: 0.7431 - val_loss: 0.5016 - val_accuracy: 0.8148 - lr: 5.0000e-06
# Epoch 29/200
# 27/27 [==============================] - 3s 124ms/step - loss: 0.5340 - accuracy: 0.7500 - val_loss: 0.5037 - val_accuracy: 0.8148 - lr: 5.0000e-06
# Epoch 30/200
# 27/27 [==============================] - 3s 124ms/step - loss: 0.5475 - accuracy: 0.7593 - val_loss: 0.5012 - val_accuracy: 0.8148 - lr: 5.0000e-06
# Epoch 31/200
# 27/27 [==============================] - 3s 122ms/step - loss: 0.5386 - accuracy: 0.7407 - val_loss: 0.5000 - val_accuracy: 0.8148 - lr: 5.0000e-06
# Epoch 32/200
# 27/27 [==============================] - 3s 124ms/step - loss: 0.5389 - accuracy: 0.7338 - val_loss: 0.5079 - val_accuracy: 0.8148 - lr: 5.0000e-06
# Epoch 33/200
# 27/27 [==============================] - 3s 121ms/step - loss: 0.5455 - accuracy: 0.7338 - val_loss: 0.5080 - val_accuracy: 0.8148 - lr: 5.0000e-06
# Epoch 34/200
# 27/27 [==============================] - 3s 118ms/step - loss: 0.5218 - accuracy: 0.7662 - val_loss: 0.5045 - val_accuracy: 0.8148 - lr: 5.0000e-06
# Epoch 35/200
# 27/27 [==============================] - 3s 121ms/step - loss: 0.5326 - accuracy: 0.7616 - val_loss: 0.5025 - val_accuracy: 0.8148 - lr: 5.0000e-06
# Epoch 36/200
# 27/27 [==============================] - 3s 125ms/step - loss: 0.5186 - accuracy: 0.7662 - val_loss: 0.5016 - val_accuracy: 0.8148 - lr: 5.0000e-06
# Epoch 37/200
# 27/27 [==============================] - 3s 115ms/step - loss: 0.5461 - accuracy: 0.7361 - val_loss: 0.5046 - val_accuracy: 0.8148 - lr: 5.0000e-06
# Epoch 38/200
# 27/27 [==============================] - 3s 118ms/step - loss: 0.5460 - accuracy: 0.7292 - val_loss: 0.5005 - val_accuracy: 0.8148 - lr: 5.0000e-06
# Epoch 39/200
# 27/27 [==============================] - 3s 120ms/step - loss: 0.5335 - accuracy: 0.7546 - val_loss: 0.5003 - val_accuracy: 0.8148 - lr: 5.0000e-06
# Epoch 40/200
# 27/27 [==============================] - 3s 116ms/step - loss: 0.5378 - accuracy: 0.7616 - val_loss: 0.5061 - val_accuracy: 0.8148 - lr: 5.0000e-06
# Epoch 41/200
# 27/27 [==============================] - 3s 115ms/step - loss: 0.5458 - accuracy: 0.7361 - val_loss: 0.5043 - val_accuracy: 0.8148 - lr: 5.0000e-06
# Epoch 42/200
# 27/27 [==============================] - 3s 125ms/step - loss: 0.5402 - accuracy: 0.7616 - val_loss: 0.5062 - val_accuracy: 0.8148 - lr: 5.0000e-06
# Epoch 43/200
# 27/27 [==============================] - 3s 121ms/step - loss: 0.5336 - accuracy: 0.7454 - val_loss: 0.5060 - val_accuracy: 0.8148 - lr: 5.0000e-06
# Epoch 44/200
# 27/27 [==============================] - 3s 119ms/step - loss: 0.5463 - accuracy: 0.7361 - val_loss: 0.5001 - val_accuracy: 0.8148 - lr: 5.0000e-06
# Epoch 45/200
# 27/27 [==============================] - 3s 125ms/step - loss: 0.5330 - accuracy: 0.7431 - val_loss: 0.5002 - val_accuracy: 0.8148 - lr: 5.0000e-06
# Epoch 46/200
# 27/27 [==============================] - 3s 122ms/step - loss: 0.5348 - accuracy: 0.7338 - val_loss: 0.4990 - val_accuracy: 0.8148 - lr: 5.0000e-06
# Epoch 47/200
# 27/27 [==============================] - 3s 119ms/step - loss: 0.5386 - accuracy: 0.7292 - val_loss: 0.5012 - val_accuracy: 0.8148 - lr: 5.0000e-06
# Epoch 48/200
# 27/27 [==============================] - 3s 118ms/step - loss: 0.5267 - accuracy: 0.7546 - val_loss: 0.5047 - val_accuracy: 0.8148 - lr: 5.0000e-06
# Epoch 49/200
# 27/27 [==============================] - 3s 124ms/step - loss: 0.5340 - accuracy: 0.7477 - val_loss: 0.5035 - val_accuracy: 0.8148 - lr: 5.0000e-06
# Epoch 50/200
# 27/27 [==============================] - 3s 123ms/step - loss: 0.5411 - accuracy: 0.7361 - val_loss: 0.5056 - val_accuracy: 0.8148 - lr: 5.0000e-06
# Epoch 51/200
# 27/27 [==============================] - ETA: 0s - loss: 0.5232 - accuracy: 0.7407
# Epoch 51: ReduceLROnPlateau reducing learning rate to 3.968502529667691e-06.
# 27/27 [==============================] - 3s 119ms/step - loss: 0.5232 - accuracy: 0.7407 - val_loss: 0.5074 - val_accuracy: 0.8056 - lr: 5.0000e-06
# Epoch 52/200
# 27/27 [==============================] - 3s 122ms/step - loss: 0.5297 - accuracy: 0.7338 - val_loss: 0.5027 - val_accuracy: 0.8148 - lr: 3.9685e-06
# Epoch 53/200
# 27/27 [==============================] - 3s 121ms/step - loss: 0.5290 - accuracy: 0.7500 - val_loss: 0.5029 - val_accuracy: 0.8148 - lr: 3.9685e-06
# Epoch 54/200
# 27/27 [==============================] - 3s 117ms/step - loss: 0.5324 - accuracy: 0.7431 - val_loss: 0.5072 - val_accuracy: 0.7963 - lr: 3.9685e-06
# Epoch 55/200
# 27/27 [==============================] - 3s 123ms/step - loss: 0.5386 - accuracy: 0.7269 - val_loss: 0.5001 - val_accuracy: 0.8148 - lr: 3.9685e-06
# Epoch 56/200
# 27/27 [==============================] - 3s 121ms/step - loss: 0.5320 - accuracy: 0.7616 - val_loss: 0.5031 - val_accuracy: 0.8148 - lr: 3.9685e-06
# Epoch 57/200
# 27/27 [==============================] - 3s 119ms/step - loss: 0.5343 - accuracy: 0.7546 - val_loss: 0.5030 - val_accuracy: 0.8148 - lr: 3.9685e-06
# Epoch 58/200
# 27/27 [==============================] - 3s 124ms/step - loss: 0.5189 - accuracy: 0.7477 - val_loss: 0.5069 - val_accuracy: 0.7963 - lr: 3.9685e-06
# Epoch 59/200
# 27/27 [==============================] - 3s 120ms/step - loss: 0.5393 - accuracy: 0.7546 - val_loss: 0.5051 - val_accuracy: 0.8148 - lr: 3.9685e-06
# Epoch 60/200
# 27/27 [==============================] - 3s 125ms/step - loss: 0.5331 - accuracy: 0.7315 - val_loss: 0.5050 - val_accuracy: 0.8148 - lr: 3.9685e-06
# Epoch 61/200
# 27/27 [==============================] - 3s 119ms/step - loss: 0.5421 - accuracy: 0.7431 - val_loss: 0.5031 - val_accuracy: 0.8148 - lr: 3.9685e-06
# Epoch 62/200
# 27/27 [==============================] - 3s 122ms/step - loss: 0.5271 - accuracy: 0.7546 - val_loss: 0.5003 - val_accuracy: 0.8148 - lr: 3.9685e-06
# Epoch 63/200
# 27/27 [==============================] - 3s 122ms/step - loss: 0.5315 - accuracy: 0.7384 - val_loss: 0.5066 - val_accuracy: 0.8056 - lr: 3.9685e-06
# Epoch 64/200
# 27/27 [==============================] - 3s 123ms/step - loss: 0.5355 - accuracy: 0.7477 - val_loss: 0.5002 - val_accuracy: 0.8148 - lr: 3.9685e-06
# Epoch 65/200
# 27/27 [==============================] - 3s 123ms/step - loss: 0.5345 - accuracy: 0.7384 - val_loss: 0.5002 - val_accuracy: 0.8148 - lr: 3.9685e-06
# Epoch 66/200
# 27/27 [==============================] - ETA: 0s - loss: 0.5267 - accuracy: 0.7384
# Epoch 66: ReduceLROnPlateau reducing learning rate to 3.1498024179533314e-06.
# 27/27 [==============================] - 3s 119ms/step - loss: 0.5267 - accuracy: 0.7384 - val_loss: 0.5060 - val_accuracy: 0.8148 - lr: 3.9685e-06
# Epoch 67/200
# 27/27 [==============================] - 3s 124ms/step - loss: 0.5225 - accuracy: 0.7546 - val_loss: 0.5033 - val_accuracy: 0.8148 - lr: 3.1498e-06
# Epoch 68/200
# 27/27 [==============================] - 3s 122ms/step - loss: 0.5419 - accuracy: 0.7546 - val_loss: 0.4975 - val_accuracy: 0.8148 - lr: 3.1498e-06
# Epoch 69/200
# 27/27 [==============================] - 3s 119ms/step - loss: 0.5332 - accuracy: 0.7338 - val_loss: 0.4984 - val_accuracy: 0.8148 - lr: 3.1498e-06
# Epoch 70/200
# 27/27 [==============================] - 3s 121ms/step - loss: 0.5271 - accuracy: 0.7639 - val_loss: 0.5007 - val_accuracy: 0.8148 - lr: 3.1498e-06
# Epoch 71/200
# 27/27 [==============================] - 3s 125ms/step - loss: 0.5303 - accuracy: 0.7546 - val_loss: 0.5010 - val_accuracy: 0.8148 - lr: 3.1498e-06
# Epoch 72/200
# 27/27 [==============================] - 3s 103ms/step - loss: 0.5292 - accuracy: 0.7616 - val_loss: 0.4964 - val_accuracy: 0.8148 - lr: 3.1498e-06
# Epoch 73/200
# 27/27 [==============================] - 3s 96ms/step - loss: 0.5204 - accuracy: 0.7431 - val_loss: 0.4992 - val_accuracy: 0.8148 - lr: 3.1498e-06
# Epoch 74/200
# 27/27 [==============================] - 3s 94ms/step - loss: 0.5433 - accuracy: 0.7384 - val_loss: 0.5029 - val_accuracy: 0.8148 - lr: 3.1498e-06
# Epoch 75/200
# 27/27 [==============================] - 3s 95ms/step - loss: 0.5265 - accuracy: 0.7431 - val_loss: 0.5001 - val_accuracy: 0.8148 - lr: 3.1498e-06
# Epoch 76/200
# 27/27 [==============================] - 3s 94ms/step - loss: 0.5262 - accuracy: 0.7500 - val_loss: 0.4981 - val_accuracy: 0.8148 - lr: 3.1498e-06
# Epoch 77/200
# 27/27 [==============================] - 3s 97ms/step - loss: 0.5166 - accuracy: 0.7731 - val_loss: 0.5005 - val_accuracy: 0.8148 - lr: 3.1498e-06
# Epoch 78/200
# 27/27 [==============================] - 3s 96ms/step - loss: 0.5225 - accuracy: 0.7523 - val_loss: 0.5034 - val_accuracy: 0.8148 - lr: 3.1498e-06
# Epoch 79/200
# 27/27 [==============================] - 3s 93ms/step - loss: 0.5338 - accuracy: 0.7384 - val_loss: 0.5028 - val_accuracy: 0.8148 - lr: 3.1498e-06
# Epoch 80/200
# 27/27 [==============================] - 3s 95ms/step - loss: 0.5175 - accuracy: 0.7477 - val_loss: 0.5066 - val_accuracy: 0.7963 - lr: 3.1498e-06
# Epoch 81/200
# 27/27 [==============================] - 3s 95ms/step - loss: 0.5277 - accuracy: 0.7500 - val_loss: 0.5069 - val_accuracy: 0.7963 - lr: 3.1498e-06
# Epoch 82/200
# 27/27 [==============================] - 3s 94ms/step - loss: 0.5389 - accuracy: 0.7338 - val_loss: 0.5014 - val_accuracy: 0.8148 - lr: 3.1498e-06
# Epoch 83/200
# 27/27 [==============================] - 6s 241ms/step - loss: 0.5408 - accuracy: 0.7269 - val_loss: 0.5001 - val_accuracy: 0.8148 - lr: 3.1498e-06
# Epoch 84/200
# 27/27 [==============================] - 3s 123ms/step - loss: 0.5268 - accuracy: 0.7338 - val_loss: 0.4998 - val_accuracy: 0.8148 - lr: 3.1498e-06
# Epoch 85/200
# 27/27 [==============================] - 3s 101ms/step - loss: 0.5238 - accuracy: 0.7569 - val_loss: 0.5009 - val_accuracy: 0.8148 - lr: 3.1498e-06
# Epoch 86/200
# 27/27 [==============================] - 3s 94ms/step - loss: 0.5391 - accuracy: 0.7500 - val_loss: 0.5010 - val_accuracy: 0.8148 - lr: 3.1498e-06
# Epoch 87/200
# 27/27 [==============================] - 3s 99ms/step - loss: 0.5293 - accuracy: 0.7569 - val_loss: 0.4964 - val_accuracy: 0.8148 - lr: 3.1498e-06
# Epoch 88/200
# 27/27 [==============================] - 3s 102ms/step - loss: 0.5235 - accuracy: 0.7431 - val_loss: 0.5003 - val_accuracy: 0.8148 - lr: 3.1498e-06
# Epoch 89/200
# 27/27 [==============================] - 3s 97ms/step - loss: 0.5118 - accuracy: 0.7593 - val_loss: 0.5000 - val_accuracy: 0.8148 - lr: 3.1498e-06
# Epoch 90/200
# 27/27 [==============================] - 3s 100ms/step - loss: 0.5182 - accuracy: 0.7616 - val_loss: 0.4983 - val_accuracy: 0.8148 - lr: 3.1498e-06
# Epoch 91/200
# 27/27 [==============================] - 3s 98ms/step - loss: 0.5299 - accuracy: 0.7431 - val_loss: 0.4957 - val_accuracy: 0.8148 - lr: 3.1498e-06
# Epoch 92/200
# 27/27 [==============================] - 3s 97ms/step - loss: 0.5166 - accuracy: 0.7662 - val_loss: 0.4994 - val_accuracy: 0.8148 - lr: 3.1498e-06
# Epoch 93/200
# 27/27 [==============================] - 3s 103ms/step - loss: 0.5306 - accuracy: 0.7454 - val_loss: 0.4989 - val_accuracy: 0.8148 - lr: 3.1498e-06
# Epoch 94/200
# 27/27 [==============================] - 3s 99ms/step - loss: 0.5254 - accuracy: 0.7523 - val_loss: 0.5033 - val_accuracy: 0.8056 - lr: 3.1498e-06
# Epoch 95/200
# 27/27 [==============================] - 3s 98ms/step - loss: 0.5211 - accuracy: 0.7477 - val_loss: 0.5051 - val_accuracy: 0.7963 - lr: 3.1498e-06
# Epoch 96/200
# 27/27 [==============================] - 3s 97ms/step - loss: 0.5301 - accuracy: 0.7523 - val_loss: 0.4995 - val_accuracy: 0.8148 - lr: 3.1498e-06
# Epoch 97/200
# 27/27 [==============================] - 3s 106ms/step - loss: 0.5317 - accuracy: 0.7361 - val_loss: 0.4967 - val_accuracy: 0.8148 - lr: 3.1498e-06
# Epoch 98/200
# 27/27 [==============================] - 3s 107ms/step - loss: 0.5269 - accuracy: 0.7546 - val_loss: 0.4950 - val_accuracy: 0.8148 - lr: 3.1498e-06
# Epoch 99/200
# 27/27 [==============================] - 3s 98ms/step - loss: 0.5172 - accuracy: 0.7616 - val_loss: 0.4980 - val_accuracy: 0.8148 - lr: 3.1498e-06
# Epoch 100/200
# 27/27 [==============================] - 3s 96ms/step - loss: 0.5177 - accuracy: 0.7477 - val_loss: 0.5029 - val_accuracy: 0.8148 - lr: 3.1498e-06
# Epoch 101/200
# 27/27 [==============================] - 3s 95ms/step - loss: 0.5235 - accuracy: 0.7569 - val_loss: 0.5030 - val_accuracy: 0.8148 - lr: 3.1498e-06
# Epoch 102/200
# 27/27 [==============================] - 3s 96ms/step - loss: 0.5371 - accuracy: 0.7523 - val_loss: 0.4979 - val_accuracy: 0.8148 - lr: 3.1498e-06
# Epoch 103/200
# 27/27 [==============================] - 3s 93ms/step - loss: 0.5338 - accuracy: 0.7407 - val_loss: 0.4978 - val_accuracy: 0.8148 - lr: 3.1498e-06
# Epoch 104/200
# 27/27 [==============================] - ETA: 0s - loss: 0.5153 - accuracy: 0.7708
# Epoch 104: ReduceLROnPlateau reducing learning rate to 2.499999919802159e-06.
# 27/27 [==============================] - 3s 98ms/step - loss: 0.5153 - accuracy: 0.7708 - val_loss: 0.4991 - val_accuracy: 0.8148 - lr: 3.1498e-06
# Epoch 105/200
# 27/27 [==============================] - 3s 94ms/step - loss: 0.5239 - accuracy: 0.7546 - val_loss: 0.4993 - val_accuracy: 0.8148 - lr: 2.5000e-06
# Epoch 106/200
# 27/27 [==============================] - 3s 96ms/step - loss: 0.5295 - accuracy: 0.7616 - val_loss: 0.4973 - val_accuracy: 0.8241 - lr: 2.5000e-06
# Epoch 107/200
# 27/27 [==============================] - 3s 94ms/step - loss: 0.5223 - accuracy: 0.7477 - val_loss: 0.4992 - val_accuracy: 0.8148 - lr: 2.5000e-06
# Epoch 108/200
# 27/27 [==============================] - 3s 94ms/step - loss: 0.5160 - accuracy: 0.7407 - val_loss: 0.4978 - val_accuracy: 0.8241 - lr: 2.5000e-06
# Epoch 109/200
# 27/27 [==============================] - 3s 93ms/step - loss: 0.5459 - accuracy: 0.7222 - val_loss: 0.4962 - val_accuracy: 0.8241 - lr: 2.5000e-06
# Epoch 110/200
# 27/27 [==============================] - 2s 92ms/step - loss: 0.5217 - accuracy: 0.7708 - val_loss: 0.4970 - val_accuracy: 0.8241 - lr: 2.5000e-06
# Epoch 111/200
# 27/27 [==============================] - 3s 97ms/step - loss: 0.5113 - accuracy: 0.7431 - val_loss: 0.4953 - val_accuracy: 0.8241 - lr: 2.5000e-06
# Epoch 112/200
# 27/27 [==============================] - 3s 96ms/step - loss: 0.5326 - accuracy: 0.7361 - val_loss: 0.4949 - val_accuracy: 0.8241 - lr: 2.5000e-06
# Epoch 113/200
# 27/27 [==============================] - 3s 95ms/step - loss: 0.5246 - accuracy: 0.7454 - val_loss: 0.4973 - val_accuracy: 0.8241 - lr: 2.5000e-06
# Epoch 114/200
# 27/27 [==============================] - 3s 97ms/step - loss: 0.5319 - accuracy: 0.7407 - val_loss: 0.4971 - val_accuracy: 0.8241 - lr: 2.5000e-06
# Epoch 115/200
# 27/27 [==============================] - 3s 96ms/step - loss: 0.5087 - accuracy: 0.7523 - val_loss: 0.4937 - val_accuracy: 0.8241 - lr: 2.5000e-06
# Epoch 116/200
# 27/27 [==============================] - 3s 96ms/step - loss: 0.5290 - accuracy: 0.7199 - val_loss: 0.4970 - val_accuracy: 0.8241 - lr: 2.5000e-06
# Epoch 117/200
# 27/27 [==============================] - 3s 96ms/step - loss: 0.5288 - accuracy: 0.7407 - val_loss: 0.4970 - val_accuracy: 0.8241 - lr: 2.5000e-06
# Epoch 118/200
# 27/27 [==============================] - 3s 93ms/step - loss: 0.5307 - accuracy: 0.7407 - val_loss: 0.4944 - val_accuracy: 0.8241 - lr: 2.5000e-06
# Epoch 119/200
# 27/27 [==============================] - 3s 97ms/step - loss: 0.5122 - accuracy: 0.7546 - val_loss: 0.4944 - val_accuracy: 0.8241 - lr: 2.5000e-06
# Epoch 120/200
# 27/27 [==============================] - 3s 95ms/step - loss: 0.5174 - accuracy: 0.7593 - val_loss: 0.4965 - val_accuracy: 0.8241 - lr: 2.5000e-06
# Epoch 121/200
# 27/27 [==============================] - 3s 94ms/step - loss: 0.5244 - accuracy: 0.7384 - val_loss: 0.4966 - val_accuracy: 0.8241 - lr: 2.5000e-06
# Epoch 122/200
# 27/27 [==============================] - 3s 94ms/step - loss: 0.5309 - accuracy: 0.7407 - val_loss: 0.4953 - val_accuracy: 0.8241 - lr: 2.5000e-06
# Epoch 123/200
# 27/27 [==============================] - 3s 97ms/step - loss: 0.5191 - accuracy: 0.7500 - val_loss: 0.4958 - val_accuracy: 0.8241 - lr: 2.5000e-06
# Epoch 124/200
# 27/27 [==============================] - 3s 96ms/step - loss: 0.5244 - accuracy: 0.7269 - val_loss: 0.4965 - val_accuracy: 0.8241 - lr: 2.5000e-06
# Epoch 125/200
# 27/27 [==============================] - 3s 96ms/step - loss: 0.5268 - accuracy: 0.7616 - val_loss: 0.4982 - val_accuracy: 0.8241 - lr: 2.5000e-06
# Epoch 126/200
# 27/27 [==============================] - 2s 81ms/step - loss: 0.5260 - accuracy: 0.7384 - val_loss: 0.5044 - val_accuracy: 0.8148 - lr: 2.5000e-06
# Epoch 127/200
# 27/27 [==============================] - 2s 74ms/step - loss: 0.5272 - accuracy: 0.7431 - val_loss: 0.5010 - val_accuracy: 0.8241 - lr: 2.5000e-06
# Epoch 128/200
# 27/27 [==============================] - 2s 68ms/step - loss: 0.5295 - accuracy: 0.7454 - val_loss: 0.5000 - val_accuracy: 0.8241 - lr: 2.5000e-06
# Epoch 129/200
# 27/27 [==============================] - 2s 70ms/step - loss: 0.5229 - accuracy: 0.7477 - val_loss: 0.4969 - val_accuracy: 0.8241 - lr: 2.5000e-06
# Epoch 130/200
# 27/27 [==============================] - ETA: 0s - loss: 0.5118 - accuracy: 0.7315
# Epoch 130: ReduceLROnPlateau reducing learning rate to 1.9842512648338455e-06.
# 27/27 [==============================] - 2s 72ms/step - loss: 0.5118 - accuracy: 0.7315 - val_loss: 0.4972 - val_accuracy: 0.8241 - lr: 2.5000e-06
# Epoch 131/200
# 27/27 [==============================] - 2s 72ms/step - loss: 0.5193 - accuracy: 0.7500 - val_loss: 0.4935 - val_accuracy: 0.8241 - lr: 1.9843e-06
# Epoch 132/200
# 27/27 [==============================] - 2s 70ms/step - loss: 0.5170 - accuracy: 0.7454 - val_loss: 0.4981 - val_accuracy: 0.8241 - lr: 1.9843e-06
# Epoch 133/200
# 27/27 [==============================] - 2s 73ms/step - loss: 0.5129 - accuracy: 0.7454 - val_loss: 0.5011 - val_accuracy: 0.8241 - lr: 1.9843e-06
# Epoch 134/200
# 27/27 [==============================] - 2s 70ms/step - loss: 0.5293 - accuracy: 0.7523 - val_loss: 0.4992 - val_accuracy: 0.8241 - lr: 1.9843e-06
# Epoch 135/200
# 27/27 [==============================] - 2s 72ms/step - loss: 0.5170 - accuracy: 0.7477 - val_loss: 0.4992 - val_accuracy: 0.8241 - lr: 1.9843e-06
# Epoch 136/200
# 27/27 [==============================] - 2s 69ms/step - loss: 0.5275 - accuracy: 0.7477 - val_loss: 0.4993 - val_accuracy: 0.8241 - lr: 1.9843e-06
# Epoch 137/200
# 27/27 [==============================] - 2s 72ms/step - loss: 0.5167 - accuracy: 0.7407 - val_loss: 0.4992 - val_accuracy: 0.8241 - lr: 1.9843e-06
# Epoch 138/200
# 27/27 [==============================] - 2s 70ms/step - loss: 0.5379 - accuracy: 0.7477 - val_loss: 0.4983 - val_accuracy: 0.8241 - lr: 1.9843e-06
# Epoch 139/200
# 27/27 [==============================] - 2s 70ms/step - loss: 0.5286 - accuracy: 0.7361 - val_loss: 0.4966 - val_accuracy: 0.8241 - lr: 1.9843e-06
# Epoch 140/200
# 27/27 [==============================] - 2s 70ms/step - loss: 0.5118 - accuracy: 0.7523 - val_loss: 0.5023 - val_accuracy: 0.8241 - lr: 1.9843e-06
# Epoch 141/200
# 27/27 [==============================] - 2s 69ms/step - loss: 0.5206 - accuracy: 0.7546 - val_loss: 0.5014 - val_accuracy: 0.8241 - lr: 1.9843e-06
# Epoch 142/200
# 27/27 [==============================] - 3s 123ms/step - loss: 0.5196 - accuracy: 0.7245 - val_loss: 0.4998 - val_accuracy: 0.8241 - lr: 1.9843e-06
# Epoch 143/200
# 27/27 [==============================] - 5s 170ms/step - loss: 0.5299 - accuracy: 0.7222 - val_loss: 0.5037 - val_accuracy: 0.8241 - lr: 1.9843e-06
# Epoch 144/200
# 27/27 [==============================] - 2s 70ms/step - loss: 0.5172 - accuracy: 0.7685 - val_loss: 0.4988 - val_accuracy: 0.8241 - lr: 1.9843e-06
# Epoch 145/200
# 27/27 [==============================] - ETA: 0s - loss: 0.5296 - accuracy: 0.7338
# Epoch 145: ReduceLROnPlateau reducing learning rate to 1.5749012089766657e-06.
# 27/27 [==============================] - 2s 70ms/step - loss: 0.5296 - accuracy: 0.7338 - val_loss: 0.4989 - val_accuracy: 0.8241 - lr: 1.9843e-06
# Epoch 146/200
# 27/27 [==============================] - 2s 71ms/step - loss: 0.5273 - accuracy: 0.7431 - val_loss: 0.4981 - val_accuracy: 0.8241 - lr: 1.5749e-06
# Epoch 147/200
# 27/27 [==============================] - 2s 71ms/step - loss: 0.5204 - accuracy: 0.7384 - val_loss: 0.4971 - val_accuracy: 0.8241 - lr: 1.5749e-06
# Epoch 148/200
# 27/27 [==============================] - 2s 70ms/step - loss: 0.5312 - accuracy: 0.7407 - val_loss: 0.4965 - val_accuracy: 0.8241 - lr: 1.5749e-06
# Epoch 149/200
# 27/27 [==============================] - 2s 70ms/step - loss: 0.5313 - accuracy: 0.7454 - val_loss: 0.4981 - val_accuracy: 0.8241 - lr: 1.5749e-06
# Epoch 150/200
# 27/27 [==============================] - 2s 70ms/step - loss: 0.5282 - accuracy: 0.7338 - val_loss: 0.4957 - val_accuracy: 0.8241 - lr: 1.5749e-06
# Epoch 151/200
# 27/27 [==============================] - 2s 70ms/step - loss: 0.5287 - accuracy: 0.7523 - val_loss: 0.4963 - val_accuracy: 0.8241 - lr: 1.5749e-06
# Epoch 152/200
# 27/27 [==============================] - 2s 70ms/step - loss: 0.5243 - accuracy: 0.7222 - val_loss: 0.4953 - val_accuracy: 0.8241 - lr: 1.5749e-06
# Epoch 153/200
# 27/27 [==============================] - 2s 69ms/step - loss: 0.5429 - accuracy: 0.7477 - val_loss: 0.4962 - val_accuracy: 0.8241 - lr: 1.5749e-06
# Epoch 154/200
# 27/27 [==============================] - 2s 71ms/step - loss: 0.5202 - accuracy: 0.7523 - val_loss: 0.4961 - val_accuracy: 0.8241 - lr: 1.5749e-06
# Epoch 155/200
# 27/27 [==============================] - 2s 70ms/step - loss: 0.5163 - accuracy: 0.7616 - val_loss: 0.4970 - val_accuracy: 0.8241 - lr: 1.5749e-06
# Epoch 156/200
# 27/27 [==============================] - 2s 71ms/step - loss: 0.5100 - accuracy: 0.7407 - val_loss: 0.4982 - val_accuracy: 0.8241 - lr: 1.5749e-06
# Epoch 157/200
# 27/27 [==============================] - 2s 71ms/step - loss: 0.5296 - accuracy: 0.7384 - val_loss: 0.4977 - val_accuracy: 0.8241 - lr: 1.5749e-06
# Epoch 158/200
# 27/27 [==============================] - 2s 70ms/step - loss: 0.5206 - accuracy: 0.7616 - val_loss: 0.4998 - val_accuracy: 0.8241 - lr: 1.5749e-06
# Epoch 159/200
# 27/27 [==============================] - 2s 70ms/step - loss: 0.5206 - accuracy: 0.7569 - val_loss: 0.4993 - val_accuracy: 0.8241 - lr: 1.5749e-06
# Epoch 160/200
# 27/27 [==============================] - ETA: 0s - loss: 0.5180 - accuracy: 0.7361
# Epoch 160: ReduceLROnPlateau reducing learning rate to 1.2499999599010794e-06.
# 27/27 [==============================] - 2s 69ms/step - loss: 0.5180 - accuracy: 0.7361 - val_loss: 0.4974 - val_accuracy: 0.8241 - lr: 1.5749e-06
# Epoch 161/200
# 27/27 [==============================] - 2s 68ms/step - loss: 0.5306 - accuracy: 0.7269 - val_loss: 0.4978 - val_accuracy: 0.8241 - lr: 1.2500e-06
# Epoch 162/200
# 27/27 [==============================] - 2s 69ms/step - loss: 0.5195 - accuracy: 0.7454 - val_loss: 0.4972 - val_accuracy: 0.8241 - lr: 1.2500e-06
# Epoch 163/200
# 27/27 [==============================] - 2s 68ms/step - loss: 0.5155 - accuracy: 0.7546 - val_loss: 0.4988 - val_accuracy: 0.8241 - lr: 1.2500e-06
# Epoch 164/200
# 27/27 [==============================] - 2s 71ms/step - loss: 0.5205 - accuracy: 0.7431 - val_loss: 0.4969 - val_accuracy: 0.8241 - lr: 1.2500e-06
# Epoch 165/200
# 27/27 [==============================] - 2s 70ms/step - loss: 0.5351 - accuracy: 0.7245 - val_loss: 0.4953 - val_accuracy: 0.8241 - lr: 1.2500e-06
# Epoch 166/200
# 27/27 [==============================] - 2s 71ms/step - loss: 0.5266 - accuracy: 0.7407 - val_loss: 0.4941 - val_accuracy: 0.8241 - lr: 1.2500e-06
# Epoch 167/200
# 27/27 [==============================] - 2s 72ms/step - loss: 0.5073 - accuracy: 0.7523 - val_loss: 0.4960 - val_accuracy: 0.8241 - lr: 1.2500e-06
# Epoch 168/200
# 27/27 [==============================] - 2s 70ms/step - loss: 0.5307 - accuracy: 0.7407 - val_loss: 0.4942 - val_accuracy: 0.8241 - lr: 1.2500e-06
# Epoch 169/200
# 27/27 [==============================] - 2s 70ms/step - loss: 0.5203 - accuracy: 0.7523 - val_loss: 0.4953 - val_accuracy: 0.8241 - lr: 1.2500e-06
# Epoch 170/200
# 27/27 [==============================] - 2s 71ms/step - loss: 0.5239 - accuracy: 0.7477 - val_loss: 0.4964 - val_accuracy: 0.8241 - lr: 1.2500e-06
# Epoch 171/200
# 27/27 [==============================] - 2s 70ms/step - loss: 0.5233 - accuracy: 0.7315 - val_loss: 0.4957 - val_accuracy: 0.8241 - lr: 1.2500e-06
# Epoch 172/200
# 27/27 [==============================] - 2s 69ms/step - loss: 0.5150 - accuracy: 0.7477 - val_loss: 0.4944 - val_accuracy: 0.8241 - lr: 1.2500e-06
# Epoch 173/200
# 27/27 [==============================] - 2s 71ms/step - loss: 0.5243 - accuracy: 0.7431 - val_loss: 0.4955 - val_accuracy: 0.8241 - lr: 1.2500e-06
# Epoch 174/200
# 27/27 [==============================] - 2s 70ms/step - loss: 0.5441 - accuracy: 0.7130 - val_loss: 0.4918 - val_accuracy: 0.8241 - lr: 1.2500e-06
# Epoch 175/200
# 27/27 [==============================] - 2s 66ms/step - loss: 0.5220 - accuracy: 0.7431 - val_loss: 0.4954 - val_accuracy: 0.8241 - lr: 1.2500e-06
# Epoch 176/200
# 27/27 [==============================] - 1s 50ms/step - loss: 0.5163 - accuracy: 0.7500 - val_loss: 0.4963 - val_accuracy: 0.8241 - lr: 1.2500e-06
# Epoch 177/200
# 27/27 [==============================] - 1s 48ms/step - loss: 0.5059 - accuracy: 0.7662 - val_loss: 0.4975 - val_accuracy: 0.8241 - lr: 1.2500e-06
# Epoch 178/200
# 27/27 [==============================] - 1s 47ms/step - loss: 0.5214 - accuracy: 0.7454 - val_loss: 0.4982 - val_accuracy: 0.8241 - lr: 1.2500e-06
# Epoch 179/200
# 27/27 [==============================] - 1s 46ms/step - loss: 0.5249 - accuracy: 0.7338 - val_loss: 0.4965 - val_accuracy: 0.8241 - lr: 1.2500e-06
# Epoch 180/200
# 27/27 [==============================] - 1s 47ms/step - loss: 0.5448 - accuracy: 0.7153 - val_loss: 0.4942 - val_accuracy: 0.8241 - lr: 1.2500e-06
# Epoch 181/200
# 27/27 [==============================] - 1s 46ms/step - loss: 0.5194 - accuracy: 0.7384 - val_loss: 0.4944 - val_accuracy: 0.8241 - lr: 1.2500e-06
# Epoch 182/200
# 27/27 [==============================] - 1s 47ms/step - loss: 0.5155 - accuracy: 0.7269 - val_loss: 0.4986 - val_accuracy: 0.8241 - lr: 1.2500e-06
# Epoch 183/200
# 27/27 [==============================] - 1s 46ms/step - loss: 0.5155 - accuracy: 0.7477 - val_loss: 0.4966 - val_accuracy: 0.8241 - lr: 1.2500e-06
# Epoch 184/200
# 27/27 [==============================] - 1s 45ms/step - loss: 0.5294 - accuracy: 0.7292 - val_loss: 0.4991 - val_accuracy: 0.8241 - lr: 1.2500e-06
# Epoch 185/200
# 27/27 [==============================] - 1s 47ms/step - loss: 0.5100 - accuracy: 0.7269 - val_loss: 0.4993 - val_accuracy: 0.8241 - lr: 1.2500e-06
# Epoch 186/200
# 27/27 [==============================] - 1s 45ms/step - loss: 0.5342 - accuracy: 0.7269 - val_loss: 0.4959 - val_accuracy: 0.8241 - lr: 1.2500e-06
# Epoch 187/200
# 27/27 [==============================] - 1s 47ms/step - loss: 0.5191 - accuracy: 0.7407 - val_loss: 0.4969 - val_accuracy: 0.8241 - lr: 1.2500e-06
# Epoch 188/200
# 27/27 [==============================] - 1s 45ms/step - loss: 0.5143 - accuracy: 0.7384 - val_loss: 0.4948 - val_accuracy: 0.8241 - lr: 1.2500e-06
# Epoch 189/200
# 27/27 [==============================] - 1s 46ms/step - loss: 0.5201 - accuracy: 0.7569 - val_loss: 0.4983 - val_accuracy: 0.8241 - lr: 1.2500e-06
# Epoch 190/200
# 27/27 [==============================] - 1s 46ms/step - loss: 0.5264 - accuracy: 0.7477 - val_loss: 0.4978 - val_accuracy: 0.8241 - lr: 1.2500e-06
# Epoch 191/200
# 27/27 [==============================] - 1s 47ms/step - loss: 0.5166 - accuracy: 0.7477 - val_loss: 0.4975 - val_accuracy: 0.8241 - lr: 1.2500e-06
# Epoch 192/200
# 27/27 [==============================] - ETA: 0s - loss: 0.5156 - accuracy: 0.7546
# Epoch 192: ReduceLROnPlateau reducing learning rate to 1e-06.
# 27/27 [==============================] - 1s 47ms/step - loss: 0.5156 - accuracy: 0.7546 - val_loss: 0.4977 - val_accuracy: 0.8241 - lr: 1.2500e-06
# Epoch 193/200
# 27/27 [==============================] - 1s 47ms/step - loss: 0.5219 - accuracy: 0.7338 - val_loss: 0.4970 - val_accuracy: 0.8241 - lr: 1.0000e-06
# Epoch 194/200
# 27/27 [==============================] - 1s 48ms/step - loss: 0.5158 - accuracy: 0.7546 - val_loss: 0.4968 - val_accuracy: 0.8241 - lr: 1.0000e-06
# Epoch 195/200
# 27/27 [==============================] - 1s 46ms/step - loss: 0.5211 - accuracy: 0.7500 - val_loss: 0.4960 - val_accuracy: 0.8241 - lr: 1.0000e-06
# Epoch 196/200
# 27/27 [==============================] - 1s 46ms/step - loss: 0.5181 - accuracy: 0.7245 - val_loss: 0.4993 - val_accuracy: 0.8241 - lr: 1.0000e-06
# Epoch 197/200
# 27/27 [==============================] - 1s 46ms/step - loss: 0.5188 - accuracy: 0.7384 - val_loss: 0.4976 - val_accuracy: 0.8241 - lr: 1.0000e-06
# Epoch 198/200
# 27/27 [==============================] - 1s 47ms/step - loss: 0.5188 - accuracy: 0.7500 - val_loss: 0.4996 - val_accuracy: 0.8241 - lr: 1.0000e-06
# Epoch 199/200
# 27/27 [==============================] - 1s 47ms/step - loss: 0.5111 - accuracy: 0.7523 - val_loss: 0.4989 - val_accuracy: 0.8241 - lr: 1.0000e-06
# Epoch 200/200
# 27/27 [==============================] - 1s 48ms/step - loss: 0.5156 - accuracy: 0.7292 - val_loss: 0.4989 - val_accuracy: 0.8241 - lr: 1.0000e-06
# 5/5 [==============================] - 0s 13ms/step
# Test Accuracy: 0.7571
# Test F1 Score: 0.7571
# Test Precision: 0.7571
# Test Recall: 0.7571
# Test ROC AUC Score: 0.8349
