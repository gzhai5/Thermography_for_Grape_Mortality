# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import accuracy_score, roc_auc_score, recall_score, precision_score, f1_score
from sklearn.metrics import confusion_matrix, precision_recall_fscore_support
import seaborn as sns
from collections import Counter
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau
import sys
sys.path.append(r'C:\Users\Mud\Desktop\2ndPaper\lstm')
from model.lstmfcn import generate_lstmfcn
from model.fcn import generate_fcn
from model.lstm import generate_lstm
from utils.class_weight import compute_class_weight
import tensorflow as tf
import random as python_random

# %%
# load the data
X_test_time = np.load(r'C:\Users\Mud\Desktop\2ndPaper\lstm\cultivar-specific\data\ries\X_test_ries.npy')
X_train_time = np.load(r'C:\Users\Mud\Desktop\2ndPaper\lstm\cultivar-specific\data\ries\X_train_ries.npy')
y_test = np.load(r'C:\Users\Mud\Desktop\2ndPaper\lstm\cultivar-specific\data\ries\y_test_ries.npy')
y_train = np.load(r'C:\Users\Mud\Desktop\2ndPaper\lstm\cultivar-specific\data\ries\y_train_ries.npy')
X_test_features = np.load(r'C:\Users\Mud\Desktop\2ndPaper\traditional_ml\weka\data\ries\X_test_ries.npy', allow_pickle=True)
X_train_features = np.load(r'C:\Users\Mud\Desktop\2ndPaper\traditional_ml\weka\data\ries\X_train_ries.npy', allow_pickle=True)

# # load fake data
#X_train = np.load('./fake/train/X_train.npy')
#y_train = np.load('./fake/train/y_train.npy')
#X_test = np.load('./fake/test/X_test.npy')
#y_test = np.load('./fake/test/y_test.npy')


print('X_train of time series shape:', X_train_time.shape)
print('X_test of time series shape:', X_test_time.shape)
print('X_train of features shape:', X_train_features.shape)
print('X_test of features shape:', X_test_features.shape)
print('y_train shape:', y_train.shape)
print('y_test shape:', y_test.shape)
# Out:
# X_train of time series shape: (540, 600)
# X_test of time series shape: (140, 600)
# X_train of features shape: (540,)
# X_test of features shape: (140,)
# y_train shape: (540,)
# y_test shape: (140,)

# %%
def reset_random_seeds(seed=42):
   np.random.seed(seed)
   python_random.seed(seed)
   tf.random.set_seed(seed)

reset_random_seeds()

# %%
# normalize the data to have same starting pt for all time series
# input shape: (n_samples, n_timepoints), want each samples - its mean of 0-30th timepts
def normalize_curves_mean_method(unnormalized_datas):
    normalized_datas = []
    for unnormalized_data in unnormalized_datas:
        mean = np.mean(unnormalized_data[:30])
        normalized_data = unnormalized_data - mean
        normalized_datas.append(normalized_data)
    normalized_datas = np.array(normalized_datas)
    assert normalized_datas.shape == unnormalized_datas.shape
    return normalized_datas

# normalize the data using z-score, have mean 0 and std 1
def normalize_curves_zscore(unnormalized_datas):
    normalized_datas = []
    for unnormalized_data in unnormalized_datas:
        mean = np.mean(unnormalized_data)
        std = np.std(unnormalized_data)
        normalized_data = (unnormalized_data - mean) / std
        normalized_datas.append(normalized_data)
    normalized_datas = np.array(normalized_datas)
    assert normalized_datas.shape == unnormalized_datas.shape
    return normalized_datas


# apply ln() to the time series data
def apply_ln_to_curves(datas):
    ln_datas = []
    for data in datas:
        ln_data = np.log(data)
        ln_datas.append(ln_data)
    ln_datas = np.array(ln_datas)
    assert ln_datas.shape == datas.shape
    return ln_datas


# split the time series data into wanted time points
def split_time_series(datas, start, end):
    datas = datas[:, start:end]
    return datas


# plot the time series data, randomly picked n samples, different colors represent different classes
def plot_random_time_series(datas, n, labels):
    for i in range(n):
        idx = np.random.randint(datas.shape[0])
        plt.plot(datas[idx], color = 'blue' if labels[idx] == 1 else 'red', alpha = 0.2)
    plt.show()


X_train_time = normalize_curves_mean_method(X_train_time)
X_test_time = normalize_curves_mean_method(X_test_time)
plot_random_time_series(X_train_time, 100, y_train)

# %%
# normalize the features data
X_train_features = pd.DataFrame.from_records(X_train_features.flatten())
X_test_features = pd.DataFrame.from_records(X_test_features.flatten())
print(X_train_features.head(1))

scaler = StandardScaler()
features = X_train_features.columns
X_train_features[features] = scaler.fit_transform(X_train_features[features])
X_test_features[features] = scaler.transform(X_test_features[features])
print(X_train_features.head(1))
# Out:
#            pc0        pc1        pc2  rising_waveform  falling_waveform  \
# 0 -1320.506845  47.462699  39.931146         0.965372          0.547959
#
#    peak_temperature  cultivar
# 0        260.650491         1
#         pc0       pc1       pc2  rising_waveform  falling_waveform  \
# 0 -1.301383  0.182964  0.410809        -1.356883         -1.452817
#
#    peak_temperature  cultivar
# 0         -1.356883       0.0

# %%
# normalize the time series data
# compute mean & std of the training set, then normalize the whole dataset using z-normalization
mean = np.mean(X_train_time)
std = np.std(X_train_time)
X_train_time = (X_train_time - mean) / std
X_test_time = (X_test_time - mean) / std

# %%
# Ensure data is shaped correctly
X_train_time = X_train_time.reshape(-1, 1, 600)  # Convert to (samples, 1, timesteps)
X_test_time = X_test_time.reshape(-1, 1, 600)
y_train = y_train.reshape(-1, 1)  # Ensure labels are in shape (samples, 1)
y_test = y_test.reshape(-1, 1)
X_train_features = X_train_features.values
X_test_features = X_test_features.values

print('X_train shape of time series:', X_train_time.shape)
print('y_train shape:', y_train.shape)
print('X_test shape of time series:', X_test_time.shape)
print('y_test shape:', y_test.shape)
print('X_train shape of features:', X_train_features.shape)
print('X_test shape of features:', X_test_features.shape)
# Out:
# X_train shape of time series: (540, 1, 600)
# y_train shape: (540, 1)
# X_test shape of time series: (140, 1, 600)
# y_test shape: (140, 1)
# X_train shape of features: (540, 7)
# X_test shape of features: (140, 7)

# %%
# Train final model on full training data# Initialize model
final_model = generate_lstmfcn(feature_input_accept=True, dropout=0.0)
class_weights = compute_class_weight(y_train)
print('class_weights:', class_weights)
reduce_lr = ReduceLROnPlateau(monitor='loss', patience=15, mode='auto',
    factor=1. / np.cbrt(2), cooldown=0, min_lr=1e-6, verbose=2)
final_model.compile(optimizer=Adam(learning_rate=5e-6), loss='binary_crossentropy', metrics=['accuracy'])

# split the data into training and validation set
X_train_time, X_val_time, X_train_features, X_val_features, y_train, y_val = train_test_split(
    X_train_time, X_train_features, y_train, test_size=0.2, random_state=42)
print('X_train shape of time series:', X_train_time.shape)
print('y_train shape:', y_train.shape)
print('X_val shape of time series:', X_val_time.shape)
print('y_val shape:', y_val.shape)
print('X_train shape of features:', X_train_features.shape)
print('X_val shape of features:', X_val_features.shape)

# Train model
history = final_model.fit(
    [X_train_time, X_train_features], y_train,
    validation_data=([X_val_time, X_val_features], y_val),
    callbacks=[reduce_lr],
    epochs=200, batch_size=16, class_weight={0: class_weights[0], 1: class_weights[1]},
    verbose=1
)

# Predict on test set
y_pred_prob = final_model.predict([X_test_time, X_test_features])
y_pred = (y_pred_prob > 0.5).astype(int)

# Calculate metrics
accuracy = accuracy_score(y_test, y_pred)
precision, recall, f1, _ = precision_recall_fscore_support(y_test, y_pred, average='binary')
roc_auc = roc_auc_score(y_test, y_pred_prob)
conf_matrix = confusion_matrix(y_test, y_pred)

# plot the metrics
print(f"Test Accuracy: {accuracy:.4f}")
print(f"Test F1 Score: {f1:.4f}")
print(f"Test Precision: {precision:.4f}")
print(f"Test Recall: {recall:.4f}")
print(f"Test ROC AUC Score: {roc_auc:.4f}")
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Dead', 'Alive'], yticklabels=['Dead', 'Alive'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()


# plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.figure(figsize=(10, 7))
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.figure(figsize=(10, 7))
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# class_weights: [1.86206897 0.6835443 ]
# X_train shape of time series: (432, 1, 600)
# y_train shape: (432, 1)
# X_val shape of time series: (108, 1, 600)
# y_val shape: (108, 1)
# X_train shape of features: (432, 7)
# X_val shape of features: (108, 7)
# Epoch 1/200
# 27/27 [==============================] - 28s 313ms/step - loss: 0.9930 - accuracy: 0.7222 - val_loss: 0.6354 - val_accuracy: 0.7685 - lr: 5.0000e-06
# Epoch 2/200
# 27/27 [==============================] - 3s 120ms/step - loss: 0.9169 - accuracy: 0.7222 - val_loss: 0.6238 - val_accuracy: 0.7685 - lr: 5.0000e-06
# Epoch 3/200
# 27/27 [==============================] - 3s 123ms/step - loss: 0.8549 - accuracy: 0.7222 - val_loss: 0.6148 - val_accuracy: 0.7685 - lr: 5.0000e-06
# Epoch 4/200
# 27/27 [==============================] - 3s 118ms/step - loss: 0.8035 - accuracy: 0.7222 - val_loss: 0.6008 - val_accuracy: 0.7685 - lr: 5.0000e-06
# Epoch 5/200
# 27/27 [==============================] - 3s 122ms/step - loss: 0.7562 - accuracy: 0.7222 - val_loss: 0.5864 - val_accuracy: 0.7685 - lr: 5.0000e-06
# Epoch 6/200
# 27/27 [==============================] - 3s 121ms/step - loss: 0.7279 - accuracy: 0.7245 - val_loss: 0.5734 - val_accuracy: 0.7685 - lr: 5.0000e-06
# Epoch 7/200
# 27/27 [==============================] - 3s 120ms/step - loss: 0.6907 - accuracy: 0.7315 - val_loss: 0.5604 - val_accuracy: 0.7778 - lr: 5.0000e-06
# Epoch 8/200
# 27/27 [==============================] - 3s 119ms/step - loss: 0.6666 - accuracy: 0.7546 - val_loss: 0.5505 - val_accuracy: 0.7500 - lr: 5.0000e-06
# Epoch 9/200
# 27/27 [==============================] - 3s 127ms/step - loss: 0.6412 - accuracy: 0.7708 - val_loss: 0.5425 - val_accuracy: 0.8148 - lr: 5.0000e-06
# Epoch 10/200
# 27/27 [==============================] - 3s 125ms/step - loss: 0.6235 - accuracy: 0.7685 - val_loss: 0.5331 - val_accuracy: 0.8241 - lr: 5.0000e-06
# Epoch 11/200
# 27/27 [==============================] - 3s 119ms/step - loss: 0.6139 - accuracy: 0.7963 - val_loss: 0.5280 - val_accuracy: 0.8241 - lr: 5.0000e-06
# Epoch 12/200
# 27/27 [==============================] - 3s 128ms/step - loss: 0.6036 - accuracy: 0.7963 - val_loss: 0.5238 - val_accuracy: 0.8333 - lr: 5.0000e-06
# Epoch 13/200
# 27/27 [==============================] - 3s 125ms/step - loss: 0.5993 - accuracy: 0.7940 - val_loss: 0.5192 - val_accuracy: 0.8333 - lr: 5.0000e-06
# Epoch 14/200
# 27/27 [==============================] - 3s 128ms/step - loss: 0.5851 - accuracy: 0.7870 - val_loss: 0.5147 - val_accuracy: 0.8241 - lr: 5.0000e-06
# Epoch 15/200
# 27/27 [==============================] - 3s 123ms/step - loss: 0.5813 - accuracy: 0.7824 - val_loss: 0.5141 - val_accuracy: 0.8333 - lr: 5.0000e-06
# Epoch 16/200
# 27/27 [==============================] - 3s 118ms/step - loss: 0.5757 - accuracy: 0.7870 - val_loss: 0.5119 - val_accuracy: 0.8241 - lr: 5.0000e-06
# Epoch 17/200
# 27/27 [==============================] - 3s 121ms/step - loss: 0.5681 - accuracy: 0.7917 - val_loss: 0.5095 - val_accuracy: 0.8241 - lr: 5.0000e-06
# Epoch 18/200
# 27/27 [==============================] - 3s 120ms/step - loss: 0.5639 - accuracy: 0.7778 - val_loss: 0.5063 - val_accuracy: 0.8241 - lr: 5.0000e-06
# Epoch 19/200
# 27/27 [==============================] - 3s 123ms/step - loss: 0.5696 - accuracy: 0.7708 - val_loss: 0.5053 - val_accuracy: 0.8241 - lr: 5.0000e-06
# Epoch 20/200
# 27/27 [==============================] - 3s 125ms/step - loss: 0.5793 - accuracy: 0.7546 - val_loss: 0.5059 - val_accuracy: 0.8241 - lr: 5.0000e-06
# Epoch 21/200
# 27/27 [==============================] - 3s 121ms/step - loss: 0.5573 - accuracy: 0.7824 - val_loss: 0.5039 - val_accuracy: 0.8241 - lr: 5.0000e-06
# Epoch 22/200
# 27/27 [==============================] - 3s 116ms/step - loss: 0.5568 - accuracy: 0.7824 - val_loss: 0.5030 - val_accuracy: 0.8241 - lr: 5.0000e-06
# Epoch 23/200
# 27/27 [==============================] - 3s 118ms/step - loss: 0.5512 - accuracy: 0.7639 - val_loss: 0.5030 - val_accuracy: 0.8148 - lr: 5.0000e-06
# Epoch 24/200
# 27/27 [==============================] - 3s 118ms/step - loss: 0.5535 - accuracy: 0.7685 - val_loss: 0.5021 - val_accuracy: 0.8241 - lr: 5.0000e-06
# Epoch 25/200
# 27/27 [==============================] - 3s 119ms/step - loss: 0.5535 - accuracy: 0.7685 - val_loss: 0.5035 - val_accuracy: 0.8148 - lr: 5.0000e-06
# Epoch 26/200
# 27/27 [==============================] - 3s 119ms/step - loss: 0.5473 - accuracy: 0.7662 - val_loss: 0.5029 - val_accuracy: 0.8148 - lr: 5.0000e-06
# Epoch 27/200
# 27/27 [==============================] - 3s 122ms/step - loss: 0.5516 - accuracy: 0.7685 - val_loss: 0.5051 - val_accuracy: 0.8148 - lr: 5.0000e-06
# Epoch 28/200
# 27/27 [==============================] - 3s 117ms/step - loss: 0.5490 - accuracy: 0.7569 - val_loss: 0.5032 - val_accuracy: 0.8148 - lr: 5.0000e-06
# Epoch 29/200
# 27/27 [==============================] - 3s 122ms/step - loss: 0.5428 - accuracy: 0.7616 - val_loss: 0.5044 - val_accuracy: 0.8148 - lr: 5.0000e-06
# Epoch 30/200
# 27/27 [==============================] - 3s 123ms/step - loss: 0.5560 - accuracy: 0.7569 - val_loss: 0.5008 - val_accuracy: 0.8241 - lr: 5.0000e-06
# Epoch 31/200
# 27/27 [==============================] - 3s 120ms/step - loss: 0.5477 - accuracy: 0.7546 - val_loss: 0.5019 - val_accuracy: 0.8241 - lr: 5.0000e-06
# Epoch 32/200
# 27/27 [==============================] - 3s 120ms/step - loss: 0.5458 - accuracy: 0.7546 - val_loss: 0.5080 - val_accuracy: 0.8148 - lr: 5.0000e-06
# Epoch 33/200
# 27/27 [==============================] - 3s 124ms/step - loss: 0.5512 - accuracy: 0.7454 - val_loss: 0.5104 - val_accuracy: 0.8148 - lr: 5.0000e-06
# Epoch 34/200
# 27/27 [==============================] - 3s 115ms/step - loss: 0.5316 - accuracy: 0.7755 - val_loss: 0.5072 - val_accuracy: 0.8148 - lr: 5.0000e-06
# Epoch 35/200
# 27/27 [==============================] - 3s 126ms/step - loss: 0.5386 - accuracy: 0.7639 - val_loss: 0.5062 - val_accuracy: 0.8148 - lr: 5.0000e-06
# Epoch 36/200
# 27/27 [==============================] - 3s 113ms/step - loss: 0.5296 - accuracy: 0.7755 - val_loss: 0.5032 - val_accuracy: 0.8148 - lr: 5.0000e-06
# Epoch 37/200
# 27/27 [==============================] - 3s 118ms/step - loss: 0.5514 - accuracy: 0.7384 - val_loss: 0.5078 - val_accuracy: 0.8148 - lr: 5.0000e-06
# Epoch 38/200
# 27/27 [==============================] - 3s 119ms/step - loss: 0.5511 - accuracy: 0.7523 - val_loss: 0.5063 - val_accuracy: 0.8148 - lr: 5.0000e-06
# Epoch 39/200
# 27/27 [==============================] - 3s 119ms/step - loss: 0.5370 - accuracy: 0.7546 - val_loss: 0.5063 - val_accuracy: 0.8148 - lr: 5.0000e-06
# Epoch 40/200
# 27/27 [==============================] - 3s 121ms/step - loss: 0.5431 - accuracy: 0.7708 - val_loss: 0.5110 - val_accuracy: 0.8056 - lr: 5.0000e-06
# Epoch 41/200
# 27/27 [==============================] - 3s 116ms/step - loss: 0.5533 - accuracy: 0.7407 - val_loss: 0.5092 - val_accuracy: 0.8056 - lr: 5.0000e-06
# Epoch 42/200
# 27/27 [==============================] - 3s 120ms/step - loss: 0.5441 - accuracy: 0.7546 - val_loss: 0.5094 - val_accuracy: 0.8056 - lr: 5.0000e-06
# Epoch 43/200
# 27/27 [==============================] - 3s 120ms/step - loss: 0.5382 - accuracy: 0.7500 - val_loss: 0.5094 - val_accuracy: 0.8056 - lr: 5.0000e-06
# Epoch 44/200
# 27/27 [==============================] - 3s 121ms/step - loss: 0.5473 - accuracy: 0.7431 - val_loss: 0.5065 - val_accuracy: 0.8056 - lr: 5.0000e-06
# Epoch 45/200
# 27/27 [==============================] - 3s 124ms/step - loss: 0.5329 - accuracy: 0.7616 - val_loss: 0.5061 - val_accuracy: 0.8056 - lr: 5.0000e-06
# Epoch 46/200
# 27/27 [==============================] - 3s 116ms/step - loss: 0.5384 - accuracy: 0.7407 - val_loss: 0.5079 - val_accuracy: 0.8056 - lr: 5.0000e-06
# Epoch 47/200
# 27/27 [==============================] - 3s 122ms/step - loss: 0.5431 - accuracy: 0.7477 - val_loss: 0.5059 - val_accuracy: 0.8056 - lr: 5.0000e-06
# Epoch 48/200
# 27/27 [==============================] - 3s 127ms/step - loss: 0.5337 - accuracy: 0.7616 - val_loss: 0.5107 - val_accuracy: 0.7963 - lr: 5.0000e-06
# Epoch 49/200
# 27/27 [==============================] - 3s 121ms/step - loss: 0.5400 - accuracy: 0.7431 - val_loss: 0.5083 - val_accuracy: 0.7963 - lr: 5.0000e-06
# Epoch 50/200
# 27/27 [==============================] - 3s 122ms/step - loss: 0.5423 - accuracy: 0.7407 - val_loss: 0.5104 - val_accuracy: 0.7963 - lr: 5.0000e-06
# Epoch 51/200
# 27/27 [==============================] - 3s 116ms/step - loss: 0.5267 - accuracy: 0.7454 - val_loss: 0.5110 - val_accuracy: 0.7963 - lr: 5.0000e-06
# Epoch 52/200
# 27/27 [==============================] - 3s 123ms/step - loss: 0.5336 - accuracy: 0.7477 - val_loss: 0.5076 - val_accuracy: 0.7963 - lr: 5.0000e-06
# Epoch 53/200
# 27/27 [==============================] - 3s 117ms/step - loss: 0.5321 - accuracy: 0.7593 - val_loss: 0.5093 - val_accuracy: 0.7963 - lr: 5.0000e-06
# Epoch 54/200
# 27/27 [==============================] - 3s 124ms/step - loss: 0.5354 - accuracy: 0.7616 - val_loss: 0.5116 - val_accuracy: 0.7963 - lr: 5.0000e-06
# Epoch 55/200
# 27/27 [==============================] - 3s 118ms/step - loss: 0.5424 - accuracy: 0.7338 - val_loss: 0.5065 - val_accuracy: 0.7963 - lr: 5.0000e-06
# Epoch 56/200
# 27/27 [==============================] - 3s 120ms/step - loss: 0.5342 - accuracy: 0.7662 - val_loss: 0.5086 - val_accuracy: 0.7963 - lr: 5.0000e-06
# Epoch 57/200
# 27/27 [==============================] - 3s 122ms/step - loss: 0.5382 - accuracy: 0.7523 - val_loss: 0.5103 - val_accuracy: 0.7963 - lr: 5.0000e-06
# Epoch 58/200
# 27/27 [==============================] - 3s 124ms/step - loss: 0.5235 - accuracy: 0.7616 - val_loss: 0.5112 - val_accuracy: 0.7963 - lr: 5.0000e-06
# Epoch 59/200
# 27/27 [==============================] - 3s 116ms/step - loss: 0.5448 - accuracy: 0.7546 - val_loss: 0.5117 - val_accuracy: 0.7963 - lr: 5.0000e-06
# Epoch 60/200
# 27/27 [==============================] - 3s 122ms/step - loss: 0.5347 - accuracy: 0.7338 - val_loss: 0.5108 - val_accuracy: 0.7963 - lr: 5.0000e-06
# Epoch 61/200
# 27/27 [==============================] - 3s 122ms/step - loss: 0.5459 - accuracy: 0.7477 - val_loss: 0.5100 - val_accuracy: 0.7963 - lr: 5.0000e-06
# Epoch 62/200
# 27/27 [==============================] - 3s 120ms/step - loss: 0.5307 - accuracy: 0.7639 - val_loss: 0.5068 - val_accuracy: 0.7963 - lr: 5.0000e-06
# Epoch 63/200
# 27/27 [==============================] - 3s 121ms/step - loss: 0.5377 - accuracy: 0.7454 - val_loss: 0.5133 - val_accuracy: 0.7963 - lr: 5.0000e-06
# Epoch 64/200
# 27/27 [==============================] - 3s 124ms/step - loss: 0.5389 - accuracy: 0.7477 - val_loss: 0.5069 - val_accuracy: 0.7963 - lr: 5.0000e-06
# Epoch 65/200
# 27/27 [==============================] - 3s 120ms/step - loss: 0.5372 - accuracy: 0.7431 - val_loss: 0.5072 - val_accuracy: 0.7963 - lr: 5.0000e-06
# Epoch 66/200
# 27/27 [==============================] - 3s 118ms/step - loss: 0.5302 - accuracy: 0.7477 - val_loss: 0.5117 - val_accuracy: 0.7963 - lr: 5.0000e-06
# Epoch 67/200
# 27/27 [==============================] - 3s 121ms/step - loss: 0.5274 - accuracy: 0.7546 - val_loss: 0.5094 - val_accuracy: 0.7963 - lr: 5.0000e-06
# Epoch 68/200
# 27/27 [==============================] - 3s 117ms/step - loss: 0.5461 - accuracy: 0.7616 - val_loss: 0.5038 - val_accuracy: 0.7963 - lr: 5.0000e-06
# Epoch 69/200
# 27/27 [==============================] - 3s 122ms/step - loss: 0.5353 - accuracy: 0.7338 - val_loss: 0.5048 - val_accuracy: 0.7963 - lr: 5.0000e-06
# Epoch 70/200
# 27/27 [==============================] - 3s 126ms/step - loss: 0.5306 - accuracy: 0.7593 - val_loss: 0.5080 - val_accuracy: 0.7963 - lr: 5.0000e-06
# Epoch 71/200
# 27/27 [==============================] - 3s 122ms/step - loss: 0.5308 - accuracy: 0.7569 - val_loss: 0.5078 - val_accuracy: 0.7963 - lr: 5.0000e-06
# Epoch 72/200
# 27/27 [==============================] - 3s 123ms/step - loss: 0.5307 - accuracy: 0.7639 - val_loss: 0.5014 - val_accuracy: 0.7963 - lr: 5.0000e-06
# Epoch 73/200
# 27/27 [==============================] - ETA: 0s - loss: 0.5265 - accuracy: 0.7454
# Epoch 73: ReduceLROnPlateau reducing learning rate to 3.968502529667691e-06.
# 27/27 [==============================] - 3s 123ms/step - loss: 0.5265 - accuracy: 0.7454 - val_loss: 0.5026 - val_accuracy: 0.7963 - lr: 5.0000e-06
# Epoch 74/200
# 27/27 [==============================] - 3s 120ms/step - loss: 0.5453 - accuracy: 0.7361 - val_loss: 0.5080 - val_accuracy: 0.7963 - lr: 3.9685e-06
# Epoch 75/200
# 27/27 [==============================] - 3s 119ms/step - loss: 0.5288 - accuracy: 0.7454 - val_loss: 0.5059 - val_accuracy: 0.7963 - lr: 3.9685e-06
# Epoch 76/200
# 27/27 [==============================] - 3s 123ms/step - loss: 0.5253 - accuracy: 0.7546 - val_loss: 0.5041 - val_accuracy: 0.7963 - lr: 3.9685e-06
# Epoch 77/200
# 27/27 [==============================] - 3s 120ms/step - loss: 0.5205 - accuracy: 0.7708 - val_loss: 0.5056 - val_accuracy: 0.7963 - lr: 3.9685e-06
# Epoch 78/200
# 27/27 [==============================] - 3s 123ms/step - loss: 0.5235 - accuracy: 0.7523 - val_loss: 0.5079 - val_accuracy: 0.7963 - lr: 3.9685e-06
# Epoch 79/200
# 27/27 [==============================] - 3s 125ms/step - loss: 0.5359 - accuracy: 0.7546 - val_loss: 0.5083 - val_accuracy: 0.7963 - lr: 3.9685e-06
# Epoch 80/200
# 27/27 [==============================] - 3s 122ms/step - loss: 0.5237 - accuracy: 0.7500 - val_loss: 0.5099 - val_accuracy: 0.7963 - lr: 3.9685e-06
# Epoch 81/200
# 27/27 [==============================] - 3s 117ms/step - loss: 0.5312 - accuracy: 0.7593 - val_loss: 0.5105 - val_accuracy: 0.7963 - lr: 3.9685e-06
# Epoch 82/200
# 27/27 [==============================] - 3s 123ms/step - loss: 0.5385 - accuracy: 0.7523 - val_loss: 0.5070 - val_accuracy: 0.7963 - lr: 3.9685e-06
# Epoch 83/200
# 27/27 [==============================] - 3s 123ms/step - loss: 0.5446 - accuracy: 0.7407 - val_loss: 0.5069 - val_accuracy: 0.7963 - lr: 3.9685e-06
# Epoch 84/200
# 27/27 [==============================] - 3s 124ms/step - loss: 0.5301 - accuracy: 0.7269 - val_loss: 0.5060 - val_accuracy: 0.7963 - lr: 3.9685e-06
# Epoch 85/200
# 27/27 [==============================] - 3s 119ms/step - loss: 0.5261 - accuracy: 0.7569 - val_loss: 0.5051 - val_accuracy: 0.7963 - lr: 3.9685e-06
# Epoch 86/200
# 27/27 [==============================] - 3s 122ms/step - loss: 0.5410 - accuracy: 0.7477 - val_loss: 0.5051 - val_accuracy: 0.7963 - lr: 3.9685e-06
# Epoch 87/200
# 27/27 [==============================] - 3s 119ms/step - loss: 0.5311 - accuracy: 0.7523 - val_loss: 0.5019 - val_accuracy: 0.7963 - lr: 3.9685e-06
# Epoch 88/200
# 27/27 [==============================] - 3s 119ms/step - loss: 0.5266 - accuracy: 0.7454 - val_loss: 0.5040 - val_accuracy: 0.7963 - lr: 3.9685e-06
# Epoch 89/200
# 27/27 [==============================] - 3s 120ms/step - loss: 0.5144 - accuracy: 0.7616 - val_loss: 0.5031 - val_accuracy: 0.7963 - lr: 3.9685e-06
# Epoch 90/200
# 27/27 [==============================] - 3s 120ms/step - loss: 0.5216 - accuracy: 0.7639 - val_loss: 0.5006 - val_accuracy: 0.7963 - lr: 3.9685e-06
# Epoch 91/200
# 27/27 [==============================] - 3s 120ms/step - loss: 0.5334 - accuracy: 0.7407 - val_loss: 0.5001 - val_accuracy: 0.7963 - lr: 3.9685e-06
# Epoch 92/200
# 27/27 [==============================] - 3s 123ms/step - loss: 0.5178 - accuracy: 0.7685 - val_loss: 0.5036 - val_accuracy: 0.7963 - lr: 3.9685e-06
# Epoch 93/200
# 27/27 [==============================] - 3s 122ms/step - loss: 0.5318 - accuracy: 0.7500 - val_loss: 0.5035 - val_accuracy: 0.7963 - lr: 3.9685e-06
# Epoch 94/200
# 27/27 [==============================] - 3s 124ms/step - loss: 0.5272 - accuracy: 0.7500 - val_loss: 0.5064 - val_accuracy: 0.7963 - lr: 3.9685e-06
# Epoch 95/200
# 27/27 [==============================] - 3s 126ms/step - loss: 0.5239 - accuracy: 0.7546 - val_loss: 0.5091 - val_accuracy: 0.7963 - lr: 3.9685e-06
# Epoch 96/200
# 27/27 [==============================] - 3s 121ms/step - loss: 0.5307 - accuracy: 0.7477 - val_loss: 0.5034 - val_accuracy: 0.7963 - lr: 3.9685e-06
# Epoch 97/200
# 27/27 [==============================] - 3s 120ms/step - loss: 0.5343 - accuracy: 0.7338 - val_loss: 0.5013 - val_accuracy: 0.7963 - lr: 3.9685e-06
# Epoch 98/200
# 27/27 [==============================] - 3s 120ms/step - loss: 0.5302 - accuracy: 0.7546 - val_loss: 0.5000 - val_accuracy: 0.8056 - lr: 3.9685e-06
# Epoch 99/200
# 27/27 [==============================] - 3s 121ms/step - loss: 0.5199 - accuracy: 0.7662 - val_loss: 0.5021 - val_accuracy: 0.7963 - lr: 3.9685e-06
# Epoch 100/200
# 27/27 [==============================] - 3s 123ms/step - loss: 0.5198 - accuracy: 0.7500 - val_loss: 0.5057 - val_accuracy: 0.7963 - lr: 3.9685e-06
# Epoch 101/200
# 27/27 [==============================] - 3s 120ms/step - loss: 0.5264 - accuracy: 0.7569 - val_loss: 0.5066 - val_accuracy: 0.7963 - lr: 3.9685e-06
# Epoch 102/200
# 27/27 [==============================] - 3s 119ms/step - loss: 0.5382 - accuracy: 0.7546 - val_loss: 0.5026 - val_accuracy: 0.8056 - lr: 3.9685e-06
# Epoch 103/200
# 27/27 [==============================] - 3s 122ms/step - loss: 0.5371 - accuracy: 0.7477 - val_loss: 0.5014 - val_accuracy: 0.8056 - lr: 3.9685e-06
# Epoch 104/200
# 27/27 [==============================] - ETA: 0s - loss: 0.5173 - accuracy: 0.7731
# Epoch 104: ReduceLROnPlateau reducing learning rate to 3.1498024179533314e-06.
# 27/27 [==============================] - 3s 126ms/step - loss: 0.5173 - accuracy: 0.7731 - val_loss: 0.5037 - val_accuracy: 0.7963 - lr: 3.9685e-06
# Epoch 105/200
# 27/27 [==============================] - 3s 122ms/step - loss: 0.5284 - accuracy: 0.7407 - val_loss: 0.5047 - val_accuracy: 0.7963 - lr: 3.1498e-06
# Epoch 106/200
# 27/27 [==============================] - 3s 123ms/step - loss: 0.5316 - accuracy: 0.7685 - val_loss: 0.5027 - val_accuracy: 0.8056 - lr: 3.1498e-06
# Epoch 107/200
# 27/27 [==============================] - 3s 121ms/step - loss: 0.5254 - accuracy: 0.7523 - val_loss: 0.5041 - val_accuracy: 0.7963 - lr: 3.1498e-06
# Epoch 108/200
# 27/27 [==============================] - 3s 120ms/step - loss: 0.5180 - accuracy: 0.7477 - val_loss: 0.5031 - val_accuracy: 0.8056 - lr: 3.1498e-06
# Epoch 109/200
# 27/27 [==============================] - 3s 119ms/step - loss: 0.5462 - accuracy: 0.7292 - val_loss: 0.5014 - val_accuracy: 0.8056 - lr: 3.1498e-06
# Epoch 110/200
# 27/27 [==============================] - 3s 117ms/step - loss: 0.5242 - accuracy: 0.7731 - val_loss: 0.5022 - val_accuracy: 0.8056 - lr: 3.1498e-06
# Epoch 111/200
# 27/27 [==============================] - 3s 117ms/step - loss: 0.5133 - accuracy: 0.7523 - val_loss: 0.4991 - val_accuracy: 0.8056 - lr: 3.1498e-06
# Epoch 112/200
# 27/27 [==============================] - 3s 118ms/step - loss: 0.5329 - accuracy: 0.7454 - val_loss: 0.4991 - val_accuracy: 0.8056 - lr: 3.1498e-06
# Epoch 113/200
# 27/27 [==============================] - 3s 123ms/step - loss: 0.5265 - accuracy: 0.7500 - val_loss: 0.5015 - val_accuracy: 0.8056 - lr: 3.1498e-06
# Epoch 114/200
# 27/27 [==============================] - 3s 123ms/step - loss: 0.5333 - accuracy: 0.7407 - val_loss: 0.5008 - val_accuracy: 0.8056 - lr: 3.1498e-06
# Epoch 115/200
# 27/27 [==============================] - 3s 124ms/step - loss: 0.5128 - accuracy: 0.7616 - val_loss: 0.4978 - val_accuracy: 0.8056 - lr: 3.1498e-06
# Epoch 116/200
# 27/27 [==============================] - 3s 122ms/step - loss: 0.5324 - accuracy: 0.7338 - val_loss: 0.5002 - val_accuracy: 0.8056 - lr: 3.1498e-06
# Epoch 117/200
# 27/27 [==============================] - 3s 120ms/step - loss: 0.5291 - accuracy: 0.7431 - val_loss: 0.5001 - val_accuracy: 0.8056 - lr: 3.1498e-06
# Epoch 118/200
# 27/27 [==============================] - 3s 122ms/step - loss: 0.5318 - accuracy: 0.7407 - val_loss: 0.4986 - val_accuracy: 0.8056 - lr: 3.1498e-06
# Epoch 119/200
# 27/27 [==============================] - 3s 119ms/step - loss: 0.5190 - accuracy: 0.7593 - val_loss: 0.4984 - val_accuracy: 0.8056 - lr: 3.1498e-06
# Epoch 120/200
# 27/27 [==============================] - 3s 120ms/step - loss: 0.5211 - accuracy: 0.7546 - val_loss: 0.4999 - val_accuracy: 0.8056 - lr: 3.1498e-06
# Epoch 121/200
# 27/27 [==============================] - 3s 123ms/step - loss: 0.5266 - accuracy: 0.7407 - val_loss: 0.5001 - val_accuracy: 0.8056 - lr: 3.1498e-06
# Epoch 122/200
# 27/27 [==============================] - 3s 123ms/step - loss: 0.5293 - accuracy: 0.7407 - val_loss: 0.4984 - val_accuracy: 0.8056 - lr: 3.1498e-06
# Epoch 123/200
# 27/27 [==============================] - 3s 124ms/step - loss: 0.5219 - accuracy: 0.7454 - val_loss: 0.4993 - val_accuracy: 0.8056 - lr: 3.1498e-06
# Epoch 124/200
# 27/27 [==============================] - 3s 112ms/step - loss: 0.5254 - accuracy: 0.7454 - val_loss: 0.5002 - val_accuracy: 0.8056 - lr: 3.1498e-06
# Epoch 125/200
# 27/27 [==============================] - 3s 120ms/step - loss: 0.5282 - accuracy: 0.7662 - val_loss: 0.5015 - val_accuracy: 0.8056 - lr: 3.1498e-06
# Epoch 126/200
# 27/27 [==============================] - 3s 121ms/step - loss: 0.5250 - accuracy: 0.7500 - val_loss: 0.5068 - val_accuracy: 0.7963 - lr: 3.1498e-06
# Epoch 127/200
# 27/27 [==============================] - 3s 124ms/step - loss: 0.5277 - accuracy: 0.7431 - val_loss: 0.5044 - val_accuracy: 0.7963 - lr: 3.1498e-06
# Epoch 128/200
# 27/27 [==============================] - 3s 121ms/step - loss: 0.5307 - accuracy: 0.7431 - val_loss: 0.5035 - val_accuracy: 0.8056 - lr: 3.1498e-06
# Epoch 129/200
# 27/27 [==============================] - 3s 119ms/step - loss: 0.5234 - accuracy: 0.7384 - val_loss: 0.5009 - val_accuracy: 0.8056 - lr: 3.1498e-06
# Epoch 130/200
# 27/27 [==============================] - ETA: 0s - loss: 0.5175 - accuracy: 0.7431
# Epoch 130: ReduceLROnPlateau reducing learning rate to 2.499999919802159e-06.
# 27/27 [==============================] - 3s 125ms/step - loss: 0.5175 - accuracy: 0.7431 - val_loss: 0.4999 - val_accuracy: 0.8056 - lr: 3.1498e-06
# Epoch 131/200
# 27/27 [==============================] - 3s 124ms/step - loss: 0.5193 - accuracy: 0.7477 - val_loss: 0.4970 - val_accuracy: 0.8148 - lr: 2.5000e-06
# Epoch 132/200
# 27/27 [==============================] - 3s 119ms/step - loss: 0.5222 - accuracy: 0.7546 - val_loss: 0.5006 - val_accuracy: 0.8056 - lr: 2.5000e-06
# Epoch 133/200
# 27/27 [==============================] - 3s 124ms/step - loss: 0.5155 - accuracy: 0.7523 - val_loss: 0.5039 - val_accuracy: 0.7963 - lr: 2.5000e-06
# Epoch 134/200
# 27/27 [==============================] - 3s 121ms/step - loss: 0.5313 - accuracy: 0.7546 - val_loss: 0.5026 - val_accuracy: 0.8056 - lr: 2.5000e-06
# Epoch 135/200
# 27/27 [==============================] - 3s 121ms/step - loss: 0.5181 - accuracy: 0.7546 - val_loss: 0.5020 - val_accuracy: 0.8056 - lr: 2.5000e-06
# Epoch 136/200
# 27/27 [==============================] - 3s 107ms/step - loss: 0.5300 - accuracy: 0.7500 - val_loss: 0.5020 - val_accuracy: 0.8056 - lr: 2.5000e-06
# Epoch 137/200
# 27/27 [==============================] - 2s 93ms/step - loss: 0.5179 - accuracy: 0.7500 - val_loss: 0.5022 - val_accuracy: 0.8056 - lr: 2.5000e-06
# Epoch 138/200
# 27/27 [==============================] - 3s 95ms/step - loss: 0.5366 - accuracy: 0.7523 - val_loss: 0.5010 - val_accuracy: 0.8056 - lr: 2.5000e-06
# Epoch 139/200
# 27/27 [==============================] - 2s 92ms/step - loss: 0.5309 - accuracy: 0.7384 - val_loss: 0.5007 - val_accuracy: 0.8056 - lr: 2.5000e-06
# Epoch 140/200
# 27/27 [==============================] - 2s 91ms/step - loss: 0.5151 - accuracy: 0.7593 - val_loss: 0.5055 - val_accuracy: 0.7963 - lr: 2.5000e-06
# Epoch 141/200
# 27/27 [==============================] - 2s 88ms/step - loss: 0.5204 - accuracy: 0.7477 - val_loss: 0.5047 - val_accuracy: 0.8056 - lr: 2.5000e-06
# Epoch 142/200
# 27/27 [==============================] - 2s 91ms/step - loss: 0.5220 - accuracy: 0.7361 - val_loss: 0.5039 - val_accuracy: 0.8056 - lr: 2.5000e-06
# Epoch 143/200
# 27/27 [==============================] - 2s 90ms/step - loss: 0.5300 - accuracy: 0.7361 - val_loss: 0.5064 - val_accuracy: 0.7963 - lr: 2.5000e-06
# Epoch 144/200
# 27/27 [==============================] - 3s 94ms/step - loss: 0.5200 - accuracy: 0.7639 - val_loss: 0.5024 - val_accuracy: 0.8056 - lr: 2.5000e-06
# Epoch 145/200
# 27/27 [==============================] - ETA: 0s - loss: 0.5284 - accuracy: 0.7454
# Epoch 145: ReduceLROnPlateau reducing learning rate to 1.9842512648338455e-06.
# 27/27 [==============================] - 2s 92ms/step - loss: 0.5284 - accuracy: 0.7454 - val_loss: 0.5028 - val_accuracy: 0.8056 - lr: 2.5000e-06
# Epoch 146/200
# 27/27 [==============================] - 2s 92ms/step - loss: 0.5285 - accuracy: 0.7407 - val_loss: 0.5019 - val_accuracy: 0.8056 - lr: 1.9843e-06
# Epoch 147/200
# 27/27 [==============================] - 2s 92ms/step - loss: 0.5244 - accuracy: 0.7477 - val_loss: 0.5012 - val_accuracy: 0.8056 - lr: 1.9843e-06
# Epoch 148/200
# 27/27 [==============================] - 3s 93ms/step - loss: 0.5332 - accuracy: 0.7338 - val_loss: 0.5002 - val_accuracy: 0.8056 - lr: 1.9843e-06
# Epoch 149/200
# 27/27 [==============================] - 3s 93ms/step - loss: 0.5305 - accuracy: 0.7593 - val_loss: 0.5012 - val_accuracy: 0.8056 - lr: 1.9843e-06
# Epoch 150/200
# 27/27 [==============================] - 2s 91ms/step - loss: 0.5300 - accuracy: 0.7454 - val_loss: 0.4988 - val_accuracy: 0.8056 - lr: 1.9843e-06
# Epoch 151/200
# 27/27 [==============================] - 2s 89ms/step - loss: 0.5253 - accuracy: 0.7546 - val_loss: 0.4992 - val_accuracy: 0.8056 - lr: 1.9843e-06
# Epoch 152/200
# 27/27 [==============================] - 3s 94ms/step - loss: 0.5251 - accuracy: 0.7454 - val_loss: 0.4985 - val_accuracy: 0.8056 - lr: 1.9843e-06
# Epoch 153/200
# 27/27 [==============================] - 2s 89ms/step - loss: 0.5395 - accuracy: 0.7477 - val_loss: 0.4995 - val_accuracy: 0.8056 - lr: 1.9843e-06
# Epoch 154/200
# 27/27 [==============================] - 2s 87ms/step - loss: 0.5240 - accuracy: 0.7593 - val_loss: 0.4993 - val_accuracy: 0.8056 - lr: 1.9843e-06
# Epoch 155/200
# 27/27 [==============================] - 2s 68ms/step - loss: 0.5179 - accuracy: 0.7639 - val_loss: 0.4999 - val_accuracy: 0.8056 - lr: 1.9843e-06
# Epoch 156/200
# 27/27 [==============================] - 2s 67ms/step - loss: 0.5101 - accuracy: 0.7500 - val_loss: 0.5005 - val_accuracy: 0.8056 - lr: 1.9843e-06
# Epoch 157/200
# 27/27 [==============================] - 2s 67ms/step - loss: 0.5295 - accuracy: 0.7523 - val_loss: 0.5007 - val_accuracy: 0.8056 - lr: 1.9843e-06
# Epoch 158/200
# 27/27 [==============================] - 2s 67ms/step - loss: 0.5217 - accuracy: 0.7569 - val_loss: 0.5025 - val_accuracy: 0.8056 - lr: 1.9843e-06
# Epoch 159/200
# 27/27 [==============================] - 2s 67ms/step - loss: 0.5218 - accuracy: 0.7569 - val_loss: 0.5022 - val_accuracy: 0.8056 - lr: 1.9843e-06
# Epoch 160/200
# 27/27 [==============================] - 2s 67ms/step - loss: 0.5206 - accuracy: 0.7431 - val_loss: 0.5007 - val_accuracy: 0.8056 - lr: 1.9843e-06
# Epoch 161/200
# 27/27 [==============================] - 2s 66ms/step - loss: 0.5319 - accuracy: 0.7407 - val_loss: 0.5016 - val_accuracy: 0.8056 - lr: 1.9843e-06
# Epoch 162/200
# 27/27 [==============================] - 2s 67ms/step - loss: 0.5205 - accuracy: 0.7500 - val_loss: 0.5009 - val_accuracy: 0.8056 - lr: 1.9843e-06
# Epoch 163/200
# 27/27 [==============================] - 2s 67ms/step - loss: 0.5171 - accuracy: 0.7523 - val_loss: 0.5025 - val_accuracy: 0.8056 - lr: 1.9843e-06
# Epoch 164/200
# 27/27 [==============================] - 2s 66ms/step - loss: 0.5214 - accuracy: 0.7431 - val_loss: 0.4998 - val_accuracy: 0.8056 - lr: 1.9843e-06
# Epoch 165/200
# 27/27 [==============================] - 2s 67ms/step - loss: 0.5350 - accuracy: 0.7407 - val_loss: 0.4980 - val_accuracy: 0.8056 - lr: 1.9843e-06
# Epoch 166/200
# 27/27 [==============================] - 2s 68ms/step - loss: 0.5286 - accuracy: 0.7546 - val_loss: 0.4956 - val_accuracy: 0.8056 - lr: 1.9843e-06
# Epoch 167/200
# 27/27 [==============================] - 2s 68ms/step - loss: 0.5109 - accuracy: 0.7523 - val_loss: 0.4986 - val_accuracy: 0.8056 - lr: 1.9843e-06
# Epoch 168/200
# 27/27 [==============================] - 2s 68ms/step - loss: 0.5303 - accuracy: 0.7384 - val_loss: 0.4961 - val_accuracy: 0.8056 - lr: 1.9843e-06
# Epoch 169/200
# 27/27 [==============================] - 2s 68ms/step - loss: 0.5213 - accuracy: 0.7616 - val_loss: 0.4981 - val_accuracy: 0.8056 - lr: 1.9843e-06
# Epoch 170/200
# 27/27 [==============================] - 2s 67ms/step - loss: 0.5238 - accuracy: 0.7523 - val_loss: 0.4996 - val_accuracy: 0.8056 - lr: 1.9843e-06
# Epoch 171/200
# 27/27 [==============================] - ETA: 0s - loss: 0.5241 - accuracy: 0.7431
# Epoch 171: ReduceLROnPlateau reducing learning rate to 1.5749012089766657e-06.
# 27/27 [==============================] - 2s 67ms/step - loss: 0.5241 - accuracy: 0.7431 - val_loss: 0.4985 - val_accuracy: 0.8056 - lr: 1.9843e-06
# Epoch 172/200
# 27/27 [==============================] - 2s 68ms/step - loss: 0.5167 - accuracy: 0.7523 - val_loss: 0.4971 - val_accuracy: 0.8056 - lr: 1.5749e-06
# Epoch 173/200
# 27/27 [==============================] - 2s 68ms/step - loss: 0.5239 - accuracy: 0.7500 - val_loss: 0.4981 - val_accuracy: 0.8056 - lr: 1.5749e-06
# Epoch 174/200
# 27/27 [==============================] - 2s 68ms/step - loss: 0.5432 - accuracy: 0.7292 - val_loss: 0.4954 - val_accuracy: 0.8241 - lr: 1.5749e-06
# Epoch 175/200
# 27/27 [==============================] - 2s 66ms/step - loss: 0.5227 - accuracy: 0.7454 - val_loss: 0.4984 - val_accuracy: 0.8056 - lr: 1.5749e-06
# Epoch 176/200
# 27/27 [==============================] - 2s 65ms/step - loss: 0.5162 - accuracy: 0.7454 - val_loss: 0.4993 - val_accuracy: 0.8056 - lr: 1.5749e-06
# Epoch 177/200
# 27/27 [==============================] - 2s 68ms/step - loss: 0.5094 - accuracy: 0.7778 - val_loss: 0.5001 - val_accuracy: 0.8056 - lr: 1.5749e-06
# Epoch 178/200
# 27/27 [==============================] - 2s 67ms/step - loss: 0.5224 - accuracy: 0.7639 - val_loss: 0.5008 - val_accuracy: 0.8056 - lr: 1.5749e-06
# Epoch 179/200
# 27/27 [==============================] - 2s 68ms/step - loss: 0.5262 - accuracy: 0.7384 - val_loss: 0.4992 - val_accuracy: 0.8056 - lr: 1.5749e-06
# Epoch 180/200
# 27/27 [==============================] - 2s 67ms/step - loss: 0.5433 - accuracy: 0.7361 - val_loss: 0.4976 - val_accuracy: 0.8056 - lr: 1.5749e-06
# Epoch 181/200
# 27/27 [==============================] - 2s 67ms/step - loss: 0.5204 - accuracy: 0.7384 - val_loss: 0.4978 - val_accuracy: 0.8056 - lr: 1.5749e-06
# Epoch 182/200
# 27/27 [==============================] - 2s 69ms/step - loss: 0.5177 - accuracy: 0.7361 - val_loss: 0.5008 - val_accuracy: 0.8056 - lr: 1.5749e-06
# Epoch 183/200
# 27/27 [==============================] - 2s 65ms/step - loss: 0.5178 - accuracy: 0.7454 - val_loss: 0.4994 - val_accuracy: 0.8056 - lr: 1.5749e-06
# Epoch 184/200
# 27/27 [==============================] - 2s 67ms/step - loss: 0.5274 - accuracy: 0.7454 - val_loss: 0.5016 - val_accuracy: 0.8056 - lr: 1.5749e-06
# Epoch 185/200
# 27/27 [==============================] - 2s 68ms/step - loss: 0.5142 - accuracy: 0.7338 - val_loss: 0.5015 - val_accuracy: 0.8056 - lr: 1.5749e-06
# Epoch 186/200
# 27/27 [==============================] - 2s 68ms/step - loss: 0.5354 - accuracy: 0.7315 - val_loss: 0.4980 - val_accuracy: 0.8056 - lr: 1.5749e-06
# Epoch 187/200
# 27/27 [==============================] - 2s 67ms/step - loss: 0.5180 - accuracy: 0.7454 - val_loss: 0.4987 - val_accuracy: 0.8056 - lr: 1.5749e-06
# Epoch 188/200
# 27/27 [==============================] - 2s 68ms/step - loss: 0.5173 - accuracy: 0.7500 - val_loss: 0.4970 - val_accuracy: 0.8056 - lr: 1.5749e-06
# Epoch 189/200
# 27/27 [==============================] - 2s 67ms/step - loss: 0.5228 - accuracy: 0.7523 - val_loss: 0.4997 - val_accuracy: 0.8056 - lr: 1.5749e-06
# Epoch 190/200
# 27/27 [==============================] - 2s 68ms/step - loss: 0.5259 - accuracy: 0.7454 - val_loss: 0.4994 - val_accuracy: 0.8056 - lr: 1.5749e-06
# Epoch 191/200
# 27/27 [==============================] - 2s 68ms/step - loss: 0.5172 - accuracy: 0.7431 - val_loss: 0.4998 - val_accuracy: 0.8056 - lr: 1.5749e-06
# Epoch 192/200
# 27/27 [==============================] - ETA: 0s - loss: 0.5161 - accuracy: 0.7569
# Epoch 192: ReduceLROnPlateau reducing learning rate to 1.2499999599010794e-06.
# 27/27 [==============================] - 2s 68ms/step - loss: 0.5161 - accuracy: 0.7569 - val_loss: 0.4996 - val_accuracy: 0.8056 - lr: 1.5749e-06
# Epoch 193/200
# 27/27 [==============================] - 2s 68ms/step - loss: 0.5230 - accuracy: 0.7361 - val_loss: 0.4989 - val_accuracy: 0.8056 - lr: 1.2500e-06
# Epoch 194/200
# 27/27 [==============================] - 2s 68ms/step - loss: 0.5195 - accuracy: 0.7639 - val_loss: 0.4991 - val_accuracy: 0.8056 - lr: 1.2500e-06
# Epoch 195/200
# 27/27 [==============================] - 2s 67ms/step - loss: 0.5250 - accuracy: 0.7500 - val_loss: 0.4980 - val_accuracy: 0.8056 - lr: 1.2500e-06
# Epoch 196/200
# 27/27 [==============================] - 2s 67ms/step - loss: 0.5199 - accuracy: 0.7292 - val_loss: 0.5012 - val_accuracy: 0.8056 - lr: 1.2500e-06
# Epoch 197/200
# 27/27 [==============================] - 2s 68ms/step - loss: 0.5216 - accuracy: 0.7384 - val_loss: 0.4996 - val_accuracy: 0.8056 - lr: 1.2500e-06
# Epoch 198/200
# 27/27 [==============================] - 2s 67ms/step - loss: 0.5202 - accuracy: 0.7431 - val_loss: 0.5011 - val_accuracy: 0.8056 - lr: 1.2500e-06
# Epoch 199/200
# 27/27 [==============================] - 2s 69ms/step - loss: 0.5146 - accuracy: 0.7500 - val_loss: 0.5005 - val_accuracy: 0.8056 - lr: 1.2500e-06
# Epoch 200/200
# 27/27 [==============================] - 2s 65ms/step - loss: 0.5197 - accuracy: 0.7338 - val_loss: 0.5008 - val_accuracy: 0.8056 - lr: 1.2500e-06
# 5/5 [==============================] - 0s 14ms/step
# Test Accuracy: 0.7571
# Test F1 Score: 0.7571
# Test Precision: 0.7571
# Test Recall: 0.7571
# Test ROC AUC Score: 0.8333
