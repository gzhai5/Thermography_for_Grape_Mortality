# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import accuracy_score, roc_auc_score, recall_score, precision_score, f1_score
from sklearn.metrics import confusion_matrix, precision_recall_fscore_support
import seaborn as sns
from collections import Counter
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau
import sys
sys.path.append(r'C:\Users\Mud\Desktop\2ndPaper\lstm')
from model.lstmfcn import generate_lstmfcn
from model.fcn import generate_fcn
from model.lstm import generate_lstm
from utils.class_weight import compute_class_weight
import tensorflow as tf
import random as python_random

# %%
# # load the data
X_test = np.load(r'C:\Users\Mud\Desktop\2ndPaper\lstm\cultivar-specific\data\ries\X_test_ries.npy')
y_test = np.load(r'C:\Users\Mud\Desktop\2ndPaper\lstm\cultivar-specific\data\ries\y_test_ries.npy')
X_train = np.load(r'C:\Users\Mud\Desktop\2ndPaper\lstm\cultivar-specific\data\ries\X_train_ries.npy')
y_train = np.load(r'C:\Users\Mud\Desktop\2ndPaper\lstm\cultivar-specific\data\ries\y_train_ries.npy')

# # load fake data
#X_train = np.load('./fake/train/X_train.npy')
#y_train = np.load('./fake/train/y_train.npy')
#X_test = np.load('./fake/test/X_test.npy')
#y_test = np.load('./fake/test/y_test.npy')


print('X_train shape:', X_train.shape)
print('y_train shape:', y_train.shape)
print('X_test shape:', X_test.shape)
print('y_test shape:', y_test.shape)
# Out:
# X_train shape: (540, 600)
# y_train shape: (540,)
# X_test shape: (140, 600)
# y_test shape: (140,)

# %%
def reset_random_seeds(seed=42):
   np.random.seed(seed)
   python_random.seed(seed)
   tf.random.set_seed(seed)

reset_random_seeds()

# %%
# normalize the data to have same starting pt for all time series
# input shape: (n_samples, n_timepoints), want each samples - its mean of 0-30th timepts
def normalize_curves_mean_method(unnormalized_datas):
    normalized_datas = []
    for unnormalized_data in unnormalized_datas:
        mean = np.mean(unnormalized_data[:30])
        normalized_data = unnormalized_data - mean
        normalized_datas.append(normalized_data)
    normalized_datas = np.array(normalized_datas)
    assert normalized_datas.shape == unnormalized_datas.shape
    return normalized_datas

# normalize the data using z-score, have mean 0 and std 1
def normalize_curves_zscore(unnormalized_datas):
    normalized_datas = []
    for unnormalized_data in unnormalized_datas:
        mean = np.mean(unnormalized_data)
        std = np.std(unnormalized_data)
        normalized_data = (unnormalized_data - mean) / std
        normalized_datas.append(normalized_data)
    normalized_datas = np.array(normalized_datas)
    assert normalized_datas.shape == unnormalized_datas.shape
    return normalized_datas


# apply ln() to the time series data
def apply_ln_to_curves(datas):
    ln_datas = []
    for data in datas:
        ln_data = np.log(data)
        ln_datas.append(ln_data)
    ln_datas = np.array(ln_datas)
    assert ln_datas.shape == datas.shape
    return ln_datas


# split the time series data into wanted time points
def split_time_series(datas, start, end):
    datas = datas[:, start:end]
    return datas


# plot the time series data, randomly picked n samples, different colors represent different classes
def plot_random_time_series(datas, n, labels):
    for i in range(n):
        idx = np.random.randint(datas.shape[0])
        plt.plot(datas[idx], color = 'blue' if labels[idx] == 1 else 'red', alpha = 0.2)
    plt.show()


X_train = normalize_curves_mean_method(X_train)
X_test = normalize_curves_mean_method(X_test)
plot_random_time_series(X_train, 100, y_train)
# X_train = normalize_curves_zscore(X_train)
# X_test = normalize_curves_zscore(X_test)
print('X_train shape:', X_train.shape)
print('X_train range:', np.min(X_train), np.max(X_train))
print('X_test shape:', X_test.shape)
print('X_test range:', np.min(X_test), np.max(X_test))
# Out:
# X_train shape: (540, 600)
# X_train range: -27.382237339377753 890.6585034013606
# X_test shape: (140, 600)
# X_test range: -33.20770975056621 708.0417989417983

# %%
# upsample the one class in the training set by given factor
# add some level of noise to the time series data with maintaining mean & std
# class_label: 1 is alive, 0 is dead
def data_augmentation(X_train, y_train, n_times, class_label=1, random_seed=42):
    np.random.seed(random_seed)
    X_train_augmented = X_train.copy()
    y_train_augmented = y_train.copy()
    for i in range(len(y_train)):
        if y_train[i] == class_label:
            for _ in range(n_times):
                X_train_augmented = np.concatenate((X_train_augmented, [X_train[i] + np.random.normal(0, 0.1, X_train[i].shape)]), axis=0)
                y_train_augmented = np.concatenate((y_train_augmented, [y_train[i]]), axis=0)
    return X_train_augmented, y_train_augmented



print('Before, Class ratio:', Counter(y_train))
#X_train, y_train = data_augmentation(X_train, y_train, 10, class_label=0)
#X_train, y_train = data_augmentation(X_train, y_train, 4, class_label=1)
print('After, Class ratio:', Counter(y_train))
# Out:
# Before, Class ratio: Counter({1: 395, 0: 145})
# After, Class ratio: Counter({1: 395, 0: 145})

# %%
# compute mean & std of the training set, then normalize the whole dataset using z-normalization
mean = np.mean(X_train)
std = np.std(X_train)
X_train = (X_train - mean) / std
X_test = (X_test - mean) / std

# %%
# Ensure data is shaped correctly
X_train = X_train.reshape(-1, 1, 600)  # Convert to (samples, 1, timesteps)
X_test = X_test.reshape(-1, 1, 600)
y_train = y_train.reshape(-1, 1)  # Ensure labels are in shape (samples, 1)
y_test = y_test.reshape(-1, 1)

print('X_train shape:', X_train.shape)
print('y_train shape:', y_train.shape)
print('X_test shape:', X_test.shape)
print('y_test shape:', y_test.shape)
# Out:
# X_train shape: (540, 1, 600)
# y_train shape: (540, 1)
# X_test shape: (140, 1, 600)
# y_test shape: (140, 1)

# %%
# Train final model on full training data
final_model = generate_lstm(dropout=0)
class_weights = compute_class_weight(y_train)
print('class_weights:', class_weights)
reduce_lr = ReduceLROnPlateau(monitor='loss', patience=15, mode='auto',
    factor=1. / np.cbrt(2), cooldown=0, min_lr=5e-7, verbose=2)
final_model.compile(optimizer=Adam(learning_rate=8e-6), loss='binary_crossentropy', metrics=['accuracy'])

# split the data into training and validation set
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# Train model
history = final_model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    callbacks=[reduce_lr],
    epochs=1100, batch_size=16, class_weight={0: class_weights[0], 1: class_weights[1]},
    verbose=1
)

# Predict on test set
y_pred_prob = final_model.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)

# Calculate metrics
accuracy = accuracy_score(y_test, y_pred)
precision, recall, f1, _ = precision_recall_fscore_support(y_test, y_pred, average='binary')
roc_auc = roc_auc_score(y_test, y_pred_prob)
conf_matrix = confusion_matrix(y_test, y_pred)

# plot the metrics
print(f"Test Accuracy: {accuracy:.4f}")
print(f"Test F1 Score: {f1:.4f}")
print(f"Test Precision: {precision:.4f}")
print(f"Test Recall: {recall:.4f}")
print(f"Test ROC AUC Score: {roc_auc:.4f}")
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Dead', 'Alive'], yticklabels=['Dead', 'Alive'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()


# plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.figure(figsize=(10, 7))
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.figure(figsize=(10, 7))
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# class_weights: [1.86206897 0.6835443 ]
# Epoch 1/1100
# 27/27 [==============================] - 1s 10ms/step - loss: 0.6890 - accuracy: 0.3032 - val_loss: 0.7239 - val_accuracy: 0.2870 - lr: 8.0000e-06
# Epoch 2/1100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6843 - accuracy: 0.3218 - val_loss: 0.7163 - val_accuracy: 0.3241 - lr: 8.0000e-06
# Epoch 3/1100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.6796 - accuracy: 0.3565 - val_loss: 0.7085 - val_accuracy: 0.3611 - lr: 8.0000e-06
# Epoch 4/1100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.6752 - accuracy: 0.4051 - val_loss: 0.7011 - val_accuracy: 0.4167 - lr: 8.0000e-06
# Epoch 5/1100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6707 - accuracy: 0.4653 - val_loss: 0.6930 - val_accuracy: 0.4815 - lr: 8.0000e-06
# Epoch 6/1100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.6661 - accuracy: 0.5116 - val_loss: 0.6864 - val_accuracy: 0.5370 - lr: 8.0000e-06
# Epoch 7/1100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.6619 - accuracy: 0.5787 - val_loss: 0.6787 - val_accuracy: 0.5648 - lr: 8.0000e-06
# Epoch 8/1100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.6573 - accuracy: 0.6273 - val_loss: 0.6727 - val_accuracy: 0.5926 - lr: 8.0000e-06
# Epoch 9/1100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6529 - accuracy: 0.6412 - val_loss: 0.6676 - val_accuracy: 0.6204 - lr: 8.0000e-06
# Epoch 10/1100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.6485 - accuracy: 0.6597 - val_loss: 0.6612 - val_accuracy: 0.6481 - lr: 8.0000e-06
# Epoch 11/1100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.6440 - accuracy: 0.6806 - val_loss: 0.6548 - val_accuracy: 0.6944 - lr: 8.0000e-06
# Epoch 12/1100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.6394 - accuracy: 0.6991 - val_loss: 0.6485 - val_accuracy: 0.6944 - lr: 8.0000e-06
# Epoch 13/1100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.
- val_accuracy: 0.7778 - lr: 8.0000e-06
# Epoch 1057/1100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4855 - accuracy: 0.7847 - val_loss: 0.4899 - val_accuracy: 0.7870 - lr: 8.0000e-06
# Epoch 1058/1100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4856 - accuracy: 0.7824 - val_loss: 0.4927 - val_accuracy: 0.7778 - lr: 8.0000e-06
# Epoch 1059/1100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4853 - accuracy: 0.7801 - val_loss: 0.4918 - val_accuracy: 0.7778 - lr: 8.0000e-06
# Epoch 1060/1100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4854 - accuracy: 0.7801 - val_loss: 0.4927 - val_accuracy: 0.7778 - lr: 8.0000e-06
# Epoch 1061/1100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4853 - accuracy: 0.7801 - val_loss: 0.4908 - val_accuracy: 0.7870 - lr: 8.0000e-06
# Epoch 1062/1100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4855 - accuracy: 0.7801 - val_loss: 0.4913 - val_accuracy: 0.7778 - lr: 8.0000e-06
# Epoch 1063/1100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4854 - accuracy: 0.7801 - val_loss: 0.4917 - val_accuracy: 0.7778 - lr: 8.0000e-06
# Epoch 1064/1100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4852 - accuracy: 0.7801 - val_loss: 0.4916 - val_accuracy: 0.7778 - lr: 8.0000e-06
# Epoch 1065/1100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4852 - accuracy: 0.7801 - val_loss: 0.4903 - val_accuracy: 0.7870 - lr: 8.0000e-06
# Epoch 1066/1100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4853 - accuracy: 0.7801 - val_loss: 0.4906 - val_accuracy: 0.7870 - lr: 8.0000e-06
# Epoch 1067/1100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4852 - accuracy: 0.7801 - val_loss: 0.4917 - val_accuracy: 0.7778 - lr: 8.0000e-06
# Epoch 1068/1100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4854 - accuracy: 0.7847 - val_loss: 0.4891 - val_accuracy: 0.7870 - lr: 8.0000e-06
# Epoch 1069/1100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4851 - accuracy: 0.7847 - val_loss: 0.4901 - val_accuracy: 0.7870 - lr: 8.0000e-06
# Epoch 1070/1100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4852 - accuracy: 0.7801 - val_loss: 0.4918 - val_accuracy: 0.7778 - lr: 8.0000e-06
# Epoch 1071/1100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4850 - accuracy: 0.7801 - val_loss: 0.4910 - val_accuracy: 0.7778 - lr: 8.0000e-06
# Epoch 1072/1100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4853 - accuracy: 0.7801 - val_loss: 0.4933 - val_accuracy: 0.7778 - lr: 8.0000e-06
# Epoch 1073/1100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4850 - accuracy: 0.7801 - val_loss: 0.4908 - val_accuracy: 0.7778 - lr: 8.0000e-06
# Epoch 1074/1100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4850 - accuracy: 0.7801 - val_loss: 0.4908 - val_accuracy: 0.7870 - lr: 8.0000e-06
# Epoch 1075/1100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4850 - accuracy: 0.7847 - val_loss: 0.4898 - val_accuracy: 0.7870 - lr: 8.0000e-06
# Epoch 1076/1100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4851 - accuracy: 0.7801 - val_loss: 0.4918 - val_accuracy: 0.7778 - lr: 8.0000e-06
# Epoch 1077/1100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4849 - accuracy: 0.7801 - val_loss: 0.4913 - val_accuracy: 0.7778 - lr: 8.0000e-06
# Epoch 1078/1100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4849 - accuracy: 0.7801 - val_loss: 0.4919 - val_accuracy: 0.7778 - lr: 8.0000e-06
# Epoch 1079/1100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4849 - accuracy: 0.7801 - val_loss: 0.4914 - val_accuracy: 0.7778 - lr: 8.0000e-06
# Epoch 1080/1100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4849 - accuracy: 0.7801 - val_loss: 0.4919 - val_accuracy: 0.7778 - lr: 8.0000e-06
# Epoch 1081/1100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4849 - accuracy: 0.7824 - val_loss: 0.4907 - val_accuracy: 0.7778 - lr: 8.0000e-06
# Epoch 1082/1100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4849 - accuracy: 0.7801 - val_loss: 0.4917 - val_accuracy: 0.7778 - lr: 8.0000e-06
# Epoch 1083/1100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4849 - accuracy: 0.7801 - val_loss: 0.4917 - val_accuracy: 0.7778 - lr: 8.0000e-06
# Epoch 1084/1100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4848 - accuracy: 0.7801 - val_loss: 0.4921 - val_accuracy: 0.7778 - lr: 8.0000e-06
# Epoch 1085/1100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4855 - accuracy: 0.7870 - val_loss: 0.4891 - val_accuracy: 0.7870 - lr: 8.0000e-06
# Epoch 1086/1100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4847 - accuracy: 0.7824 - val_loss: 0.4918 - val_accuracy: 0.7778 - lr: 8.0000e-06
# Epoch 1087/1100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4847 - accuracy: 0.7801 - val_loss: 0.4920 - val_accuracy: 0.7778 - lr: 8.0000e-06
# Epoch 1088/1100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4846 - accuracy: 0.7801 - val_loss: 0.4919 - val_accuracy: 0.7778 - lr: 8.0000e-06
# Epoch 1089/1100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4848 - accuracy: 0.7824 - val_loss: 0.4907 - val_accuracy: 0.7778 - lr: 8.0000e-06
# Epoch 1090/1100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4847 - accuracy: 0.7801 - val_loss: 0.4922 - val_accuracy: 0.7778 - lr: 8.0000e-06
# Epoch 1091/1100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4846 - accuracy: 0.7801 - val_loss: 0.4911 - val_accuracy: 0.7778 - lr: 8.0000e-06
# Epoch 1092/1100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4846 - accuracy: 0.7801 - val_loss: 0.4917 - val_accuracy: 0.7778 - lr: 8.0000e-06
# Epoch 1093/1100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4846 - accuracy: 0.7801 - val_loss: 0.4907 - val_accuracy: 0.7778 - lr: 8.0000e-06
# Epoch 1094/1100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4846 - accuracy: 0.7801 - val_loss: 0.4916 - val_accuracy: 0.7778 - lr: 8.0000e-06
# Epoch 1095/1100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4845 - accuracy: 0.7801 - val_loss: 0.4920 - val_accuracy: 0.7778 - lr: 8.0000e-06
# Epoch 1096/1100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4845 - accuracy: 0.7801 - val_loss: 0.4914 - val_accuracy: 0.7778 - lr: 8.0000e-06
# Epoch 1097/1100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4845 - accuracy: 0.7824 - val_loss: 0.4910 - val_accuracy: 0.7778 - lr: 8.0000e-06
# Epoch 1098/1100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4846 - accuracy: 0.7801 - val_loss: 0.4908 - val_accuracy: 0.7778 - lr: 8.0000e-06
# Epoch 1099/1100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4844 - accuracy: 0.7824 - val_loss: 0.4901 - val_accuracy: 0.7778 - lr: 8.0000e-06
# Epoch 1100/1100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4844 - accuracy: 0.7801 - val_loss: 0.4902 - val_accuracy: 0.7778 - lr: 8.0000e-06
# 5/5 [==============================] - 0s 895us/step
# Test Accuracy: 0.7714
# Test F1 Score: 0.7778
# Test Precision: 0.7568
# Test Recall: 0.8000
# Test ROC AUC Score: 0.8392
