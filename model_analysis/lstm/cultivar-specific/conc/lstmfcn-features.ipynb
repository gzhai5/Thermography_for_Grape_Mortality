# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import accuracy_score, roc_auc_score, recall_score, precision_score, f1_score
from sklearn.metrics import confusion_matrix, precision_recall_fscore_support
import seaborn as sns
from collections import Counter
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau
import sys
sys.path.append(r'C:\Users\Mud\Desktop\2ndPaper\lstm')
from model.lstmfcn import generate_lstmfcn
from model.fcn import generate_fcn
from model.lstm import generate_lstm
from utils.class_weight import compute_class_weight
import tensorflow as tf
import random as python_random

# %%
# load the data
X_test_time = np.load(r'C:\Users\Mud\Desktop\2ndPaper\lstm\cultivar-specific\data\conc\X_test_con.npy')
X_train_time = np.load(r'C:\Users\Mud\Desktop\2ndPaper\lstm\cultivar-specific\data\conc\X_train_con.npy')
y_test = np.load(r'C:\Users\Mud\Desktop\2ndPaper\lstm\cultivar-specific\data\conc\y_test_con.npy')
y_train = np.load(r'C:\Users\Mud\Desktop\2ndPaper\lstm\cultivar-specific\data\conc\y_train_con.npy')
X_test_features = np.load(r'C:\Users\Mud\Desktop\2ndPaper\traditional_ml\weka\data\conc\X_test_con.npy', allow_pickle=True)
X_train_features = np.load(r'C:\Users\Mud\Desktop\2ndPaper\traditional_ml\weka\data\conc\X_train_con.npy', allow_pickle=True)

# # load fake data
#X_train = np.load('./fake/train/X_train.npy')
#y_train = np.load('./fake/train/y_train.npy')
#X_test = np.load('./fake/test/X_test.npy')
#y_test = np.load('./fake/test/y_test.npy')


print('X_train of time series shape:', X_train_time.shape)
print('X_test of time series shape:', X_test_time.shape)
print('X_train of features shape:', X_train_features.shape)
print('X_test of features shape:', X_test_features.shape)
print('y_train shape:', y_train.shape)
print('y_test shape:', y_test.shape)
# Out:
# X_train of time series shape: (526, 600)
# X_test of time series shape: (140, 600)
# X_train of features shape: (526,)
# X_test of features shape: (140,)
# y_train shape: (526,)
# y_test shape: (140,)

# %%
def reset_random_seeds(seed=42):
   np.random.seed(seed)
   python_random.seed(seed)
   tf.random.set_seed(seed)

reset_random_seeds()

# %%
# normalize the data to have same starting pt for all time series
# input shape: (n_samples, n_timepoints), want each samples - its mean of 0-30th timepts
def normalize_curves_mean_method(unnormalized_datas):
    normalized_datas = []
    for unnormalized_data in unnormalized_datas:
        mean = np.mean(unnormalized_data[:30])
        normalized_data = unnormalized_data - mean
        normalized_datas.append(normalized_data)
    normalized_datas = np.array(normalized_datas)
    assert normalized_datas.shape == unnormalized_datas.shape
    return normalized_datas

# normalize the data using z-score, have mean 0 and std 1
def normalize_curves_zscore(unnormalized_datas):
    normalized_datas = []
    for unnormalized_data in unnormalized_datas:
        mean = np.mean(unnormalized_data)
        std = np.std(unnormalized_data)
        normalized_data = (unnormalized_data - mean) / std
        normalized_datas.append(normalized_data)
    normalized_datas = np.array(normalized_datas)
    assert normalized_datas.shape == unnormalized_datas.shape
    return normalized_datas


# apply ln() to the time series data
def apply_ln_to_curves(datas):
    ln_datas = []
    for data in datas:
        ln_data = np.log(data)
        ln_datas.append(ln_data)
    ln_datas = np.array(ln_datas)
    assert ln_datas.shape == datas.shape
    return ln_datas


# split the time series data into wanted time points
def split_time_series(datas, start, end):
    datas = datas[:, start:end]
    return datas


# plot the time series data, randomly picked n samples, different colors represent different classes
def plot_random_time_series(datas, n, labels):
    for i in range(n):
        idx = np.random.randint(datas.shape[0])
        plt.plot(datas[idx], color = 'blue' if labels[idx] == 1 else 'red', alpha = 0.2)
    plt.show()


X_train_time = normalize_curves_mean_method(X_train_time)
X_test_time = normalize_curves_mean_method(X_test_time)
plot_random_time_series(X_train_time, 100, y_train)

# %%
# normalize the features data
X_train_features = pd.DataFrame.from_records(X_train_features.flatten())
X_test_features = pd.DataFrame.from_records(X_test_features.flatten())
print(X_train_features.head(1))

scaler = StandardScaler()
features = X_train_features.columns
X_train_features[features] = scaler.fit_transform(X_train_features[features])
X_test_features[features] = scaler.transform(X_test_features[features])
print(X_train_features.head(1))
# Out:
#           pc0         pc1        pc2  rising_waveform  falling_waveform  \
# 0 -1145.10333 -184.335831  44.555012         1.008289          0.595026
#
#    peak_temperature  cultivar
# 0        272.237944         3
#         pc0       pc1       pc2  rising_waveform  falling_waveform  \
# 0 -0.292195 -1.162778  0.450848        -0.342958         -0.361642
#
#    peak_temperature  cultivar
# 0         -0.342958       0.0

# %%
# normalize the time series data
# compute mean & std of the training set, then normalize the whole dataset using z-normalization
mean = np.mean(X_train_time)
std = np.std(X_train_time)
X_train_time = (X_train_time - mean) / std
X_test_time = (X_test_time - mean) / std

# %%
# Ensure data is shaped correctly
X_train_time = X_train_time.reshape(-1, 1, 600)  # Convert to (samples, 1, timesteps)
X_test_time = X_test_time.reshape(-1, 1, 600)
y_train = y_train.reshape(-1, 1)  # Ensure labels are in shape (samples, 1)
y_test = y_test.reshape(-1, 1)
X_train_features = X_train_features.values
X_test_features = X_test_features.values

print('X_train shape of time series:', X_train_time.shape)
print('y_train shape:', y_train.shape)
print('X_test shape of time series:', X_test_time.shape)
print('y_test shape:', y_test.shape)
print('X_train shape of features:', X_train_features.shape)
print('X_test shape of features:', X_test_features.shape)
# Out:
# X_train shape of time series: (526, 1, 600)
# y_train shape: (526, 1)
# X_test shape of time series: (140, 1, 600)
# y_test shape: (140, 1)
# X_train shape of features: (526, 7)
# X_test shape of features: (140, 7)

# %%
# Train final model on full training data# Initialize model
final_model = generate_lstmfcn(feature_input_accept=True, dropout=0.0)
class_weights = compute_class_weight(y_train)
print('class_weights:', class_weights)
reduce_lr = ReduceLROnPlateau(monitor='loss', patience=15, mode='auto',
    factor=1. / np.cbrt(2), cooldown=0, min_lr=1e-6, verbose=2)
final_model.compile(optimizer=Adam(learning_rate=5e-6), loss='binary_crossentropy', metrics=['accuracy'])

# split the data into training and validation set
X_train_time, X_val_time, X_train_features, X_val_features, y_train, y_val = train_test_split(
    X_train_time, X_train_features, y_train, test_size=0.2, random_state=42)
print('X_train shape of time series:', X_train_time.shape)
print('y_train shape:', y_train.shape)
print('X_val shape of time series:', X_val_time.shape)
print('y_val shape:', y_val.shape)
print('X_train shape of features:', X_train_features.shape)
print('X_val shape of features:', X_val_features.shape)

# Train model
history = final_model.fit(
    [X_train_time, X_train_features], y_train,
    validation_data=([X_val_time, X_val_features], y_val),
    callbacks=[reduce_lr],
    epochs=200, batch_size=16, class_weight={0: class_weights[0], 1: class_weights[1]},
    verbose=1
)

# Predict on test set
y_pred_prob = final_model.predict([X_test_time, X_test_features])
y_pred = (y_pred_prob > 0.5).astype(int)

# Calculate metrics
accuracy = accuracy_score(y_test, y_pred)
precision, recall, f1, _ = precision_recall_fscore_support(y_test, y_pred, average='binary')
roc_auc = roc_auc_score(y_test, y_pred_prob)
conf_matrix = confusion_matrix(y_test, y_pred)

# plot the metrics
print(f"Test Accuracy: {accuracy:.4f}")
print(f"Test F1 Score: {f1:.4f}")
print(f"Test Precision: {precision:.4f}")
print(f"Test Recall: {recall:.4f}")
print(f"Test ROC AUC Score: {roc_auc:.4f}")
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Dead', 'Alive'], yticklabels=['Dead', 'Alive'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()


# plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.figure(figsize=(10, 7))
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.figure(figsize=(10, 7))
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# class_weights: [1.51149425 0.74715909]
# X_train shape of time series: (420, 1, 600)
# y_train shape: (420, 1)
# X_val shape of time series: (106, 1, 600)
# y_val shape: (106, 1)
# X_train shape of features: (420, 7)
# X_val shape of features: (106, 7)
# Epoch 1/200
# 27/27 [==============================] - 6s 101ms/step - loss: 0.9208 - accuracy: 0.6738 - val_loss: 0.7775 - val_accuracy: 0.6509 - lr: 5.0000e-06
# Epoch 2/200
# 27/27 [==============================] - 2s 67ms/step - loss: 0.8572 - accuracy: 0.6738 - val_loss: 0.7281 - val_accuracy: 0.6509 - lr: 5.0000e-06
# Epoch 3/200
# 27/27 [==============================] - 2s 70ms/step - loss: 0.8202 - accuracy: 0.6738 - val_loss: 0.6973 - val_accuracy: 0.6509 - lr: 5.0000e-06
# Epoch 4/200
# 27/27 [==============================] - 2s 70ms/step - loss: 0.7789 - accuracy: 0.6738 - val_loss: 0.6725 - val_accuracy: 0.6509 - lr: 5.0000e-06
# Epoch 5/200
# 27/27 [==============================] - 2s 68ms/step - loss: 0.7381 - accuracy: 0.6738 - val_loss: 0.6513 - val_accuracy: 0.6509 - lr: 5.0000e-06
# Epoch 6/200
# 27/27 [==============================] - 2s 68ms/step - loss: 0.7123 - accuracy: 0.6738 - val_loss: 0.6336 - val_accuracy: 0.6509 - lr: 5.0000e-06
# Epoch 7/200
# 27/27 [==============================] - 2s 68ms/step - loss: 0.6952 - accuracy: 0.6786 - val_loss: 0.6175 - val_accuracy: 0.6415 - lr: 5.0000e-06
# Epoch 8/200
# 27/27 [==============================] - 2s 75ms/step - loss: 0.6762 - accuracy: 0.6833 - val_loss: 0.6036 - val_accuracy: 0.6887 - lr: 5.0000e-06
# Epoch 9/200
# 27/27 [==============================] - 2s 72ms/step - loss: 0.6590 - accuracy: 0.6976 - val_loss: 0.5896 - val_accuracy: 0.7358 - lr: 5.0000e-06
# Epoch 10/200
# 27/27 [==============================] - 2s 72ms/step - loss: 0.6456 - accuracy: 0.7048 - val_loss: 0.5797 - val_accuracy: 0.7642 - lr: 5.0000e-06
# Epoch 11/200
# 27/27 [==============================] - 2s 71ms/step - loss: 0.6350 - accuracy: 0.7214 - val_loss: 0.5708 - val_accuracy: 0.7453 - lr: 5.0000e-06
# Epoch 12/200
# 27/27 [==============================] - 2s 75ms/step - loss: 0.6308 - accuracy: 0.7286 - val_loss: 0.5637 - val_accuracy: 0.7642 - lr: 5.0000e-06
# Epoch 13/200
# 27/27 [==============================] - 2s 69ms/step - loss: 0.6319 - accuracy: 0.7262 - val_loss: 0.5578 - val_accuracy: 0.7547 - lr: 5.0000e-06
# Epoch 14/200
# 27/27 [==============================] - 2s 69ms/step - loss: 0.6227 - accuracy: 0.7286 - val_loss: 0.5515 - val_accuracy: 0.7547 - lr: 5.0000e-06
# Epoch 15/200
# 27/27 [==============================] - 2s 67ms/step - loss: 0.6190 - accuracy: 0.7262 - val_loss: 0.5495 - val_accuracy: 0.7736 - lr: 5.0000e-06
# Epoch 16/200
# 27/27 [==============================] - 2s 70ms/step - loss: 0.6128 - accuracy: 0.7310 - val_loss: 0.5456 - val_accuracy: 0.7642 - lr: 5.0000e-06
# Epoch 17/200
# 27/27 [==============================] - 2s 70ms/step - loss: 0.6101 - accuracy: 0.7381 - val_loss: 0.5437 - val_accuracy: 0.7642 - lr: 5.0000e-06
# Epoch 18/200
# 27/27 [==============================] - 2s 67ms/step - loss: 0.6162 - accuracy: 0.7357 - val_loss: 0.5425 - val_accuracy: 0.7736 - lr: 5.0000e-06
# Epoch 19/200
# 27/27 [==============================] - 2s 68ms/step - loss: 0.6043 - accuracy: 0.7381 - val_loss: 0.5407 - val_accuracy: 0.7830 - lr: 5.0000e-06
# Epoch 20/200
# 27/27 [==============================] - 2s 68ms/step - loss: 0.6040 - accuracy: 0.7476 - val_loss: 0.5396 - val_accuracy: 0.7925 - lr: 5.0000e-06
# Epoch 21/200
# 27/27 [==============================] - 2s 83ms/step - loss: 0.6135 - accuracy: 0.7143 - val_loss: 0.5403 - val_accuracy: 0.7925 - lr: 5.0000e-06
# Epoch 22/200
# 27/27 [==============================] - 3s 94ms/step - loss: 0.6022 - accuracy: 0.7262 - val_loss: 0.5404 - val_accuracy: 0.7925 - lr: 5.0000e-06
# Epoch 23/200
# 27/27 [==============================] - 2s 81ms/step - loss: 0.5959 - accuracy: 0.7310 - val_loss: 0.5416 - val_accuracy: 0.7925 - lr: 5.0000e-06
# Epoch 24/200
# 27/27 [==============================] - 3s 95ms/step - loss: 0.5982 - accuracy: 0.7286 - val_loss: 0.5382 - val_accuracy: 0.7925 - lr: 5.0000e-06
# Epoch 25/200
# 27/27 [==============================] - 3s 96ms/step - loss: 0.5967 - accuracy: 0.7405 - val_loss: 0.5370 - val_accuracy: 0.7925 - lr: 5.0000e-06
# Epoch 26/200
# 27/27 [==============================] - 3s 99ms/step - loss: 0.5856 - accuracy: 0.7500 - val_loss: 0.5382 - val_accuracy: 0.7830 - lr: 5.0000e-06
# Epoch 27/200
# 27/27 [==============================] - 3s 97ms/step - loss: 0.5945 - accuracy: 0.7238 - val_loss: 0.5367 - val_accuracy: 0.7925 - lr: 5.0000e-06
# Epoch 28/200
# 27/27 [==============================] - 3s 96ms/step - loss: 0.5942 - accuracy: 0.7429 - val_loss: 0.5355 - val_accuracy: 0.7925 - lr: 5.0000e-06
# Epoch 29/200
# 27/27 [==============================] - 3s 94ms/step - loss: 0.5942 - accuracy: 0.7190 - val_loss: 0.5366 - val_accuracy: 0.7925 - lr: 5.0000e-06
# Epoch 30/200
# 27/27 [==============================] - 3s 94ms/step - loss: 0.5928 - accuracy: 0.7357 - val_loss: 0.5344 - val_accuracy: 0.7925 - lr: 5.0000e-06
# Epoch 31/200
# 27/27 [==============================] - 2s 93ms/step - loss: 0.5825 - accuracy: 0.7476 - val_loss: 0.5326 - val_accuracy: 0.8019 - lr: 5.0000e-06
# Epoch 32/200
# 27/27 [==============================] - 3s 95ms/step - loss: 0.5852 - accuracy: 0.7381 - val_loss: 0.5316 - val_accuracy: 0.8019 - lr: 5.0000e-06
# Epoch 33/200
# 27/27 [==============================] - 3s 98ms/step - loss: 0.5895 - accuracy: 0.7333 - val_loss: 0.5308 - val_accuracy: 0.8019 - lr: 5.0000e-06
# Epoch 34/200
# 27/27 [==============================] - 3s 94ms/step - loss: 0.5818 - accuracy: 0.7262 - val_loss: 0.5311 - val_accuracy: 0.8113 - lr: 5.0000e-06
# Epoch 35/200
# 27/27 [==============================] - 3s 95ms/step - loss: 0.5900 - accuracy: 0.7071 - val_loss: 0.5302 - val_accuracy: 0.8113 - lr: 5.0000e-06
# Epoch 36/200
# 27/27 [==============================] - 3s 93ms/step - loss: 0.5775 - accuracy: 0.7238 - val_loss: 0.5296 - val_accuracy: 0.8113 - lr: 5.0000e-06
# Epoch 37/200
# 27/27 [==============================] - 3s 96ms/step - loss: 0.5826 - accuracy: 0.7524 - val_loss: 0.5269 - val_accuracy: 0.8113 - lr: 5.0000e-06
# Epoch 38/200
# 27/27 [==============================] - 3s 92ms/step - loss: 0.5863 - accuracy: 0.7452 - val_loss: 0.5262 - val_accuracy: 0.8113 - lr: 5.0000e-06
# Epoch 39/200
# 27/27 [==============================] - 3s 97ms/step - loss: 0.5787 - accuracy: 0.7357 - val_loss: 0.5263 - val_accuracy: 0.8113 - lr: 5.0000e-06
# Epoch 40/200
# 27/27 [==============================] - 3s 99ms/step - loss: 0.5808 - accuracy: 0.7286 - val_loss: 0.5257 - val_accuracy: 0.8113 - lr: 5.0000e-06
# Epoch 41/200
# 27/27 [==============================] - 3s 93ms/step - loss: 0.5793 - accuracy: 0.7119 - val_loss: 0.5241 - val_accuracy: 0.8113 - lr: 5.0000e-06
# Epoch 42/200
# 27/27 [==============================] - 3s 96ms/step - loss: 0.5744 - accuracy: 0.7452 - val_loss: 0.5228 - val_accuracy: 0.8113 - lr: 5.0000e-06
# Epoch 43/200
# 27/27 [==============================] - 3s 94ms/step - loss: 0.5798 - accuracy: 0.7167 - val_loss: 0.5225 - val_accuracy: 0.8113 - lr: 5.0000e-06
# Epoch 44/200
# 27/27 [==============================] - 3s 104ms/step - loss: 0.5711 - accuracy: 0.7381 - val_loss: 0.5214 - val_accuracy: 0.8113 - lr: 5.0000e-06
# Epoch
200
# 27/27 [==============================] - 3s 121ms/step - loss: 0.5687 - accuracy: 0.7262 - val_loss: 0.5144 - val_accuracy: 0.8019 - lr: 3.1498e-06
# Epoch 112/200
# 27/27 [==============================] - 3s 120ms/step - loss: 0.5583 - accuracy: 0.7119 - val_loss: 0.5140 - val_accuracy: 0.8113 - lr: 3.1498e-06
# Epoch 113/200
# 27/27 [==============================] - 3s 118ms/step - loss: 0.5500 - accuracy: 0.7476 - val_loss: 0.5153 - val_accuracy: 0.8019 - lr: 3.1498e-06
# Epoch 114/200
# 27/27 [==============================] - 3s 118ms/step - loss: 0.5654 - accuracy: 0.7357 - val_loss: 0.5132 - val_accuracy: 0.8019 - lr: 3.1498e-06
# Epoch 115/200
# 27/27 [==============================] - 3s 122ms/step - loss: 0.5584 - accuracy: 0.7405 - val_loss: 0.5140 - val_accuracy: 0.8019 - lr: 3.1498e-06
# Epoch 116/200
# 27/27 [==============================] - 3s 114ms/step - loss: 0.5546 - accuracy: 0.7405 - val_loss: 0.5131 - val_accuracy: 0.8019 - lr: 3.1498e-06
# Epoch 117/200
# 27/27 [==============================] - 3s 118ms/step - loss: 0.5605 - accuracy: 0.7405 - val_loss: 0.5117 - val_accuracy: 0.8113 - lr: 3.1498e-06
# Epoch 118/200
# 27/27 [==============================] - 3s 122ms/step - loss: 0.5512 - accuracy: 0.7429 - val_loss: 0.5131 - val_accuracy: 0.8019 - lr: 3.1498e-06
# Epoch 119/200
# 27/27 [==============================] - 3s 119ms/step - loss: 0.5657 - accuracy: 0.7143 - val_loss: 0.5125 - val_accuracy: 0.8019 - lr: 3.1498e-06
# Epoch 120/200
# 27/27 [==============================] - 3s 119ms/step - loss: 0.5556 - accuracy: 0.7357 - val_loss: 0.5125 - val_accuracy: 0.8019 - lr: 3.1498e-06
# Epoch 121/200
# 27/27 [==============================] - 3s 123ms/step - loss: 0.5593 - accuracy: 0.7429 - val_loss: 0.5114 - val_accuracy: 0.8019 - lr: 3.1498e-06
# Epoch 122/200
# 27/27 [==============================] - 3s 116ms/step - loss: 0.5583 - accuracy: 0.7190 - val_loss: 0.5107 - val_accuracy: 0.8019 - lr: 3.1498e-06
# Epoch 123/200
# 27/27 [==============================] - 3s 124ms/step - loss: 0.5712 - accuracy: 0.7119 - val_loss: 0.5119 - val_accuracy: 0.8019 - lr: 3.1498e-06
# Epoch 124/200
# 27/27 [==============================] - 3s 120ms/step - loss: 0.5620 - accuracy: 0.7357 - val_loss: 0.5121 - val_accuracy: 0.8019 - lr: 3.1498e-06
# Epoch 125/200
# 27/27 [==============================] - 3s 118ms/step - loss: 0.5568 - accuracy: 0.7286 - val_loss: 0.5108 - val_accuracy: 0.8019 - lr: 3.1498e-06
# Epoch 126/200
# 27/27 [==============================] - 3s 119ms/step - loss: 0.5619 - accuracy: 0.7429 - val_loss: 0.5117 - val_accuracy: 0.8019 - lr: 3.1498e-06
# Epoch 127/200
# 27/27 [==============================] - 3s 120ms/step - loss: 0.5635 - accuracy: 0.7452 - val_loss: 0.5119 - val_accuracy: 0.8019 - lr: 3.1498e-06
# Epoch 128/200
# 26/27 [===========================>..] - ETA: 0s - loss: 0.5744 - accuracy: 0.7236
# Epoch 128: ReduceLROnPlateau reducing learning rate to 2.499999919802159e-06.
# 27/27 [==============================] - 3s 120ms/step - loss: 0.5747 - accuracy: 0.7238 - val_loss: 0.5119 - val_accuracy: 0.8019 - lr: 3.1498e-06
# Epoch 129/200
# 27/27 [==============================] - 3s 119ms/step - loss: 0.5522 - accuracy: 0.7310 - val_loss: 0.5116 - val_accuracy: 0.8019 - lr: 2.5000e-06
# Epoch 130/200
# 27/27 [==============================] - 3s 118ms/step - loss: 0.5604 - accuracy: 0.7452 - val_loss: 0.5125 - val_accuracy: 0.8019 - lr: 2.5000e-06
# Epoch 131/200
# 27/27 [==============================] - 3s 123ms/step - loss: 0.5640 - accuracy: 0.7333 - val_loss: 0.5134 - val_accuracy: 0.8019 - lr: 2.5000e-06
# Epoch 132/200
# 27/27 [==============================] - 3s 122ms/step - loss: 0.5637 - accuracy: 0.7214 - val_loss: 0.5146 - val_accuracy: 0.8019 - lr: 2.5000e-06
# Epoch 133/200
# 27/27 [==============================] - 3s 123ms/step - loss: 0.5582 - accuracy: 0.7524 - val_loss: 0.5154 - val_accuracy: 0.8019 - lr: 2.5000e-06
# Epoch 134/200
# 27/27 [==============================] - 3s 124ms/step - loss: 0.5642 - accuracy: 0.7452 - val_loss: 0.5160 - val_accuracy: 0.8019 - lr: 2.5000e-06
# Epoch 135/200
# 27/27 [==============================] - 3s 124ms/step - loss: 0.5663 - accuracy: 0.7333 - val_loss: 0.5147 - val_accuracy: 0.8019 - lr: 2.5000e-06
# Epoch 136/200
# 27/27 [==============================] - 3s 123ms/step - loss: 0.5559 - accuracy: 0.7429 - val_loss: 0.5144 - val_accuracy: 0.8019 - lr: 2.5000e-06
# Epoch 137/200
# 27/27 [==============================] - 3s 122ms/step - loss: 0.5654 - accuracy: 0.7238 - val_loss: 0.5155 - val_accuracy: 0.8019 - lr: 2.5000e-06
# Epoch 138/200
# 27/27 [==============================] - 3s 123ms/step - loss: 0.5533 - accuracy: 0.7452 - val_loss: 0.5159 - val_accuracy: 0.7925 - lr: 2.5000e-06
# Epoch 139/200
# 27/27 [==============================] - 3s 123ms/step - loss: 0.5554 - accuracy: 0.7476 - val_loss: 0.5157 - val_accuracy: 0.8019 - lr: 2.5000e-06
# Epoch 140/200
# 27/27 [==============================] - 3s 122ms/step - loss: 0.5537 - accuracy: 0.7333 - val_loss: 0.5149 - val_accuracy: 0.8019 - lr: 2.5000e-06
# Epoch 141/200
# 27/27 [==============================] - 3s 122ms/step - loss: 0.5613 - accuracy: 0.7167 - val_loss: 0.5141 - val_accuracy: 0.8019 - lr: 2.5000e-06
# Epoch 142/200
# 27/27 [==============================] - 3s 116ms/step - loss: 0.5571 - accuracy: 0.7500 - val_loss: 0.5138 - val_accuracy: 0.7925 - lr: 2.5000e-06
# Epoch 143/200
# 26/27 [===========================>..] - ETA: 0s - loss: 0.5504 - accuracy: 0.7452
# Epoch 143: ReduceLROnPlateau reducing learning rate to 1.9842512648338455e-06.
# 27/27 [==============================] - 3s 122ms/step - loss: 0.5515 - accuracy: 0.7429 - val_loss: 0.5135 - val_accuracy: 0.7925 - lr: 2.5000e-06
# Epoch 144/200
# 27/27 [==============================] - 3s 127ms/step - loss: 0.5495 - accuracy: 0.7476 - val_loss: 0.5134 - val_accuracy: 0.7925 - lr: 1.9843e-06
# Epoch 145/200
# 27/27 [==============================] - 3s 116ms/step - loss: 0.5576 - accuracy: 0.7405 - val_loss: 0.5131 - val_accuracy: 0.7925 - lr: 1.9843e-06
# Epoch 146/200
# 27/27 [==============================] - 3s 119ms/step - loss: 0.5690 - accuracy: 0.7190 - val_loss: 0.5130 - val_accuracy: 0.8019 - lr: 1.9843e-06
# Epoch 147/200
# 27/27 [==============================] - 3s 120ms/step - loss: 0.5576 - accuracy: 0.7476 - val_loss: 0.5127 - val_accuracy: 0.8019 - lr: 1.9843e-06
# Epoch 148/200
# 27/27 [==============================] - 3s 119ms/step - loss: 0.5531 - accuracy: 0.7262 - val_loss: 0.5124 - val_accuracy: 0.8019 - lr: 1.9843e-06
# Epoch 149/200
# 27/27 [==============================] - 3s 123ms/step - loss: 0.5550 - accuracy: 0.7500 - val_loss: 0.5121 - val_accuracy: 0.8019 - lr: 1.9843e-06
# Epoch 150/200
# 27/27 [==============================] - 3s 116ms/step - loss: 0.5521 - accuracy: 0.7429 - val_loss: 0.5117 - val_accuracy: 0.8019 - lr: 1.9843e-06
# Epoch 151/200
# 27/27 [==============================] - 3s 122ms/step - loss: 0.5548 - accuracy: 0.7357 - val_loss: 0.5112 - val_accuracy: 0.8019 - lr: 1.9843e-06
# Epoch 152/200
# 27/27 [==============================] - 3s 124ms/step - loss: 0.5608 - accuracy: 0.7286 - val_loss: 0.5115 - val_accuracy: 0.8019 - lr: 1.9843e-06
# Epoch 153/200
# 27/27 [==============================] - 3s 119ms/step - loss: 0.5464 - accuracy: 0.7476 - val_loss: 0.5111 - val_accuracy: 0.8019 - lr: 1.9843e-06
# Epoch 154/200
# 27/27 [==============================] - 3s 121ms/step - loss: 0.5517 - accuracy: 0.7524 - val_loss: 0.5108 - val_accuracy: 0.8019 - lr: 1.9843e-06
# Epoch 155/200
# 27/27 [==============================] - 3s 122ms/step - loss: 0.5604 - accuracy: 0.7429 - val_loss: 0.5091 - val_accuracy: 0.8019 - lr: 1.9843e-06
# Epoch 156/200
# 27/27 [==============================] - 3s 116ms/step - loss: 0.5584 - accuracy: 0.7429 - val_loss: 0.5093 - val_accuracy: 0.8019 - lr: 1.9843e-06
# Epoch 157/200
# 27/27 [==============================] - 3s 120ms/step - loss: 0.5596 - accuracy: 0.7500 - val_loss: 0.5092 - val_accuracy: 0.8019 - lr: 1.9843e-06
# Epoch 158/200
# 27/27 [==============================] - 3s 117ms/step - loss: 0.5499 - accuracy: 0.7429 - val_loss: 0.5094 - val_accuracy: 0.8019 - lr: 1.9843e-06
# Epoch 159/200
# 27/27 [==============================] - 3s 119ms/step - loss: 0.5557 - accuracy: 0.7357 - val_loss: 0.5102 - val_accuracy: 0.8019 - lr: 1.9843e-06
# Epoch 160/200
# 27/27 [==============================] - 3s 125ms/step - loss: 0.5620 - accuracy: 0.7524 - val_loss: 0.5104 - val_accuracy: 0.8019 - lr: 1.9843e-06
# Epoch 161/200
# 27/27 [==============================] - 3s 122ms/step - loss: 0.5586 - accuracy: 0.7714 - val_loss: 0.5105 - val_accuracy: 0.8019 - lr: 1.9843e-06
# Epoch 162/200
# 27/27 [==============================] - 3s 118ms/step - loss: 0.5555 - accuracy: 0.7500 - val_loss: 0.5083 - val_accuracy: 0.8019 - lr: 1.9843e-06
# Epoch 163/200
# 27/27 [==============================] - 3s 121ms/step - loss: 0.5533 - accuracy: 0.7310 - val_loss: 0.5069 - val_accuracy: 0.8019 - lr: 1.9843e-06
# Epoch 164/200
# 27/27 [==============================] - 3s 117ms/step - loss: 0.5642 - accuracy: 0.7405 - val_loss: 0.5080 - val_accuracy: 0.8019 - lr: 1.9843e-06
# Epoch 165/200
# 27/27 [==============================] - 3s 123ms/step - loss: 0.5508 - accuracy: 0.7405 - val_loss: 0.5084 - val_accuracy: 0.8019 - lr: 1.9843e-06
# Epoch 166/200
# 27/27 [==============================] - 3s 121ms/step - loss: 0.5518 - accuracy: 0.7429 - val_loss: 0.5086 - val_accuracy: 0.8019 - lr: 1.9843e-06
# Epoch 167/200
# 27/27 [==============================] - 3s 119ms/step - loss: 0.5673 - accuracy: 0.7214 - val_loss: 0.5096 - val_accuracy: 0.8019 - lr: 1.9843e-06
# Epoch 168/200
# 27/27 [==============================] - ETA: 0s - loss: 0.5491 - accuracy: 0.7405
# Epoch 168: ReduceLROnPlateau reducing learning rate to 1.5749012089766657e-06.
# 27/27 [==============================] - 3s 120ms/step - loss: 0.5491 - accuracy: 0.7405 - val_loss: 0.5088 - val_accuracy: 0.8019 - lr: 1.9843e-06
# Epoch 169/200
# 27/27 [==============================] - 3s 121ms/step - loss: 0.5612 - accuracy: 0.7476 - val_loss: 0.5087 - val_accuracy: 0.8019 - lr: 1.5749e-06
# Epoch 170/200
# 27/27 [==============================] - 3s 122ms/step - loss: 0.5637 - accuracy: 0.7310 - val_loss: 0.5083 - val_accuracy: 0.8019 - lr: 1.5749e-06
# Epoch 171/200
# 27/27 [==============================] - 3s 125ms/step - loss: 0.5637 - accuracy: 0.7143 - val_loss: 0.5088 - val_accuracy: 0.8019 - lr: 1.5749e-06
# Epoch 172/200
# 27/27 [==============================] - 3s 124ms/step - loss: 0.5638 - accuracy: 0.7286 - val_loss: 0.5103 - val_accuracy: 0.8019 - lr: 1.5749e-06
# Epoch 173/200
# 27/27 [==============================] - 3s 120ms/step - loss: 0.5492 - accuracy: 0.7381 - val_loss: 0.5108 - val_accuracy: 0.8019 - lr: 1.5749e-06
# Epoch 174/200
# 27/27 [==============================] - 3s 122ms/step - loss: 0.5544 - accuracy: 0.7524 - val_loss: 0.5119 - val_accuracy: 0.8019 - lr: 1.5749e-06
# Epoch 175/200
# 27/27 [==============================] - 3s 122ms/step - loss: 0.5593 - accuracy: 0.7381 - val_loss: 0.5111 - val_accuracy: 0.8019 - lr: 1.5749e-06
# Epoch 176/200
# 27/27 [==============================] - 3s 119ms/step - loss: 0.5513 - accuracy: 0.7333 - val_loss: 0.5105 - val_accuracy: 0.8019 - lr: 1.5749e-06
# Epoch 177/200
# 27/27 [==============================] - 3s 119ms/step - loss: 0.5469 - accuracy: 0.7571 - val_loss: 0.5104 - val_accuracy: 0.8019 - lr: 1.5749e-06
# Epoch 178/200
# 27/27 [==============================] - 3s 122ms/step - loss: 0.5547 - accuracy: 0.7286 - val_loss: 0.5101 - val_accuracy: 0.8019 - lr: 1.5749e-06
# Epoch 179/200
# 27/27 [==============================] - 3s 118ms/step - loss: 0.5550 - accuracy: 0.7238 - val_loss: 0.5100 - val_accuracy: 0.8019 - lr: 1.5749e-06
# Epoch 180/200
# 27/27 [==============================] - 3s 117ms/step - loss: 0.5584 - accuracy: 0.7500 - val_loss: 0.5101 - val_accuracy: 0.8019 - lr: 1.5749e-06
# Epoch 181/200
# 27/27 [==============================] - 3s 116ms/step - loss: 0.5558 - accuracy: 0.7405 - val_loss: 0.5110 - val_accuracy: 0.8019 - lr: 1.5749e-06
# Epoch 182/200
# 27/27 [==============================] - 3s 117ms/step - loss: 0.5495 - accuracy: 0.7357 - val_loss: 0.5105 - val_accuracy: 0.8019 - lr: 1.5749e-06
# Epoch 183/200
# 26/27 [===========================>..] - ETA: 0s - loss: 0.5551 - accuracy: 0.7476
# Epoch 183: ReduceLROnPlateau reducing learning rate to 1.2499999599010794e-06.
# 27/27 [==============================] - 2s 92ms/step - loss: 0.5545 - accuracy: 0.7476 - val_loss: 0.5109 - val_accuracy: 0.8019 - lr: 1.5749e-06
# Epoch 184/200
# 27/27 [==============================] - 3s 95ms/step - loss: 0.5531 - accuracy: 0.7333 - val_loss: 0.5111 - val_accuracy: 0.7925 - lr: 1.2500e-06
# Epoch 185/200
# 27/27 [==============================] - 2s 92ms/step - loss: 0.5492 - accuracy: 0.7429 - val_loss: 0.5109 - val_accuracy: 0.8019 - lr: 1.2500e-06
# Epoch 186/200
# 27/27 [==============================] - 2s 92ms/step - loss: 0.5560 - accuracy: 0.7429 - val_loss: 0.5104 - val_accuracy: 0.7925 - lr: 1.2500e-06
# Epoch 187/200
# 27/27 [==============================] - 3s 94ms/step - loss: 0.5470 - accuracy: 0.7405 - val_loss: 0.5096 - val_accuracy: 0.8019 - lr: 1.2500e-06
# Epoch 188/200
# 27/27 [==============================] - 2s 91ms/step - loss: 0.5668 - accuracy: 0.7238 - val_loss: 0.5103 - val_accuracy: 0.7925 - lr: 1.2500e-06
# Epoch 189/200
# 27/27 [==============================] - 3s 95ms/step - loss: 0.5561 - accuracy: 0.7429 - val_loss: 0.5097 - val_accuracy: 0.8019 - lr: 1.2500e-06
# Epoch 190/200
# 27/27 [==============================] - 2s 90ms/step - loss: 0.5645 - accuracy: 0.7381 - val_loss: 0.5087 - val_accuracy: 0.8019 - lr: 1.2500e-06
# Epoch 191/200
# 27/27 [==============================] - 2s 90ms/step - loss: 0.5565 - accuracy: 0.7167 - val_loss: 0.5082 - val_accuracy: 0.8019 - lr: 1.2500e-06
# Epoch 192/200
# 27/27 [==============================] - 2s 90ms/step - loss: 0.5588 - accuracy: 0.7310 - val_loss: 0.5084 - val_accuracy: 0.8019 - lr: 1.2500e-06
# Epoch 193/200
# 27/27 [==============================] - 2s 91ms/step - loss: 0.5601 - accuracy: 0.7429 - val_loss: 0.5088 - val_accuracy: 0.8019 - lr: 1.2500e-06
# Epoch 194/200
# 27/27 [==============================] - 2s 91ms/step - loss: 0.5570 - accuracy: 0.7190 - val_loss: 0.5094 - val_accuracy: 0.8019 - lr: 1.2500e-06
# Epoch 195/200
# 27/27 [==============================] - 2s 89ms/step - loss: 0.5560 - accuracy: 0.7286 - val_loss: 0.5085 - val_accuracy: 0.8019 - lr: 1.2500e-06
# Epoch 196/200
# 27/27 [==============================] - 2s 91ms/step - loss: 0.5473 - accuracy: 0.7548 - val_loss: 0.5088 - val_accuracy: 0.8019 - lr: 1.2500e-06
# Epoch 197/200
# 27/27 [==============================] - 3s 95ms/step - loss: 0.5562 - accuracy: 0.7238 - val_loss: 0.5085 - val_accuracy: 0.8019 - lr: 1.2500e-06
# Epoch 198/200
# 26/27 [===========================>..] - ETA: 0s - loss: 0.5555 - accuracy: 0.7380
# Epoch 198: ReduceLROnPlateau reducing learning rate to 1e-06.
# 27/27 [==============================] - 2s 87ms/step - loss: 0.5548 - accuracy: 0.7381 - val_loss: 0.5099 - val_accuracy: 0.7925 - lr: 1.2500e-06
# Epoch 199/200
# 27/27 [==============================] - 2s 92ms/step - loss: 0.5542 - accuracy: 0.7214 - val_loss: 0.5088 - val_accuracy: 0.8019 - lr: 1.0000e-06
# Epoch 200/200
# 27/27 [==============================] - 2s 90ms/step - loss: 0.5566 - accuracy: 0.7286 - val_loss: 0.5087 - val_accuracy: 0.8019 - lr: 1.0000e-06
# 5/5 [==============================] - 1s 22ms/step
# Test Accuracy: 0.6500
# Test F1 Score: 0.6423
# Test Precision: 0.6567
# Test Recall: 0.6286
# Test ROC AUC Score: 0.7024
