# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import accuracy_score, roc_auc_score, recall_score, precision_score, f1_score
from sklearn.metrics import confusion_matrix, precision_recall_fscore_support
import seaborn as sns
from collections import Counter
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau
import sys
sys.path.append(r'C:\Users\Mud\Desktop\2ndPaper\lstm')
from model.lstmfcn import generate_lstmfcn
from model.fcn import generate_fcn
from model.lstm import generate_lstm
from utils.class_weight import compute_class_weight
import tensorflow as tf
import random as python_random

# %%
# # load the data
X_test = np.load(r'C:\Users\Mud\Desktop\2ndPaper\lstm\cultivar-specific\data\conc\X_test_con.npy')
y_test = np.load(r'C:\Users\Mud\Desktop\2ndPaper\lstm\cultivar-specific\data\conc\y_test_con.npy')
X_train = np.load(r'C:\Users\Mud\Desktop\2ndPaper\lstm\cultivar-specific\data\conc\X_train_con.npy')
y_train = np.load(r'C:\Users\Mud\Desktop\2ndPaper\lstm\cultivar-specific\data\conc\y_train_con.npy')

# # load fake data
#X_train = np.load('./fake/train/X_train.npy')
#y_train = np.load('./fake/train/y_train.npy')
#X_test = np.load('./fake/test/X_test.npy')
#y_test = np.load('./fake/test/y_test.npy')


print('X_train shape:', X_train.shape)
print('y_train shape:', y_train.shape)
print('X_test shape:', X_test.shape)
print('y_test shape:', y_test.shape)
# Out:
# X_train shape: (526, 600)
# y_train shape: (526,)
# X_test shape: (140, 600)
# y_test shape: (140,)

# %%
def reset_random_seeds(seed=42):
   np.random.seed(seed)
   python_random.seed(seed)
   tf.random.set_seed(seed)

reset_random_seeds()

# %%
# normalize the data to have same starting pt for all time series
# input shape: (n_samples, n_timepoints), want each samples - its mean of 0-30th timepts
def normalize_curves_mean_method(unnormalized_datas):
    normalized_datas = []
    for unnormalized_data in unnormalized_datas:
        mean = np.mean(unnormalized_data[:30])
        normalized_data = unnormalized_data - mean
        normalized_datas.append(normalized_data)
    normalized_datas = np.array(normalized_datas)
    assert normalized_datas.shape == unnormalized_datas.shape
    return normalized_datas

# normalize the data using z-score, have mean 0 and std 1
def normalize_curves_zscore(unnormalized_datas):
    normalized_datas = []
    for unnormalized_data in unnormalized_datas:
        mean = np.mean(unnormalized_data)
        std = np.std(unnormalized_data)
        normalized_data = (unnormalized_data - mean) / std
        normalized_datas.append(normalized_data)
    normalized_datas = np.array(normalized_datas)
    assert normalized_datas.shape == unnormalized_datas.shape
    return normalized_datas


# apply ln() to the time series data
def apply_ln_to_curves(datas):
    ln_datas = []
    for data in datas:
        ln_data = np.log(data)
        ln_datas.append(ln_data)
    ln_datas = np.array(ln_datas)
    assert ln_datas.shape == datas.shape
    return ln_datas


# split the time series data into wanted time points
def split_time_series(datas, start, end):
    datas = datas[:, start:end]
    return datas


# plot the time series data, randomly picked n samples, different colors represent different classes
def plot_random_time_series(datas, n, labels):
    for i in range(n):
        idx = np.random.randint(datas.shape[0])
        plt.plot(datas[idx], color = 'blue' if labels[idx] == 1 else 'red', alpha = 0.2)
    plt.show()


X_train = normalize_curves_mean_method(X_train)
X_test = normalize_curves_mean_method(X_test)
plot_random_time_series(X_train, 100, y_train)
# X_train = normalize_curves_zscore(X_train)
# X_test = normalize_curves_zscore(X_test)
print('X_train shape:', X_train.shape)
print('X_train range:', np.min(X_train), np.max(X_train))
print('X_test shape:', X_test.shape)
print('X_test range:', np.min(X_test), np.max(X_test))
# Out:
# X_train shape: (526, 600)
# X_train range: -10.496825396825443 630.8869236583523
# X_test shape: (140, 600)
# X_test range: -9.013378684805502 582.6590325018897

# %%
# upsample the one class in the training set by given factor
# add some level of noise to the time series data with maintaining mean & std
# class_label: 1 is alive, 0 is dead
def data_augmentation(X_train, y_train, n_times, class_label=1, random_seed=42):
    np.random.seed(random_seed)
    X_train_augmented = X_train.copy()
    y_train_augmented = y_train.copy()
    for i in range(len(y_train)):
        if y_train[i] == class_label:
            for _ in range(n_times):
                X_train_augmented = np.concatenate((X_train_augmented, [X_train[i] + np.random.normal(0, 0.1, X_train[i].shape)]), axis=0)
                y_train_augmented = np.concatenate((y_train_augmented, [y_train[i]]), axis=0)
    return X_train_augmented, y_train_augmented



print('Before, Class ratio:', Counter(y_train))
#X_train, y_train = data_augmentation(X_train, y_train, 10, class_label=0)
#X_train, y_train = data_augmentation(X_train, y_train, 4, class_label=1)
print('After, Class ratio:', Counter(y_train))
# Out:
# Before, Class ratio: Counter({1: 352, 0: 174})
# After, Class ratio: Counter({1: 352, 0: 174})

# %%
# compute mean & std of the training set, then normalize the whole dataset using z-normalization
mean = np.mean(X_train)
std = np.std(X_train)
X_train = (X_train - mean) / std
X_test = (X_test - mean) / std

# %%
# Ensure data is shaped correctly
X_train = X_train.reshape(-1, 1, 600)  # Convert to (samples, 1, timesteps)
X_test = X_test.reshape(-1, 1, 600)
y_train = y_train.reshape(-1, 1)  # Ensure labels are in shape (samples, 1)
y_test = y_test.reshape(-1, 1)

print('X_train shape:', X_train.shape)
print('y_train shape:', y_train.shape)
print('X_test shape:', X_test.shape)
print('y_test shape:', y_test.shape)
# Out:
# X_train shape: (526, 1, 600)
# y_train shape: (526, 1)
# X_test shape: (140, 1, 600)
# y_test shape: (140, 1)

# %%
# Train final model on full training data
final_model = generate_lstm(dropout=0)
class_weights = compute_class_weight(y_train)
print('class_weights:', class_weights)
reduce_lr = ReduceLROnPlateau(monitor='loss', patience=15, mode='auto',
    factor=1. / np.cbrt(2), cooldown=0, min_lr=5e-7, verbose=2)
final_model.compile(optimizer=Adam(learning_rate=8e-6), loss='binary_crossentropy', metrics=['accuracy'])

# split the data into training and validation set
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# Train model
history = final_model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    callbacks=[reduce_lr],
    epochs=1100, batch_size=16, class_weight={0: class_weights[0], 1: class_weights[1]},
    verbose=1
)

# Predict on test set
y_pred_prob = final_model.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)

# Calculate metrics
accuracy = accuracy_score(y_test, y_pred)
precision, recall, f1, _ = precision_recall_fscore_support(y_test, y_pred, average='binary')
roc_auc = roc_auc_score(y_test, y_pred_prob)
conf_matrix = confusion_matrix(y_test, y_pred)

# plot the metrics
print(f"Test Accuracy: {accuracy:.4f}")
print(f"Test F1 Score: {f1:.4f}")
print(f"Test Precision: {precision:.4f}")
print(f"Test Recall: {recall:.4f}")
print(f"Test ROC AUC Score: {roc_auc:.4f}")
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Dead', 'Alive'], yticklabels=['Dead', 'Alive'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()


# plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.figure(figsize=(10, 7))
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.figure(figsize=(10, 7))
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# class_weights: [1.51149425 0.74715909]
# Epoch 1/1100
# 27/27 [==============================] - 1s 9ms/step - loss: 0.6768 - accuracy: 0.4024 - val_loss: 0.6969 - val_accuracy: 0.4245 - lr: 8.0000e-06
# Epoch 2/1100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6729 - accuracy: 0.4476 - val_loss: 0.6903 - val_accuracy: 0.4811 - lr: 8.0000e-06
# Epoch 3/1100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.6693 - accuracy: 0.4929 - val_loss: 0.6844 - val_accuracy: 0.5472 - lr: 8.0000e-06
# Epoch 4/1100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6657 - accuracy: 0.5238 - val_loss: 0.6788 - val_accuracy: 0.5849 - lr: 8.0000e-06
# Epoch 5/1100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6624 - accuracy: 0.5571 - val_loss: 0.6723 - val_accuracy: 0.6226 - lr: 8.0000e-06
# Epoch 6/1100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.6590 - accuracy: 0.5810 - val_loss: 0.6666 - val_accuracy: 0.6415 - lr: 8.0000e-06
# Epoch 7/1100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6558 - accuracy: 0.6262 - val_loss: 0.6608 - val_accuracy: 0.6604 - lr: 8.0000e-06
# Epoch 8/1100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6527 - accuracy: 0.6476 - val_loss: 0.6549 - val_accuracy: 0.6887 - lr: 8.0000e-06
# Epoch 9/1100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6500 - accuracy: 0.6619 - val_loss: 0.6500 - val_accuracy: 0.7170 - lr: 8.0000e-06
# Epoch 10/1100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6472 - accuracy: 0.6595 - val_loss: 0.6463 - val_accuracy: 0.7264 - lr: 8.0000e-06
# Epoch 11/1100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.6447 - accuracy: 0.6619 - val_loss: 0.6414 - val_accuracy: 0.7358 - lr: 8.0000e-06
# Epoch 12/1100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.
1100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5459 - accuracy: 0.7262 - val_loss: 0.4983 - val_accuracy: 0.8113 - lr: 8.0000e-06
# Epoch 1063/1100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5455 - accuracy: 0.7214 - val_loss: 0.5008 - val_accuracy: 0.8113 - lr: 8.0000e-06
# Epoch 1064/1100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.7214 - val_loss: 0.4997 - val_accuracy: 0.8113 - lr: 8.0000e-06
# Epoch 1065/1100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.7238 - val_loss: 0.4994 - val_accuracy: 0.8113 - lr: 8.0000e-06
# Epoch 1066/1100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5452 - accuracy: 0.7238 - val_loss: 0.5008 - val_accuracy: 0.8113 - lr: 8.0000e-06
# Epoch 1067/1100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5453 - accuracy: 0.7190 - val_loss: 0.5005 - val_accuracy: 0.8113 - lr: 8.0000e-06
# Epoch 1068/1100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5452 - accuracy: 0.7190 - val_loss: 0.5004 - val_accuracy: 0.8113 - lr: 8.0000e-06
# Epoch 1069/1100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5453 - accuracy: 0.7190 - val_loss: 0.5013 - val_accuracy: 0.8113 - lr: 8.0000e-06
# Epoch 1070/1100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.7190 - val_loss: 0.5008 - val_accuracy: 0.8113 - lr: 8.0000e-06
# Epoch 1071/1100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5455 - accuracy: 0.7190 - val_loss: 0.5025 - val_accuracy: 0.8019 - lr: 8.0000e-06
# Epoch 1072/1100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.7167 - val_loss: 0.4991 - val_accuracy: 0.8113 - lr: 8.0000e-06
# Epoch 1073/1100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5452 - accuracy: 0.7190 - val_loss: 0.4994 - val_accuracy: 0.8113 - lr: 8.0000e-06
# Epoch 1074/1100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5451 - accuracy: 0.7190 - val_loss: 0.5008 - val_accuracy: 0.8113 - lr: 8.0000e-06
# Epoch 1075/1100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5452 - accuracy: 0.7238 - val_loss: 0.4996 - val_accuracy: 0.8113 - lr: 8.0000e-06
# Epoch 1076/1100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5450 - accuracy: 0.7190 - val_loss: 0.5015 - val_accuracy: 0.8113 - lr: 8.0000e-06
# Epoch 1077/1100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5451 - accuracy: 0.7190 - val_loss: 0.5006 - val_accuracy: 0.8113 - lr: 8.0000e-06
# Epoch 1078/1100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5450 - accuracy: 0.7190 - val_loss: 0.5007 - val_accuracy: 0.8113 - lr: 8.0000e-06
# Epoch 1079/1100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5451 - accuracy: 0.7190 - val_loss: 0.5016 - val_accuracy: 0.8113 - lr: 8.0000e-06
# Epoch 1080/1100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5450 - accuracy: 0.7190 - val_loss: 0.5015 - val_accuracy: 0.8113 - lr: 8.0000e-06
# Epoch 1081/1100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.5449 - accuracy: 0.7190 - val_loss: 0.5011 - val_accuracy: 0.8113 - lr: 8.0000e-06
# Epoch 1082/1100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5451 - accuracy: 0.7190 - val_loss: 0.5014 - val_accuracy: 0.8113 - lr: 8.0000e-06
# Epoch 1083/1100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5449 - accuracy: 0.7190 - val_loss: 0.5008 - val_accuracy: 0.8113 - lr: 8.0000e-06
# Epoch 1084/1100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5451 - accuracy: 0.7238 - val_loss: 0.4998 - val_accuracy: 0.8113 - lr: 8.0000e-06
# Epoch 1085/1100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5448 - accuracy: 0.7262 - val_loss: 0.5002 - val_accuracy: 0.8208 - lr: 8.0000e-06
# Epoch 1086/1100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5449 - accuracy: 0.7190 - val_loss: 0.5013 - val_accuracy: 0.8113 - lr: 8.0000e-06
# Epoch 1087/1100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5448 - accuracy: 0.7214 - val_loss: 0.5005 - val_accuracy: 0.8113 - lr: 8.0000e-06
# Epoch 1088/1100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5449 - accuracy: 0.7262 - val_loss: 0.4994 - val_accuracy: 0.8113 - lr: 8.0000e-06
# Epoch 1089/1100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5450 - accuracy: 0.7190 - val_loss: 0.5015 - val_accuracy: 0.8113 - lr: 8.0000e-06
# Epoch 1090/1100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5450 - accuracy: 0.7214 - val_loss: 0.5031 - val_accuracy: 0.8113 - lr: 8.0000e-06
# Epoch 1091/1100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5449 - accuracy: 0.7214 - val_loss: 0.5002 - val_accuracy: 0.8208 - lr: 8.0000e-06
# Epoch 1092/1100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5447 - accuracy: 0.7214 - val_loss: 0.5014 - val_accuracy: 0.8113 - lr: 8.0000e-06
# Epoch 1093/1100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5450 - accuracy: 0.7190 - val_loss: 0.5021 - val_accuracy: 0.8113 - lr: 8.0000e-06
# Epoch 1094/1100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5451 - accuracy: 0.7214 - val_loss: 0.5045 - val_accuracy: 0.8019 - lr: 8.0000e-06
# Epoch 1095/1100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5448 - accuracy: 0.7190 - val_loss: 0.5015 - val_accuracy: 0.8113 - lr: 8.0000e-06
# Epoch 1096/1100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5447 - accuracy: 0.7190 - val_loss: 0.5012 - val_accuracy: 0.8113 - lr: 8.0000e-06
# Epoch 1097/1100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5448 - accuracy: 0.7190 - val_loss: 0.5010 - val_accuracy: 0.8113 - lr: 8.0000e-06
# Epoch 1098/1100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5448 - accuracy: 0.7238 - val_loss: 0.5001 - val_accuracy: 0.8208 - lr: 8.0000e-06
# Epoch 1099/1100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5446 - accuracy: 0.7214 - val_loss: 0.5002 - val_accuracy: 0.8208 - lr: 8.0000e-06
# Epoch 1100/1100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5450 - accuracy: 0.7214 - val_loss: 0.4988 - val_accuracy: 0.8113 - lr: 8.0000e-06
# 5/5 [==============================] - 0s 499us/step
# Test Accuracy: 0.6571
# Test F1 Score: 0.6364
# Test Precision: 0.6774
# Test Recall: 0.6000
# Test ROC AUC Score: 0.7084
