# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import accuracy_score, roc_auc_score, recall_score, precision_score, f1_score
from sklearn.metrics import confusion_matrix, precision_recall_fscore_support
import seaborn as sns
from collections import Counter
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau
import sys
sys.path.append(r'C:\Users\Mud\Desktop\2ndPaper\lstm')
from model.lstmfcn import generate_lstmfcn
from model.fcn import generate_fcn
from model.lstm import generate_lstm
from utils.class_weight import compute_class_weight
import tensorflow as tf
import random as python_random

# %%
# # load the data
X_test = np.load(r'C:\Users\Mud\Desktop\2ndPaper\lstm\cultivar-specific\data\conc\X_test_con.npy')
y_test = np.load(r'C:\Users\Mud\Desktop\2ndPaper\lstm\cultivar-specific\data\conc\y_test_con.npy')
X_train = np.load(r'C:\Users\Mud\Desktop\2ndPaper\lstm\cultivar-specific\data\conc\X_train_con.npy')
y_train = np.load(r'C:\Users\Mud\Desktop\2ndPaper\lstm\cultivar-specific\data\conc\y_train_con.npy')

# # load fake data
#X_train = np.load('./fake/train/X_train.npy')
#y_train = np.load('./fake/train/y_train.npy')
#X_test = np.load('./fake/test/X_test.npy')
#y_test = np.load('./fake/test/y_test.npy')


print('X_train shape:', X_train.shape)
print('y_train shape:', y_train.shape)
print('X_test shape:', X_test.shape)
print('y_test shape:', y_test.shape)
# Out:
# X_train shape: (526, 600)
# y_train shape: (526,)
# X_test shape: (140, 600)
# y_test shape: (140,)

# %%
def reset_random_seeds(seed=42):
   np.random.seed(seed)
   python_random.seed(seed)
   tf.random.set_seed(seed)

reset_random_seeds()

# %%
# normalize the data to have same starting pt for all time series
# input shape: (n_samples, n_timepoints), want each samples - its mean of 0-30th timepts
def normalize_curves_mean_method(unnormalized_datas):
    normalized_datas = []
    for unnormalized_data in unnormalized_datas:
        mean = np.mean(unnormalized_data[:30])
        normalized_data = unnormalized_data - mean
        normalized_datas.append(normalized_data)
    normalized_datas = np.array(normalized_datas)
    assert normalized_datas.shape == unnormalized_datas.shape
    return normalized_datas

# normalize the data using z-score, have mean 0 and std 1
def normalize_curves_zscore(unnormalized_datas):
    normalized_datas = []
    for unnormalized_data in unnormalized_datas:
        mean = np.mean(unnormalized_data)
        std = np.std(unnormalized_data)
        normalized_data = (unnormalized_data - mean) / std
        normalized_datas.append(normalized_data)
    normalized_datas = np.array(normalized_datas)
    assert normalized_datas.shape == unnormalized_datas.shape
    return normalized_datas


# apply ln() to the time series data
def apply_ln_to_curves(datas):
    ln_datas = []
    for data in datas:
        ln_data = np.log(data)
        ln_datas.append(ln_data)
    ln_datas = np.array(ln_datas)
    assert ln_datas.shape == datas.shape
    return ln_datas


# split the time series data into wanted time points
def split_time_series(datas, start, end):
    datas = datas[:, start:end]
    return datas


# plot the time series data, randomly picked n samples, different colors represent different classes
def plot_random_time_series(datas, n, labels):
    for i in range(n):
        idx = np.random.randint(datas.shape[0])
        plt.plot(datas[idx], color = 'blue' if labels[idx] == 1 else 'red', alpha = 0.2)
    plt.show()


X_train = normalize_curves_mean_method(X_train)
X_test = normalize_curves_mean_method(X_test)
plot_random_time_series(X_train, 100, y_train)
# X_train = normalize_curves_zscore(X_train)
# X_test = normalize_curves_zscore(X_test)
print('X_train shape:', X_train.shape)
print('X_train range:', np.min(X_train), np.max(X_train))
print('X_test shape:', X_test.shape)
print('X_test range:', np.min(X_test), np.max(X_test))
# Out:
# X_train shape: (526, 600)
# X_train range: -10.496825396825443 630.8869236583523
# X_test shape: (140, 600)
# X_test range: -9.013378684805502 582.6590325018897

# %%
# upsample the one class in the training set by given factor
# add some level of noise to the time series data with maintaining mean & std
# class_label: 1 is alive, 0 is dead
def data_augmentation(X_train, y_train, n_times, class_label=1, random_seed=42):
    np.random.seed(random_seed)
    X_train_augmented = X_train.copy()
    y_train_augmented = y_train.copy()
    for i in range(len(y_train)):
        if y_train[i] == class_label:
            for _ in range(n_times):
                X_train_augmented = np.concatenate((X_train_augmented, [X_train[i] + np.random.normal(0, 0.1, X_train[i].shape)]), axis=0)
                y_train_augmented = np.concatenate((y_train_augmented, [y_train[i]]), axis=0)
    return X_train_augmented, y_train_augmented



print('Before, Class ratio:', Counter(y_train))
#X_train, y_train = data_augmentation(X_train, y_train, 10, class_label=0)
#X_train, y_train = data_augmentation(X_train, y_train, 4, class_label=1)
print('After, Class ratio:', Counter(y_train))
# Out:
# Before, Class ratio: Counter({1: 352, 0: 174})
# After, Class ratio: Counter({1: 352, 0: 174})

# %%
# compute mean & std of the training set, then normalize the whole dataset using z-normalization
mean = np.mean(X_train)
std = np.std(X_train)
#X_train = (X_train - mean) / std
#X_test = (X_test - mean) / std

# %%
# Ensure data is shaped correctly
X_train = X_train.reshape(-1, 1, 600)  # Convert to (samples, 1, timesteps)
X_test = X_test.reshape(-1, 1, 600)
y_train = y_train.reshape(-1, 1)  # Ensure labels are in shape (samples, 1)
y_test = y_test.reshape(-1, 1)

print('X_train shape:', X_train.shape)
print('y_train shape:', y_train.shape)
print('X_test shape:', X_test.shape)
print('y_test shape:', y_test.shape)
# Out:
# X_train shape: (526, 1, 600)
# y_train shape: (526, 1)
# X_test shape: (140, 1, 600)
# y_test shape: (140, 1)

# %%
# Train final model on full training data# Initialize model
final_model = generate_lstmfcn(dropout=0.0)
class_weights = compute_class_weight(y_train)
print('class_weights:', class_weights)
reduce_lr = ReduceLROnPlateau(monitor='loss', patience=15, mode='auto',
    factor=1. / np.cbrt(2), cooldown=0, min_lr=1e-6, verbose=2)
final_model.compile(optimizer=Adam(learning_rate=5e-6), loss='binary_crossentropy', metrics=['accuracy'])

# split the data into training and validation set
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# Train model
history = final_model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    callbacks=[reduce_lr],
    epochs=200, batch_size=16, class_weight={0: class_weights[0], 1: class_weights[1]},
    verbose=1
)

# Predict on test set
y_pred_prob = final_model.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)

# Calculate metrics
accuracy = accuracy_score(y_test, y_pred)
precision, recall, f1, _ = precision_recall_fscore_support(y_test, y_pred, average='binary')
roc_auc = roc_auc_score(y_test, y_pred_prob)
conf_matrix = confusion_matrix(y_test, y_pred)

# plot the metrics
print(f"Test Accuracy: {accuracy:.4f}")
print(f"Test F1 Score: {f1:.4f}")
print(f"Test Precision: {precision:.4f}")
print(f"Test Recall: {recall:.4f}")
print(f"Test ROC AUC Score: {roc_auc:.4f}")
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Dead', 'Alive'], yticklabels=['Dead', 'Alive'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()


# plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.figure(figsize=(10, 7))
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.figure(figsize=(10, 7))
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# class_weights: [1.51149425 0.74715909]
# Epoch 1/200
# 27/27 [==============================] - 5s 88ms/step - loss: 0.7252 - accuracy: 0.6738 - val_loss: 1.1912 - val_accuracy: 0.6509 - lr: 5.0000e-06
# Epoch 2/200
# 27/27 [==============================] - 2s 65ms/step - loss: 0.6827 - accuracy: 0.6738 - val_loss: 0.7375 - val_accuracy: 0.6509 - lr: 5.0000e-06
# Epoch 3/200
# 27/27 [==============================] - 2s 69ms/step - loss: 0.6623 - accuracy: 0.6881 - val_loss: 0.7029 - val_accuracy: 0.5000 - lr: 5.0000e-06
# Epoch 4/200
# 27/27 [==============================] - 2s 71ms/step - loss: 0.6434 - accuracy: 0.7357 - val_loss: 0.6973 - val_accuracy: 0.4623 - lr: 5.0000e-06
# Epoch 5/200
# 27/27 [==============================] - 2s 71ms/step - loss: 0.6237 - accuracy: 0.7476 - val_loss: 0.6853 - val_accuracy: 0.4811 - lr: 5.0000e-06
# Epoch 6/200
# 27/27 [==============================] - 2s 73ms/step - loss: 0.6169 - accuracy: 0.7429 - val_loss: 0.6673 - val_accuracy: 0.5849 - lr: 5.0000e-06
# Epoch 7/200
# 27/27 [==============================] - 2s 70ms/step - loss: 0.6077 - accuracy: 0.7524 - val_loss: 0.6487 - val_accuracy: 0.6132 - lr: 5.0000e-06
# Epoch 8/200
# 27/27 [==============================] - 2s 69ms/step - loss: 0.6023 - accuracy: 0.7571 - val_loss: 0.6304 - val_accuracy: 0.6509 - lr: 5.0000e-06
# Epoch 9/200
# 27/27 [==============================] - 2s 69ms/step - loss: 0.5952 - accuracy: 0.7571 - val_loss: 0.6112 - val_accuracy: 0.7264 - lr: 5.0000e-06
# Epoch 10/200
# 27/27 [==============================] - 2s 71ms/step - loss: 0.5897 - accuracy: 0.7429 - val_loss: 0.5978 - val_accuracy: 0.7547 - lr: 5.0000e-06
# Epoch 11/200
# 27/27 [==============================] - 2s 68ms/step - loss: 0.5864 - accuracy: 0.7333 - val_loss: 0.5872 - val_accuracy: 0.7736 - lr: 5.0000e-06
# Epoch 12/200
# 27/27 [==============================] - 2s 69ms/step - loss: 0.5840 - accuracy: 0.7405 - val_loss: 0.5799 - val_accuracy: 0.7925 - lr: 5.0000e-06
# Epoch 13/200
# 27/27 [==============================] - 2s 66ms/step - loss: 0.5942 - accuracy: 0.7167 - val_loss: 0.5703 - val_accuracy: 0.7736 - lr: 5.0000e-06
# Epoch 14/200
# 27/27 [==============================] - 2s 68ms/step - loss: 0.5826 - accuracy: 0.7333 - val_loss: 0.5599 - val_accuracy: 0.8019 - lr: 5.0000e-06
# Epoch 15/200
# 27/27 [==============================] - 2s 68ms/step - loss: 0.5871 - accuracy: 0.7381 - val_loss: 0.5542 - val_accuracy: 0.8208 - lr: 5.0000e-06
# Epoch 16/200
# 27/27 [==============================] - 2s 77ms/step - loss: 0.5813 - accuracy: 0.7619 - val_loss: 0.5492 - val_accuracy: 0.8208 - lr: 5.0000e-06
# Epoch 17/200
# 27/27 [==============================] - 2s 72ms/step - loss: 0.5808 - accuracy: 0.7214 - val_loss: 0.5454 - val_accuracy: 0.8208 - lr: 5.0000e-06
# Epoch 18/200
# 27/27 [==============================] - 2s 68ms/step - loss: 0.5944 - accuracy: 0.7190 - val_loss: 0.5405 - val_accuracy: 0.8208 - lr: 5.0000e-06
# Epoch 19/200
# 27/27 [==============================] - 2s 69ms/step - loss: 0.5762 - accuracy: 0.7310 - val_loss: 0.5369 - val_accuracy: 0.8208 - lr: 5.0000e-06
# Epoch 20/200
# 27/27 [==============================] - 2s 70ms/step - loss: 0.5784 - accuracy: 0.7357 - val_loss: 0.5337 - val_accuracy: 0.8113 - lr: 5.0000e-06
# Epoch 21/200
# 27/27 [==============================] - 2s 68ms/step - loss: 0.5926 - accuracy: 0.7310 - val_loss: 0.5323 - val_accuracy: 0.8208 - lr: 5.0000e-06
# Epoch 22/200
# 27/27 [==============================] - 2s 69ms/step - loss: 0.5778 - accuracy: 0.7381 - val_loss: 0.5314 - val_accuracy: 0.8113 - lr: 5.0000e-06
# Epoch 23/200
# 27/27 [==============================] - 2s 68ms/step - loss: 0.5759 - accuracy: 0.7452 - val_loss: 0.5316 - val_accuracy: 0.8113 - lr: 5.0000e-06
# Epoch 24/200
# 27/27 [==============================] - 2s 71ms/step - loss: 0.5790 - accuracy: 0.7286 - val_loss: 0.5272 - val_accuracy: 0.8113 - lr: 5.0000e-06
# Epoch 25/200
# 27/27 [==============================] - 2s 69ms/step - loss: 0.5782 - accuracy: 0.7452 - val_loss: 0.5256 - val_accuracy: 0.8208 - lr: 5.0000e-06
# Epoch 26/200
# 27/27 [==============================] - 2s 68ms/step - loss: 0.5686 - accuracy: 0.7357 - val_loss: 0.5277 - val_accuracy: 0.8208 - lr: 5.0000e-06
# Epoch 27/200
# 27/27 [==============================] - 2s 67ms/step - loss: 0.5774 - accuracy: 0.7357 - val_loss: 0.5263 - val_accuracy: 0.8302 - lr: 5.0000e-06
# Epoch 28/200
# 27/27 [==============================] - 2s 82ms/step - loss: 0.5764 - accuracy: 0.7381 - val_loss: 0.5246 - val_accuracy: 0.8208 - lr: 5.0000e-06
# Epoch 29/200
# 27/27 [==============================] - 2s 81ms/step - loss: 0.5784 - accuracy: 0.7143 - val_loss: 0.5266 - val_accuracy: 0.8302 - lr: 5.0000e-06
# Epoch 30/200
# 27/27 [==============================] - 2s 88ms/step - loss: 0.5730 - accuracy: 0.7476 - val_loss: 0.5251 - val_accuracy: 0.8302 - lr: 5.0000e-06
# Epoch 31/200
# 27/27 [==============================] - 3s 96ms/step - loss: 0.5606 - accuracy: 0.7476 - val_loss: 0.5240 - val_accuracy: 0.8208 - lr: 5.0000e-06
# Epoch 32/200
# 27/27 [==============================] - 3s 93ms/step - loss: 0.5701 - accuracy: 0.7524 - val_loss: 0.5230 - val_accuracy: 0.8302 - lr: 5.0000e-06
# Epoch 33/200
# 27/27 [==============================] - 3s 95ms/step - loss: 0.5752 - accuracy: 0.7357 - val_loss: 0.5229 - val_accuracy: 0.8302 - lr: 5.0000e-06
# Epoch 34/200
# 27/27 [==============================] - 3s 95ms/step - loss: 0.5670 - accuracy: 0.7262 - val_loss: 0.5224 - val_accuracy: 0.8302 - lr: 5.0000e-06
# Epoch 35/200
# 27/27 [==============================] - 3s 94ms/step - loss: 0.5767 - accuracy: 0.7357 - val_loss: 0.5211 - val_accuracy: 0.8302 - lr: 5.0000e-06
# Epoch 36/200
# 27/27 [==============================] - 3s 95ms/step - loss: 0.5630 - accuracy: 0.7405 - val_loss: 0.5214 - val_accuracy: 0.8302 - lr: 5.0000e-06
# Epoch 37/200
# 27/27 [==============================] - 3s 94ms/step - loss: 0.5669 - accuracy: 0.7452 - val_loss: 0.5181 - val_accuracy: 0.8208 - lr: 5.0000e-06
# Epoch 38/200
# 27/27 [==============================] - 2s 92ms/step - loss: 0.5682 - accuracy: 0.7405 - val_loss: 0.5176 - val_accuracy: 0.8208 - lr: 5.0000e-06
# Epoch 39/200
# 27/27 [==============================] - 3s 100ms/step - loss: 0.5576 - accuracy: 0.7452 - val_loss: 0.5165 - val_accuracy: 0.8113 - lr: 5.0000e-06
# Epoch 40/200
# 27/27 [==============================] - 3s 98ms/step - loss: 0.5688 - accuracy: 0.7357 - val_loss: 0.5158 - val_accuracy: 0.8113 - lr: 5.0000e-06
# Epoch 41/200
# 27/27 [==============================] - 3s 94ms/step - loss: 0.5655 - accuracy: 0.7214 - val_loss: 0.5144 - val_accuracy: 0.8113 - lr: 5.0000e-06
# Epoch 42/200
# 27/27 [==============================] - 3s 98ms/step - loss: 0.5614 - accuracy: 0.7452 - val_loss: 0.5146 - val_accuracy: 0.8208 - lr: 5.0000e-06
# Epoch 43/200
# 27/27 [==============================] - 2s 92ms/step - loss: 0.5685 - accuracy: 0.7167 - val_loss: 0.5147 - val_accuracy: 0.8208 - lr: 5.0000e-06
# Epoch 44/200
# 27/27 [==============================] - 2s 93ms/step - loss: 0.5559 - accuracy: 0.7524 - val_loss: 0.5129 - val_accuracy: 0.8208 - lr: 5.0000e-06
# Epoch 45/200
# 27/27 [==============================] - 3s 97ms/step - loss: 0.5643 - accuracy: 0.7571 - val_loss: 0.5108 - val_accuracy: 0.8113 - lr: 5.0000e-06
# Epoch 46/200
# 27/27 [==============================] - 3s 94ms/step - loss: 0.5678 - accuracy: 0.7405 - val_loss: 0.5120 - val_accuracy: 0.8113 - lr: 5.0000e-06
# Epoch 47/200
# 27/27 [==============================] - 3s 93ms/step - loss: 0.5637 - accuracy: 0.7381 - val_loss: 0.5120 - val_accuracy: 0.8113 - lr: 5.0000e-06
# Epoch 48/200
# 27/27 [==============================] - 3s 94ms/step - loss: 0.5610 - accuracy: 0.7476 - val_loss: 0.5075 - val_accuracy: 0.8113 - lr: 5.0000e-06
# Epoch 49/200
# 27/27 [==============================] - 3s 97ms/step - loss: 0.5608 - accuracy: 0.7524 - val_loss: 0.5091 - val_accuracy: 0.8113 - lr: 5.0000e-06
# Epoch 50/200
# 27/27 [==============================] - 3s 97ms/step - loss: 0.5639 - accuracy: 0.7357 - val_loss: 0.5068 - val_accuracy: 0.8113 - lr: 5.0000e-06
# Epoch 51/200
# 27/27 [==============================] - 3s 102ms/step - loss: 0.5736 - accuracy: 0.7190 - val_loss: 0.5051 - val_accuracy: 0.8113 - lr: 5.0000e-06
# Epoch 52/200
# 27/27 [==============================] - 3s 96ms/step - loss: 0.5711 - accuracy: 0.7357 - val_loss: 0.5051 - val_accuracy: 0.8113 - lr: 5.0000e-06
# Epoch 53/200
# 27/27 [==============================] - 3s 94ms/step - loss: 0.5698 - accuracy: 0.7286 - val_loss: 0.5039 - val_accuracy: 0.8113 - lr: 5.0000e-06
# Epoch 54/200
# 27/27 [==============================] - 3s 93ms/step - loss: 0.5719 - accuracy: 0.7286 - val_loss: 0.5050 - val_accuracy: 0.8113 - lr: 5.0000e-06
# Epoch 55/200
# 27/27 [==============================] - 3s 97ms/step - loss: 0.5519 - accuracy: 0.7357 - val_loss: 0.5056 - val_accuracy: 0.8113 - lr: 5.0000e-06
# Epoch 56/200
# 27/27 [==============================] - 3s 94ms/step - loss: 0.5529 - accuracy: 0.7333 - val_loss: 0.5113 - val_accuracy: 0.8113 - lr: 5.0000e-06
# Epoch 57/200
# 27/27 [==============================] - 3s 94ms/step - loss: 0.5642 - accuracy: 0.7333 - val_loss: 0.5096 - val_accuracy: 0.8113 - lr: 5.0000e-06
# Epoch 58/200
# 27/27 [==============================] - 2s 92ms/step - loss: 0.5585 - accuracy: 0.7357 - val_loss: 0.5079 - val_accuracy: 0.8113 - lr: 5.0000e-06
# Epoch 59/200
# 27/27 [==============================] - 2s 92ms/step - loss: 0.5706 - accuracy: 0.7048 - val_loss: 0.5070 - val_accuracy: 0.8019 - lr: 5.0000e-06
# Epoch 60/200
# 27/27 [==============================] - 2s 91ms/step - loss: 0.5573 - accuracy: 0.7405 - val_loss: 0.5097 - val_accuracy: 0.8113 - lr: 5.0000e-06
# Epoch 61/200
# 27/27 [==============================] - 2s 93ms/step - loss: 0.5557 - accuracy: 0.7357 - val_loss: 0.5076 - val_accuracy: 0.8113 - lr: 5.0000e-06
# Epoch 62/200
# 27/27 [==============================] - 3s 93ms/step - loss: 0.5510 - accuracy: 0.7333 - val_loss: 0.5094 - val_accuracy: 0.8113 - lr: 5.0000e-06
# Epoch 63/200
# 27/27 [==============================] - 3s 95ms/step - loss: 0.5575 - accuracy: 0.7476 - val_loss: 0.5086 - val_accuracy: 0.8113 - lr: 5.0000e-06
# Epoch 64/200
# 27/27 [==============================] - 3s 96ms/step - loss: 0.5450 - accuracy: 0.7381 - val_loss: 0.5106 - val_accuracy: 0.8113 - lr: 5.0000e-06
# Epoch 65/200
# 27/27 [==============================] - 3s 95ms/step - loss: 0.5606 - accuracy: 0.7262 - val_loss: 0.5078 - val_accuracy: 0.8113 - lr: 5.0000e-06
# Epoch 66/200
# 27/27 [==============================] - 2s 91ms/step - loss: 0.5576 - accuracy: 0.7476 - val_loss: 0.5079 - val_accuracy: 0.8019 - lr: 5.0000e-06
# Epoch 67/200
# 27/27 [==============================] - 2s 92ms/step - loss: 0.5610 - accuracy: 0.7333 - val_loss: 0.5068 - val_accuracy: 0.8019 - lr: 5.0000e-06
# Epoch 68/200
# 27/27 [==============================] - 2s 91ms/step - loss: 0.5684 - accuracy: 0.7310 - val_loss: 0.5068 - val_accuracy: 0.8019 - lr: 5.0000e-06
# Epoch 69/200
# 27/27 [==============================] - 2s 92ms/step - loss: 0.5540 - accuracy: 0.7190 - val_loss: 0.5065 - val_accuracy: 0.8019 - lr: 5.0000e-06
# Epoch 70/200
# 27/27 [==============================] - 2s 93ms/step - loss: 0.5469 - accuracy: 0.7500 - val_loss: 0.5089 - val_accuracy: 0.8113 - lr: 5.0000e-06
# Epoch 71/200
# 27/27 [==============================] - 2s 92ms/step - loss: 0.5581 - accuracy: 0.7190 - val_loss: 0.5085 - val_accuracy: 0.8113 - lr: 5.0000e-06
# Epoch 72/200
# 27/27 [==============================] - 3s 95ms/step - loss: 0.5591 - accuracy: 0.7214 - val_loss: 0.5097 - val_accuracy: 0.8113 - lr: 5.0000e-06
# Epoch 73/200
# 27/27 [==============================] - 3s 117ms/step - loss: 0.5526 - accuracy: 0.7429 - val_loss: 0.5106 - val_accuracy: 0.8113 - lr: 5.0000e-06
# Epoch 74/200
# 27/27 [==============================] - 3s 96ms/step - loss: 0.5571 - accuracy: 0.7429 - val_loss: 0.5082 - val_accuracy: 0.8113 - lr: 5.0000e-06
# Epoch 75/200
# 27/27 [==============================] - 3s 104ms/step - loss: 0.5639 - accuracy: 0.7214 - val_loss: 0.5084 - val_accuracy: 0.8208 - lr: 5.0000e-06
# Epoch 76/200
# 27/27 [==============================] - 3s 117ms/step - loss: 0.5497 - accuracy: 0.7405 - val_loss: 0.5077 - val_accuracy: 0.8113 - lr: 5.0000e-06
# Epoch 77/200
# 27/27 [==============================] - 3s 123ms/step - loss: 0.5533 - accuracy: 0.7476 - val_loss: 0.5088 - val_accuracy: 0.8113 - lr: 5.0000e-06
# Epoch 78/200
# 27/27 [==============================] - 3s 124ms/step - loss: 0.5635 - accuracy: 0.7357 - val_loss: 0.5061 - val_accuracy: 0.8113 - lr: 5.0000e-06
# Epoch 79/200
# 27/27 [==============================] - ETA: 0s - loss: 0.5552 - accuracy: 0.7500
# Epoch 79: ReduceLROnPlateau reducing learning rate to 3.968502529667691e-06.
# 27/27 [==============================] - 3s 122ms/step - loss: 0.5552 - accuracy: 0.7500 - val_loss: 0.5049 - val_accuracy: 0.8019 - lr: 5.0000e-06
# Epoch 80/200
# 27/27 [==============================] - 3s 117ms/step - loss: 0.5504 - accuracy: 0.7357 - val_loss: 0.5075 - val_accuracy: 0.8113 - lr: 3.9685e-06
# Epoch 81/200
# 27/27 [==============================] - 3s 120ms/step - loss: 0.5499 - accuracy: 0.7286 - val_loss: 0.5086 - val_accuracy: 0.8208 - lr: 3.9685e-06
# Epoch 82/200
# 27/27 [==============================] - 3s 117ms/step - loss: 0.5595 - accuracy: 0.7333 - val_loss: 0.5096 - val_accuracy: 0.8302 - lr: 3.9685e-06
# Epoch 83/200
# 27/27 [==============================] - 3s 118ms/step - loss: 0.5578 - accuracy: 0.7381 - val_loss: 0.5102 - val_accuracy: 0.8208 - lr: 3.9685e-06
# Epoch 84/200
# 27/27 [==============================] - 3s 122ms/step - loss: 0.5518 - accuracy: 0.7214 - val_loss: 0.5081 - val_accuracy: 0.8208 - lr: 3.9685e-06
# Epoch 85/200
# 27/27 [==============================] - 3s 119ms/step - loss: 0.5474 - accuracy: 0.7429 - val_loss: 0.5089 - val_accuracy: 0.8208 - lr: 3.9685e-06
# Epoch 86/200
# 27/27 [==============================] - 3s 125ms/step - loss: 0.5481 - accuracy: 0.7405 - val_loss: 0.5104 - val_accuracy: 0.8302 - lr: 3.9685e-06
# Epoch 87/200
# 27/27 [==============================] - 3s 116ms/step - loss: 0.5598 - accuracy: 0.7262 - val_loss: 0.5119 - val_accuracy: 0.8208 - lr: 3.9685e-06
# Epoch 88/200
# 27/27 [==============================] - 3s 126ms/step - loss: 0.5552 - accuracy: 0.7333 - val_loss: 0.5103 - val_accuracy: 0.8302 - lr: 3.9685e-06
# Epoch 89/200
# 27/27 [==============================] - 6s 217ms/step - loss: 0.5470 - accuracy: 0.7405 - val_loss: 0.5093 - val_accuracy: 0.8302 - lr: 3.9685e-06
# Epoch 90/200
# 27/27 [==============================] - 9s 341ms/step - loss: 0.5613 - accuracy: 0.7286 - val_loss: 0.5096 - val_accuracy: 0.8302 - lr: 3.9685e-06
# Epoch 91/200
# 27/27 [==============================] - 9s 339ms/step - loss: 0.5514 - accuracy: 0.7310 - val_loss: 0.5073 - val_accuracy: 0.8208 - lr: 3.9685e-06
# Epoch 92/200
# 27/27 [==============================] - 9s 345ms/step - loss: 0.5554 - accuracy: 0.7357 - val_loss: 0.5074 - val_accuracy: 0.8113 - lr: 3.9685e-06
# Epoch 93/200
# 27/27 [==============================] - 4s 145ms/step - loss: 0.5501 - accuracy: 0.7452 - val_loss: 0.5057 - val_accuracy: 0.8208 - lr: 3.9685e-06
# Epoch 94/200
# 27/27 [==============================] - ETA: 0s - loss: 0.5508 - accuracy: 0.7286
# Epoch 94: ReduceLROnPlateau reducing learning rate to 3.1498024179533314e-06.
# 27/27 [==============================] - 3s 122ms/step - loss: 0.5508 - accuracy: 0.7286 - val_loss: 0.5074 - val_accuracy: 0.8208 - lr: 3.9685e-06
# Epoch 95/200
# 27/27 [==============================] - 3s 119ms/step - loss: 0.5671 - accuracy: 0.7333 - val_loss: 0.5063 - val_accuracy: 0.8208 - lr: 3.1498e-06
# Epoch 96/200
# 27/27 [==============================] - 3s 120ms/step - loss: 0.5530 - accuracy: 0.7381 - val_loss: 0.5090 - val_accuracy: 0.8113 - lr: 3.1498e-06
# Epoch 97/200
# 27/27 [==============================] - 3s 123ms/step - loss: 0.5442 - accuracy: 0.7381 - val_loss: 0.5074 - val_accuracy: 0.8208 - lr: 3.1498e-06
# Epoch 98/200
# 27/27 [==============================] - 3s 115ms/step - loss: 0.5577 - accuracy: 0.7190 - val_loss: 0.5074 - val_accuracy: 0.8208 - lr: 3.1498e-06
# Epoch 99/200
# 27/27 [==============================] - 3s 122ms/step - loss: 0.5535 - accuracy: 0.7238 - val_loss: 0.5056 - val_accuracy: 0.8208 - lr: 3.1498e-06
# Epoch 100/200
# 27/27 [==============================] - 3s 122ms/step - loss: 0.5598 - accuracy: 0.7238 - val_loss: 0.5067 - val_accuracy: 0.8208 - lr: 3.1498e-06
# Epoch 101/200
# 27/27 [==============================] - 3s 123ms/step - loss: 0.5688 - accuracy: 0.7095 - val_loss: 0.5076 - val_accuracy: 0.8208 - lr: 3.1498e-06
# Epoch 102/200
# 27/27 [==============================] - 3s 122ms/step - loss: 0.5505 - accuracy: 0.7357 - val_loss: 0.5093 - val_accuracy: 0.8302 - lr: 3.1498e-06
# Epoch 103/200
# 27/27 [==============================] - 3s 122ms/step - loss: 0.5543 - accuracy: 0.7357 - val_loss: 0.5068 - val_accuracy: 0.8208 - lr: 3.1498e-06
# Epoch 104/200
# 27/27 [==============================] - 3s 117ms/step - loss: 0.5507 - accuracy: 0.7214 - val_loss: 0.5088 - val_accuracy: 0.8302 - lr: 3.1498e-06
# Epoch 105/200
# 27/27 [==============================] - 3s 119ms/step - loss: 0.5539 - accuracy: 0.7452 - val_loss: 0.5080 - val_accuracy: 0.8302 - lr: 3.1498e-06
# Epoch 106/200
# 27/27 [==============================] - 3s 117ms/step - loss: 0.5490 - accuracy: 0.7452 - val_loss: 0.5080 - val_accuracy: 0.8302 - lr: 3.1498e-06
# Epoch 107/200
# 27/27 [==============================] - 3s 120ms/step - loss: 0.5567 - accuracy: 0.7262 - val_loss: 0.5075 - val_accuracy: 0.8208 - lr: 3.1498e-06
# Epoch 108/200
# 27/27 [==============================] - 3s 118ms/step - loss: 0.5573 - accuracy: 0.7119 - val_loss: 0.5089 - val_accuracy: 0.8208 - lr: 3.1498e-06
# Epoch 109/200
# 27/27 [==============================] - 3s 122ms/step - loss: 0.5515 - accuracy: 0.7143 - val_loss: 0.5076 - val_accuracy: 0.8208 - lr: 3.1498e-06
# Epoch 110/200
# 27/27 [==============================] - 3s 119ms/step - loss: 0.5532 - accuracy: 0.7238 - val_loss: 0.5102 - val_accuracy: 0.8302 - lr: 3.1498e-06
# Epoch 111/200
# 27/27 [==============================] - 3s 122ms/step - loss: 0.5631 - accuracy: 0.7333 - val_loss: 0.5116 - val_accuracy: 0.8302 - lr: 3.1498e-06
# Epoch 112/200
# 27/27 [==============================] - ETA: 0s - loss: 0.5498 - accuracy: 0.7214
# Epoch 112: ReduceLROnPlateau reducing learning rate to 2.499999919802159e-06.
# 27/27 [==============================] - 3s 126ms/step - loss: 0.5498 - accuracy: 0.7214 - val_loss: 0.5111 - val_accuracy: 0.8302 - lr: 3.1498e-06
# Epoch 113/200
# 27/27 [==============================] - 3s 122ms/step - loss: 0.5420 - accuracy: 0.7476 - val_loss: 0.5116 - val_accuracy: 0.8302 - lr: 2.5000e-06
# Epoch 114/200
# 27/27 [==============================] - 3s 127ms/step - loss: 0.5536 - accuracy: 0.7429 - val_loss: 0.5099 - val_accuracy: 0.8302 - lr: 2.5000e-06
# Epoch 115/200
# 27/27 [==============================] - 3s 129ms/step - loss: 0.5520 - accuracy: 0.7524 - val_loss: 0.5115 - val_accuracy: 0.8302 - lr: 2.5000e-06
# Epoch 116/200
# 27/27 [==============================] - 3s 122ms/step - loss: 0.5458 - accuracy: 0.7429 - val_loss: 0.5106 - val_accuracy: 0.8302 - lr: 2.5000e-06
# Epoch 117/200
# 27/27 [==============================] - 3s 119ms/step - loss: 0.5546 - accuracy: 0.7357 - val_loss: 0.5099 - val_accuracy: 0.8302 - lr: 2.5000e-06
# Epoch 118/200
# 27/27 [==============================] - 3s 122ms/step - loss: 0.5436 - accuracy: 0.7405 - val_loss: 0.5114 - val_accuracy: 0.8302 - lr: 2.5000e-06
# Epoch 119/200
# 27/27 [==============================] - 3s 119ms/step - loss: 0.5605 - accuracy: 0.6976 - val_loss: 0.5113 - val_accuracy: 0.8302 - lr: 2.5000e-06
# Epoch 120/200
# 27/27 [==============================] - 3s 123ms/step - loss: 0.5468 - accuracy: 0.7381 - val_loss: 0.5112 - val_accuracy: 0.8302 - lr: 2.5000e-06
# Epoch 121/200
# 27/27 [==============================] - 3s 122ms/step - loss: 0.5495 - accuracy: 0.7333 - val_loss: 0.5109 - val_accuracy: 0.8302 - lr: 2.5000e-06
# Epoch 122/200
# 27/27 [==============================] - 3s 124ms/step - loss: 0.5529 - accuracy: 0.7214 - val_loss: 0.5100 - val_accuracy: 0.8302 - lr: 2.5000e-06
# Epoch 123/200
# 27/27 [==============================] - 3s 120ms/step - loss: 0.5649 - accuracy: 0.7095 - val_loss: 0.5108 - val_accuracy: 0.8302 - lr: 2.5000e-06
# Epoch 124/200
# 27/27 [==============================] - 3s 125ms/step - loss: 0.5544 - accuracy: 0.7310 - val_loss: 0.5105 - val_accuracy: 0.8302 - lr: 2.5000e-06
# Epoch 125/200
# 27/27 [==============================] - 3s 122ms/step - loss: 0.5515 - accuracy: 0.7333 - val_loss: 0.5091 - val_accuracy: 0.8302 - lr: 2.5000e-06
# Epoch 126/200
# 27/27 [==============================] - 3s 123ms/step - loss: 0.5552 - accuracy: 0.7357 - val_loss: 0.5101 - val_accuracy: 0.8302 - lr: 2.5000e-06
# Epoch 127/200
# 27/27 [==============================] - 3s 122ms/step - loss: 0.5577 - accuracy: 0.7333 - val_loss: 0.5100 - val_accuracy: 0.8302 - lr: 2.5000e-06
# Epoch 128/200
# 26/27 [===========================>..] - ETA: 0s - loss: 0.5684 - accuracy: 0.7188
# Epoch 128: ReduceLROnPlateau reducing learning rate to 1.9842512648338455e-06.
# 27/27 [==============================] - 3s 119ms/step - loss: 0.5684 - accuracy: 0.7190 - val_loss: 0.5097 - val_accuracy: 0.8302 - lr: 2.5000e-06
# Epoch 129/200
# 27/27 [==============================] - 3s 121ms/step - loss: 0.5423 - accuracy: 0.7286 - val_loss: 0.5086 - val_accuracy: 0.8302 - lr: 1.9843e-06
# Epoch 130/200
# 27/27 [==============================] - 3s 118ms/step - loss: 0.5554 - accuracy: 0.7381 - val_loss: 0.5093 - val_accuracy: 0.8302 - lr: 1.9843e-06
# Epoch 131/200
# 27/27 [==============================] - 3s 121ms/step - loss: 0.5559 - accuracy: 0.7381 - val_loss: 0.5104 - val_accuracy: 0.8302 - lr: 1.9843e-06
# Epoch 132/200
# 27/27 [==============================] - 3s 122ms/step - loss: 0.5562 - accuracy: 0.7310 - val_loss: 0.5119 - val_accuracy: 0.8302 - lr: 1.9843e-06
# Epoch 133/200
# 27/27 [==============================] - 3s 119ms/step - loss: 0.5505 - accuracy: 0.7500 - val_loss: 0.5129 - val_accuracy: 0.8302 - lr: 1.9843e-06
# Epoch 134/200
# 27/27 [==============================] - 3s 121ms/step - loss: 0.5545 - accuracy: 0.7548 - val_loss: 0.5138 - val_accuracy: 0.8208 - lr: 1.9843e-06
# Epoch 135/200
# 27/27 [==============================] - 3s 119ms/step - loss: 0.5594 - accuracy: 0.7310 - val_loss: 0.5127 - val_accuracy: 0.8302 - lr: 1.9843e-06
# Epoch 136/200
# 27/27 [==============================] - 3s 120ms/step - loss: 0.5516 - accuracy: 0.7429 - val_loss: 0.5130 - val_accuracy: 0.8302 - lr: 1.9843e-06
# Epoch 137/200
# 27/27 [==============================] - 3s 121ms/step - loss: 0.5622 - accuracy: 0.7310 - val_loss: 0.5141 - val_accuracy: 0.8208 - lr: 1.9843e-06
# Epoch 138/200
# 27/27 [==============================] - 3s 117ms/step - loss: 0.5449 - accuracy: 0.7405 - val_loss: 0.5146 - val_accuracy: 0.8208 - lr: 1.9843e-06
# Epoch 139/200
# 27/27 [==============================] - 3s 120ms/step - loss: 0.5462 - accuracy: 0.7476 - val_loss: 0.5147 - val_accuracy: 0.8208 - lr: 1.9843e-06
# Epoch 140/200
# 27/27 [==============================] - 3s 123ms/step - loss: 0.5463 - accuracy: 0.7452 - val_loss: 0.5141 - val_accuracy: 0.8208 - lr: 1.9843e-06
# Epoch 141/200
# 27/27 [==============================] - 3s 123ms/step - loss: 0.5575 - accuracy: 0.7119 - val_loss: 0.5127 - val_accuracy: 0.8208 - lr: 1.9843e-06
# Epoch 142/200
# 27/27 [==============================] - 3s 120ms/step - loss: 0.5500 - accuracy: 0.7381 - val_loss: 0.5122 - val_accuracy: 0.8208 - lr: 1.9843e-06
# Epoch 143/200
# 26/27 [===========================>..] - ETA: 0s - loss: 0.5434 - accuracy: 0.7332
# Epoch 143: ReduceLROnPlateau reducing learning rate to 1.5749012089766657e-06.
# 27/27 [==============================] - 3s 123ms/step - loss: 0.5443 - accuracy: 0.7310 - val_loss: 0.5125 - val_accuracy: 0.8208 - lr: 1.9843e-06
# Epoch 144/200
# 27/27 [==============================] - 3s 128ms/step - loss: 0.5419 - accuracy: 0.7381 - val_loss: 0.5124 - val_accuracy: 0.8208 - lr: 1.5749e-06
# Epoch 145/200
# 27/27 [==============================] - 3s 122ms/step - loss: 0.5504 - accuracy: 0.7405 - val_loss: 0.5118 - val_accuracy: 0.8208 - lr: 1.5749e-06
# Epoch 146/200
# 27/27 [==============================] - 3s 98ms/step - loss: 0.5642 - accuracy: 0.7262 - val_loss: 0.5113 - val_accuracy: 0.8208 - lr: 1.5749e-06
# Epoch 147/200
# 27/27 [==============================] - 3s 96ms/step - loss: 0.5524 - accuracy: 0.7429 - val_loss: 0.5112 - val_accuracy: 0.8208 - lr: 1.5749e-06
# Epoch 148/200
# 27/27 [==============================] - 2s 92ms/step - loss: 0.5467 - accuracy: 0.7333 - val_loss: 0.5107 - val_accuracy: 0.8302 - lr: 1.5749e-06
# Epoch 149/200
# 27/27 [==============================] - 2s 93ms/step - loss: 0.5477 - accuracy: 0.7429 - val_loss: 0.5105 - val_accuracy: 0.8302 - lr: 1.5749e-06
# Epoch 150/200
# 27/27 [==============================] - 2s 93ms/step - loss: 0.5465 - accuracy: 0.7405 - val_loss: 0.5103 - val_accuracy: 0.8302 - lr: 1.5749e-06
# Epoch 151/200
# 27/27 [==============================] - 2s 91ms/step - loss: 0.5471 - accuracy: 0.7357 - val_loss: 0.5101 - val_accuracy: 0.8302 - lr: 1.5749e-06
# Epoch 152/200
# 27/27 [==============================] - 3s 98ms/step - loss: 0.5511 - accuracy: 0.7214 - val_loss: 0.5105 - val_accuracy: 0.8302 - lr: 1.5749e-06
# Epoch 153/200
# 27/27 [==============================] - 2s 92ms/step - loss: 0.5396 - accuracy: 0.7500 - val_loss: 0.5102 - val_accuracy: 0.8302 - lr: 1.5749e-06
# Epoch 154/200
# 27/27 [==============================] - 2s 91ms/step - loss: 0.5438 - accuracy: 0.7571 - val_loss: 0.5100 - val_accuracy: 0.8302 - lr: 1.5749e-06
# Epoch 155/200
# 27/27 [==============================] - 3s 96ms/step - loss: 0.5560 - accuracy: 0.7381 - val_loss: 0.5085 - val_accuracy: 0.8302 - lr: 1.5749e-06
# Epoch 156/200
# 27/27 [==============================] - 3s 95ms/step - loss: 0.5538 - accuracy: 0.7405 - val_loss: 0.5087 - val_accuracy: 0.8302 - lr: 1.5749e-06
# Epoch 157/200
# 27/27 [==============================] - 6s 221ms/step - loss: 0.5542 - accuracy: 0.7405 - val_loss: 0.5087 - val_accuracy: 0.8302 - lr: 1.5749e-06
# Epoch 158/200
# 27/27 [==============================] - 4s 139ms/step - loss: 0.5450 - accuracy: 0.7310 - val_loss: 0.5088 - val_accuracy: 0.8302 - lr: 1.5749e-06
# Epoch 159/200
# 27/27 [==============================] - 3s 99ms/step - loss: 0.5448 - accuracy: 0.7452 - val_loss: 0.5097 - val_accuracy: 0.8302 - lr: 1.5749e-06
# Epoch 160/200
# 27/27 [==============================] - 3s 94ms/step - loss: 0.5565 - accuracy: 0.7548 - val_loss: 0.5097 - val_accuracy: 0.8302 - lr: 1.5749e-06
# Epoch 161/200
# 27/27 [==============================] - 3s 94ms/step - loss: 0.5503 - accuracy: 0.7524 - val_loss: 0.5098 - val_accuracy: 0.8302 - lr: 1.5749e-06
# Epoch 162/200
# 27/27 [==============================] - 3s 104ms/step - loss: 0.5498 - accuracy: 0.7405 - val_loss: 0.5077 - val_accuracy: 0.8302 - lr: 1.5749e-06
# Epoch 163/200
# 27/27 [==============================] - 3s 95ms/step - loss: 0.5447 - accuracy: 0.7310 - val_loss: 0.5067 - val_accuracy: 0.8302 - lr: 1.5749e-06
# Epoch 164/200
# 27/27 [==============================] - 3s 99ms/step - loss: 0.5578 - accuracy: 0.7452 - val_loss: 0.5074 - val_accuracy: 0.8302 - lr: 1.5749e-06
# Epoch 165/200
# 27/27 [==============================] - 3s 97ms/step - loss: 0.5474 - accuracy: 0.7405 - val_loss: 0.5077 - val_accuracy: 0.8302 - lr: 1.5749e-06
# Epoch 166/200
# 27/27 [==============================] - 3s 99ms/step - loss: 0.5492 - accuracy: 0.7310 - val_loss: 0.5079 - val_accuracy: 0.8302 - lr: 1.5749e-06
# Epoch 167/200
# 27/27 [==============================] - 3s 100ms/step - loss: 0.5625 - accuracy: 0.7095 - val_loss: 0.5091 - val_accuracy: 0.8302 - lr: 1.5749e-06
# Epoch 168/200
# 27/27 [==============================] - 3s 94ms/step - loss: 0.5393 - accuracy: 0.7405 - val_loss: 0.5083 - val_accuracy: 0.8302 - lr: 1.5749e-06
# Epoch 169/200
# 27/27 [==============================] - 3s 98ms/step - loss: 0.5520 - accuracy: 0.7405 - val_loss: 0.5081 - val_accuracy: 0.8302 - lr: 1.5749e-06
# Epoch 170/200
# 27/27 [==============================] - 3s 95ms/step - loss: 0.5603 - accuracy: 0.7190 - val_loss: 0.5076 - val_accuracy: 0.8302 - lr: 1.5749e-06
# Epoch 171/200
# 27/27 [==============================] - 3s 100ms/step - loss: 0.5588 - accuracy: 0.7214 - val_loss: 0.5081 - val_accuracy: 0.8302 - lr: 1.5749e-06
# Epoch 172/200
# 27/27 [==============================] - 3s 104ms/step - loss: 0.5614 - accuracy: 0.7310 - val_loss: 0.5096 - val_accuracy: 0.8302 - lr: 1.5749e-06
# Epoch 173/200
# 27/27 [==============================] - 3s 102ms/step - loss: 0.5448 - accuracy: 0.7357 - val_loss: 0.5100 - val_accuracy: 0.8302 - lr: 1.5749e-06
# Epoch 174/200
# 27/27 [==============================] - 3s 97ms/step - loss: 0.5505 - accuracy: 0.7405 - val_loss: 0.5112 - val_accuracy: 0.8302 - lr: 1.5749e-06
# Epoch 175/200
# 27/27 [==============================] - 3s 97ms/step - loss: 0.5489 - accuracy: 0.7381 - val_loss: 0.5101 - val_accuracy: 0.8302 - lr: 1.5749e-06
# Epoch 176/200
# 27/27 [==============================] - 3s 96ms/step - loss: 0.5442 - accuracy: 0.7476 - val_loss: 0.5096 - val_accuracy: 0.8302 - lr: 1.5749e-06
# Epoch 177/200
# 27/27 [==============================] - 3s 96ms/step - loss: 0.5391 - accuracy: 0.7429 - val_loss: 0.5092 - val_accuracy: 0.8302 - lr: 1.5749e-06
# Epoch 178/200
# 27/27 [==============================] - 3s 93ms/step - loss: 0.5503 - accuracy: 0.7167 - val_loss: 0.5091 - val_accuracy: 0.8302 - lr: 1.5749e-06
# Epoch 179/200
# 27/27 [==============================] - 3s 95ms/step - loss: 0.5502 - accuracy: 0.7381 - val_loss: 0.5090 - val_accuracy: 0.8302 - lr: 1.5749e-06
# Epoch 180/200
# 27/27 [==============================] - 2s 92ms/step - loss: 0.5528 - accuracy: 0.7357 - val_loss: 0.5092 - val_accuracy: 0.8302 - lr: 1.5749e-06
# Epoch 181/200
# 27/27 [==============================] - 2s 92ms/step - loss: 0.5521 - accuracy: 0.7429 - val_loss: 0.5104 - val_accuracy: 0.8302 - lr: 1.5749e-06
# Epoch 182/200
# 27/27 [==============================] - 3s 94ms/step - loss: 0.5451 - accuracy: 0.7310 - val_loss: 0.5099 - val_accuracy: 0.8302 - lr: 1.5749e-06
# Epoch 183/200
# 27/27 [==============================] - 3s 96ms/step - loss: 0.5482 - accuracy: 0.7405 - val_loss: 0.5104 - val_accuracy: 0.8302 - lr: 1.5749e-06
# Epoch 184/200
# 27/27 [==============================] - 3s 95ms/step - loss: 0.5484 - accuracy: 0.7262 - val_loss: 0.5109 - val_accuracy: 0.8208 - lr: 1.5749e-06
# Epoch 185/200
# 27/27 [==============================] - 2s 92ms/step - loss: 0.5404 - accuracy: 0.7500 - val_loss: 0.5110 - val_accuracy: 0.8208 - lr: 1.5749e-06
# Epoch 186/200
# 27/27 [==============================] - 3s 94ms/step - loss: 0.5536 - accuracy: 0.7524 - val_loss: 0.5104 - val_accuracy: 0.8208 - lr: 1.5749e-06
# Epoch 187/200
# 27/27 [==============================] - 3s 94ms/step - loss: 0.5419 - accuracy: 0.7381 - val_loss: 0.5093 - val_accuracy: 0.8302 - lr: 1.5749e-06
# Epoch 188/200
# 27/27 [==============================] - 3s 93ms/step - loss: 0.5623 - accuracy: 0.7119 - val_loss: 0.5102 - val_accuracy: 0.8208 - lr: 1.5749e-06
# Epoch 189/200
# 27/27 [==============================] - 3s 94ms/step - loss: 0.5482 - accuracy: 0.7381 - val_loss: 0.5093 - val_accuracy: 0.8302 - lr: 1.5749e-06
# Epoch 190/200
# 27/27 [==============================] - 3s 93ms/step - loss: 0.5593 - accuracy: 0.7333 - val_loss: 0.5081 - val_accuracy: 0.8302 - lr: 1.5749e-06
# Epoch 191/200
# 27/27 [==============================] - 2s 91ms/step - loss: 0.5558 - accuracy: 0.7190 - val_loss: 0.5076 - val_accuracy: 0.8302 - lr: 1.5749e-06
# Epoch 192/200
# 26/27 [===========================>..] - ETA: 0s - loss: 0.5569 - accuracy: 0.7308
# Epoch 192: ReduceLROnPlateau reducing learning rate to 1.2499999599010794e-06.
# 27/27 [==============================] - 3s 97ms/step - loss: 0.5550 - accuracy: 0.7333 - val_loss: 0.5080 - val_accuracy: 0.8302 - lr: 1.5749e-06
# Epoch 193/200
# 27/27 [==============================] - 3s 94ms/step - loss: 0.5527 - accuracy: 0.7333 - val_loss: 0.5086 - val_accuracy: 0.8302 - lr: 1.2500e-06
# Epoch 194/200
# 27/27 [==============================] - 2s 93ms/step - loss: 0.5529 - accuracy: 0.7238 - val_loss: 0.5090 - val_accuracy: 0.8302 - lr: 1.2500e-06
# Epoch 195/200
# 27/27 [==============================] - 3s 96ms/step - loss: 0.5502 - accuracy: 0.7167 - val_loss: 0.5081 - val_accuracy: 0.8302 - lr: 1.2500e-06
# Epoch 196/200
# 27/27 [==============================] - 3s 96ms/step - loss: 0.5437 - accuracy: 0.7500 - val_loss: 0.5085 - val_accuracy: 0.8302 - lr: 1.2500e-06
# Epoch 197/200
# 27/27 [==============================] - 3s 93ms/step - loss: 0.5508 - accuracy: 0.7190 - val_loss: 0.5081 - val_accuracy: 0.8302 - lr: 1.2500e-06
# Epoch 198/200
# 27/27 [==============================] - 3s 96ms/step - loss: 0.5498 - accuracy: 0.7262 - val_loss: 0.5095 - val_accuracy: 0.8208 - lr: 1.2500e-06
# Epoch 199/200
# 27/27 [==============================] - 3s 95ms/step - loss: 0.5492 - accuracy: 0.7238 - val_loss: 0.5082 - val_accuracy: 0.8302 - lr: 1.2500e-06
# Epoch 200/200
# 27/27 [==============================] - 3s 101ms/step - loss: 0.5502 - accuracy: 0.7262 - val_loss: 0.5083 - val_accuracy: 0.8302 - lr: 1.2500e-06
# 5/5 [==============================] - 1s 25ms/step
# Test Accuracy: 0.6786
# Test F1 Score: 0.6667
# Test Precision: 0.6923
# Test Recall: 0.6429
# Test ROC AUC Score: 0.7131
