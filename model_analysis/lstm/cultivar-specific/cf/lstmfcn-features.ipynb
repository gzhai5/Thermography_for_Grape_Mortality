# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import accuracy_score, roc_auc_score, recall_score, precision_score, f1_score
from sklearn.metrics import confusion_matrix, precision_recall_fscore_support
import seaborn as sns
from collections import Counter
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau
import sys
sys.path.append(r'C:\Users\Mud\Desktop\2ndPaper\lstm')
from model.lstmfcn import generate_lstmfcn
from model.fcn import generate_fcn
from model.lstm import generate_lstm
from utils.class_weight import compute_class_weight
import tensorflow as tf
import random as python_random

# %%
# load the data
X_test_time = np.load(r'C:\Users\Mud\Desktop\2ndPaper\lstm\cultivar-specific\data\cf\X_test_cf.npy')
X_train_time = np.load(r'C:\Users\Mud\Desktop\2ndPaper\lstm\cultivar-specific\data\cf\X_train_cf.npy')
y_test = np.load(r'C:\Users\Mud\Desktop\2ndPaper\lstm\cultivar-specific\data\cf\y_test_cf.npy')
y_train = np.load(r'C:\Users\Mud\Desktop\2ndPaper\lstm\cultivar-specific\data\cf\y_train_cf.npy')
X_test_features = np.load(r'C:\Users\Mud\Desktop\2ndPaper\traditional_ml\weka\data\cf\X_test_cf.npy', allow_pickle=True)
X_train_features = np.load(r'C:\Users\Mud\Desktop\2ndPaper\traditional_ml\weka\data\cf\X_train_cf.npy', allow_pickle=True)

# # load fake data
#X_train = np.load('./fake/train/X_train.npy')
#y_train = np.load('./fake/train/y_train.npy')
#X_test = np.load('./fake/test/X_test.npy')
#y_test = np.load('./fake/test/y_test.npy')


print('X_train of time series shape:', X_train_time.shape)
print('X_test of time series shape:', X_test_time.shape)
print('X_train of features shape:', X_train_features.shape)
print('X_test of features shape:', X_test_features.shape)
print('y_train shape:', y_train.shape)
print('y_test shape:', y_test.shape)
# Out:
# X_train of time series shape: (569, 600)
# X_test of time series shape: (140, 600)
# X_train of features shape: (569,)
# X_test of features shape: (140,)
# y_train shape: (569,)
# y_test shape: (140,)

# %%
def reset_random_seeds(seed=42):
   np.random.seed(seed)
   python_random.seed(seed)
   tf.random.set_seed(seed)

reset_random_seeds()

# %%
# normalize the data to have same starting pt for all time series
# input shape: (n_samples, n_timepoints), want each samples - its mean of 0-30th timepts
def normalize_curves_mean_method(unnormalized_datas):
    normalized_datas = []
    for unnormalized_data in unnormalized_datas:
        mean = np.mean(unnormalized_data[:30])
        normalized_data = unnormalized_data - mean
        normalized_datas.append(normalized_data)
    normalized_datas = np.array(normalized_datas)
    assert normalized_datas.shape == unnormalized_datas.shape
    return normalized_datas

# normalize the data using z-score, have mean 0 and std 1
def normalize_curves_zscore(unnormalized_datas):
    normalized_datas = []
    for unnormalized_data in unnormalized_datas:
        mean = np.mean(unnormalized_data)
        std = np.std(unnormalized_data)
        normalized_data = (unnormalized_data - mean) / std
        normalized_datas.append(normalized_data)
    normalized_datas = np.array(normalized_datas)
    assert normalized_datas.shape == unnormalized_datas.shape
    return normalized_datas


# apply ln() to the time series data
def apply_ln_to_curves(datas):
    ln_datas = []
    for data in datas:
        ln_data = np.log(data)
        ln_datas.append(ln_data)
    ln_datas = np.array(ln_datas)
    assert ln_datas.shape == datas.shape
    return ln_datas


# split the time series data into wanted time points
def split_time_series(datas, start, end):
    datas = datas[:, start:end]
    return datas


# plot the time series data, randomly picked n samples, different colors represent different classes
def plot_random_time_series(datas, n, labels):
    for i in range(n):
        idx = np.random.randint(datas.shape[0])
        plt.plot(datas[idx], color = 'blue' if labels[idx] == 1 else 'red', alpha = 0.2)
    plt.show()


X_train_time = normalize_curves_mean_method(X_train_time)
X_test_time = normalize_curves_mean_method(X_test_time)
plot_random_time_series(X_train_time, 100, y_train)

# %%
# normalize the features data
X_train_features = pd.DataFrame.from_records(X_train_features.flatten())
X_test_features = pd.DataFrame.from_records(X_test_features.flatten())
print(X_train_features.head(1))

scaler = StandardScaler()
features = X_train_features.columns
X_train_features[features] = scaler.fit_transform(X_train_features[features])
X_test_features[features] = scaler.transform(X_test_features[features])
print(X_train_features.head(1))
# Out:
#          pc0         pc1        pc2  rising_waveform  falling_waveform  \
# 0  484.55438 -555.562154 -89.885701         1.480652          1.079909
#
#    peak_temperature  cultivar
# 0        399.776039         2
#         pc0       pc1       pc2  rising_waveform  falling_waveform  \
# 0  0.069903 -1.210385 -0.552584          0.19026           0.51659
#
#    peak_temperature  cultivar
# 0           0.19026       0.0

# %%
# normalize the time series data
# compute mean & std of the training set, then normalize the whole dataset using z-normalization
mean = np.mean(X_train_time)
std = np.std(X_train_time)
X_train_time = (X_train_time - mean) / std
X_test_time = (X_test_time - mean) / std

# %%
# Ensure data is shaped correctly
X_train_time = X_train_time.reshape(-1, 1, 600)  # Convert to (samples, 1, timesteps)
X_test_time = X_test_time.reshape(-1, 1, 600)
y_train = y_train.reshape(-1, 1)  # Ensure labels are in shape (samples, 1)
y_test = y_test.reshape(-1, 1)
X_train_features = X_train_features.values
X_test_features = X_test_features.values

print('X_train shape of time series:', X_train_time.shape)
print('y_train shape:', y_train.shape)
print('X_test shape of time series:', X_test_time.shape)
print('y_test shape:', y_test.shape)
print('X_train shape of features:', X_train_features.shape)
print('X_test shape of features:', X_test_features.shape)
# Out:
# X_train shape of time series: (569, 1, 600)
# y_train shape: (569, 1)
# X_test shape of time series: (140, 1, 600)
# y_test shape: (140, 1)
# X_train shape of features: (569, 7)
# X_test shape of features: (140, 7)

# %%
# Train final model on full training data# Initialize model
final_model = generate_lstmfcn(feature_input_accept=True, dropout=0.0)
class_weights = compute_class_weight(y_train)
print('class_weights:', class_weights)
reduce_lr = ReduceLROnPlateau(monitor='loss', patience=15, mode='auto',
    factor=1. / np.cbrt(2), cooldown=0, min_lr=1e-6, verbose=2)
final_model.compile(optimizer=Adam(learning_rate=5e-6), loss='binary_crossentropy', metrics=['accuracy'])

# split the data into training and validation set
X_train_time, X_val_time, X_train_features, X_val_features, y_train, y_val = train_test_split(
    X_train_time, X_train_features, y_train, test_size=0.2, random_state=42)
print('X_train shape of time series:', X_train_time.shape)
print('y_train shape:', y_train.shape)
print('X_val shape of time series:', X_val_time.shape)
print('y_val shape:', y_val.shape)
print('X_train shape of features:', X_train_features.shape)
print('X_val shape of features:', X_val_features.shape)

# Train model
history = final_model.fit(
    [X_train_time, X_train_features], y_train,
    validation_data=([X_val_time, X_val_features], y_val),
    callbacks=[reduce_lr],
    epochs=200, batch_size=16, class_weight={0: class_weights[0], 1: class_weights[1]},
    verbose=1
)

# Predict on test set
y_pred_prob = final_model.predict([X_test_time, X_test_features])
y_pred = (y_pred_prob > 0.5).astype(int)

# Calculate metrics
accuracy = accuracy_score(y_test, y_pred)
precision, recall, f1, _ = precision_recall_fscore_support(y_test, y_pred, average='binary')
roc_auc = roc_auc_score(y_test, y_pred_prob)
conf_matrix = confusion_matrix(y_test, y_pred)

# plot the metrics
print(f"Test Accuracy: {accuracy:.4f}")
print(f"Test F1 Score: {f1:.4f}")
print(f"Test Precision: {precision:.4f}")
print(f"Test Recall: {recall:.4f}")
print(f"Test ROC AUC Score: {roc_auc:.4f}")
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Dead', 'Alive'], yticklabels=['Dead', 'Alive'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()


# plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.figure(figsize=(10, 7))
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.figure(figsize=(10, 7))
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# class_weights: [1.48177083 0.75464191]
# X_train shape of time series: (455, 1, 600)
# y_train shape: (455, 1)
# X_val shape of time series: (114, 1, 600)
# y_val shape: (114, 1)
# X_train shape of features: (455, 7)
# X_val shape of features: (114, 7)
# Epoch 1/200
# 29/29 [==============================] - 3s 55ms/step - loss: 0.8917 - accuracy: 0.6725 - val_loss: 0.7834 - val_accuracy: 0.6228 - lr: 5.0000e-06
# Epoch 2/200
# 29/29 [==============================] - 1s 47ms/step - loss: 0.8288 - accuracy: 0.6725 - val_loss: 0.7294 - val_accuracy: 0.6228 - lr: 5.0000e-06
# Epoch 3/200
# 29/29 [==============================] - 1s 47ms/step - loss: 0.7836 - accuracy: 0.6725 - val_loss: 0.7014 - val_accuracy: 0.6228 - lr: 5.0000e-06
# Epoch 4/200
# 29/29 [==============================] - 1s 46ms/step - loss: 0.7426 - accuracy: 0.6725 - val_loss: 0.6806 - val_accuracy: 0.6228 - lr: 5.0000e-06
# Epoch 5/200
# 29/29 [==============================] - 1s 46ms/step - loss: 0.7143 - accuracy: 0.6725 - val_loss: 0.6613 - val_accuracy: 0.6228 - lr: 5.0000e-06
# Epoch 6/200
# 29/29 [==============================] - 1s 46ms/step - loss: 0.6838 - accuracy: 0.6725 - val_loss: 0.6463 - val_accuracy: 0.6228 - lr: 5.0000e-06
# Epoch 7/200
# 29/29 [==============================] - 1s 46ms/step - loss: 0.6576 - accuracy: 0.6769 - val_loss: 0.6326 - val_accuracy: 0.6228 - lr: 5.0000e-06
# Epoch 8/200
# 29/29 [==============================] - 1s 46ms/step - loss: 0.6421 - accuracy: 0.6989 - val_loss: 0.6214 - val_accuracy: 0.6667 - lr: 5.0000e-06
# Epoch 9/200
# 29/29 [==============================] - 1s 46ms/step - loss: 0.6232 - accuracy: 0.7187 - val_loss: 0.6131 - val_accuracy: 0.6842 - lr: 5.0000e-06
# Epoch 10/200
# 29/29 [==============================] - 1s 46ms/step - loss: 0.6112 - accuracy: 0.7319 - val_loss: 0.6050 - val_accuracy: 0.7018 - lr: 5.0000e-06
# Epoch 11/200
# 29/29 [==============================] - 1s 47ms/step - loss: 0.5977 - accuracy: 0.7407 - val_loss: 0.6002 - val_accuracy: 0.7281 - lr: 5.0000e-06
# Epoch 12/200
# 29/29 [==============================] - 1s 47ms/step - loss: 0.5960 - accuracy: 0.7451 - val_loss: 0.5960 - val_accuracy: 0.7281 - lr: 5.0000e-06
# Epoch 13/200
# 29/29 [==============================] - 1s 47ms/step - loss: 0.5805 - accuracy: 0.7451 - val_loss: 0.5905 - val_accuracy: 0.7281 - lr: 5.0000e-06
# Epoch 14/200
# 29/29 [==============================] - 1s 47ms/step - loss: 0.5829 - accuracy: 0.7670 - val_loss: 0.5876 - val_accuracy: 0.7368 - lr: 5.0000e-06
# Epoch 15/200
# 29/29 [==============================] - 1s 48ms/step - loss: 0.5709 - accuracy: 0.7538 - val_loss: 0.5837 - val_accuracy: 0.7368 - lr: 5.0000e-06
# Epoch 16/200
# 29/29 [==============================] - 1s 47ms/step - loss: 0.5694 - accuracy: 0.7451 - val_loss: 0.5820 - val_accuracy: 0.7281 - lr: 5.0000e-06
# Epoch 17/200
# 29/29 [==============================] - 1s 46ms/step - loss: 0.5621 - accuracy: 0.7429 - val_loss: 0.5799 - val_accuracy: 0.7281 - lr: 5.0000e-06
# Epoch 18/200
# 29/29 [==============================] - 1s 46ms/step - loss: 0.5703 - accuracy: 0.7275 - val_loss: 0.5793 - val_accuracy: 0.7281 - lr: 5.0000e-06
# Epoch 19/200
# 29/29 [==============================] - 1s 46ms/step - loss: 0.5622 - accuracy: 0.7604 - val_loss: 0.5789 - val_accuracy: 0.7193 - lr: 5.0000e-06
# Epoch 20/200
# 29/29 [==============================] - 1s 47ms/step - loss: 0.5523 - accuracy: 0.7538 - val_loss: 0.5774 - val_accuracy: 0.7193 - lr: 5.0000e-06
# Epoch 21/200
# 29/29 [==============================] - 1s 47ms/step - loss: 0.5480 - accuracy: 0.7560 - val_loss: 0.5775 - val_accuracy: 0.7281 - lr: 5.0000e-06
# Epoch 22/200
# 29/29 [==============================] - 1s 48ms/step - loss: 0.5583 - accuracy: 0.7516 - val_loss: 0.5810 - val_accuracy: 0.7105 - lr: 5.0000e-06
# Epoch 23/200
# 29/29 [==============================] - 1s 47ms/step - loss: 0.5512 - accuracy: 0.7429 - val_loss: 0.5812 - val_accuracy: 0.7105 - lr: 5.0000e-06
# Epoch 24/200
# 29/29 [==============================] - 1s 47ms/step - loss: 0.5409 - accuracy: 0.7516 - val_loss: 0.5778 - val_accuracy: 0.7193 - lr: 5.0000e-06
# Epoch 25/200
# 29/29 [==============================] - 1s 48ms/step - loss: 0.5521 - accuracy: 0.7560 - val_loss: 0.5796 - val_accuracy: 0.7105 - lr: 5.0000e-06
# Epoch 26/200
# 29/29 [==============================] - 2s 52ms/step - loss: 0.5461 - accuracy: 0.7473 - val_loss: 0.5840 - val_accuracy: 0.7105 - lr: 5.0000e-06
# Epoch 27/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.5421 - accuracy: 0.7297 - val_loss: 0.5829 - val_accuracy: 0.7105 - lr: 5.0000e-06
# Epoch 28/200
# 29/29 [==============================] - 1s 47ms/step - loss: 0.5432 - accuracy: 0.7473 - val_loss: 0.5844 - val_accuracy: 0.7105 - lr: 5.0000e-06
# Epoch 29/200
# 29/29 [==============================] - 1s 48ms/step - loss: 0.5405 - accuracy: 0.7495 - val_loss: 0.5840 - val_accuracy: 0.7105 - lr: 5.0000e-06
# Epoch 30/200
# 29/29 [==============================] - 1s 48ms/step - loss: 0.5360 - accuracy: 0.7451 - val_loss: 0.5853 - val_accuracy: 0.7105 - lr: 5.0000e-06
# Epoch 31/200
# 29/29 [==============================] - 1s 47ms/step - loss: 0.5331 - accuracy: 0.7626 - val_loss: 0.5848 - val_accuracy: 0.7105 - lr: 5.0000e-06
# Epoch 32/200
# 29/29 [==============================] - 2s 59ms/step - loss: 0.5272 - accuracy: 0.7714 - val_loss: 0.5867 - val_accuracy: 0.7105 - lr: 5.0000e-06
# Epoch 33/200
# 29/29 [==============================] - 2s 62ms/step - loss: 0.5307 - accuracy: 0.7560 - val_loss: 0.5889 - val_accuracy: 0.6842 - lr: 5.0000e-06
# Epoch 34/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.5320 - accuracy: 0.7626 - val_loss: 0.5875 - val_accuracy: 0.7018 - lr: 5.0000e-06
# Epoch 35/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.5344 - accuracy: 0.7560 - val_loss: 0.5894 - val_accuracy: 0.6842 - lr: 5.0000e-06
# Epoch 36/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.5389 - accuracy: 0.7363 - val_loss: 0.5874 - val_accuracy: 0.6930 - lr: 5.0000e-06
# Epoch 37/200
# 29/29 [==============================] - 2s 67ms/step - loss: 0.5304 - accuracy: 0.7429 - val_loss: 0.5880 - val_accuracy: 0.6930 - lr: 5.0000e-06
# Epoch 38/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.5302 - accuracy: 0.7429 - val_loss: 0.5883 - val_accuracy: 0.6930 - lr: 5.0000e-06
# Epoch 39/200
# 29/29 [==============================] - 2s 70ms/step - loss: 0.5379 - accuracy: 0.7319 - val_loss: 0.5916 - val_accuracy: 0.6930 - lr: 5.0000e-06
# Epoch 40/200
# 29/29 [==============================] - 2s 78ms/step - loss: 0.5269 - accuracy: 0.7495 - val_loss: 0.5918 - val_accuracy: 0.6930 - lr: 5.0000e-06
# Epoch 41/200
# 29/29 [==============================] - 2s 72ms/step - loss: 0.5349 - accuracy: 0.7407 - val_loss: 0.5902 - val_accuracy: 0.7018 - lr: 5.0000e-06
# Epoch 42/200
# 29/29 [==============================] - 2s 74ms/step - loss: 0.5270 - accuracy: 0.7451 - val_loss: 0.5914 - val_accuracy: 0.7018 - lr: 5.0000e-06
# Epoch 43/200
# 29/29 [==============================] - 2s 78ms/step - loss: 0.5242 - accuracy: 0.7429 - val_loss: 0.5924 - val_accuracy: 0.6930 - lr: 5.0000e-06
# Epoch 44/200
# 29/29 [==============================] - 2s 71ms/step - loss: 0.5322 - accuracy: 0.7560 - val_loss: 0.5946 - val_accuracy: 0.6930 - lr: 5.0000e-06
# Epoch 45/200
# 29/29 [==============================] - 2s 71ms/step - loss: 0.5222 - accuracy: 0.7626 - val_loss: 0.5939 - val_accuracy: 0.6930 - lr: 5.0000e-06
# Epoch 46/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.5486 - accuracy: 0.7341 - val_loss: 0.5962 - val_accuracy: 0.6930 - lr: 5.0000e-06
# Epoch 47/200
# 29/29 [==============================] - 2s 73ms/step - loss: 0.5310 - accuracy: 0.7407 - val_loss: 0.5954 - val_accuracy: 0.6930 - lr: 5.0000e-06
# Epoch 48/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.5255 - accuracy: 0.7187 - val_loss: 0.5944 - val_accuracy: 0.6842 - lr: 5.0000e-06
# Epoch 49/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.5317 - accuracy: 0.7407 - val_loss: 0.5964 - val_accuracy: 0.6930 - lr: 5.0000e-06
# Epoch 50/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.5213 - accuracy: 0.7451 - val_loss: 0.5955 - val_accuracy: 0.6930 - lr: 5.0000e-06
# Epoch 51/200
# 29/29 [==============================] - 2s 71ms/step - loss: 0.5316 - accuracy: 0.7516 - val_loss: 0.5944 - val_accuracy: 0.6930 - lr: 5.0000e-06
# Epoch 52/200
# 29/29 [==============================] - 3s 101ms/step - loss: 0.5156 - accuracy: 0.7560 - val_loss: 0.5950 - val_accuracy: 0.6930 - lr: 5.0000e-06
# Epoch 53/200
# 29/29 [==============================] - 2s 76ms/step - loss: 0.5262 - accuracy: 0.7429 - val_loss: 0.5974 - val_accuracy: 0.6930 - lr: 5.0000e-06
# Epoch
- val_accuracy: 0.6667 - lr: 3.9685e-06
# Epoch 165/200
# 29/29 [==============================] - ETA: 0s - loss: 0.4923 - accuracy: 0.7604
# Epoch 165: ReduceLROnPlateau reducing learning rate to 3.1498024179533314e-06.
# 29/29 [==============================] - 3s 121ms/step - loss: 0.4923 - accuracy: 0.7604 - val_loss: 0.6194 - val_accuracy: 0.6754 - lr: 3.9685e-06
# Epoch 166/200
# 29/29 [==============================] - 3s 121ms/step - loss: 0.4858 - accuracy: 0.7714 - val_loss: 0.6199 - val_accuracy: 0.6842 - lr: 3.1498e-06
# Epoch 167/200
# 29/29 [==============================] - 4s 122ms/step - loss: 0.4883 - accuracy: 0.7648 - val_loss: 0.6192 - val_accuracy: 0.6842 - lr: 3.1498e-06
# Epoch 168/200
# 29/29 [==============================] - 3s 119ms/step - loss: 0.4824 - accuracy: 0.7758 - val_loss: 0.6162 - val_accuracy: 0.6754 - lr: 3.1498e-06
# Epoch 169/200
# 29/29 [==============================] - 3s 120ms/step - loss: 0.4916 - accuracy: 0.7868 - val_loss: 0.6157 - val_accuracy: 0.6754 - lr: 3.1498e-06
# Epoch 170/200
# 29/29 [==============================] - 3s 120ms/step - loss: 0.4998 - accuracy: 0.7736 - val_loss: 0.6187 - val_accuracy: 0.6842 - lr: 3.1498e-06
# Epoch 171/200
# 29/29 [==============================] - 3s 119ms/step - loss: 0.4849 - accuracy: 0.7648 - val_loss: 0.6152 - val_accuracy: 0.6754 - lr: 3.1498e-06
# Epoch 172/200
# 29/29 [==============================] - 3s 121ms/step - loss: 0.4866 - accuracy: 0.7626 - val_loss: 0.6164 - val_accuracy: 0.6754 - lr: 3.1498e-06
# Epoch 173/200
# 29/29 [==============================] - 4s 122ms/step - loss: 0.4988 - accuracy: 0.7560 - val_loss: 0.6125 - val_accuracy: 0.6667 - lr: 3.1498e-06
# Epoch 174/200
# 29/29 [==============================] - 3s 118ms/step - loss: 0.4938 - accuracy: 0.7538 - val_loss: 0.6134 - val_accuracy: 0.6667 - lr: 3.1498e-06
# Epoch 175/200
# 29/29 [==============================] - 3s 121ms/step - loss: 0.5007 - accuracy: 0.7626 - val_loss: 0.6151 - val_accuracy: 0.6754 - lr: 3.1498e-06
# Epoch 176/200
# 29/29 [==============================] - 4s 125ms/step - loss: 0.4870 - accuracy: 0.7670 - val_loss: 0.6182 - val_accuracy: 0.6754 - lr: 3.1498e-06
# Epoch 177/200
# 29/29 [==============================] - 4s 124ms/step - loss: 0.4830 - accuracy: 0.7670 - val_loss: 0.6149 - val_accuracy: 0.6754 - lr: 3.1498e-06
# Epoch 178/200
# 29/29 [==============================] - 4s 125ms/step - loss: 0.4876 - accuracy: 0.7758 - val_loss: 0.6129 - val_accuracy: 0.6667 - lr: 3.1498e-06
# Epoch 179/200
# 29/29 [==============================] - 3s 116ms/step - loss: 0.4894 - accuracy: 0.7626 - val_loss: 0.6140 - val_accuracy: 0.6754 - lr: 3.1498e-06
# Epoch 180/200
# 29/29 [==============================] - ETA: 0s - loss: 0.4932 - accuracy: 0.7626
# Epoch 180: ReduceLROnPlateau reducing learning rate to 2.499999919802159e-06.
# 29/29 [==============================] - 3s 120ms/step - loss: 0.4932 - accuracy: 0.7626 - val_loss: 0.6153 - val_accuracy: 0.6754 - lr: 3.1498e-06
# Epoch 181/200
# 29/29 [==============================] - 3s 121ms/step - loss: 0.4869 - accuracy: 0.7582 - val_loss: 0.6131 - val_accuracy: 0.6754 - lr: 2.5000e-06
# Epoch 182/200
# 29/29 [==============================] - 3s 121ms/step - loss: 0.5012 - accuracy: 0.7626 - val_loss: 0.6155 - val_accuracy: 0.6754 - lr: 2.5000e-06
# Epoch 183/200
# 29/29 [==============================] - 4s 123ms/step - loss: 0.5013 - accuracy: 0.7495 - val_loss: 0.6129 - val_accuracy: 0.6754 - lr: 2.5000e-06
# Epoch 184/200
# 29/29 [==============================] - 3s 120ms/step - loss: 0.5016 - accuracy: 0.7714 - val_loss: 0.6149 - val_accuracy: 0.6754 - lr: 2.5000e-06
# Epoch 185/200
# 29/29 [==============================] - 4s 123ms/step - loss: 0.4893 - accuracy: 0.7736 - val_loss: 0.6157 - val_accuracy: 0.6754 - lr: 2.5000e-06
# Epoch 186/200
# 29/29 [==============================] - 4s 123ms/step - loss: 0.4876 - accuracy: 0.7692 - val_loss: 0.6140 - val_accuracy: 0.6754 - lr: 2.5000e-06
# Epoch 187/200
# 29/29 [==============================] - 3s 120ms/step - loss: 0.5006 - accuracy: 0.7604 - val_loss: 0.6150 - val_accuracy: 0.6754 - lr: 2.5000e-06
# Epoch 188/200
# 29/29 [==============================] - 4s 123ms/step - loss: 0.4885 - accuracy: 0.7648 - val_loss: 0.6146 - val_accuracy: 0.6754 - lr: 2.5000e-06
# Epoch 189/200
# 29/29 [==============================] - 3s 119ms/step - loss: 0.5023 - accuracy: 0.7560 - val_loss: 0.6142 - val_accuracy: 0.6754 - lr: 2.5000e-06
# Epoch 190/200
# 29/29 [==============================] - 4s 124ms/step - loss: 0.4791 - accuracy: 0.7780 - val_loss: 0.6148 - val_accuracy: 0.6754 - lr: 2.5000e-06
# Epoch 191/200
# 29/29 [==============================] - 3s 121ms/step - loss: 0.4877 - accuracy: 0.7604 - val_loss: 0.6161 - val_accuracy: 0.6754 - lr: 2.5000e-06
# Epoch 192/200
# 29/29 [==============================] - 4s 122ms/step - loss: 0.4848 - accuracy: 0.7670 - val_loss: 0.6150 - val_accuracy: 0.6754 - lr: 2.5000e-06
# Epoch 193/200
# 29/29 [==============================] - 3s 116ms/step - loss: 0.4879 - accuracy: 0.7538 - val_loss: 0.6165 - val_accuracy: 0.6754 - lr: 2.5000e-06
# Epoch 194/200
# 29/29 [==============================] - 4s 123ms/step - loss: 0.4946 - accuracy: 0.7714 - val_loss: 0.6184 - val_accuracy: 0.6842 - lr: 2.5000e-06
# Epoch 195/200
# 29/29 [==============================] - 3s 120ms/step - loss: 0.4903 - accuracy: 0.7516 - val_loss: 0.6153 - val_accuracy: 0.6754 - lr: 2.5000e-06
# Epoch 196/200
# 29/29 [==============================] - 4s 123ms/step - loss: 0.4910 - accuracy: 0.7648 - val_loss: 0.6196 - val_accuracy: 0.6842 - lr: 2.5000e-06
# Epoch 197/200
# 29/29 [==============================] - 4s 124ms/step - loss: 0.4942 - accuracy: 0.7582 - val_loss: 0.6172 - val_accuracy: 0.6754 - lr: 2.5000e-06
# Epoch 198/200
# 29/29 [==============================] - 3s 120ms/step - loss: 0.4851 - accuracy: 0.7692 - val_loss: 0.6150 - val_accuracy: 0.6754 - lr: 2.5000e-06
# Epoch 199/200
# 29/29 [==============================] - 4s 128ms/step - loss: 0.4921 - accuracy: 0.7846 - val_loss: 0.6167 - val_accuracy: 0.6842 - lr: 2.5000e-06
# Epoch 200/200
# 29/29 [==============================] - 3s 122ms/step - loss: 0.4943 - accuracy: 0.7758 - val_loss: 0.6164 - val_accuracy: 0.6842 - lr: 2.5000e-06
# 5/5 [==============================] - 5s 33ms/step
# Test Accuracy: 0.7429
# Test F1 Score: 0.7534
# Test Precision: 0.7237
# Test Recall: 0.7857
# Test ROC AUC Score: 0.7896
