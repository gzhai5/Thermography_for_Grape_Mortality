# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import accuracy_score, roc_auc_score, recall_score, precision_score, f1_score
from sklearn.metrics import confusion_matrix, precision_recall_fscore_support
import seaborn as sns
from collections import Counter
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau
import sys
sys.path.append(r'C:\Users\Mud\Desktop\2ndPaper\lstm')
from model.lstmfcn import generate_lstmfcn
from model.fcn import generate_fcn
from model.lstm import generate_lstm
from utils.class_weight import compute_class_weight
import tensorflow as tf
import random as python_random

# %%
# # load the data
X_test = np.load(r'C:\Users\Mud\Desktop\2ndPaper\lstm\cultivar-specific\data\cf\X_test_cf.npy')
y_test = np.load(r'C:\Users\Mud\Desktop\2ndPaper\lstm\cultivar-specific\data\cf\y_test_cf.npy')
X_train = np.load(r'C:\Users\Mud\Desktop\2ndPaper\lstm\cultivar-specific\data\cf\X_train_cf.npy')
y_train = np.load(r'C:\Users\Mud\Desktop\2ndPaper\lstm\cultivar-specific\data\cf\y_train_cf.npy')

# # load fake data
#X_train = np.load('./fake/train/X_train.npy')
#y_train = np.load('./fake/train/y_train.npy')
#X_test = np.load('./fake/test/X_test.npy')
#y_test = np.load('./fake/test/y_test.npy')


print('X_train shape:', X_train.shape)
print('y_train shape:', y_train.shape)
print('X_test shape:', X_test.shape)
print('y_test shape:', y_test.shape)
# Out:
# X_train shape: (569, 600)
# y_train shape: (569,)
# X_test shape: (140, 600)
# y_test shape: (140,)

# %%
def reset_random_seeds(seed=42):
   np.random.seed(seed)
   python_random.seed(seed)
   tf.random.set_seed(seed)

reset_random_seeds()

# %%
# normalize the data to have same starting pt for all time series
# input shape: (n_samples, n_timepoints), want each samples - its mean of 0-30th timepts
def normalize_curves_mean_method(unnormalized_datas):
    normalized_datas = []
    for unnormalized_data in unnormalized_datas:
        mean = np.mean(unnormalized_data[:30])
        normalized_data = unnormalized_data - mean
        normalized_datas.append(normalized_data)
    normalized_datas = np.array(normalized_datas)
    assert normalized_datas.shape == unnormalized_datas.shape
    return normalized_datas

# normalize the data using z-score, have mean 0 and std 1
def normalize_curves_zscore(unnormalized_datas):
    normalized_datas = []
    for unnormalized_data in unnormalized_datas:
        mean = np.mean(unnormalized_data)
        std = np.std(unnormalized_data)
        normalized_data = (unnormalized_data - mean) / std
        normalized_datas.append(normalized_data)
    normalized_datas = np.array(normalized_datas)
    assert normalized_datas.shape == unnormalized_datas.shape
    return normalized_datas


# apply ln() to the time series data
def apply_ln_to_curves(datas):
    ln_datas = []
    for data in datas:
        ln_data = np.log(data)
        ln_datas.append(ln_data)
    ln_datas = np.array(ln_datas)
    assert ln_datas.shape == datas.shape
    return ln_datas


# split the time series data into wanted time points
def split_time_series(datas, start, end):
    datas = datas[:, start:end]
    return datas


# plot the time series data, randomly picked n samples, different colors represent different classes
def plot_random_time_series(datas, n, labels):
    for i in range(n):
        idx = np.random.randint(datas.shape[0])
        plt.plot(datas[idx], color = 'blue' if labels[idx] == 1 else 'red', alpha = 0.2)
    plt.show()


X_train = normalize_curves_mean_method(X_train)
X_test = normalize_curves_mean_method(X_test)
plot_random_time_series(X_train, 100, y_train)
# X_train = normalize_curves_zscore(X_train)
# X_test = normalize_curves_zscore(X_test)
print('X_train shape:', X_train.shape)
print('X_train range:', np.min(X_train), np.max(X_train))
print('X_test shape:', X_test.shape)
print('X_test range:', np.min(X_test), np.max(X_test))
# Out:
# X_train shape: (569, 600)
# X_train range: -17.047241118669263 635.5291005290983
# X_test shape: (140, 600)
# X_test range: -19.581783824642116 604.2200302343135

# %%
# upsample the one class in the training set by given factor
# add some level of noise to the time series data with maintaining mean & std
# class_label: 1 is alive, 0 is dead
def data_augmentation(X_train, y_train, n_times, class_label=1, random_seed=42):
    np.random.seed(random_seed)
    X_train_augmented = X_train.copy()
    y_train_augmented = y_train.copy()
    for i in range(len(y_train)):
        if y_train[i] == class_label:
            for _ in range(n_times):
                X_train_augmented = np.concatenate((X_train_augmented, [X_train[i] + np.random.normal(0, 0.1, X_train[i].shape)]), axis=0)
                y_train_augmented = np.concatenate((y_train_augmented, [y_train[i]]), axis=0)
    return X_train_augmented, y_train_augmented



print('Before, Class ratio:', Counter(y_train))
#X_train, y_train = data_augmentation(X_train, y_train, 10, class_label=0)
#X_train, y_train = data_augmentation(X_train, y_train, 4, class_label=1)
print('After, Class ratio:', Counter(y_train))
# Out:
# Before, Class ratio: Counter({1: 377, 0: 192})
# After, Class ratio: Counter({1: 377, 0: 192})

# %%
# compute mean & std of the training set, then normalize the whole dataset using z-normalization
mean = np.mean(X_train)
std = np.std(X_train)
#X_train = (X_train - mean) / std
#X_test = (X_test - mean) / std

# %%
# Ensure data is shaped correctly
X_train = X_train.reshape(-1, 1, 600)  # Convert to (samples, 1, timesteps)
X_test = X_test.reshape(-1, 1, 600)
y_train = y_train.reshape(-1, 1)  # Ensure labels are in shape (samples, 1)
y_test = y_test.reshape(-1, 1)

print('X_train shape:', X_train.shape)
print('y_train shape:', y_train.shape)
print('X_test shape:', X_test.shape)
print('y_test shape:', y_test.shape)
# Out:
# X_train shape: (569, 1, 600)
# y_train shape: (569, 1)
# X_test shape: (140, 1, 600)
# y_test shape: (140, 1)

# %%
# Train final model on full training data# Initialize model
final_model = generate_lstmfcn(dropout=0.0)
class_weights = compute_class_weight(y_train)
print('class_weights:', class_weights)
reduce_lr = ReduceLROnPlateau(monitor='loss', patience=15, mode='auto',
    factor=1. / np.cbrt(2), cooldown=0, min_lr=1e-6, verbose=2)
final_model.compile(optimizer=Adam(learning_rate=5e-6), loss='binary_crossentropy', metrics=['accuracy'])

# split the data into training and validation set
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# Train model
history = final_model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    callbacks=[reduce_lr],
    epochs=200, batch_size=16, class_weight={0: class_weights[0], 1: class_weights[1]},
    verbose=1
)

# Predict on test set
y_pred_prob = final_model.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)

# Calculate metrics
accuracy = accuracy_score(y_test, y_pred)
precision, recall, f1, _ = precision_recall_fscore_support(y_test, y_pred, average='binary')
roc_auc = roc_auc_score(y_test, y_pred_prob)
conf_matrix = confusion_matrix(y_test, y_pred)

# plot the metrics
print(f"Test Accuracy: {accuracy:.4f}")
print(f"Test F1 Score: {f1:.4f}")
print(f"Test Precision: {precision:.4f}")
print(f"Test Recall: {recall:.4f}")
print(f"Test ROC AUC Score: {roc_auc:.4f}")
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Dead', 'Alive'], yticklabels=['Dead', 'Alive'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()


# plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.figure(figsize=(10, 7))
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.figure(figsize=(10, 7))
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# class_weights: [1.48177083 0.75464191]
# Epoch 1/200
# 29/29 [==============================] - 3s 55ms/step - loss: 0.7368 - accuracy: 0.6725 - val_loss: 1.2085 - val_accuracy: 0.6228 - lr: 5.0000e-06
# Epoch 2/200
# 29/29 [==============================] - 1s 46ms/step - loss: 0.6915 - accuracy: 0.6725 - val_loss: 0.7439 - val_accuracy: 0.6228 - lr: 5.0000e-06
# Epoch 3/200
# 29/29 [==============================] - 1s 47ms/step - loss: 0.6614 - accuracy: 0.6769 - val_loss: 0.6776 - val_accuracy: 0.6228 - lr: 5.0000e-06
# Epoch 4/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.6418 - accuracy: 0.7319 - val_loss: 0.6694 - val_accuracy: 0.6930 - lr: 5.0000e-06
# Epoch 5/200
# 29/29 [==============================] - 1s 46ms/step - loss: 0.6177 - accuracy: 0.7538 - val_loss: 0.6636 - val_accuracy: 0.5526 - lr: 5.0000e-06
# Epoch 6/200
# 29/29 [==============================] - 1s 47ms/step - loss: 0.5996 - accuracy: 0.7560 - val_loss: 0.6511 - val_accuracy: 0.5877 - lr: 5.0000e-06
# Epoch 7/200
# 29/29 [==============================] - 1s 46ms/step - loss: 0.5890 - accuracy: 0.7626 - val_loss: 0.6380 - val_accuracy: 0.5965 - lr: 5.0000e-06
# Epoch 8/200
# 29/29 [==============================] - 1s 46ms/step - loss: 0.5838 - accuracy: 0.7560 - val_loss: 0.6252 - val_accuracy: 0.6404 - lr: 5.0000e-06
# Epoch 9/200
# 29/29 [==============================] - 1s 46ms/step - loss: 0.5771 - accuracy: 0.7582 - val_loss: 0.6153 - val_accuracy: 0.6754 - lr: 5.0000e-06
# Epoch 10/200
# 29/29 [==============================] - 1s 47ms/step - loss: 0.5732 - accuracy: 0.7429 - val_loss: 0.6041 - val_accuracy: 0.6754 - lr: 5.0000e-06
# Epoch 11/200
# 29/29 [==============================] - 1s 47ms/step - loss: 0.5650 - accuracy: 0.7385 - val_loss: 0.5976 - val_accuracy: 0.6930 - lr: 5.0000e-06
# Epoch 12/200
# 29/29 [==============================] - 1s 47ms/step - loss: 0.5628 - accuracy: 0.7429 - val_loss: 0.5947 - val_accuracy: 0.6930 - lr: 5.0000e-06
# Epoch 13/200
# 29/29 [==============================] - 1s 47ms/step - loss: 0.5486 - accuracy: 0.7604 - val_loss: 0.5913 - val_accuracy: 0.7105 - lr: 5.0000e-06
# Epoch 14/200
# 29/29 [==============================] - 1s 48ms/step - loss: 0.5574 - accuracy: 0.7319 - val_loss: 0.5896 - val_accuracy: 0.7105 - lr: 5.0000e-06
# Epoch 15/200
# 29/29 [==============================] - 1s 47ms/step - loss: 0.5477 - accuracy: 0.7582 - val_loss: 0.5868 - val_accuracy: 0.7018 - lr: 5.0000e-06
# Epoch 16/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.5510 - accuracy: 0.7538 - val_loss: 0.5844 - val_accuracy: 0.7018 - lr: 5.0000e-06
# Epoch 17/200
# 29/29 [==============================] - 1s 50ms/step - loss: 0.5460 - accuracy: 0.7363 - val_loss: 0.5837 - val_accuracy: 0.7018 - lr: 5.0000e-06
# Epoch 18/200
# 29/29 [==============================] - 1s 46ms/step - loss: 0.5557 - accuracy: 0.7385 - val_loss: 0.5824 - val_accuracy: 0.7018 - lr: 5.0000e-06
# Epoch 19/200
# 29/29 [==============================] - 1s 46ms/step - loss: 0.5447 - accuracy: 0.7407 - val_loss: 0.5799 - val_accuracy: 0.7018 - lr: 5.0000e-06
# Epoch 20/200
# 29/29 [==============================] - 1s 46ms/step - loss: 0.5388 - accuracy: 0.7495 - val_loss: 0.5785 - val_accuracy: 0.7193 - lr: 5.0000e-06
# Epoch 21/200
# 29/29 [==============================] - 1s 46ms/step - loss: 0.5329 - accuracy: 0.7473 - val_loss: 0.5797 - val_accuracy: 0.7105 - lr: 5.0000e-06
# Epoch 22/200
# 29/29 [==============================] - 1s 46ms/step - loss: 0.5448 - accuracy: 0.7407 - val_loss: 0.5830 - val_accuracy: 0.7105 - lr: 5.0000e-06
# Epoch 23/200
# 29/29 [==============================] - 1s 45ms/step - loss: 0.5370 - accuracy: 0.7407 - val_loss: 0.5823 - val_accuracy: 0.7193 - lr: 5.0000e-06
# Epoch 24/200
# 29/29 [==============================] - 1s 47ms/step - loss: 0.5264 - accuracy: 0.7604 - val_loss: 0.5806 - val_accuracy: 0.7193 - lr: 5.0000e-06
# Epoch 25/200
# 29/29 [==============================] - 1s 46ms/step - loss: 0.5405 - accuracy: 0.7429 - val_loss: 0.5813 - val_accuracy: 0.7105 - lr: 5.0000e-06
# Epoch 26/200
# 29/29 [==============================] - 1s 48ms/step - loss: 0.5350 - accuracy: 0.7473 - val_loss: 0.5856 - val_accuracy: 0.6930 - lr: 5.0000e-06
# Epoch 27/200
# 29/29 [==============================] - 1s 46ms/step - loss: 0.5290 - accuracy: 0.7297 - val_loss: 0.5865 - val_accuracy: 0.6930 - lr: 5.0000e-06
# Epoch 28/200
# 29/29 [==============================] - 1s 47ms/step - loss: 0.5323 - accuracy: 0.7341 - val_loss: 0.5867 - val_accuracy: 0.7018 - lr: 5.0000e-06
# Epoch 29/200
# 29/29 [==============================] - 1s 46ms/step - loss: 0.5303 - accuracy: 0.7341 - val_loss: 0.5877 - val_accuracy: 0.7018 - lr: 5.0000e-06
# Epoch 30/200
# 29/29 [==============================] - 1s 46ms/step - loss: 0.5229 - accuracy: 0.7473 - val_loss: 0.5897 - val_accuracy: 0.7018 - lr: 5.0000e-06
# Epoch 31/200
# 29/29 [==============================] - 1s 47ms/step - loss: 0.5195 - accuracy: 0.7560 - val_loss: 0.5900 - val_accuracy: 0.7018 - lr: 5.0000e-06
# Epoch 32/200
# 29/29 [==============================] - 1s 45ms/step - loss: 0.5176 - accuracy: 0.7648 - val_loss: 0.5911 - val_accuracy: 0.6930 - lr: 5.0000e-06
# Epoch 33/200
# 29/29 [==============================] - 1s 46ms/step - loss: 0.5173 - accuracy: 0.7495 - val_loss: 0.5969 - val_accuracy: 0.6754 - lr: 5.0000e-06
# Epoch 34/200
# 29/29 [==============================] - 1s 46ms/step - loss: 0.5213 - accuracy: 0.7495 - val_loss: 0.5952 - val_accuracy: 0.6754 - lr: 5.0000e-06
# Epoch 35/200
# 29/29 [==============================] - 1s 46ms/step - loss: 0.5218 - accuracy: 0.7538 - val_loss: 0.5959 - val_accuracy: 0.6754 - lr: 5.0000e-06
# Epoch 36/200
# 29/29 [==============================] - 1s 46ms/step - loss: 0.5280 - accuracy: 0.7407 - val_loss: 0.5930 - val_accuracy: 0.6842 - lr: 5.0000e-06
# Epoch 37/200
# 29/29 [==============================] - 1s 45ms/step - loss: 0.5197 - accuracy: 0.7429 - val_loss: 0.5928 - val_accuracy: 0.6930 - lr: 5.0000e-06
# Epoch 38/200
# 29/29 [==============================] - 1s 47ms/step - loss: 0.5175 - accuracy: 0.7407 - val_loss: 0.5963 - val_accuracy: 0.6754 - lr: 5.0000e-06
# Epoch 39/200
# 29/29 [==============================] - 1s 46ms/step - loss: 0.5311 - accuracy: 0.7275 - val_loss: 0.6013 - val_accuracy: 0.6754 - lr: 5.0000e-06
# Epoch 40/200
# 29/29 [==============================] - 1s 45ms/step - loss: 0.5170 - accuracy: 0.7582 - val_loss: 0.6005 - val_accuracy: 0.6842 - lr: 5.0000e-06
# Epoch 41/200
# 29/29 [==============================] - 1s 47ms/step - loss: 0.5287 - accuracy: 0.7363 - val_loss: 0.5954 - val_accuracy: 0.6842 - lr: 5.0000e-06
# Epoch 42/200
# 29/29 [==============================] - 1s 45ms/step - loss: 0.5184 - accuracy: 0.7385 - val_loss: 0.5979 - val_accuracy: 0.6842 - lr: 5.0000e-06
# Epoch 43/200
# 29/29 [==============================] - 1s 46ms/step - loss: 0.5161 - accuracy: 0.7451 - val_loss: 0.6029 - val_accuracy: 0.6667 - lr: 5.0000e-06
# Epoch 44/200
# 29/29 [==============================] - 1s 45ms/step - loss: 0.5227 - accuracy: 0.7560 - val_loss: 0.6081 - val_accuracy: 0.6667 - lr: 5.0000e-06
# Epoch 45/200
# 29/29 [==============================] - 1s 47ms/step - loss: 0.5158 - accuracy: 0.7560 - val_loss: 0.6052 - val_accuracy: 0.6667 - lr: 5.0000e-06
# Epoch 46/200
# 29/29 [==============================] - 1s 46ms/step - loss: 0.5410 - accuracy: 0.7231 - val_loss: 0.6089 - val_accuracy: 0.6579 - lr: 5.0000e-06
# Epoch 47/200
# 29/29 [==============================] - 1s 46ms/step - loss: 0.5231 - accuracy: 0.7429 - val_loss: 0.6064 - val_accuracy: 0.6667 - lr: 5.0000e-06
# Epoch 48/200
# 29/29 [==============================] - 1s 47ms/step - loss: 0.5194 - accuracy: 0.7319 - val_loss: 0.6047 - val_accuracy: 0.6667 - lr: 5.0000e-06
# Epoch 49/200
# 29/29 [==============================] - 1s 45ms/step - loss: 0.5257 - accuracy: 0.7341 - val_loss: 0.6095 - val_accuracy: 0.6579 - lr: 5.0000e-06
# Epoch 50/200
# 29/29 [==============================] - 1s 46ms/step - loss: 0.5163 - accuracy: 0.7429 - val_loss: 0.6078 - val_accuracy: 0.6579 - lr: 5.0000e-06
# Epoch 51/200
# 29/29 [==============================] - 1s 47ms/step - loss: 0.5293 - accuracy: 0.7407 - val_loss: 0.6042 - val_accuracy: 0.6667 - lr: 5.0000e-06
# Epoch 52/200
# 29/29 [==============================] - 1s 46ms/step - loss: 0.5067 - accuracy: 0.7473 - val_loss: 0.6080 - val_accuracy: 0.6579 - lr: 5.0000e-06
# Epoch 53/200
# 29/29 [==============================] - 1s 47ms/step - loss: 0.5236 - accuracy: 0.7429 - val_loss: 0.6081 - val_accuracy: 0.6579 - lr: 5.0000e-06
# Epoch 54/200
# 29/29 [==============================] - 1s 45ms/step - loss: 0.5094 - accuracy: 0.7297 - val_loss: 0.6096 - val_accuracy: 0.6579 - lr: 5.0000e-06
# Epoch 55/200
# 29/29 [==============================] - 1s 48ms/step - loss: 0.5172 - accuracy: 0.7429 - val_loss: 0.6075 - val_accuracy: 0.6579 - lr: 5.0000e-06
# Epoch 56/200
# 29/29 [==============================] - 1s 46ms/step - loss: 0.5113 - accuracy: 0.7451 - val_loss: 0.6054 - val_accuracy: 0.6667 - lr: 5.0000e-06
# Epoch 57/200
# 29/29 [==============================] - 1s 47ms/step - loss: 0.5262 - accuracy: 0.7253 - val_loss: 0.6050 - val_accuracy: 0.6667 - lr: 5.0000e-06
# Epoch 58/200
# 29/29 [==============================] - 1s 46ms/step - loss: 0.5116 - accuracy: 0.7560 - val_loss: 0.6098 - val_accuracy: 0.6579 - lr: 5.0000e-06
# Epoch 59/200
# 29/29 [==============================] - 1s 49ms/step - loss: 0.5070 - accuracy: 0.7516 - val_loss: 0.6090 - val_accuracy: 0.6579 - lr: 5.0000e-06
# Epoch 60/200
# 29/29 [==============================] - 1s 51ms/step - loss: 0.5123 - accuracy: 0.7538 - val_loss: 0.6094 - val_accuracy: 0.6579 - lr: 5.0000e-06
# Epoch 61/200
# 29/29 [==============================] - 1s 47ms/step - loss: 0.5103 - accuracy: 0.7429 - val_loss: 0.6074 - val_accuracy: 0.6579 - lr: 5.0000e-06
# Epoch 62/200
# 29/29 [==============================] - 1s 47ms/step - loss: 0.5146 - accuracy: 0.7516 - val_loss: 0.6089 - val_accuracy: 0.6579 - lr: 5.0000e-06
# Epoch 63/200
# 29/29 [==============================] - 1s 47ms/step - loss: 0.5016 - accuracy: 0.7582 - val_loss: 0.6101 - val_accuracy: 0.6579 - lr: 5.0000e-06
# Epoch 64/200
# 29/29 [==============================] - 1s 47ms/step - loss: 0.5110 - accuracy: 0.7429 - val_loss: 0.6121 - val_accuracy: 0.6579 - lr: 5.0000e-06
# Epoch 65/200
# 29/29 [==============================] - 1s 48ms/step - loss: 0.5041 - accuracy: 0.7451 - val_loss: 0.6143 - val_accuracy: 0.6579 - lr: 5.0000e-06
# Epoch 66/200
# 29/29 [==============================] - 2s 67ms/step - loss: 0.5014 - accuracy: 0.7692 - val_loss: 0.6135 - val_accuracy: 0.6579 - lr: 5.0000e-06
# Epoch 67/200
# 29/29 [==============================] - 2s 59ms/step - loss: 0.5135 - accuracy: 0.7582 - val_loss: 0.6067 - val_accuracy: 0.6579 - lr: 5.0000e-06
# Epoch 68/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.5258 - accuracy: 0.7231 - val_loss: 0.6114 - val_accuracy: 0.6579 - lr: 5.0000e-06
# Epoch 69/200
# 29/29 [==============================] - 2s 72ms/step - loss: 0.5205 - accuracy: 0.7341 - val_loss: 0.6124 - val_accuracy: 0.6579 - lr: 5.0000e-06
# Epoch 70/200
# 29/29 [==============================] - 2s 70ms/step - loss: 0.5177 - accuracy: 0.7495 - val_loss: 0.6114 - val_accuracy: 0.6579 - lr: 5.0000e-06
# Epoch 71/200
# 29/29 [==============================] - 2s 73ms/step - loss: 0.5125 - accuracy: 0.7582 - val_loss: 0.6109 - val_accuracy: 0.6579 - lr: 5.0000e-06
# Epoch 72/200
# 29/29 [==============================] - 2s 70ms/step - loss: 0.5054 - accuracy: 0.7626 - val_loss: 0.6093 - val_accuracy: 0.6579 - lr: 5.0000e-06
# Epoch 73/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.5071 - accuracy: 0.7495 - val_loss: 0.6114 - val_accuracy: 0.6579 - lr: 5.0000e-06
# Epoch 74/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.5173 - accuracy: 0.7407 - val_loss: 0.6106 - val_accuracy: 0.6579 - lr: 5.0000e-06
# Epoch 75/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.5007 - accuracy: 0.7560 - val_loss: 0.6100 - val_accuracy: 0.6579 - lr: 5.0000e-06
# Epoch 76/200
# 29/29 [==============================] - 2s 68ms/step - loss: 0.5083 - accuracy: 0.7648 - val_loss: 0.6098 - val_accuracy: 0.6579 - lr: 5.0000e-06
# Epoch 77/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.5171 - accuracy: 0.7473 - val_loss: 0.6140 - val_accuracy: 0.6579 - lr: 5.0000e-06
# Epoch 78/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.5028 - accuracy: 0.7582 - val_loss: 0.6066 - val_accuracy: 0.6579 - lr: 5.0000e-06
# Epoch 79/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.4972 - accuracy: 0.7670 - val_loss: 0.6127 - val_accuracy: 0.6579 - lr: 5.0000e-06
# Epoch 80/200
# 29/29 [==============================] - 2s 73ms/step - loss: 0.5065 - accuracy: 0.7560 - val_loss: 0.6158 - val_accuracy: 0.6579 - lr: 5.0000e-06
# Epoch 81/200
# 29/29 [==============================] - 2s 75ms/step - loss: 0.5136 - accuracy: 0.7451 - val_loss: 0.6137 - val_accuracy: 0.6579 - lr: 5.0000e-06
# Epoch 82/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.5048 - accuracy: 0.7626 - val_loss: 0.6067 - val_accuracy: 0.6579 - lr: 5.0000e-06
# Epoch 83/200
# 29/29 [==============================] - 2s 71ms/step - loss: 0.5056 - accuracy: 0.7582 - val_loss: 0.6105 - val_accuracy: 0.6579 - lr: 5.0000e-06
# Epoch 84/200
# 29/29 [==============================] - 2s 70ms/step - loss: 0.5059 - accuracy: 0.7363 - val_loss: 0.6204 - val_accuracy: 0.6754 - lr: 5.0000e-06
# Epoch 85/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.5150 - accuracy: 0.7429 - val_loss: 0.6135 - val_accuracy: 0.6579 - lr: 5.0000e-06
# Epoch 86/200
# 29/29 [==============================] - 2s 70ms/step - loss: 0.5055 - accuracy: 0.7473 - val_loss: 0.6179 - val_accuracy: 0.6754 - lr: 5.0000e-06
# Epoch 87/200
# 29/29 [==============================] - 2s 71ms/step - loss: 0.5058 - accuracy: 0.7473 - val_loss: 0.6100 - val_accuracy: 0.6579 - lr: 5.0000e-06
# Epoch 88/200
# 29/29 [==============================] - 2s 67ms/step - loss: 0.5047 - accuracy: 0.7670 - val_loss: 0.6040 - val_accuracy: 0.6579 - lr: 5.0000e-06
# Epoch 89/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.5086 - accuracy: 0.7451 - val_loss: 0.6081 - val_accuracy: 0.6579 - lr: 5.0000e-06
# Epoch 90/200
# 29/29 [==============================] - 2s 69ms/step - loss: 0.4975 - accuracy: 0.7736 - val_loss: 0.6088 - val_accuracy: 0.6579 - lr: 5.0000e-06
# Epoch 91/200
# 29/29 [==============================] - 2s 70ms/step - loss: 0.5235 - accuracy: 0.7297 - val_loss: 0.6147 - val_accuracy: 0.6579 - lr: 5.0000e-06
# Epoch 92/200
# 29/29 [==============================] - 3s 93ms/step - loss: 0.4957 - accuracy: 0.7538 - val_loss: 0.6166 - val_accuracy: 0.6754 - lr: 5.0000e-06
# Epoch 93/200
# 29/29 [==============================] - 2s 82ms/step - loss: 0.5089 - accuracy: 0.7319 - val_loss: 0.6167 - val_accuracy: 0.6754 - lr: 5.0000e-06
# Epoch 94/200
# 29/29 [==============================] - 3s 94ms/step - loss: 0.5111 - accuracy: 0.7451 - val_loss: 0.6110 - val_accuracy: 0.6579 - lr: 5.0000e-06
# Epoch 95/200
# 29/29 [==============================] - 3s 97ms/step - loss: 0.5028 - accuracy: 0.7560 - val_loss: 0.6154 - val_accuracy: 0.6667 - lr: 5.0000e-06
# Epoch 96/200
# 29/29 [==============================] - 3s 96ms/step - loss: 0.4987 - accuracy: 0.7670 - val_loss: 0.6086 - val_accuracy: 0.6579 - lr: 5.0000e-06
# Epoch 97/200
# 29/29 [==============================] - 3s 93ms/step - loss: 0.5048 - accuracy: 0.7626 - val_loss: 0.6138 - val_accuracy: 0.6667 - lr: 5.0000e-06
# Epoch 98/200
# 29/29 [==============================] - 3s 94ms/step - loss: 0.5097 - accuracy: 0.7495 - val_loss: 0.6128 - val_accuracy: 0.6579 - lr: 5.0000e-06
# Epoch 99/200
# 29/29 [==============================] - 3s 93ms/step - loss: 0.5059 - accuracy: 0.7626 - val_loss: 0.6133 - val_accuracy: 0.6579 - lr: 5.0000e-06
# Epoch 100/200
# 29/29 [==============================] - 3s 92ms/step - loss: 0.5148 - accuracy: 0.7341 - val_loss: 0.6047 - val_accuracy: 0.6579 - lr: 5.0000e-06
# Epoch 101/200
# 29/29 [==============================] - 3s 96ms/step - loss: 0.4953 - accuracy: 0.7516 - val_loss: 0.6060 - val_accuracy: 0.6579 - lr: 5.0000e-06
# Epoch 102/200
# 29/29 [==============================] - 3s 99ms/step - loss: 0.5067 - accuracy: 0.7516 - val_loss: 0.6109 - val_accuracy: 0.6579 - lr: 5.0000e-06
# Epoch 103/200
# 29/29 [==============================] - 3s 97ms/step - loss: 0.4933 - accuracy: 0.7736 - val_loss: 0.6066 - val_accuracy: 0.6667 - lr: 5.0000e-06
# Epoch 104/200
# 29/29 [==============================] - 3s 101ms/step - loss: 0.4967 - accuracy: 0.7626 - val_loss: 0.6037 - val_accuracy: 0.6491 - lr: 5.0000e-06
# Epoch 105/200
# 29/29 [==============================] - 3s 95ms/step - loss: 0.4977 - accuracy: 0.7692 - val_loss: 0.6146 - val_accuracy: 0.6667 - lr: 5.0000e-06
# Epoch 106/200
# 29/29 [==============================] - 3s 91ms/step - loss: 0.5046 - accuracy: 0.7604 - val_loss: 0.6096 - val_accuracy: 0.6579 - lr: 5.0000e-06
# Epoch 107/200
# 29/29 [==============================] - 3s 99ms/step - loss: 0.5042 - accuracy: 0.7648 - val_loss: 0.6077 - val_accuracy: 0.6579 - lr: 5.0000e-06
# Epoch 108/200
# 29/29 [==============================] - 3s 92ms/step - loss: 0.5081 - accuracy: 0.7516 - val_loss: 0.6057 - val_accuracy: 0.6491 - lr: 5.0000e-06
# Epoch 109/200
# 29/29 [==============================] - 3s 94ms/step - loss: 0.5117 - accuracy: 0.7714 - val_loss: 0.6152 - val_accuracy: 0.6754 - lr: 5.0000e-06
# Epoch 110/200
# 29/29 [==============================] - 3s 90ms/step - loss: 0.4873 - accuracy: 0.7736 - val_loss: 0.6151 - val_accuracy: 0.6754 - lr: 5.0000e-06
# Epoch 111/200
# 29/29 [==============================] - 3s 94ms/step - loss: 0.5075 - accuracy: 0.7604 - val_loss: 0.6193 - val_accuracy: 0.6754 - lr: 5.0000e-06
# Epoch 112/200
# 29/29 [==============================] - 3s 100ms/step - loss: 0.5046 - accuracy: 0.7538 - val_loss: 0.6091 - val_accuracy: 0.6667 - lr: 5.0000e-06
# Epoch 113/200
# 29/29 [==============================] - 3s 99ms/step - loss: 0.4992 - accuracy: 0.7560 - val_loss: 0.6062 - val_accuracy: 0.6667 - lr: 5.0000e-06
# Epoch 114/200
# 29/29 [==============================] - 3s 99ms/step - loss: 0.5215 - accuracy: 0.7407 - val_loss: 0.6094 - val_accuracy: 0.6579 - lr: 5.0000e-06
# Epoch 115/200
# 29/29 [==============================] - 3s 96ms/step - loss: 0.5007 - accuracy: 0.7648 - val_loss: 0.6129 - val_accuracy: 0.6579 - lr: 5.0000e-06
# Epoch 116/200
# 29/29 [==============================] - 3s 93ms/step - loss: 0.5017 - accuracy: 0.7714 - val_loss: 0.6171 - val_accuracy: 0.6754 - lr: 5.0000e-06
# Epoch 117/200
# 29/29 [==============================] - 3s 91ms/step - loss: 0.4991 - accuracy: 0.7473 - val_loss: 0.6082 - val_accuracy: 0.6667 - lr: 5.0000e-06
# Epoch 118/200
# 29/29 [==============================] - 3s 92ms/step - loss: 0.4863 - accuracy: 0.7692 - val_loss: 0.6167 - val_accuracy: 0.6754 - lr: 5.0000e-06
# Epoch 119/200
# 29/29 [==============================] - 3s 94ms/step - loss: 0.5087 - accuracy: 0.7429 - val_loss: 0.6110 - val_accuracy: 0.6667 - lr: 5.0000e-06
# Epoch 120/200
# 29/29 [==============================] - 3s 97ms/step - loss: 0.5065 - accuracy: 0.7648 - val_loss: 0.6201 - val_accuracy: 0.6754 - lr: 5.0000e-06
# Epoch 121/200
# 29/29 [==============================] - 3s 94ms/step - loss: 0.4913 - accuracy: 0.7824 - val_loss: 0.6131 - val_accuracy: 0.6842 - lr: 5.0000e-06
# Epoch 122/200
# 29/29 [==============================] - 3s 95ms/step - loss: 0.5111 - accuracy: 0.7516 - val_loss: 0.6144 - val_accuracy: 0.6842 - lr: 5.0000e-06
# Epoch 123/200
# 29/29 [==============================] - 3s 96ms/step - loss: 0.4985 - accuracy: 0.7429 - val_loss: 0.6145 - val_accuracy: 0.6842 - lr: 5.0000e-06
# Epoch 124/200
# 29/29 [==============================] - 3s 94ms/step - loss: 0.5030 - accuracy: 0.7451 - val_loss: 0.6086 - val_accuracy: 0.6667 - lr: 5.0000e-06
# Epoch 125/200
# 29/29 [==============================] - 3s 95ms/step - loss: 0.5004 - accuracy: 0.7451 - val_loss: 0.6180 - val_accuracy: 0.6842 - lr: 5.0000e-06
# Epoch 126/200
# 29/29 [==============================] - 3s 94ms/step - loss: 0.4873 - accuracy: 0.7736 - val_loss: 0.6179 - val_accuracy: 0.6754 - lr: 5.0000e-06
# Epoch 127/200
# 29/29 [==============================] - 3s 94ms/step - loss: 0.4944 - accuracy: 0.7582 - val_loss: 0.6194 - val_accuracy: 0.6754 - lr: 5.0000e-06
# Epoch 128/200
# 29/29 [==============================] - 3s 96ms/step - loss: 0.5004 - accuracy: 0.7538 - val_loss: 0.6186 - val_accuracy: 0.6842 - lr: 5.0000e-06
# Epoch 129/200
# 29/29 [==============================] - 3s 96ms/step - loss: 0.4883 - accuracy: 0.7714 - val_loss: 0.6130 - val_accuracy: 0.6842 - lr: 5.0000e-06
# Epoch 130/200
# 29/29 [==============================] - 3s 97ms/step - loss: 0.4999 - accuracy: 0.7495 - val_loss: 0.6112 - val_accuracy: 0.6842 - lr: 5.0000e-06
# Epoch 131/200
# 29/29 [==============================] - 3s 93ms/step - loss: 0.4922 - accuracy: 0.7516 - val_loss: 0.6157 - val_accuracy: 0.6842 - lr: 5.0000e-06
# Epoch 132/200
# 29/29 [==============================] - 3s 96ms/step - loss: 0.4976 - accuracy: 0.7516 - val_loss: 0.6143 - val_accuracy: 0.6842 - lr: 5.0000e-06
# Epoch 133/200
# 29/29 [==============================] - ETA: 0s - loss: 0.5038 - accuracy: 0.7582
# Epoch 133: ReduceLROnPlateau reducing learning rate to 3.968502529667691e-06.
# 29/29 [==============================] - 3s 119ms/step - loss: 0.5038 - accuracy: 0.7582 - val_loss: 0.6140 - val_accuracy: 0.6842 - lr: 5.0000e-06
# Epoch 134/200
# 29/29 [==============================] - 3s 95ms/step - loss: 0.4969 - accuracy: 0.7429 - val_loss: 0.6196 - val_accuracy: 0.6842 - lr: 3.9685e-06
# Epoch 135/200
# 29/29 [==============================] - 3s 110ms/step - loss: 0.5018 - accuracy: 0.7648 - val_loss: 0.6154 - val_accuracy: 0.6842 - lr: 3.9685e-06
# Epoch 136/200
# 29/29 [==============================] - 3s 121ms/step - loss: 0.4943 - accuracy: 0.7538 - val_loss: 0.6134 - val_accuracy: 0.6842 - lr: 3.9685e-06
# Epoch 137/200
# 29/29 [==============================] - 3s 121ms/step - loss: 0.5096 - accuracy: 0.7473 - val_loss: 0.6116 - val_accuracy: 0.6842 - lr: 3.9685e-06
# Epoch 138/200
# 29/29 [==============================] - 3s 122ms/step - loss: 0.4848 - accuracy: 0.7692 - val_loss: 0.6102 - val_accuracy: 0.6842 - lr: 3.9685e-06
# Epoch 139/200
# 29/29 [==============================] - 4s 125ms/step - loss: 0.5002 - accuracy: 0.7407 - val_loss: 0.6106 - val_accuracy: 0.6842 - lr: 3.9685e-06
# Epoch 140/200
# 29/29 [==============================] - 3s 121ms/step - loss: 0.4929 - accuracy: 0.7890 - val_loss: 0.6060 - val_accuracy: 0.6579 - lr: 3.9685e-06
# Epoch 141/200
# 29/29 [==============================] - 3s 120ms/step - loss: 0.4808 - accuracy: 0.7736 - val_loss: 0.6090 - val_accuracy: 0.6842 - lr: 3.9685e-06
# Epoch 142/200
# 29/29 [==============================] - 4s 123ms/step - loss: 0.5027 - accuracy: 0.7714 - val_loss: 0.6149 - val_accuracy: 0.6842 - lr: 3.9685e-06
# Epoch 143/200
# 29/29 [==============================] - 4s 122ms/step - loss: 0.5034 - accuracy: 0.7582 - val_loss: 0.6081 - val_accuracy: 0.6842 - lr: 3.9685e-06
# Epoch 144/200
# 29/29 [==============================] - 4s 123ms/step - loss: 0.4946 - accuracy: 0.7495 - val_loss: 0.6113 - val_accuracy: 0.6842 - lr: 3.9685e-06
# Epoch 145/200
# 29/29 [==============================] - 4s 124ms/step - loss: 0.5030 - accuracy: 0.7451 - val_loss: 0.6214 - val_accuracy: 0.6842 - lr: 3.9685e-06
# Epoch 146/200
# 29/29 [==============================] - 4s 122ms/step - loss: 0.4947 - accuracy: 0.7626 - val_loss: 0.6138 - val_accuracy: 0.6842 - lr: 3.9685e-06
# Epoch 147/200
# 29/29 [==============================] - 3s 119ms/step - loss: 0.4901 - accuracy: 0.7890 - val_loss: 0.6128 - val_accuracy: 0.6842 - lr: 3.9685e-06
# Epoch 148/200
# 29/29 [==============================] - 8s 291ms/step - loss: 0.4909 - accuracy: 0.7626 - val_loss: 0.6105 - val_accuracy: 0.6842 - lr: 3.9685e-06
# Epoch 149/200
# 29/29 [==============================] - 10s 342ms/step - loss: 0.4905 - accuracy: 0.7582 - val_loss: 0.6096 - val_accuracy: 0.6842 - lr: 3.9685e-06
# Epoch 150/200
# 29/29 [==============================] - 10s 341ms/step - loss: 0.4815 - accuracy: 0.7604 - val_loss: 0.6090 - val_accuracy: 0.6754 - lr: 3.9685e-06
# Epoch 151/200
# 29/29 [==============================] - 7s 254ms/step - loss: 0.4986 - accuracy: 0.7538 - val_loss: 0.6066 - val_accuracy: 0.6667 - lr: 3.9685e-06
# Epoch 152/200
# 29/29 [==============================] - 4s 122ms/step - loss: 0.4881 - accuracy: 0.7626 - val_loss: 0.6078 - val_accuracy: 0.6667 - lr: 3.9685e-06
# Epoch 153/200
# 29/29 [==============================] - 4s 124ms/step - loss: 0.4910 - accuracy: 0.7538 - val_loss: 0.6182 - val_accuracy: 0.6842 - lr: 3.9685e-06
# Epoch 154/200
# 29/29 [==============================] - 4s 125ms/step - loss: 0.5057 - accuracy: 0.7451 - val_loss: 0.6159 - val_accuracy: 0.6842 - lr: 3.9685e-06
# Epoch 155/200
# 29/29 [==============================] - 4s 123ms/step - loss: 0.4894 - accuracy: 0.7560 - val_loss: 0.6147 - val_accuracy: 0.6842 - lr: 3.9685e-06
# Epoch 156/200
# 29/29 [==============================] - ETA: 0s - loss: 0.4898 - accuracy: 0.7736
# Epoch 156: ReduceLROnPlateau reducing learning rate to 3.1498024179533314e-06.
# 29/29 [==============================] - 4s 125ms/step - loss: 0.4898 - accuracy: 0.7736 - val_loss: 0.6159 - val_accuracy: 0.6842 - lr: 3.9685e-06
# Epoch 157/200
# 29/29 [==============================] - 4s 126ms/step - loss: 0.4932 - accuracy: 0.7560 - val_loss: 0.6192 - val_accuracy: 0.6842 - lr: 3.1498e-06
# Epoch 158/200
# 29/29 [==============================] - 4s 121ms/step - loss: 0.4884 - accuracy: 0.7648 - val_loss: 0.6134 - val_accuracy: 0.6842 - lr: 3.1498e-06
# Epoch 159/200
# 29/29 [==============================] - 4s 122ms/step - loss: 0.4963 - accuracy: 0.7670 - val_loss: 0.6116 - val_accuracy: 0.6842 - lr: 3.1498e-06
# Epoch 160/200
# 29/29 [==============================] - 3s 118ms/step - loss: 0.4976 - accuracy: 0.7582 - val_loss: 0.6084 - val_accuracy: 0.6842 - lr: 3.1498e-06
# Epoch 161/200
# 29/29 [==============================] - 4s 123ms/step - loss: 0.4997 - accuracy: 0.7714 - val_loss: 0.6077 - val_accuracy: 0.6842 - lr: 3.1498e-06
# Epoch 162/200
# 29/29 [==============================] - 3s 119ms/step - loss: 0.4962 - accuracy: 0.7582 - val_loss: 0.6055 - val_accuracy: 0.6667 - lr: 3.1498e-06
# Epoch 163/200
# 29/29 [==============================] - 4s 125ms/step - loss: 0.4818 - accuracy: 0.7626 - val_loss: 0.6109 - val_accuracy: 0.6842 - lr: 3.1498e-06
# Epoch 164/200
# 29/29 [==============================] - 3s 119ms/step - loss: 0.4977 - accuracy: 0.7495 - val_loss: 0.6085 - val_accuracy: 0.6842 - lr: 3.1498e-06
# Epoch 165/200
# 29/29 [==============================] - 3s 119ms/step - loss: 0.4964 - accuracy: 0.7538 - val_loss: 0.6161 - val_accuracy: 0.6842 - lr: 3.1498e-06
# Epoch 166/200
# 29/29 [==============================] - 3s 121ms/step - loss: 0.4878 - accuracy: 0.7758 - val_loss: 0.6182 - val_accuracy: 0.6842 - lr: 3.1498e-06
# Epoch 167/200
# 29/29 [==============================] - 3s 121ms/step - loss: 0.4912 - accuracy: 0.7604 - val_loss: 0.6172 - val_accuracy: 0.6842 - lr: 3.1498e-06
# Epoch 168/200
# 29/29 [==============================] - 3s 118ms/step - loss: 0.4827 - accuracy: 0.7692 - val_loss: 0.6128 - val_accuracy: 0.6842 - lr: 3.1498e-06
# Epoch 169/200
# 29/29 [==============================] - 3s 121ms/step - loss: 0.4969 - accuracy: 0.7758 - val_loss: 0.6146 - val_accuracy: 0.6842 - lr: 3.1498e-06
# Epoch 170/200
# 29/29 [==============================] - 4s 124ms/step - loss: 0.5058 - accuracy: 0.7736 - val_loss: 0.6170 - val_accuracy: 0.6842 - lr: 3.1498e-06
# Epoch 171/200
# 29/29 [==============================] - ETA: 0s - loss: 0.4875 - accuracy: 0.7626
# Epoch 171: ReduceLROnPlateau reducing learning rate to 2.499999919802159e-06.
# 29/29 [==============================] - 3s 115ms/step - loss: 0.4875 - accuracy: 0.7626 - val_loss: 0.6123 - val_accuracy: 0.6842 - lr: 3.1498e-06
# Epoch 172/200
# 29/29 [==============================] - 3s 115ms/step - loss: 0.4884 - accuracy: 0.7670 - val_loss: 0.6161 - val_accuracy: 0.6842 - lr: 2.5000e-06
# Epoch 173/200
# 29/29 [==============================] - 3s 117ms/step - loss: 0.5035 - accuracy: 0.7538 - val_loss: 0.6114 - val_accuracy: 0.6842 - lr: 2.5000e-06
# Epoch 174/200
# 29/29 [==============================] - 4s 126ms/step - loss: 0.4997 - accuracy: 0.7538 - val_loss: 0.6112 - val_accuracy: 0.6842 - lr: 2.5000e-06
# Epoch 175/200
# 29/29 [==============================] - 4s 123ms/step - loss: 0.5073 - accuracy: 0.7473 - val_loss: 0.6132 - val_accuracy: 0.6842 - lr: 2.5000e-06
# Epoch 176/200
# 29/29 [==============================] - 3s 121ms/step - loss: 0.4872 - accuracy: 0.7648 - val_loss: 0.6171 - val_accuracy: 0.6842 - lr: 2.5000e-06
# Epoch 177/200
# 29/29 [==============================] - 4s 125ms/step - loss: 0.4868 - accuracy: 0.7692 - val_loss: 0.6142 - val_accuracy: 0.6842 - lr: 2.5000e-06
# Epoch 178/200
# 29/29 [==============================] - 4s 124ms/step - loss: 0.4899 - accuracy: 0.7736 - val_loss: 0.6125 - val_accuracy: 0.6842 - lr: 2.5000e-06
# Epoch 179/200
# 29/29 [==============================] - 3s 120ms/step - loss: 0.4937 - accuracy: 0.7516 - val_loss: 0.6140 - val_accuracy: 0.6842 - lr: 2.5000e-06
# Epoch 180/200
# 29/29 [==============================] - 4s 125ms/step - loss: 0.4950 - accuracy: 0.7495 - val_loss: 0.6160 - val_accuracy: 0.6842 - lr: 2.5000e-06
# Epoch 181/200
# 29/29 [==============================] - 4s 122ms/step - loss: 0.4864 - accuracy: 0.7648 - val_loss: 0.6131 - val_accuracy: 0.6842 - lr: 2.5000e-06
# Epoch 182/200
# 29/29 [==============================] - 4s 123ms/step - loss: 0.5068 - accuracy: 0.7451 - val_loss: 0.6143 - val_accuracy: 0.6842 - lr: 2.5000e-06
# Epoch 183/200
# 29/29 [==============================] - 3s 120ms/step - loss: 0.5108 - accuracy: 0.7429 - val_loss: 0.6091 - val_accuracy: 0.6842 - lr: 2.5000e-06
# Epoch 184/200
# 29/29 [==============================] - 4s 126ms/step - loss: 0.5067 - accuracy: 0.7495 - val_loss: 0.6116 - val_accuracy: 0.6842 - lr: 2.5000e-06
# Epoch 185/200
# 29/29 [==============================] - 3s 118ms/step - loss: 0.4905 - accuracy: 0.7626 - val_loss: 0.6126 - val_accuracy: 0.6842 - lr: 2.5000e-06
# Epoch 186/200
# 29/29 [==============================] - ETA: 0s - loss: 0.4891 - accuracy: 0.7714
# Epoch 186: ReduceLROnPlateau reducing learning rate to 1.9842512648338455e-06.
# 29/29 [==============================] - 4s 123ms/step - loss: 0.4891 - accuracy: 0.7714 - val_loss: 0.6114 - val_accuracy: 0.6754 - lr: 2.5000e-06
# Epoch 187/200
# 29/29 [==============================] - 3s 117ms/step - loss: 0.5021 - accuracy: 0.7516 - val_loss: 0.6146 - val_accuracy: 0.6842 - lr: 1.9843e-06
# Epoch 188/200
# 29/29 [==============================] - 3s 117ms/step - loss: 0.4931 - accuracy: 0.7648 - val_loss: 0.6141 - val_accuracy: 0.6842 - lr: 1.9843e-06
# Epoch 189/200
# 29/29 [==============================] - 4s 122ms/step - loss: 0.5102 - accuracy: 0.7385 - val_loss: 0.6140 - val_accuracy: 0.6842 - lr: 1.9843e-06
# Epoch 190/200
# 29/29 [==============================] - 3s 121ms/step - loss: 0.4787 - accuracy: 0.7912 - val_loss: 0.6153 - val_accuracy: 0.6842 - lr: 1.9843e-06
# Epoch 191/200
# 29/29 [==============================] - 3s 118ms/step - loss: 0.4944 - accuracy: 0.7670 - val_loss: 0.6161 - val_accuracy: 0.6842 - lr: 1.9843e-06
# Epoch 192/200
# 29/29 [==============================] - 3s 120ms/step - loss: 0.4890 - accuracy: 0.7626 - val_loss: 0.6148 - val_accuracy: 0.6842 - lr: 1.9843e-06
# Epoch 193/200
# 29/29 [==============================] - 3s 120ms/step - loss: 0.4927 - accuracy: 0.7582 - val_loss: 0.6167 - val_accuracy: 0.6842 - lr: 1.9843e-06
# Epoch 194/200
# 29/29 [==============================] - 3s 122ms/step - loss: 0.5036 - accuracy: 0.7604 - val_loss: 0.6184 - val_accuracy: 0.6842 - lr: 1.9843e-06
# Epoch 195/200
# 29/29 [==============================] - 3s 119ms/step - loss: 0.4920 - accuracy: 0.7495 - val_loss: 0.6148 - val_accuracy: 0.6842 - lr: 1.9843e-06
# Epoch 196/200
# 29/29 [==============================] - 3s 120ms/step - loss: 0.4949 - accuracy: 0.7648 - val_loss: 0.6190 - val_accuracy: 0.6842 - lr: 1.9843e-06
# Epoch 197/200
# 29/29 [==============================] - 3s 120ms/step - loss: 0.4968 - accuracy: 0.7582 - val_loss: 0.6170 - val_accuracy: 0.6842 - lr: 1.9843e-06
# Epoch 198/200
# 29/29 [==============================] - 3s 118ms/step - loss: 0.4882 - accuracy: 0.7736 - val_loss: 0.6153 - val_accuracy: 0.6842 - lr: 1.9843e-06
# Epoch 199/200
# 29/29 [==============================] - 3s 120ms/step - loss: 0.4953 - accuracy: 0.7934 - val_loss: 0.6177 - val_accuracy: 0.6842 - lr: 1.9843e-06
# Epoch 200/200
# 29/29 [==============================] - 3s 120ms/step - loss: 0.5009 - accuracy: 0.7582 - val_loss: 0.6171 - val_accuracy: 0.6842 - lr: 1.9843e-06
# 5/5 [==============================] - 4s 30ms/step
# Test Accuracy: 0.7286
# Test F1 Score: 0.7432
# Test Precision: 0.7051
# Test Recall: 0.7857
# Test ROC AUC Score: 0.7947
