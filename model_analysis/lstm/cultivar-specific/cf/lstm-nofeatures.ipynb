# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import accuracy_score, roc_auc_score, recall_score, precision_score, f1_score
from sklearn.metrics import confusion_matrix, precision_recall_fscore_support
import seaborn as sns
from collections import Counter
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau
import sys
sys.path.append(r'C:\Users\Mud\Desktop\2ndPaper\lstm')
from model.lstmfcn import generate_lstmfcn
from model.fcn import generate_fcn
from model.lstm import generate_lstm
from utils.class_weight import compute_class_weight
import tensorflow as tf
import random as python_random

# %%
# # load the data
X_test = np.load(r'C:\Users\Mud\Desktop\2ndPaper\lstm\cultivar-specific\data\cf\X_test_cf.npy')
y_test = np.load(r'C:\Users\Mud\Desktop\2ndPaper\lstm\cultivar-specific\data\cf\y_test_cf.npy')
X_train = np.load(r'C:\Users\Mud\Desktop\2ndPaper\lstm\cultivar-specific\data\cf\X_train_cf.npy')
y_train = np.load(r'C:\Users\Mud\Desktop\2ndPaper\lstm\cultivar-specific\data\cf\y_train_cf.npy')

# # load fake data
#X_train = np.load('./fake/train/X_train.npy')
#y_train = np.load('./fake/train/y_train.npy')
#X_test = np.load('./fake/test/X_test.npy')
#y_test = np.load('./fake/test/y_test.npy')


print('X_train shape:', X_train.shape)
print('y_train shape:', y_train.shape)
print('X_test shape:', X_test.shape)
print('y_test shape:', y_test.shape)
# Out:
# X_train shape: (569, 600)
# y_train shape: (569,)
# X_test shape: (140, 600)
# y_test shape: (140,)

# %%
def reset_random_seeds(seed=42):
   np.random.seed(seed)
   python_random.seed(seed)
   tf.random.set_seed(seed)

reset_random_seeds()

# %%
# normalize the data to have same starting pt for all time series
# input shape: (n_samples, n_timepoints), want each samples - its mean of 0-30th timepts
def normalize_curves_mean_method(unnormalized_datas):
    normalized_datas = []
    for unnormalized_data in unnormalized_datas:
        mean = np.mean(unnormalized_data[:30])
        normalized_data = unnormalized_data - mean
        normalized_datas.append(normalized_data)
    normalized_datas = np.array(normalized_datas)
    assert normalized_datas.shape == unnormalized_datas.shape
    return normalized_datas

# normalize the data using z-score, have mean 0 and std 1
def normalize_curves_zscore(unnormalized_datas):
    normalized_datas = []
    for unnormalized_data in unnormalized_datas:
        mean = np.mean(unnormalized_data)
        std = np.std(unnormalized_data)
        normalized_data = (unnormalized_data - mean) / std
        normalized_datas.append(normalized_data)
    normalized_datas = np.array(normalized_datas)
    assert normalized_datas.shape == unnormalized_datas.shape
    return normalized_datas


# apply ln() to the time series data
def apply_ln_to_curves(datas):
    ln_datas = []
    for data in datas:
        ln_data = np.log(data)
        ln_datas.append(ln_data)
    ln_datas = np.array(ln_datas)
    assert ln_datas.shape == datas.shape
    return ln_datas


# split the time series data into wanted time points
def split_time_series(datas, start, end):
    datas = datas[:, start:end]
    return datas


# plot the time series data, randomly picked n samples, different colors represent different classes
def plot_random_time_series(datas, n, labels):
    for i in range(n):
        idx = np.random.randint(datas.shape[0])
        plt.plot(datas[idx], color = 'blue' if labels[idx] == 1 else 'red', alpha = 0.2)
    plt.show()


X_train = normalize_curves_mean_method(X_train)
X_test = normalize_curves_mean_method(X_test)
plot_random_time_series(X_train, 100, y_train)
# X_train = normalize_curves_zscore(X_train)
# X_test = normalize_curves_zscore(X_test)
print('X_train shape:', X_train.shape)
print('X_train range:', np.min(X_train), np.max(X_train))
print('X_test shape:', X_test.shape)
print('X_test range:', np.min(X_test), np.max(X_test))
# Out:
# X_train shape: (569, 600)
# X_train range: -17.047241118669263 635.5291005290983
# X_test shape: (140, 600)
# X_test range: -19.581783824642116 604.2200302343135

# %%
# upsample the one class in the training set by given factor
# add some level of noise to the time series data with maintaining mean & std
# class_label: 1 is alive, 0 is dead
def data_augmentation(X_train, y_train, n_times, class_label=1, random_seed=42):
    np.random.seed(random_seed)
    X_train_augmented = X_train.copy()
    y_train_augmented = y_train.copy()
    for i in range(len(y_train)):
        if y_train[i] == class_label:
            for _ in range(n_times):
                X_train_augmented = np.concatenate((X_train_augmented, [X_train[i] + np.random.normal(0, 0.1, X_train[i].shape)]), axis=0)
                y_train_augmented = np.concatenate((y_train_augmented, [y_train[i]]), axis=0)
    return X_train_augmented, y_train_augmented



print('Before, Class ratio:', Counter(y_train))
#X_train, y_train = data_augmentation(X_train, y_train, 10, class_label=0)
#X_train, y_train = data_augmentation(X_train, y_train, 4, class_label=1)
print('After, Class ratio:', Counter(y_train))
# Out:
# Before, Class ratio: Counter({1: 377, 0: 192})
# After, Class ratio: Counter({1: 377, 0: 192})

# %%
# compute mean & std of the training set, then normalize the whole dataset using z-normalization
mean = np.mean(X_train)
std = np.std(X_train)
X_train = (X_train - mean) / std
X_test = (X_test - mean) / std

# %%
# Ensure data is shaped correctly
X_train = X_train.reshape(-1, 1, 600)  # Convert to (samples, 1, timesteps)
X_test = X_test.reshape(-1, 1, 600)
y_train = y_train.reshape(-1, 1)  # Ensure labels are in shape (samples, 1)
y_test = y_test.reshape(-1, 1)

print('X_train shape:', X_train.shape)
print('y_train shape:', y_train.shape)
print('X_test shape:', X_test.shape)
print('y_test shape:', y_test.shape)
# Out:
# X_train shape: (569, 1, 600)
# y_train shape: (569, 1)
# X_test shape: (140, 1, 600)
# y_test shape: (140, 1)

# %%
# Train final model on full training data
final_model = generate_lstm(dropout=0)
class_weights = compute_class_weight(y_train)
print('class_weights:', class_weights)
reduce_lr = ReduceLROnPlateau(monitor='loss', patience=15, mode='auto',
    factor=1. / np.cbrt(2), cooldown=0, min_lr=5e-7, verbose=2)
final_model.compile(optimizer=Adam(learning_rate=8e-6), loss='binary_crossentropy', metrics=['accuracy'])

# split the data into training and validation set
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# Train model
history = final_model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    callbacks=[reduce_lr],
    epochs=1100, batch_size=16, class_weight={0: class_weights[0], 1: class_weights[1]},
    verbose=1
)

# Predict on test set
y_pred_prob = final_model.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)

# Calculate metrics
accuracy = accuracy_score(y_test, y_pred)
precision, recall, f1, _ = precision_recall_fscore_support(y_test, y_pred, average='binary')
roc_auc = roc_auc_score(y_test, y_pred_prob)
conf_matrix = confusion_matrix(y_test, y_pred)

# plot the metrics
print(f"Test Accuracy: {accuracy:.4f}")
print(f"Test F1 Score: {f1:.4f}")
print(f"Test Precision: {precision:.4f}")
print(f"Test Recall: {recall:.4f}")
print(f"Test ROC AUC Score: {roc_auc:.4f}")
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Dead', 'Alive'], yticklabels=['Dead', 'Alive'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()


# plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.figure(figsize=(10, 7))
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.figure(figsize=(10, 7))
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# class_weights: [1.48177083 0.75464191]
# Epoch 1/1100
# 29/29 [==============================] - 1s 9ms/step - loss: 0.6837 - accuracy: 0.3385 - val_loss: 0.7127 - val_accuracy: 0.3860 - lr: 8.0000e-06
# Epoch 2/1100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.6792 - accuracy: 0.3648 - val_loss: 0.7067 - val_accuracy: 0.3947 - lr: 8.0000e-06
# Epoch 3/1100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.6749 - accuracy: 0.3978 - val_loss: 0.7016 - val_accuracy: 0.4211 - lr: 8.0000e-06
# Epoch 4/1100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.6710 - accuracy: 0.4308 - val_loss: 0.6971 - val_accuracy: 0.4649 - lr: 8.0000e-06
# Epoch 5/1100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.6673 - accuracy: 0.4813 - val_loss: 0.6921 - val_accuracy: 0.4561 - lr: 8.0000e-06
# Epoch 6/1100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.6637 - accuracy: 0.5473 - val_loss: 0.6876 - val_accuracy: 0.4737 - lr: 8.0000e-06
# Epoch 7/1100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.6603 - accuracy: 0.5780 - val_loss: 0.6839 - val_accuracy: 0.5175 - lr: 8.0000e-06
# Epoch 8/1100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.6570 - accuracy: 0.5890 - val_loss: 0.6802 - val_accuracy: 0.5439 - lr: 8.0000e-06
# Epoch 9/1100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.6539 - accuracy: 0.6022 - val_loss: 0.6768 - val_accuracy: 0.5614 - lr: 8.0000e-06
# Epoch 10/1100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.6509 - accuracy: 0.6352 - val_loss: 0.6726 - val_accuracy: 0.5877 - lr: 8.0000e-06
# Epoch 11/1100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.6478 - accuracy: 0.6440 - val_loss: 0.6701 - val_accuracy: 0.5877 - lr: 8.0000e-06
# Epoch 12/1100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.6448 - accuracy: 0.6703 - val_loss: 0.6667 - val_accuracy: 0.6053 - lr: 8.0000e-06
# Epoch 13/1100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.6419 - accuracy: 0.6835 - val_loss: 0.6633 - val_accuracy: 0.5965 - lr: 8.0000e-06
# Epoch 14/1100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.6389 - accuracy: 0.6901 - val_loss: 0.6607 - val_accuracy: 0.6140 - lr: 8.0000e-06
# Epoch 15/1100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.6359 - accuracy: 0.6945 - val_loss: 0.6576 - val_accuracy: 0.6140 - lr: 8.0000e-06
# Epoch 16/1100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.6329 - accuracy: 0.7055 - val_loss: 0.6547 - val_accuracy: 0.6228 - lr: 8.0000e-06
# Epoch 17/1100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.6299 - accuracy: 0.7121 - val_loss: 0.6516 - val_accuracy: 0.6228 - lr: 8.0000e-06
# Epoch 18/1100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.6269 - accuracy: 0.7209 - val_loss: 0.6482 - val_accuracy: 0.6404 - lr: 8.0000e-06
# Epoch 19/1100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.6238 - accuracy: 0.7297 - val_loss: 0.6456 - val_accuracy: 0.6404 - lr: 8.0000e-06
# Epoch 20/1100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.6207 - accuracy: 0.7297 - val_loss: 0.6429 - val_accuracy: 0.6579 - lr: 8.0000e-06
# Epoch 21/1100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.6177 - accuracy: 0.7319 - val_loss: 0.6407 - val_accuracy: 0.6579 - lr: 8.0000e-06
# Epoch 22/1100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.6147 - accuracy: 0.7297 - val_loss: 0.6389 - val_accuracy: 0.6491 - lr: 8.0000e-06
# Epoch 23/1100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.6117 - accuracy: 0.7297 - val_loss: 0.6367 - val_accuracy: 0.6491 - lr: 8.0000e-06
# Epoch 24/1100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.6088 - accuracy: 0.7407 - val_loss: 0.6325 - val_accuracy: 0.6667 - lr: 8.0000e-06
# Epoch 25/1100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.6056 - accuracy: 0.7429 - val_loss: 0.6310 - val_accuracy: 0.6667 - lr: 8.0000e-06
# Epoch 26/1100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.6027 - accuracy: 0.7385 - val_loss: 0.6301 - val_accuracy: 0.6579 - lr: 8.0000e-06
# Epoch 27/1100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.5995 - accuracy: 0.7451 - val_loss: 0.6262 - val_accuracy: 0.6667 - lr: 8.0000e-06
# Epoch 28/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.5963 - accuracy: 0.7451 - val_loss: 0.6251 - val_accuracy: 0.6579 - lr: 8.0000e-06
# Epoch 29/1100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.5928 - accuracy: 0.7473 - val_loss: 0.6209 - val_accuracy: 0.6754 - lr: 8.0000e-06
# Epoch 30/1100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.5893 - accuracy: 0.7495 - val_loss: 0.6192 - val_accuracy: 0.6667 - lr: 8.0000e-06
# Epoch 31/1100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.5859 - accuracy: 0.7516 - val_loss: 0.6158 - val_accuracy: 0.6930 - lr: 8.0000e-06
# Epoch 32/1100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.5823 - accuracy: 0.7538 - val_loss: 0.6148 - val_accuracy: 0.6667 - lr: 8.0000e-06
# Epoch 33/1100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.5788 - accuracy: 0.7560 - val_loss: 0.6134 - val_accuracy: 0.6754 - lr: 8.0000e-06
# Epoch 34/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.5751 - accuracy: 0.7538 - val_loss: 0.6097 - val_accuracy: 0.7018 - lr: 8.0000e-06
# Epoch 35/1100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.5716 - accuracy: 0.7538 - val_loss: 0.6084 - val_accuracy: 0.6930 - lr: 8.0000e-06
# Epoch 36/1100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.5682 - accuracy: 0.7495 - val_loss: 0.6045 - val_accuracy: 0.7018 - lr: 8.0000e-06
# Epoch 37/1100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.5650 - accuracy: 0.7495 - val_loss: 0.6056 - val_accuracy: 0.6930 - lr: 8.0000e-06
# Epoch 38/1100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.
1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4604 - accuracy: 0.7868 - val_loss: 0.6370 - val_accuracy: 0.6842 - lr: 5.0397e-06
# Epoch 1013/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4603 - accuracy: 0.7890 - val_loss: 0.6369 - val_accuracy: 0.6842 - lr: 5.0397e-06
# Epoch 1014/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4606 - accuracy: 0.7868 - val_loss: 0.6381 - val_accuracy: 0.6842 - lr: 5.0397e-06
# Epoch 1015/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4603 - accuracy: 0.7868 - val_loss: 0.6375 - val_accuracy: 0.6842 - lr: 5.0397e-06
# Epoch 1016/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4605 - accuracy: 0.7890 - val_loss: 0.6366 - val_accuracy: 0.6842 - lr: 5.0397e-06
# Epoch 1017/1100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.4603 - accuracy: 0.7890 - val_loss: 0.6364 - val_accuracy: 0.6842 - lr: 5.0397e-06
# Epoch 1018/1100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.4603 - accuracy: 0.7890 - val_loss: 0.6371 - val_accuracy: 0.6842 - lr: 5.0397e-06
# Epoch 1019/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4603 - accuracy: 0.7868 - val_loss: 0.6374 - val_accuracy: 0.6842 - lr: 5.0397e-06
# Epoch 1020/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4603 - accuracy: 0.7890 - val_loss: 0.6373 - val_accuracy: 0.6842 - lr: 5.0397e-06
# Epoch 1021/1100
#  1/29 [>.............................] - ETA: 0s - loss: 0.4646 - accuracy: 0.7500
# Epoch 1021: ReduceLROnPlateau reducing learning rate to 4.000000088243381e-06.
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4603 - accuracy: 0.7890 - val_loss: 0.6368 - val_accuracy: 0.6842 - lr: 5.0397e-06
# Epoch 1022/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4602 - accuracy: 0.7890 - val_loss: 0.6370 - val_accuracy: 0.6842 - lr: 4.0000e-06
# Epoch 1023/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4602 - accuracy: 0.7890 - val_loss: 0.6374 - val_accuracy: 0.6842 - lr: 4.0000e-06
# Epoch 1024/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4603 - accuracy: 0.7868 - val_loss: 0.6380 - val_accuracy: 0.6842 - lr: 4.0000e-06
# Epoch 1025/1100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.4604 - accuracy: 0.7890 - val_loss: 0.6366 - val_accuracy: 0.6842 - lr: 4.0000e-06
# Epoch 1026/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4602 - accuracy: 0.7868 - val_loss: 0.6378 - val_accuracy: 0.6842 - lr: 4.0000e-06
# Epoch 1027/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4603 - accuracy: 0.7890 - val_loss: 0.6372 - val_accuracy: 0.6842 - lr: 4.0000e-06
# Epoch 1028/1100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.4603 - accuracy: 0.7868 - val_loss: 0.6381 - val_accuracy: 0.6842 - lr: 4.0000e-06
# Epoch 1029/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4602 - accuracy: 0.7868 - val_loss: 0.6383 - val_accuracy: 0.6842 - lr: 4.0000e-06
# Epoch 1030/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4603 - accuracy: 0.7868 - val_loss: 0.6376 - val_accuracy: 0.6842 - lr: 4.0000e-06
# Epoch 1031/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4602 - accuracy: 0.7890 - val_loss: 0.6380 - val_accuracy: 0.6842 - lr: 4.0000e-06
# Epoch 1032/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4603 - accuracy: 0.7890 - val_loss: 0.6369 - val_accuracy: 0.6842 - lr: 4.0000e-06
# Epoch 1033/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4602 - accuracy: 0.7868 - val_loss: 0.6381 - val_accuracy: 0.6842 - lr: 4.0000e-06
# Epoch 1034/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4603 - accuracy: 0.7868 - val_loss: 0.6370 - val_accuracy: 0.6842 - lr: 4.0000e-06
# Epoch 1035/1100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.4602 - accuracy: 0.7890 - val_loss: 0.6368 - val_accuracy: 0.6842 - lr: 4.0000e-06
# Epoch 1036/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4602 - accuracy: 0.7868 - val_loss: 0.6373 - val_accuracy: 0.6842 - lr: 4.0000e-06
# Epoch 1037/1100
#  1/29 [>.............................] - ETA: 0s - loss: 0.3451 - accuracy: 0.8125
# Epoch 1037: ReduceLROnPlateau reducing learning rate to 3.174802095920795e-06.
# 29/29 [==============================] - 0s 2ms/step - loss: 0.4602 - accuracy: 0.7890 - val_loss: 0.6372 - val_accuracy: 0.6842 - lr: 4.0000e-06
# Epoch 1038/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4602 - accuracy: 0.7890 - val_loss: 0.6363 - val_accuracy: 0.6842 - lr: 3.1748e-06
# Epoch 1039/1100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.4601 - accuracy: 0.7890 - val_loss: 0.6368 - val_accuracy: 0.6842 - lr: 3.1748e-06
# Epoch 1040/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4601 - accuracy: 0.7890 - val_loss: 0.6374 - val_accuracy: 0.6842 - lr: 3.1748e-06
# Epoch 1041/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4601 - accuracy: 0.7890 - val_loss: 0.6372 - val_accuracy: 0.6842 - lr: 3.1748e-06
# Epoch 1042/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4601 - accuracy: 0.7890 - val_loss: 0.6376 - val_accuracy: 0.6842 - lr: 3.1748e-06
# Epoch 1043/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4601 - accuracy: 0.7868 - val_loss: 0.6375 - val_accuracy: 0.6842 - lr: 3.1748e-06
# Epoch 1044/1100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.4601 - accuracy: 0.7890 - val_loss: 0.6374 - val_accuracy: 0.6842 - lr: 3.1748e-06
# Epoch 1045/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4601 - accuracy: 0.7868 - val_loss: 0.6381 - val_accuracy: 0.6842 - lr: 3.1748e-06
# Epoch 1046/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4601 - accuracy: 0.7868 - val_loss: 0.6380 - val_accuracy: 0.6842 - lr: 3.1748e-06
# Epoch 1047/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4601 - accuracy: 0.7890 - val_loss: 0.6373 - val_accuracy: 0.6842 - lr: 3.1748e-06
# Epoch 1048/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4601 - accuracy: 0.7868 - val_loss: 0.6378 - val_accuracy: 0.6842 - lr: 3.1748e-06
# Epoch 1049/1100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.4601 - accuracy: 0.7890 - val_loss: 0.6374 - val_accuracy: 0.6842 - lr: 3.1748e-06
# Epoch 1050/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4601 - accuracy: 0.7890 - val_loss: 0.6376 - val_accuracy: 0.6842 - lr: 3.1748e-06
# Epoch 1051/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4601 - accuracy: 0.7890 - val_loss: 0.6371 - val_accuracy: 0.6842 - lr: 3.1748e-06
# Epoch 1052/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4601 - accuracy: 0.7868 - val_loss: 0.6379 - val_accuracy: 0.6842 - lr: 3.1748e-06
# Epoch 1053/1100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.4601 - accuracy: 0.7868 - val_loss: 0.6377 - val_accuracy: 0.6842 - lr: 3.1748e-06
# Epoch 1054/1100
#  1/29 [>.............................] - ETA: 0s - loss: 0.5546 - accuracy: 0.8125
# Epoch 1054: ReduceLROnPlateau reducing learning rate to 2.519842042642629e-06.
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4600 - accuracy: 0.7890 - val_loss: 0.6375 - val_accuracy: 0.6842 - lr: 3.1748e-06
# Epoch 1055/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4600 - accuracy: 0.7868 - val_loss: 0.6377 - val_accuracy: 0.6842 - lr: 2.5198e-06
# Epoch 1056/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4601 - accuracy: 0.7868 - val_loss: 0.6372 - val_accuracy: 0.6842 - lr: 2.5198e-06
# Epoch 1057/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4601 - accuracy: 0.7868 - val_loss: 0.6377 - val_accuracy: 0.6842 - lr: 2.5198e-06
# Epoch 1058/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4601 - accuracy: 0.7890 - val_loss: 0.6379 - val_accuracy: 0.6842 - lr: 2.5198e-06
# Epoch 1059/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4600 - accuracy: 0.7890 - val_loss: 0.6372 - val_accuracy: 0.6842 - lr: 2.5198e-06
# Epoch 1060/1100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.4601 - accuracy: 0.7890 - val_loss: 0.6368 - val_accuracy: 0.6842 - lr: 2.5198e-06
# Epoch 1061/1100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.4600 - accuracy: 0.7890 - val_loss: 0.6371 - val_accuracy: 0.6842 - lr: 2.5198e-06
# Epoch 1062/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4600 - accuracy: 0.7890 - val_loss: 0.6373 - val_accuracy: 0.6842 - lr: 2.5198e-06
# Epoch 1063/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4600 - accuracy: 0.7890 - val_loss: 0.6370 - val_accuracy: 0.6842 - lr: 2.5198e-06
# Epoch 1064/1100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.4600 - accuracy: 0.7890 - val_loss: 0.6372 - val_accuracy: 0.6842 - lr: 2.5198e-06
# Epoch 1065/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4600 - accuracy: 0.7890 - val_loss: 0.6371 - val_accuracy: 0.6842 - lr: 2.5198e-06
# Epoch 1066/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4601 - accuracy: 0.7890 - val_loss: 0.6374 - val_accuracy: 0.6842 - lr: 2.5198e-06
# Epoch 1067/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4600 - accuracy: 0.7890 - val_loss: 0.6373 - val_accuracy: 0.6842 - lr: 2.5198e-06
# Epoch 1068/1100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.4600 - accuracy: 0.7890 - val_loss: 0.6371 - val_accuracy: 0.6842 - lr: 2.5198e-06
# Epoch 1069/1100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.4600 - accuracy: 0.7890 - val_loss: 0.6375 - val_accuracy: 0.6842 - lr: 2.5198e-06
# Epoch 1070/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4600 - accuracy: 0.7868 - val_loss: 0.6382 - val_accuracy: 0.6842 - lr: 2.5198e-06
# Epoch 1071/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4600 - accuracy: 0.7868 - val_loss: 0.6378 - val_accuracy: 0.6842 - lr: 2.5198e-06
# Epoch 1072/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4600 - accuracy: 0.7868 - val_loss: 0.6380 - val_accuracy: 0.6842 - lr: 2.5198e-06
# Epoch 1073/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4600 - accuracy: 0.7890 - val_loss: 0.6374 - val_accuracy: 0.6842 - lr: 2.5198e-06
# Epoch 1074/1100
#  1/29 [>.............................] - ETA: 0s - loss: 0.4763 - accuracy: 0.6250
# Epoch 1074: ReduceLROnPlateau reducing learning rate to 2.0000000441216903e-06.
# 29/29 [==============================] - 0s 2ms/step - loss: 0.4600 - accuracy: 0.7868 - val_loss: 0.6377 - val_accuracy: 0.6842 - lr: 2.5198e-06
# Epoch 1075/1100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.4600 - accuracy: 0.7890 - val_loss: 0.6377 - val_accuracy: 0.6842 - lr: 2.0000e-06
# Epoch 1076/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4600 - accuracy: 0.7890 - val_loss: 0.6378 - val_accuracy: 0.6842 - lr: 2.0000e-06
# Epoch 1077/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4600 - accuracy: 0.7868 - val_loss: 0.6384 - val_accuracy: 0.6842 - lr: 2.0000e-06
# Epoch 1078/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4599 - accuracy: 0.7868 - val_loss: 0.6382 - val_accuracy: 0.6842 - lr: 2.0000e-06
# Epoch 1079/1100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.4600 - accuracy: 0.7868 - val_loss: 0.6381 - val_accuracy: 0.6842 - lr: 2.0000e-06
# Epoch 1080/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4600 - accuracy: 0.7868 - val_loss: 0.6387 - val_accuracy: 0.6842 - lr: 2.0000e-06
# Epoch 1081/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4599 - accuracy: 0.7868 - val_loss: 0.6384 - val_accuracy: 0.6842 - lr: 2.0000e-06
# Epoch 1082/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4599 - accuracy: 0.7868 - val_loss: 0.6384 - val_accuracy: 0.6842 - lr: 2.0000e-06
# Epoch 1083/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4599 - accuracy: 0.7868 - val_loss: 0.6384 - val_accuracy: 0.6842 - lr: 2.0000e-06
# Epoch 1084/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4599 - accuracy: 0.7868 - val_loss: 0.6381 - val_accuracy: 0.6842 - lr: 2.0000e-06
# Epoch 1085/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4600 - accuracy: 0.7868 - val_loss: 0.6385 - val_accuracy: 0.6842 - lr: 2.0000e-06
# Epoch 1086/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4599 - accuracy: 0.7868 - val_loss: 0.6385 - val_accuracy: 0.6842 - lr: 2.0000e-06
# Epoch 1087/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4599 - accuracy: 0.7868 - val_loss: 0.6383 - val_accuracy: 0.6842 - lr: 2.0000e-06
# Epoch 1088/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4600 - accuracy: 0.7868 - val_loss: 0.6385 - val_accuracy: 0.6842 - lr: 2.0000e-06
# Epoch 1089/1100
#  1/29 [>.............................] - ETA: 0s - loss: 0.4145 - accuracy: 0.8750
# Epoch 1089: ReduceLROnPlateau reducing learning rate to 1.5874010479603974e-06.
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4599 - accuracy: 0.7868 - val_loss: 0.6381 - val_accuracy: 0.6842 - lr: 2.0000e-06
# Epoch 1090/1100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.4599 - accuracy: 0.7868 - val_loss: 0.6382 - val_accuracy: 0.6842 - lr: 1.5874e-06
# Epoch 1091/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4599 - accuracy: 0.7868 - val_loss: 0.6381 - val_accuracy: 0.6842 - lr: 1.5874e-06
# Epoch 1092/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4599 - accuracy: 0.7868 - val_loss: 0.6380 - val_accuracy: 0.6842 - lr: 1.5874e-06
# Epoch 1093/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4599 - accuracy: 0.7868 - val_loss: 0.6380 - val_accuracy: 0.6842 - lr: 1.5874e-06
# Epoch 1094/1100
# 29/29 [==============================] - 0s 1ms/step - loss: 0.4599 - accuracy: 0.7890 - val_loss: 0.6379 - val_accuracy: 0.6842 - lr: 1.5874e-06
# Epoch 1095/1100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.4599 - accuracy: 0.7868 - val_loss: 0.6382 - val_accuracy: 0.6842 - lr: 1.5874e-06
# Epoch 1096/1100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.4600 - accuracy: 0.7890 - val_loss: 0.6379 - val_accuracy: 0.6842 - lr: 1.5874e-06
# Epoch 1097/1100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.4599 - accuracy: 0.7868 - val_loss: 0.6381 - val_accuracy: 0.6842 - lr: 1.5874e-06
# Epoch 1098/1100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.4599 - accuracy: 0.7868 - val_loss: 0.6384 - val_accuracy: 0.6842 - lr: 1.5874e-06
# Epoch 1099/1100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.4599 - accuracy: 0.7868 - val_loss: 0.6383 - val_accuracy: 0.6842 - lr: 1.5874e-06
# Epoch 1100/1100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.4599 - accuracy: 0.7868 - val_loss: 0.6385 - val_accuracy: 0.6842 - lr: 1.5874e-06
# 5/5 [==============================] - 0s 750us/step
# Test Accuracy: 0.7286
# Test F1 Score: 0.7361
# Test Precision: 0.7162
# Test Recall: 0.7571
# Test ROC AUC Score: 0.8037
