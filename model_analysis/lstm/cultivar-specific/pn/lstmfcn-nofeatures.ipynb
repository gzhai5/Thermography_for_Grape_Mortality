# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import accuracy_score, roc_auc_score, recall_score, precision_score, f1_score
from sklearn.metrics import confusion_matrix, precision_recall_fscore_support
import seaborn as sns
from collections import Counter
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau
import sys
sys.path.append(r'C:\Users\Mud\Desktop\2ndPaper\lstm')
from model.lstmfcn import generate_lstmfcn
from model.fcn import generate_fcn
from model.lstm import generate_lstm
from utils.class_weight import compute_class_weight
import tensorflow as tf
import random as python_random

# %%
# load the data
X_test = np.load(r'C:\Users\Mud\Desktop\2ndPaper\lstm\cultivar-specific\data\pn\X_test_pn.npy')
y_test = np.load(r'C:\Users\Mud\Desktop\2ndPaper\lstm\cultivar-specific\data\pn\y_test_pn.npy')
X_train = np.load(r'C:\Users\Mud\Desktop\2ndPaper\lstm\cultivar-specific\data\pn\X_train_pn.npy')
y_train = np.load(r'C:\Users\Mud\Desktop\2ndPaper\lstm\cultivar-specific\data\pn\y_train_pn.npy')

# # load fake data
#X_train = np.load('./fake/train/X_train.npy')
#y_train = np.load('./fake/train/y_train.npy')
#X_test = np.load('./fake/test/X_test.npy')
#y_test = np.load('./fake/test/y_test.npy')


print('X_train shape:', X_train.shape)
print('y_train shape:', y_train.shape)
print('X_test shape:', X_test.shape)
print('y_test shape:', y_test.shape)
# Out:
# X_train shape: (588, 600)
# y_train shape: (588,)
# X_test shape: (140, 600)
# y_test shape: (140,)

# %%
def reset_random_seeds(seed=42):
   np.random.seed(seed)
   python_random.seed(seed)
   tf.random.set_seed(seed)

reset_random_seeds()

# %%
# normalize the data to have same starting pt for all time series
# input shape: (n_samples, n_timepoints), want each samples - its mean of 0-30th timepts
def normalize_curves_mean_method(unnormalized_datas):
    normalized_datas = []
    for unnormalized_data in unnormalized_datas:
        mean = np.mean(unnormalized_data[:30])
        normalized_data = unnormalized_data - mean
        normalized_datas.append(normalized_data)
    normalized_datas = np.array(normalized_datas)
    assert normalized_datas.shape == unnormalized_datas.shape
    return normalized_datas

# normalize the data using z-score, have mean 0 and std 1
def normalize_curves_zscore(unnormalized_datas):
    normalized_datas = []
    for unnormalized_data in unnormalized_datas:
        mean = np.mean(unnormalized_data)
        std = np.std(unnormalized_data)
        normalized_data = (unnormalized_data - mean) / std
        normalized_datas.append(normalized_data)
    normalized_datas = np.array(normalized_datas)
    assert normalized_datas.shape == unnormalized_datas.shape
    return normalized_datas


# apply ln() to the time series data
def apply_ln_to_curves(datas):
    ln_datas = []
    for data in datas:
        ln_data = np.log(data)
        ln_datas.append(ln_data)
    ln_datas = np.array(ln_datas)
    assert ln_datas.shape == datas.shape
    return ln_datas


# split the time series data into wanted time points
def split_time_series(datas, start, end):
    datas = datas[:, start:end]
    return datas


# plot the time series data, randomly picked n samples, different colors represent different classes
def plot_random_time_series(datas, n, labels):
    for i in range(n):
        idx = np.random.randint(datas.shape[0])
        plt.plot(datas[idx], color = 'blue' if labels[idx] == 1 else 'red', alpha = 0.2)
    plt.show()


X_train = normalize_curves_mean_method(X_train)
X_test = normalize_curves_mean_method(X_test)
plot_random_time_series(X_train, 100, y_train)
# X_train = normalize_curves_zscore(X_train)
# X_test = normalize_curves_zscore(X_test)
print('X_train shape:', X_train.shape)
print('X_train range:', np.min(X_train), np.max(X_train))
print('X_test shape:', X_test.shape)
print('X_test range:', np.min(X_test), np.max(X_test))
# Out:
# X_train shape: (588, 600)
# X_train range: -26.59554043839853 930.523356009071
# X_test shape: (140, 600)
# X_test range: -15.884504913075943 703.0394557823129

# %%
# upsample the one class in the training set by given factor
# add some level of noise to the time series data with maintaining mean & std
# class_label: 1 is alive, 0 is dead
def data_augmentation(X_train, y_train, n_times, class_label=1, random_seed=42):
    np.random.seed(random_seed)
    X_train_augmented = X_train.copy()
    y_train_augmented = y_train.copy()
    for i in range(len(y_train)):
        if y_train[i] == class_label:
            for _ in range(n_times):
                X_train_augmented = np.concatenate((X_train_augmented, [X_train[i] + np.random.normal(0, 0.1, X_train[i].shape)]), axis=0)
                y_train_augmented = np.concatenate((y_train_augmented, [y_train[i]]), axis=0)
    return X_train_augmented, y_train_augmented



print('Before, Class ratio:', Counter(y_train))
#X_train, y_train = data_augmentation(X_train, y_train, 10, class_label=0)
#X_train, y_train = data_augmentation(X_train, y_train, 4, class_label=1)
print('After, Class ratio:', Counter(y_train))
# Out:
# Before, Class ratio: Counter({1: 405, 0: 183})
# After, Class ratio: Counter({1: 405, 0: 183})

# %%
# compute mean & std of the training set, then normalize the whole dataset using z-normalization
mean = np.mean(X_train)
std = np.std(X_train)
#X_train = (X_train - mean) / std
#X_test = (X_test - mean) / std

# %%
# Ensure data is shaped correctly
X_train = X_train.reshape(-1, 1, 600)  # Convert to (samples, 1, timesteps)
X_test = X_test.reshape(-1, 1, 600)
y_train = y_train.reshape(-1, 1)  # Ensure labels are in shape (samples, 1)
y_test = y_test.reshape(-1, 1)

print('X_train shape:', X_train.shape)
print('y_train shape:', y_train.shape)
print('X_test shape:', X_test.shape)
print('y_test shape:', y_test.shape)
# Out:
# X_train shape: (588, 1, 600)
# y_train shape: (588, 1)
# X_test shape: (140, 1, 600)
# y_test shape: (140, 1)

# %%
# Train final model on full training data# Initialize model
final_model = generate_lstmfcn(dropout=0.0)
class_weights = compute_class_weight(y_train)
print('class_weights:', class_weights)
reduce_lr = ReduceLROnPlateau(monitor='loss', patience=15, mode='auto',
    factor=1. / np.cbrt(2), cooldown=0, min_lr=1e-6, verbose=2)
final_model.compile(optimizer=Adam(learning_rate=5e-6), loss='binary_crossentropy', metrics=['accuracy'])

# split the data into training and validation set
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# Train model
history = final_model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    callbacks=[reduce_lr],
    epochs=200, batch_size=16, class_weight={0: class_weights[0], 1: class_weights[1]},
    verbose=1
)

# Predict on test set
y_pred_prob = final_model.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)

# Calculate metrics
accuracy = accuracy_score(y_test, y_pred)
precision, recall, f1, _ = precision_recall_fscore_support(y_test, y_pred, average='binary')
roc_auc = roc_auc_score(y_test, y_pred_prob)
conf_matrix = confusion_matrix(y_test, y_pred)

# plot the metrics
print(f"Test Accuracy: {accuracy:.4f}")
print(f"Test F1 Score: {f1:.4f}")
print(f"Test Precision: {precision:.4f}")
print(f"Test Recall: {recall:.4f}")
print(f"Test ROC AUC Score: {roc_auc:.4f}")
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Dead', 'Alive'], yticklabels=['Dead', 'Alive'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()


# plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.figure(figsize=(10, 7))
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.figure(figsize=(10, 7))
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# class_weights: [1.60655738 0.72592593]
# Epoch 1/200
# 30/30 [==============================] - 11s 141ms/step - loss: 0.7321 - accuracy: 0.7021 - val_loss: 1.1541 - val_accuracy: 0.6356 - lr: 5.0000e-06
# Epoch 2/200
# 30/30 [==============================] - 3s 95ms/step - loss: 0.6766 - accuracy: 0.7021 - val_loss: 0.7261 - val_accuracy: 0.6356 - lr: 5.0000e-06
# Epoch 3/200
# 30/30 [==============================] - 3s 93ms/step - loss: 0.6424 - accuracy: 0.7340 - val_loss: 0.6748 - val_accuracy: 0.7203 - lr: 5.0000e-06
# Epoch 4/200
# 30/30 [==============================] - 3s 94ms/step - loss: 0.6172 - accuracy: 0.7574 - val_loss: 0.6694 - val_accuracy: 0.5339 - lr: 5.0000e-06
# Epoch 5/200
# 30/30 [==============================] - 3s 95ms/step - loss: 0.5907 - accuracy: 0.7638 - val_loss: 0.6638 - val_accuracy: 0.5508 - lr: 5.0000e-06
# Epoch 6/200
# 30/30 [==============================] - 3s 94ms/step - loss: 0.5798 - accuracy: 0.7681 - val_loss: 0.6484 - val_accuracy: 0.5678 - lr: 5.0000e-06
# Epoch 7/200
# 30/30 [==============================] - 3s 95ms/step - loss: 0.5701 - accuracy: 0.7553 - val_loss: 0.6369 - val_accuracy: 0.5763 - lr: 5.0000e-06
# Epoch 8/200
# 30/30 [==============================] - 3s 93ms/step - loss: 0.5669 - accuracy: 0.7617 - val_loss: 0.6182 - val_accuracy: 0.6525 - lr: 5.0000e-06
# Epoch 9/200
# 30/30 [==============================] - 3s 94ms/step - loss: 0.5432 - accuracy: 0.7723 - val_loss: 0.6072 - val_accuracy: 0.6864 - lr: 5.0000e-06
# Epoch 10/200
# 30/30 [==============================] - 3s 94ms/step - loss: 0.5472 - accuracy: 0.7574 - val_loss: 0.5946 - val_accuracy: 0.7034 - lr: 5.0000e-06
# Epoch 11/200
# 30/30 [==============================] - 3s 99ms/step - loss: 0.5428 - accuracy: 0.7553 - val_loss: 0.5831 - val_accuracy: 0.7542 - lr: 5.0000e-06
# Epoch 12/200
# 30/30 [==============================] - 3s 101ms/step - loss: 0.5301 - accuracy: 0.7681 - val_loss: 0.5750 - val_accuracy: 0.7712 - lr: 5.0000e-06
# Epoch 13/200
# 30/30 [==============================] - 3s 95ms/step - loss: 0.5430 - accuracy: 0.7617 - val_loss: 0.5672 - val_accuracy: 0.7797 - lr: 5.0000e-06
# Epoch 14/200
# 30/30 [==============================] - 3s 97ms/step - loss: 0.5278 - accuracy: 0.7553 - val_loss: 0.5631 - val_accuracy: 0.7797 - lr: 5.0000e-06
# Epoch 15/200
# 30/30 [==============================] - 3s 91ms/step - loss: 0.5294 - accuracy: 0.7468 - val_loss: 0.5559 - val_accuracy: 0.7797 - lr: 5.0000e-06
# Epoch 16/200
# 30/30 [==============================] - 3s 93ms/step - loss: 0.5250 - accuracy: 0.7723 - val_loss: 0.5534 - val_accuracy: 0.7797 - lr: 5.0000e-06
# Epoch 17/200
# 30/30 [==============================] - 3s 96ms/step - loss: 0.5348 - accuracy: 0.7596 - val_loss: 0.5480 - val_accuracy: 0.7797 - lr: 5.0000e-06
# Epoch 18/200
# 30/30 [==============================] - 3s 93ms/step - loss: 0.5297 - accuracy: 0.7532 - val_loss: 0.5479 - val_accuracy: 0.7881 - lr: 5.0000e-06
# Epoch 19/200
# 30/30 [==============================] - 3s 94ms/step - loss: 0.5318 - accuracy: 0.7532 - val_loss: 0.5416 - val_accuracy: 0.7797 - lr: 5.0000e-06
# Epoch 20/200
# 30/30 [==============================] - 3s 102ms/step - loss: 0.5161 - accuracy: 0.7809 - val_loss: 0.5424 - val_accuracy: 0.7797 - lr: 5.0000e-06
# Epoch 21/200
# 30/30 [==============================] - 3s 102ms/step - loss: 0.5204 - accuracy: 0.7702 - val_loss: 0.5419 - val_accuracy: 0.7797 - lr: 5.0000e-06
# Epoch 22/200
# 30/30 [==============================] - 3s 96ms/step - loss: 0.5345 - accuracy: 0.7426 - val_loss: 0.5417 - val_accuracy: 0.7797 - lr: 5.0000e-06
# Epoch 23/200
# 30/30 [==============================] - 3s 96ms/step - loss: 0.5297 - accuracy: 0.7660 - val_loss: 0.5400 - val_accuracy: 0.7797 - lr: 5.0000e-06
# Epoch 24/200
# 30/30 [==============================] - 3s 93ms/step - loss: 0.5223 - accuracy: 0.7681 - val_loss: 0.5410 - val_accuracy: 0.7797 - lr: 5.0000e-06
# Epoch 25/200
# 30/30 [==============================] - 3s 91ms/step - loss: 0.5164 - accuracy: 0.7638 - val_loss: 0.5372 - val_accuracy: 0.7712 - lr: 5.0000e-06
# Epoch 26/200
# 30/30 [==============================] - 3s 93ms/step - loss: 0.5171 - accuracy: 0.7766 - val_loss: 0.5370 - val_accuracy: 0.7797 - lr: 5.0000e-06
# Epoch 27/200
# 30/30 [==============================] - 3s 92ms/step - loss: 0.5252 - accuracy: 0.7574 - val_loss: 0.5360 - val_accuracy: 0.7797 - lr: 5.0000e-06
# Epoch 28/200
# 30/30 [==============================] - 3s 94ms/step - loss: 0.5224 - accuracy: 0.7596 - val_loss: 0.5358 - val_accuracy: 0.7797 - lr: 5.0000e-06
# Epoch 29/200
# 30/30 [==============================] - 3s 95ms/step - loss: 0.5316 - accuracy: 0.7702 - val_loss: 0.5410 - val_accuracy: 0.7797 - lr: 5.0000e-06
# Epoch 30/200
# 30/30 [==============================] - 3s 95ms/step - loss: 0.5209 - accuracy: 0.7489 - val_loss: 0.5372 - val_accuracy: 0.7797 - lr: 5.0000e-06
# Epoch 31/200
# 30/30 [==============================] - 3s 93ms/step - loss: 0.5246 - accuracy: 0.7489 - val_loss: 0.5371 - val_accuracy: 0.7797 - lr: 5.0000e-06
# Epoch 32/200
# 30/30 [==============================] - 3s 93ms/step - loss: 0.5149 - accuracy: 0.7660 - val_loss: 0.5369 - val_accuracy: 0.7797 - lr: 5.0000e-06
# Epoch 33/200
# 30/30 [==============================] - 3s 97ms/step - loss: 0.5179 - accuracy: 0.7617 - val_loss: 0.5342 - val_accuracy: 0.7797 - lr: 5.0000e-06
# Epoch 34/200
# 30/30 [==============================] - 3s 95ms/step - loss: 0.5298 - accuracy: 0.7660 - val_loss: 0.5351 - val_accuracy: 0.7797 - lr: 5.0000e-06
# Epoch 35/200
# 30/30 [==============================] - 3s 96ms/step - loss: 0.5204 - accuracy: 0.7638 - val_loss: 0.5305 - val_accuracy: 0.7712 - lr: 5.0000e-06
# Epoch 36/200
# 30/30 [==============================] - 3s 96ms/step - loss: 0.5126 - accuracy: 0.7745 - val_loss: 0.5354 - val_accuracy: 0.7712 - lr: 5.0000e-06
# Epoch 37/200
# 30/30 [==============================] - 3s 93ms/step - loss: 0.5170 - accuracy: 0.7638 - val_loss: 0.5284 - val_accuracy: 0.7712 - lr: 5.0000e-06
# Epoch 38/200
# 30/30 [==============================] - 3s 96ms/step - loss: 0.5233 - accuracy: 0.7553 - val_loss: 0.5316 - val_accuracy: 0.7712 - lr: 5.0000e-06
# Epoch 39/200
# 30/30 [==============================] - 3s 95ms/step - loss: 0.5292 - accuracy: 0.7553 - val_loss: 0.5330 - val_accuracy: 0.7712 - lr: 5.0000e-06
# Epoch 40/200
# 30/30 [==============================] - 4s 120ms/step - loss: 0.5266 - accuracy: 0.7638 - val_loss: 0.5304 - val_accuracy: 0.7712 - lr: 5.0000e-06
# Epoch 41/200
# 30/30 [==============================] - 3s 94ms/step - loss: 0.5199 - accuracy: 0.7574 - val_loss: 0.5271 - val_accuracy: 0.7627 - lr: 5.0000e-06
# Epoch 42/200
# 30/30 [==============================] - 3s 111ms/step - loss: 0.5099 - accuracy: 0.7574 - val_loss: 0.5249 - val_accuracy: 0.7627 - lr: 5.0000e-06
# Epoch 43/200
# 30/30 [==============================] - 4s 123ms/step - loss: 0.5256 - accuracy: 0.7574 - val_loss: 0.5281 - val_accuracy: 0.7712 - lr: 5.0000e-06
# Epoch 44/200
# 30/30 [==============================] - 4s 121ms/step - loss: 0.5149 - accuracy: 0.7681 - val_loss: 0.5288 - val_accuracy: 0.7712 - lr: 5.0000e-06
# Epoch 45/200
# 30/30 [==============================] - 4s 120ms/step - loss: 0.5106 - accuracy: 0.7660 - val_loss: 0.5340 - val_accuracy: 0.7797 - lr: 5.0000e-06
# Epoch 46/200
# 30/30 [==============================] - 4s 119ms/step - loss: 0.5096 - accuracy: 0.7702 - val_loss: 0.5324 - val_accuracy: 0.7797 - lr: 5.0000e-06
# Epoch 47/200
# 30/30 [==============================] - 4s 121ms/step - loss: 0.5131 - accuracy: 0.7766 - val_loss: 0.5285 - val_accuracy: 0.7712 - lr: 5.0000e-06
# Epoch 48/200
# 30/30 [==============================] - 4s 123ms/step - loss: 0.5242 - accuracy: 0.7660 - val_loss: 0.5223 - val_accuracy: 0.7712 - lr: 5.0000e-06
# Epoch 49/200
# 30/30 [==============================] - 4s 123ms/step - loss: 0.5175 - accuracy: 0.7617 - val_loss: 0.5252 - val_accuracy: 0.7712 - lr: 5.0000e-06
# Epoch 50/200
# 30/30 [==============================] - 4s 120ms/step - loss: 0.5131 - accuracy: 0.7617 - val_loss: 0.5284 - val_accuracy: 0.7712 - lr: 5.0000e-06
# Epoch 51/200
# 30/30 [==============================] - 4s 119ms/step - loss: 0.5197 - accuracy: 0.7574 - val_loss: 0.5269 - val_accuracy: 0.7712 - lr: 5.0000e-06
# Epoch 52/200
# 30/30 [==============================] - 4s 122ms/step - loss: 0.4979 - accuracy: 0.7723 - val_loss: 0.5279 - val_accuracy: 0.7797 - lr: 5.0000e-06
# Epoch 53/200
# 30/30 [==============================] - 4s 124ms/step - loss: 0.5003 - accuracy: 0.7638 - val_loss: 0.5356 - val_accuracy: 0.7627 - lr: 5.0000e-06
# Epoch 54/200
# 30/30 [==============================] - 5s 155ms/step - loss: 0.5040 - accuracy: 0.7681 - val_loss: 0.5314 - val_accuracy: 0.7797 - lr: 5.0000e-06
# Epoch 55/200
# 30/30 [==============================] - 10s 334ms/step - loss: 0.5060 - accuracy: 0.7809 - val_loss: 0.5243 - val_accuracy: 0.7712 - lr: 5.0000e-06
# Epoch 56/200
# 30/30 [==============================] - 10s 336ms/step - loss: 0.5108 - accuracy: 0.7723 - val_loss: 0.5203 - val_accuracy: 0.7712 - lr: 5.0000e-06
# Epoch 57/200
# 30/30 [==============================] - 10s 343ms/step - loss: 0.5113 - accuracy: 0.7596 - val_loss: 0.5240 - val_accuracy: 0.7712 - lr: 5.0000e-06
# Epoch 58/200
# 30/30 [==============================] - 4s 142ms/step - loss: 0.5146 - accuracy: 0.7660 - val_loss: 0.5216 - val_accuracy: 0.7712 - lr: 5.0000e-06
# Epoch 59/200
# 30/30 [==============================] - 3s 117ms/step - loss: 0.5035 - accuracy: 0.7745 - val_loss: 0.5218 - val_accuracy: 0.7797 - lr: 5.0000e-06
# Epoch 60/200
# 30/30 [==============================] - 4s 124ms/step - loss: 0.4998 - accuracy: 0.7574 - val_loss: 0.5270 - val_accuracy: 0.7797 - lr: 5.0000e-06
# Epoch 61/200
# 30/30 [==============================] - 4s 121ms/step - loss: 0.5128 - accuracy: 0.7723 - val_loss: 0.5273 - val_accuracy: 0.7797 - lr: 5.0000e-06
# Epoch 62/200
# 30/30 [==============================] - 4s 119ms/step - loss: 0.5001 - accuracy: 0.7894 - val_loss: 0.5219 - val_accuracy: 0.7797 - lr: 5.0000e-06
# Epoch 63/200
# 30/30 [==============================] - 4s 120ms/step - loss: 0.5114 - accuracy: 0.7596 - val_loss: 0.5195 - val_accuracy: 0.7712 - lr: 5.0000e-06
# Epoch 64/200
# 30/30 [==============================] - 4s 118ms/step - loss: 0.5101 - accuracy: 0.7553 - val_loss: 0.5214 - val_accuracy: 0.7797 - lr: 5.0000e-06
# Epoch 65/200
# 30/30 [==============================] - 4s 122ms/step - loss: 0.4939 - accuracy: 0.7809 - val_loss: 0.5191 - val_accuracy: 0.7797 - lr: 5.0000e-06
# Epoch 66/200
# 30/30 [==============================] - 4s 119ms/step - loss: 0.5056 - accuracy: 0.7702 - val_loss: 0.5211 - val_accuracy: 0.7797 - lr: 5.0000e-06
# Epoch 67/200
# 30/30 [==============================] - 4s 119ms/step - loss: 0.5031 - accuracy: 0.7617 - val_loss: 0.5195 - val_accuracy: 0.7797 - lr: 5.0000e-06
# Epoch 68/200
# 30/30 [==============================] - 4s 121ms/step - loss: 0.5321 - accuracy: 0.7468 - val_loss: 0.5147 - val_accuracy: 0.7712 - lr: 5.0000e-06
# Epoch 69/200
# 30/30 [==============================] - 4s 121ms/step - loss: 0.5004 - accuracy: 0.7638 - val_loss: 0.5171 - val_accuracy: 0.7712 - lr: 5.0000e-06
# Epoch 70/200
# 30/30 [==============================] - 4s 120ms/step - loss: 0.4919 - accuracy: 0.7787 - val_loss: 0.5192 - val_accuracy: 0.7797 - lr: 5.0000e-06
# Epoch 71/200
# 30/30 [==============================] - 4s 125ms/step - loss: 0.5087 - accuracy: 0.7660 - val_loss: 0.5143 - val_accuracy: 0.7712 - lr: 5.0000e-06
# Epoch 72/200
# 30/30 [==============================] - 4s 122ms/step - loss: 0.5063 - accuracy: 0.7574 - val_loss: 0.5159 - val_accuracy: 0.7797 - lr: 5.0000e-06
# Epoch 73/200
# 30/30 [==============================] - 4s 119ms/step - loss: 0.5006 - accuracy: 0.7872 - val_loss: 0.5130 - val_accuracy: 0.7712 - lr: 5.0000e-06
# Epoch 74/200
# 30/30 [==============================] - 4s 120ms/step - loss: 0.5273 - accuracy: 0.7298 - val_loss: 0.5081 - val_accuracy: 0.7712 - lr: 5.0000e-06
# Epoch 75/200
# 30/30 [==============================] - 4s 119ms/step - loss: 0.5094 - accuracy: 0.7638 - val_loss: 0.5079 - val_accuracy: 0.7712 - lr: 5.0000e-06
# Epoch 76/200
# 30/30 [==============================] - 4s 121ms/step - loss: 0.5100 - accuracy: 0.7638 - val_loss: 0.5064 - val_accuracy: 0.7712 - lr: 5.0000e-06
# Epoch 77/200
# 30/30 [==============================] - 4s 122ms/step - loss: 0.5198 - accuracy: 0.7660 - val_loss: 0.5100 - val_accuracy: 0.7712 - lr: 5.0000e-06
# Epoch 78/200
# 30/30 [==============================] - 4s 126ms/step - loss: 0.5141 - accuracy: 0.7660 - val_loss: 0.5171 - val_accuracy: 0.7712 - lr: 5.0000e-06
# Epoch 79/200
# 30/30 [==============================] - 4s 123ms/step - loss: 0.5051 - accuracy: 0.7511 - val_loss: 0.5112 - val_accuracy: 0.7627 - lr: 5.0000e-06
# Epoch 80/200
# 30/30 [==============================] - 4s 120ms/step - loss: 0.5123 - accuracy: 0.7511 - val_loss: 0.5108 - val_accuracy: 0.7627 - lr: 5.0000e-06
# Epoch 81/200
# 30/30 [==============================] - 4s 119ms/step - loss: 0.4988 - accuracy: 0.7723 - val_loss: 0.5191 - val_accuracy: 0.7797 - lr: 5.0000e-06
# Epoch 82/200
# 30/30 [==============================] - 4s 121ms/step - loss: 0.4946 - accuracy: 0.7723 - val_loss: 0.5190 - val_accuracy: 0.7797 - lr: 5.0000e-06
# Epoch 83/200
# 30/30 [==============================] - 3s 117ms/step - loss: 0.5092 - accuracy: 0.7489 - val_loss: 0.5227 - val_accuracy: 0.7797 - lr: 5.0000e-06
# Epoch 84/200
# 30/30 [==============================] - 4s 117ms/step - loss: 0.5068 - accuracy: 0.7702 - val_loss: 0.5150 - val_accuracy: 0.7712 - lr: 5.0000e-06
# Epoch 85/200
# 30/30 [==============================] - ETA: 0s - loss: 0.5067 - accuracy: 0.7660
# Epoch 85: ReduceLROnPlateau reducing learning rate to 3.968502529667691e-06.
# 30/30 [==============================] - 4s 119ms/step - loss: 0.5067 - accuracy: 0.7660 - val_loss: 0.5151 - val_accuracy: 0.7712 - lr: 5.0000e-06
# Epoch 86/200
# 30/30 [==============================] - 3s 113ms/step - loss: 0.5054 - accuracy: 0.7617 - val_loss: 0.5088 - val_accuracy: 0.7627 - lr: 3.9685e-06
# Epoch 87/200
# 30/30 [==============================] - 4s 121ms/step - loss: 0.5072 - accuracy: 0.7702 - val_loss: 0.5089 - val_accuracy: 0.7627 - lr: 3.9685e-06
# Epoch 88/200
# 30/30 [==============================] - 4s 119ms/step - loss: 0.4984 - accuracy: 0.7872 - val_loss: 0.5169 - val_accuracy: 0.7797 - lr: 3.9685e-06
# Epoch 89/200
# 30/30 [==============================] - 4s 122ms/step - loss: 0.5062 - accuracy: 0.7702 - val_loss: 0.5128 - val_accuracy: 0.7712 - lr: 3.9685e-06
# Epoch 90/200
# 30/30 [==============================] - 4s 121ms/step - loss: 0.5018 - accuracy: 0.7617 - val_loss: 0.5154 - val_accuracy: 0.7797 - lr: 3.9685e-06
# Epoch 91/200
# 30/30 [==============================] - 4s 123ms/step - loss: 0.5202 - accuracy: 0.7596 - val_loss: 0.5139 - val_accuracy: 0.7797 - lr: 3.9685e-06
# Epoch 92/200
# 30/30 [==============================] - 4s 121ms/step - loss: 0.4990 - accuracy: 0.7681 - val_loss: 0.5168 - val_accuracy: 0.7797 - lr: 3.9685e-06
# Epoch 93/200
# 30/30 [==============================] - 4s 122ms/step - loss: 0.5040 - accuracy: 0.7489 - val_loss: 0.5140 - val_accuracy: 0.7797 - lr: 3.9685e-06
# Epoch 94/200
# 30/30 [==============================] - 4s 123ms/step - loss: 0.5177 - accuracy: 0.7511 - val_loss: 0.5077 - val_accuracy: 0.7627 - lr: 3.9685e-06
# Epoch 95/200
# 30/30 [==============================] - 4s 118ms/step - loss: 0.5083 - accuracy: 0.7702 - val_loss: 0.5073 - val_accuracy: 0.7627 - lr: 3.9685e-06
# Epoch 96/200
# 30/30 [==============================] - 4s 127ms/step - loss: 0.4917 - accuracy: 0.7830 - val_loss: 0.5060 - val_accuracy: 0.7627 - lr: 3.9685e-06
# Epoch 97/200
# 30/30 [==============================] - 4s 118ms/step - loss: 0.4873 - accuracy: 0.7872 - val_loss: 0.5105 - val_accuracy: 0.7797 - lr: 3.9685e-06
# Epoch 98/200
# 30/30 [==============================] - 4s 121ms/step - loss: 0.4951 - accuracy: 0.7681 - val_loss: 0.5084 - val_accuracy: 0.7712 - lr: 3.9685e-06
# Epoch 99/200
# 30/30 [==============================] - 4s 122ms/step - loss: 0.5012 - accuracy: 0.7745 - val_loss: 0.5108 - val_accuracy: 0.7797 - lr: 3.9685e-06
# Epoch 100/200
# 30/30 [==============================] - 4s 119ms/step - loss: 0.5074 - accuracy: 0.7447 - val_loss: 0.5022 - val_accuracy: 0.7712 - lr: 3.9685e-06
# Epoch 101/200
# 30/30 [==============================] - 4s 120ms/step - loss: 0.4939 - accuracy: 0.7702 - val_loss: 0.5017 - val_accuracy: 0.7627 - lr: 3.9685e-06
# Epoch 102/200
# 30/30 [==============================] - 4s 125ms/step - loss: 0.5088 - accuracy: 0.7638 - val_loss: 0.5030 - val_accuracy: 0.7627 - lr: 3.9685e-06
# Epoch 103/200
# 30/30 [==============================] - 4s 122ms/step - loss: 0.4917 - accuracy: 0.7830 - val_loss: 0.5140 - val_accuracy: 0.7797 - lr: 3.9685e-06
# Epoch 104/200
# 30/30 [==============================] - 4s 119ms/step - loss: 0.4977 - accuracy: 0.7809 - val_loss: 0.5167 - val_accuracy: 0.7797 - lr: 3.9685e-06
# Epoch 105/200
# 30/30 [==============================] - 4s 120ms/step - loss: 0.5065 - accuracy: 0.7723 - val_loss: 0.5096 - val_accuracy: 0.7712 - lr: 3.9685e-06
# Epoch 106/200
# 30/30 [==============================] - 3s 95ms/step - loss: 0.5057 - accuracy: 0.7638 - val_loss: 0.5090 - val_accuracy: 0.7712 - lr: 3.9685e-06
# Epoch 107/200
# 30/30 [==============================] - 3s 93ms/step - loss: 0.4980 - accuracy: 0.7532 - val_loss: 0.5047 - val_accuracy: 0.7627 - lr: 3.9685e-06
# Epoch 108/200
# 30/30 [==============================] - 3s 92ms/step - loss: 0.5000 - accuracy: 0.7851 - val_loss: 0.5095 - val_accuracy: 0.7712 - lr: 3.9685e-06
# Epoch 109/200
# 30/30 [==============================] - 3s 94ms/step - loss: 0.4871 - accuracy: 0.7830 - val_loss: 0.5135 - val_accuracy: 0.7797 - lr: 3.9685e-06
# Epoch 110/200
# 30/30 [==============================] - 3s 92ms/step - loss: 0.5083 - accuracy: 0.7638 - val_loss: 0.5133 - val_accuracy: 0.7797 - lr: 3.9685e-06
# Epoch 111/200
# 30/30 [==============================] - 3s 96ms/step - loss: 0.5059 - accuracy: 0.7660 - val_loss: 0.5088 - val_accuracy: 0.7712 - lr: 3.9685e-06
# Epoch 112/200
# 30/30 [==============================] - 3s 89ms/step - loss: 0.4961 - accuracy: 0.7872 - val_loss: 0.5092 - val_accuracy: 0.7712 - lr: 3.9685e-06
# Epoch 113/200
# 30/30 [==============================] - 3s 89ms/step - loss: 0.4966 - accuracy: 0.7596 - val_loss: 0.5039 - val_accuracy: 0.7627 - lr: 3.9685e-06
# Epoch 114/200
# 30/30 [==============================] - 3s 92ms/step - loss: 0.4972 - accuracy: 0.7766 - val_loss: 0.5046 - val_accuracy: 0.7627 - lr: 3.9685e-06
# Epoch 115/200
# 30/30 [==============================] - 3s 92ms/step - loss: 0.4940 - accuracy: 0.7851 - val_loss: 0.5096 - val_accuracy: 0.7797 - lr: 3.9685e-06
# Epoch 116/200
# 30/30 [==============================] - 7s 237ms/step - loss: 0.4932 - accuracy: 0.7766 - val_loss: 0.5063 - val_accuracy: 0.7712 - lr: 3.9685e-06
# Epoch 117/200
# 30/30 [==============================] - 3s 105ms/step - loss: 0.4896 - accuracy: 0.7553 - val_loss: 0.5118 - val_accuracy: 0.7797 - lr: 3.9685e-06
# Epoch 118/200
# 30/30 [==============================] - 3s 93ms/step - loss: 0.5026 - accuracy: 0.7617 - val_loss: 0.5083 - val_accuracy: 0.7797 - lr: 3.9685e-06
# Epoch 119/200
# 30/30 [==============================] - 3s 93ms/step - loss: 0.5061 - accuracy: 0.7617 - val_loss: 0.5039 - val_accuracy: 0.7712 - lr: 3.9685e-06
# Epoch 120/200
# 30/30 [==============================] - 3s 102ms/step - loss: 0.5054 - accuracy: 0.7574 - val_loss: 0.5062 - val_accuracy: 0.7797 - lr: 3.9685e-06
# Epoch 121/200
# 30/30 [==============================] - 3s 96ms/step - loss: 0.5012 - accuracy: 0.7638 - val_loss: 0.5025 - val_accuracy: 0.7627 - lr: 3.9685e-06
# Epoch 122/200
# 30/30 [==============================] - 3s 97ms/step - loss: 0.4868 - accuracy: 0.7915 - val_loss: 0.5076 - val_accuracy: 0.7797 - lr: 3.9685e-06
# Epoch 123/200
# 30/30 [==============================] - 3s 98ms/step - loss: 0.5084 - accuracy: 0.7766 - val_loss: 0.5063 - val_accuracy: 0.7797 - lr: 3.9685e-06
# Epoch 124/200
# 30/30 [==============================] - 3s 97ms/step - loss: 0.5172 - accuracy: 0.7574 - val_loss: 0.4976 - val_accuracy: 0.7797 - lr: 3.9685e-06
# Epoch 125/200
# 30/30 [==============================] - 3s 95ms/step - loss: 0.5101 - accuracy: 0.7617 - val_loss: 0.4997 - val_accuracy: 0.7712 - lr: 3.9685e-06
# Epoch 126/200
# 30/30 [==============================] - 3s 98ms/step - loss: 0.5014 - accuracy: 0.7702 - val_loss: 0.5002 - val_accuracy: 0.7712 - lr: 3.9685e-06
# Epoch 127/200
# 30/30 [==============================] - 3s 95ms/step - loss: 0.5087 - accuracy: 0.7702 - val_loss: 0.5055 - val_accuracy: 0.7797 - lr: 3.9685e-06
# Epoch 128/200
# 30/30 [==============================] - 3s 94ms/step - loss: 0.4961 - accuracy: 0.7851 - val_loss: 0.5130 - val_accuracy: 0.7797 - lr: 3.9685e-06
# Epoch 129/200
# 30/30 [==============================] - 3s 101ms/step - loss: 0.5263 - accuracy: 0.7660 - val_loss: 0.4999 - val_accuracy: 0.7797 - lr: 3.9685e-06
# Epoch 130/200
# 30/30 [==============================] - 3s 103ms/step - loss: 0.4928 - accuracy: 0.7702 - val_loss: 0.5034 - val_accuracy: 0.7712 - lr: 3.9685e-06
# Epoch 131/200
# 30/30 [==============================] - 3s 96ms/step - loss: 0.5022 - accuracy: 0.7745 - val_loss: 0.5067 - val_accuracy: 0.7797 - lr: 3.9685e-06
# Epoch 132/200
# 30/30 [==============================] - 3s 94ms/step - loss: 0.5061 - accuracy: 0.7468 - val_loss: 0.5107 - val_accuracy: 0.7797 - lr: 3.9685e-06
# Epoch 133/200
# 30/30 [==============================] - 3s 95ms/step - loss: 0.4968 - accuracy: 0.7809 - val_loss: 0.5091 - val_accuracy: 0.7797 - lr: 3.9685e-06
# Epoch 134/200
# 30/30 [==============================] - 3s 91ms/step - loss: 0.4960 - accuracy: 0.7766 - val_loss: 0.5051 - val_accuracy: 0.7797 - lr: 3.9685e-06
# Epoch 135/200
# 30/30 [==============================] - 3s 93ms/step - loss: 0.5064 - accuracy: 0.7596 - val_loss: 0.5028 - val_accuracy: 0.7797 - lr: 3.9685e-06
# Epoch 136/200
# 30/30 [==============================] - 3s 94ms/step - loss: 0.4896 - accuracy: 0.7766 - val_loss: 0.5096 - val_accuracy: 0.7797 - lr: 3.9685e-06
# Epoch 137/200
# 29/30 [============================>.] - ETA: 0s - loss: 0.4978 - accuracy: 0.7608
# Epoch 137: ReduceLROnPlateau reducing learning rate to 3.1498024179533314e-06.
# 30/30 [==============================] - 3s 93ms/step - loss: 0.4984 - accuracy: 0.7596 - val_loss: 0.5097 - val_accuracy: 0.7797 - lr: 3.9685e-06
# Epoch 138/200
# 30/30 [==============================] - 3s 91ms/step - loss: 0.4906 - accuracy: 0.7809 - val_loss: 0.5034 - val_accuracy: 0.7797 - lr: 3.1498e-06
# Epoch 139/200
# 30/30 [==============================] - 3s 94ms/step - loss: 0.5051 - accuracy: 0.7787 - val_loss: 0.4981 - val_accuracy: 0.7797 - lr: 3.1498e-06
# Epoch 140/200
# 30/30 [==============================] - 3s 95ms/step - loss: 0.4953 - accuracy: 0.7787 - val_loss: 0.5022 - val_accuracy: 0.7797 - lr: 3.1498e-06
# Epoch 141/200
# 30/30 [==============================] - 3s 93ms/step - loss: 0.4974 - accuracy: 0.7766 - val_loss: 0.5038 - val_accuracy: 0.7797 - lr: 3.1498e-06
# Epoch 142/200
# 30/30 [==============================] - 3s 94ms/step - loss: 0.4956 - accuracy: 0.7809 - val_loss: 0.5046 - val_accuracy: 0.7797 - lr: 3.1498e-06
# Epoch 143/200
# 30/30 [==============================] - 3s 92ms/step - loss: 0.4888 - accuracy: 0.7851 - val_loss: 0.5057 - val_accuracy: 0.7797 - lr: 3.1498e-06
# Epoch 144/200
# 30/30 [==============================] - 3s 95ms/step - loss: 0.5153 - accuracy: 0.7468 - val_loss: 0.5020 - val_accuracy: 0.7797 - lr: 3.1498e-06
# Epoch 145/200
# 30/30 [==============================] - 3s 91ms/step - loss: 0.4898 - accuracy: 0.7787 - val_loss: 0.5010 - val_accuracy: 0.7797 - lr: 3.1498e-06
# Epoch 146/200
# 30/30 [==============================] - 3s 94ms/step - loss: 0.5010 - accuracy: 0.7511 - val_loss: 0.4981 - val_accuracy: 0.7797 - lr: 3.1498e-06
# Epoch 147/200
# 30/30 [==============================] - 3s 94ms/step - loss: 0.4840 - accuracy: 0.7872 - val_loss: 0.5036 - val_accuracy: 0.7797 - lr: 3.1498e-06
# Epoch 148/200
# 30/30 [==============================] - 3s 92ms/step - loss: 0.5007 - accuracy: 0.7596 - val_loss: 0.5007 - val_accuracy: 0.7797 - lr: 3.1498e-06
# Epoch 149/200
# 30/30 [==============================] - 3s 93ms/step - loss: 0.5029 - accuracy: 0.7532 - val_loss: 0.5020 - val_accuracy: 0.7881 - lr: 3.1498e-06
# Epoch 150/200
# 30/30 [==============================] - 3s 95ms/step - loss: 0.4986 - accuracy: 0.7723 - val_loss: 0.4989 - val_accuracy: 0.7797 - lr: 3.1498e-06
# Epoch 151/200
# 30/30 [==============================] - 3s 93ms/step - loss: 0.4875 - accuracy: 0.7638 - val_loss: 0.5017 - val_accuracy: 0.7881 - lr: 3.1498e-06
# Epoch 152/200
# 30/30 [==============================] - 3s 91ms/step - loss: 0.4911 - accuracy: 0.7830 - val_loss: 0.5049 - val_accuracy: 0.7797 - lr: 3.1498e-06
# Epoch 153/200
# 30/30 [==============================] - 3s 93ms/step - loss: 0.4772 - accuracy: 0.7915 - val_loss: 0.5060 - val_accuracy: 0.7797 - lr: 3.1498e-06
# Epoch 154/200
# 30/30 [==============================] - 3s 93ms/step - loss: 0.5010 - accuracy: 0.7809 - val_loss: 0.5084 - val_accuracy: 0.7797 - lr: 3.1498e-06
# Epoch 155/200
# 30/30 [==============================] - 3s 91ms/step - loss: 0.4932 - accuracy: 0.7681 - val_loss: 0.5021 - val_accuracy: 0.7797 - lr: 3.1498e-06
# Epoch 156/200
# 30/30 [==============================] - 2s 69ms/step - loss: 0.5140 - accuracy: 0.7489 - val_loss: 0.4984 - val_accuracy: 0.7797 - lr: 3.1498e-06
# Epoch 157/200
# 30/30 [==============================] - 2s 68ms/step - loss: 0.4883 - accuracy: 0.7617 - val_loss: 0.4976 - val_accuracy: 0.7797 - lr: 3.1498e-06
# Epoch 158/200
# 30/30 [==============================] - 2s 69ms/step - loss: 0.4974 - accuracy: 0.7745 - val_loss: 0.5036 - val_accuracy: 0.7797 - lr: 3.1498e-06
# Epoch 159/200
# 30/30 [==============================] - 2s 71ms/step - loss: 0.5099 - accuracy: 0.7638 - val_loss: 0.5000 - val_accuracy: 0.7797 - lr: 3.1498e-06
# Epoch 160/200
# 30/30 [==============================] - 2s 72ms/step - loss: 0.5123 - accuracy: 0.7532 - val_loss: 0.5011 - val_accuracy: 0.7881 - lr: 3.1498e-06
# Epoch 161/200
# 30/30 [==============================] - 2s 69ms/step - loss: 0.4871 - accuracy: 0.7830 - val_loss: 0.5017 - val_accuracy: 0.7881 - lr: 3.1498e-06
# Epoch 162/200
# 30/30 [==============================] - 2s 72ms/step - loss: 0.5051 - accuracy: 0.7553 - val_loss: 0.5033 - val_accuracy: 0.7797 - lr: 3.1498e-06
# Epoch 163/200
# 30/30 [==============================] - 2s 69ms/step - loss: 0.5037 - accuracy: 0.7660 - val_loss: 0.4984 - val_accuracy: 0.7881 - lr: 3.1498e-06
# Epoch 164/200
# 30/30 [==============================] - 2s 68ms/step - loss: 0.4957 - accuracy: 0.7723 - val_loss: 0.5003 - val_accuracy: 0.7797 - lr: 3.1498e-06
# Epoch 165/200
# 30/30 [==============================] - 2s 68ms/step - loss: 0.4953 - accuracy: 0.7553 - val_loss: 0.5054 - val_accuracy: 0.7797 - lr: 3.1498e-06
# Epoch 166/200
# 30/30 [==============================] - 2s 71ms/step - loss: 0.4948 - accuracy: 0.7787 - val_loss: 0.5000 - val_accuracy: 0.7881 - lr: 3.1498e-06
# Epoch 167/200
# 30/30 [==============================] - 2s 67ms/step - loss: 0.4868 - accuracy: 0.7681 - val_loss: 0.5049 - val_accuracy: 0.7797 - lr: 3.1498e-06
# Epoch 168/200
# 29/30 [============================>.] - ETA: 0s - loss: 0.4979 - accuracy: 0.7694
# Epoch 168: ReduceLROnPlateau reducing learning rate to 2.499999919802159e-06.
# 30/30 [==============================] - 2s 69ms/step - loss: 0.4974 - accuracy: 0.7660 - val_loss: 0.5090 - val_accuracy: 0.7797 - lr: 3.1498e-06
# Epoch 169/200
# 30/30 [==============================] - 2s 67ms/step - loss: 0.4941 - accuracy: 0.7617 - val_loss: 0.5048 - val_accuracy: 0.7797 - lr: 2.5000e-06
# Epoch 170/200
# 30/30 [==============================] - 3s 104ms/step - loss: 0.5005 - accuracy: 0.7766 - val_loss: 0.5041 - val_accuracy: 0.7797 - lr: 2.5000e-06
# Epoch 171/200
# 30/30 [==============================] - 5s 170ms/step - loss: 0.5030 - accuracy: 0.7617 - val_loss: 0.5000 - val_accuracy: 0.7881 - lr: 2.5000e-06
# Epoch 172/200
# 30/30 [==============================] - 2s 69ms/step - loss: 0.4818 - accuracy: 0.7809 - val_loss: 0.5005 - val_accuracy: 0.7881 - lr: 2.5000e-06
# Epoch 173/200
# 30/30 [==============================] - 2s 68ms/step - loss: 0.4989 - accuracy: 0.7766 - val_loss: 0.4984 - val_accuracy: 0.7881 - lr: 2.5000e-06
# Epoch 174/200
# 30/30 [==============================] - 2s 71ms/step - loss: 0.4957 - accuracy: 0.7553 - val_loss: 0.5001 - val_accuracy: 0.7881 - lr: 2.5000e-06
# Epoch 175/200
# 30/30 [==============================] - 2s 71ms/step - loss: 0.4941 - accuracy: 0.7681 - val_loss: 0.5013 - val_accuracy: 0.7881 - lr: 2.5000e-06
# Epoch 176/200
# 30/30 [==============================] - 2s 69ms/step - loss: 0.4900 - accuracy: 0.7681 - val_loss: 0.5042 - val_accuracy: 0.7797 - lr: 2.5000e-06
# Epoch 177/200
# 30/30 [==============================] - 2s 69ms/step - loss: 0.5059 - accuracy: 0.7617 - val_loss: 0.5013 - val_accuracy: 0.7881 - lr: 2.5000e-06
# Epoch 178/200
# 30/30 [==============================] - 2s 69ms/step - loss: 0.4959 - accuracy: 0.7723 - val_loss: 0.5053 - val_accuracy: 0.7797 - lr: 2.5000e-06
# Epoch 179/200
# 30/30 [==============================] - 2s 68ms/step - loss: 0.4869 - accuracy: 0.7787 - val_loss: 0.5007 - val_accuracy: 0.7881 - lr: 2.5000e-06
# Epoch 180/200
# 30/30 [==============================] - 2s 69ms/step - loss: 0.4994 - accuracy: 0.7553 - val_loss: 0.5009 - val_accuracy: 0.7881 - lr: 2.5000e-06
# Epoch 181/200
# 30/30 [==============================] - 2s 69ms/step - loss: 0.4897 - accuracy: 0.7809 - val_loss: 0.4997 - val_accuracy: 0.7797 - lr: 2.5000e-06
# Epoch 182/200
# 30/30 [==============================] - 2s 69ms/step - loss: 0.4879 - accuracy: 0.7745 - val_loss: 0.5037 - val_accuracy: 0.7797 - lr: 2.5000e-06
# Epoch 183/200
# 29/30 [============================>.] - ETA: 0s - loss: 0.4891 - accuracy: 0.8017
# Epoch 183: ReduceLROnPlateau reducing learning rate to 1.9842512648338455e-06.
# 30/30 [==============================] - 2s 68ms/step - loss: 0.4905 - accuracy: 0.8021 - val_loss: 0.5030 - val_accuracy: 0.7881 - lr: 2.5000e-06
# Epoch 184/200
# 30/30 [==============================] - 2s 69ms/step - loss: 0.4967 - accuracy: 0.7574 - val_loss: 0.5036 - val_accuracy: 0.7797 - lr: 1.9843e-06
# Epoch 185/200
# 30/30 [==============================] - 2s 68ms/step - loss: 0.5018 - accuracy: 0.7872 - val_loss: 0.4988 - val_accuracy: 0.7797 - lr: 1.9843e-06
# Epoch 186/200
# 30/30 [==============================] - 2s 70ms/step - loss: 0.4994 - accuracy: 0.7745 - val_loss: 0.4972 - val_accuracy: 0.7881 - lr: 1.9843e-06
# Epoch 187/200
# 30/30 [==============================] - 2s 69ms/step - loss: 0.4842 - accuracy: 0.7830 - val_loss: 0.4995 - val_accuracy: 0.7881 - lr: 1.9843e-06
# Epoch 188/200
# 30/30 [==============================] - 2s 69ms/step - loss: 0.4787 - accuracy: 0.7872 - val_loss: 0.5000 - val_accuracy: 0.7881 - lr: 1.9843e-06
# Epoch 189/200
# 30/30 [==============================] - 2s 70ms/step - loss: 0.4843 - accuracy: 0.7766 - val_loss: 0.5012 - val_accuracy: 0.7881 - lr: 1.9843e-06
# Epoch 190/200
# 30/30 [==============================] - 2s 68ms/step - loss: 0.4879 - accuracy: 0.7702 - val_loss: 0.5014 - val_accuracy: 0.7881 - lr: 1.9843e-06
# Epoch 191/200
# 30/30 [==============================] - 2s 70ms/step - loss: 0.4950 - accuracy: 0.7511 - val_loss: 0.5031 - val_accuracy: 0.7881 - lr: 1.9843e-06
# Epoch 192/200
# 30/30 [==============================] - 2s 70ms/step - loss: 0.4978 - accuracy: 0.7723 - val_loss: 0.5001 - val_accuracy: 0.7881 - lr: 1.9843e-06
# Epoch 193/200
# 30/30 [==============================] - 2s 69ms/step - loss: 0.4821 - accuracy: 0.7787 - val_loss: 0.5045 - val_accuracy: 0.7797 - lr: 1.9843e-06
# Epoch 194/200
# 30/30 [==============================] - 2s 71ms/step - loss: 0.4779 - accuracy: 0.7936 - val_loss: 0.5054 - val_accuracy: 0.7797 - lr: 1.9843e-06
# Epoch 195/200
# 30/30 [==============================] - 2s 69ms/step - loss: 0.4894 - accuracy: 0.7638 - val_loss: 0.5023 - val_accuracy: 0.7797 - lr: 1.9843e-06
# Epoch 196/200
# 30/30 [==============================] - 2s 70ms/step - loss: 0.4834 - accuracy: 0.7830 - val_loss: 0.5016 - val_accuracy: 0.7881 - lr: 1.9843e-06
# Epoch 197/200
# 30/30 [==============================] - 2s 68ms/step - loss: 0.4868 - accuracy: 0.7638 - val_loss: 0.5047 - val_accuracy: 0.7797 - lr: 1.9843e-06
# Epoch 198/200
# 29/30 [============================>.] - ETA: 0s - loss: 0.5122 - accuracy: 0.7629
# Epoch 198: ReduceLROnPlateau reducing learning rate to 1.5749012089766657e-06.
# 30/30 [==============================] - 2s 70ms/step - loss: 0.5125 - accuracy: 0.7596 - val_loss: 0.4997 - val_accuracy: 0.7797 - lr: 1.9843e-06
# Epoch 199/200
# 30/30 [==============================] - 2s 69ms/step - loss: 0.4952 - accuracy: 0.7745 - val_loss: 0.4986 - val_accuracy: 0.7797 - lr: 1.5749e-06
# Epoch 200/200
# 30/30 [==============================] - 2s 69ms/step - loss: 0.5020 - accuracy: 0.7660 - val_loss: 0.5008 - val_accuracy: 0.7881 - lr: 1.5749e-06
# 5/5 [==============================] - 0s 19ms/step
# Test Accuracy: 0.7857
# Test F1 Score: 0.7857
# Test Precision: 0.7857
# Test Recall: 0.7857
# Test ROC AUC Score: 0.8498
