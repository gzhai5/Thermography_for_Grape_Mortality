# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import accuracy_score, roc_auc_score, recall_score, precision_score, f1_score
from sklearn.metrics import confusion_matrix, precision_recall_fscore_support
import seaborn as sns
from collections import Counter
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau
import sys
sys.path.append(r'C:\Users\Mud\Desktop\2ndPaper\lstm')
from model.lstmfcn import generate_lstmfcn
from model.fcn import generate_fcn
from model.lstm import generate_lstm
from utils.class_weight import compute_class_weight
import tensorflow as tf
import random as python_random

# %%
# # load the data
X_test = np.load(r'C:\Users\Mud\Desktop\2ndPaper\lstm\cultivar-specific\data\pn\X_test_pn.npy')
y_test = np.load(r'C:\Users\Mud\Desktop\2ndPaper\lstm\cultivar-specific\data\pn\y_test_pn.npy')
X_train = np.load(r'C:\Users\Mud\Desktop\2ndPaper\lstm\cultivar-specific\data\pn\X_train_pn.npy')
y_train = np.load(r'C:\Users\Mud\Desktop\2ndPaper\lstm\cultivar-specific\data\pn\y_train_pn.npy')

# # load fake data
#X_train = np.load('./fake/train/X_train.npy')
#y_train = np.load('./fake/train/y_train.npy')
#X_test = np.load('./fake/test/X_test.npy')
#y_test = np.load('./fake/test/y_test.npy')


print('X_train shape:', X_train.shape)
print('y_train shape:', y_train.shape)
print('X_test shape:', X_test.shape)
print('y_test shape:', y_test.shape)
# Out:
# X_train shape: (588, 600)
# y_train shape: (588,)
# X_test shape: (140, 600)
# y_test shape: (140,)

# %%
def reset_random_seeds(seed=42):
   np.random.seed(seed)
   python_random.seed(seed)
   tf.random.set_seed(seed)

reset_random_seeds()

# %%
# normalize the data to have same starting pt for all time series
# input shape: (n_samples, n_timepoints), want each samples - its mean of 0-30th timepts
def normalize_curves_mean_method(unnormalized_datas):
    normalized_datas = []
    for unnormalized_data in unnormalized_datas:
        mean = np.mean(unnormalized_data[:30])
        normalized_data = unnormalized_data - mean
        normalized_datas.append(normalized_data)
    normalized_datas = np.array(normalized_datas)
    assert normalized_datas.shape == unnormalized_datas.shape
    return normalized_datas

# normalize the data using z-score, have mean 0 and std 1
def normalize_curves_zscore(unnormalized_datas):
    normalized_datas = []
    for unnormalized_data in unnormalized_datas:
        mean = np.mean(unnormalized_data)
        std = np.std(unnormalized_data)
        normalized_data = (unnormalized_data - mean) / std
        normalized_datas.append(normalized_data)
    normalized_datas = np.array(normalized_datas)
    assert normalized_datas.shape == unnormalized_datas.shape
    return normalized_datas


# apply ln() to the time series data
def apply_ln_to_curves(datas):
    ln_datas = []
    for data in datas:
        ln_data = np.log(data)
        ln_datas.append(ln_data)
    ln_datas = np.array(ln_datas)
    assert ln_datas.shape == datas.shape
    return ln_datas


# split the time series data into wanted time points
def split_time_series(datas, start, end):
    datas = datas[:, start:end]
    return datas


# plot the time series data, randomly picked n samples, different colors represent different classes
def plot_random_time_series(datas, n, labels):
    for i in range(n):
        idx = np.random.randint(datas.shape[0])
        plt.plot(datas[idx], color = 'blue' if labels[idx] == 1 else 'red', alpha = 0.2)
    plt.show()


X_train = normalize_curves_mean_method(X_train)
X_test = normalize_curves_mean_method(X_test)
plot_random_time_series(X_train, 100, y_train)
# X_train = normalize_curves_zscore(X_train)
# X_test = normalize_curves_zscore(X_test)
print('X_train shape:', X_train.shape)
print('X_train range:', np.min(X_train), np.max(X_train))
print('X_test shape:', X_test.shape)
print('X_test range:', np.min(X_test), np.max(X_test))
# Out:
# X_train shape: (588, 600)
# X_train range: -26.59554043839853 930.523356009071
# X_test shape: (140, 600)
# X_test range: -15.884504913075943 703.0394557823129

# %%
# upsample the one class in the training set by given factor
# add some level of noise to the time series data with maintaining mean & std
# class_label: 1 is alive, 0 is dead
def data_augmentation(X_train, y_train, n_times, class_label=1, random_seed=42):
    np.random.seed(random_seed)
    X_train_augmented = X_train.copy()
    y_train_augmented = y_train.copy()
    for i in range(len(y_train)):
        if y_train[i] == class_label:
            for _ in range(n_times):
                X_train_augmented = np.concatenate((X_train_augmented, [X_train[i] + np.random.normal(0, 0.1, X_train[i].shape)]), axis=0)
                y_train_augmented = np.concatenate((y_train_augmented, [y_train[i]]), axis=0)
    return X_train_augmented, y_train_augmented



print('Before, Class ratio:', Counter(y_train))
#X_train, y_train = data_augmentation(X_train, y_train, 10, class_label=0)
#X_train, y_train = data_augmentation(X_train, y_train, 4, class_label=1)
print('After, Class ratio:', Counter(y_train))
# Out:
# Before, Class ratio: Counter({1: 405, 0: 183})
# After, Class ratio: Counter({1: 405, 0: 183})

# %%
# compute mean & std of the training set, then normalize the whole dataset using z-normalization
mean = np.mean(X_train)
std = np.std(X_train)
X_train = (X_train - mean) / std
X_test = (X_test - mean) / std

# %%
# Ensure data is shaped correctly
X_train = X_train.reshape(-1, 1, 600)  # Convert to (samples, 1, timesteps)
X_test = X_test.reshape(-1, 1, 600)
y_train = y_train.reshape(-1, 1)  # Ensure labels are in shape (samples, 1)
y_test = y_test.reshape(-1, 1)

print('X_train shape:', X_train.shape)
print('y_train shape:', y_train.shape)
print('X_test shape:', X_test.shape)
print('y_test shape:', y_test.shape)
# Out:
# X_train shape: (588, 1, 600)
# y_train shape: (588, 1)
# X_test shape: (140, 1, 600)
# y_test shape: (140, 1)

# %%
# Train final model on full training data
final_model = generate_lstm(dropout=0)
class_weights = compute_class_weight(y_train)
print('class_weights:', class_weights)
reduce_lr = ReduceLROnPlateau(monitor='loss', patience=15, mode='auto',
    factor=1. / np.cbrt(2), cooldown=0, min_lr=5e-7, verbose=2)
final_model.compile(optimizer=Adam(learning_rate=8e-6), loss='binary_crossentropy', metrics=['accuracy'])

# split the data into training and validation set
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# Train model
history = final_model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    callbacks=[reduce_lr],
    epochs=1100, batch_size=16, class_weight={0: class_weights[0], 1: class_weights[1]},
    verbose=1
)

# Predict on test set
y_pred_prob = final_model.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)

# Calculate metrics
accuracy = accuracy_score(y_test, y_pred)
precision, recall, f1, _ = precision_recall_fscore_support(y_test, y_pred, average='binary')
roc_auc = roc_auc_score(y_test, y_pred_prob)
conf_matrix = confusion_matrix(y_test, y_pred)

# plot the metrics
print(f"Test Accuracy: {accuracy:.4f}")
print(f"Test F1 Score: {f1:.4f}")
print(f"Test Precision: {precision:.4f}")
print(f"Test Recall: {recall:.4f}")
print(f"Test ROC AUC Score: {roc_auc:.4f}")
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Dead', 'Alive'], yticklabels=['Dead', 'Alive'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()


# plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.figure(figsize=(10, 7))
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.figure(figsize=(10, 7))
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# class_weights: [1.60655738 0.72592593]
# Epoch 1/1100
# 30/30 [==============================] - 1s 8ms/step - loss: 0.6748 - accuracy: 0.3447 - val_loss: 0.7046 - val_accuracy: 0.4237 - lr: 8.0000e-06
# Epoch 2/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.6691 - accuracy: 0.3936 - val_loss: 0.6970 - val_accuracy: 0.4492 - lr: 8.0000e-06
# Epoch 3/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.6635 - accuracy: 0.4681 - val_loss: 0.6903 - val_accuracy: 0.4661 - lr: 8.0000e-06
# Epoch 4/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.6579 - accuracy: 0.5255 - val_loss: 0.6843 - val_accuracy: 0.5254 - lr: 8.0000e-06
# Epoch 5/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.6529 - accuracy: 0.5766 - val_loss: 0.6773 - val_accuracy: 0.5593 - lr: 8.0000e-06
# Epoch 6/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.6476 - accuracy: 0.6170 - val_loss: 0.6721 - val_accuracy: 0.5678 - lr: 8.0000e-06
# Epoch 7/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.6427 - accuracy: 0.6404 - val_loss: 0.6665 - val_accuracy: 0.5847 - lr: 8.0000e-06
# Epoch 8/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.6378 - accuracy: 0.6596 - val_loss: 0.6613 - val_accuracy: 0.5932 - lr: 8.0000e-06
# Epoch 9/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.6329 - accuracy: 0.6851 - val_loss: 0.6560 - val_accuracy: 0.6186 - lr: 8.0000e-06
# Epoch 10/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.6278 - accuracy: 0.6894 - val_loss: 0.6505 - val_accuracy: 0.6441 - lr: 8.0000e-06
# Epoch 11/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.6230 - accuracy: 0.7000 - val_loss: 0.6448 - val_accuracy: 0.6441 - lr: 8.0000e-06
# Epoch 12/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.6181 - accuracy: 0.7128 - val_loss: 0.6401 - val_accuracy: 0.6610 - lr: 8.0000e-06
# Epoch 13/1100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.6134 - accuracy: 0.7213 - val_loss: 0.6356 - val_accuracy: 0.6864 - lr: 8.0000e-06
# Epoch 14/1100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.6086 - accuracy: 0.7319 - val_loss: 0.6310 - val_accuracy: 0.6949 - lr: 8.0000e-06
# Epoch 15/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.6041 - accuracy: 0.7383 - val_loss: 0.6269 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 16/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.5997 - accuracy: 0.7362 - val_loss: 0.6222 - val_accuracy: 0.7458 - lr: 8.0000e-06
# Epoch 17/1100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.5954 - accuracy: 0.7383 - val_loss: 0.6178 - val_accuracy: 0.7542 - lr: 8.0000e-06
# Epoch 18/1100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.5912 - accuracy: 0.7447 - val_loss: 0.6150 - val_accuracy: 0.7542 - lr: 8.0000e-06
# Epoch 19/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.5874 - accuracy: 0.7468 - val_loss: 0.6100 - val_accuracy: 0.7712 - lr: 8.0000e-06
# Epoch 20/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.5830 - accuracy: 0.7511 - val_loss: 0.6074 - val_accuracy: 0.7712 - lr: 8.0000e-06
# Epoch 21/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.5792 - accuracy: 0.7511 - val_loss: 0.6044 - val_accuracy: 0.7712 - lr: 8.0000e-06
# Epoch 22/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.5754 - accuracy: 0.7553 - val_loss: 0.6012 - val_accuracy: 0.7712 - lr: 8.0000e-06
# Epoch 23/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.5716 - accuracy: 0.7489 - val_loss: 0.5981 - val_accuracy: 0.7712 - lr: 8.0000e-06
# Epoch 24/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.5682 - accuracy: 0.7468 - val_loss: 0.5968 - val_accuracy: 0.7542 - lr: 8.0000e-06
# Epoch 25/1100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.5646 - accuracy: 0.7489 - val_loss: 0.5934 - val_accuracy: 0.7627 - lr: 8.0000e-06
# Epoch 26/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.5614 - accuracy: 0.7532 - val_loss: 0.5891 - val_accuracy: 0.7712 - lr: 8.0000e-06
# Epoch 27/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.5583 - accuracy: 0.7511 - val_loss: 0.5868 - val_accuracy: 0.7627 - lr: 8.0000e-06
# Epoch 28/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.5554 - accuracy: 0.7532 - val_loss: 0.5832 - val_accuracy: 0.7627 - lr: 8.0000e-06
# Epoch 29/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.5527 - accuracy: 0.7489 - val_loss: 0.5835 - val_accuracy: 0.7627 - lr: 8.0000e-06
# Epoch 30/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.5498 - accuracy: 0.7553 - val_loss: 0.5797 - val_accuracy: 0.7627 - lr: 8.0000e-06
# Epoch 31/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.5471 - accuracy: 0.7511 - val_loss: 0.5765 - val_accuracy: 0.7542 - lr: 8.0000e-06
# Epoch 32/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.5446 - accuracy: 0.7532 - val_loss: 0.5744 - val_accuracy: 0.7542 - lr: 8.0000e-06
# Epoch 33/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.5422 - accuracy: 0.7553 - val_loss: 0.5714 - val_accuracy: 0.7542 - lr: 8.0000e-06
# Epoch 34/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.5398 - accuracy: 0.7574 - val_loss: 0.5680 - val_accuracy: 0.7542 - lr: 8.0000e-06
# Epoch 35/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.5374 - accuracy: 0.7553 - val_loss: 0.5671 - val_accuracy: 0.7542 - lr: 8.0000e-06
# Epoch 36/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.5350 - accuracy: 0.7532 - val_loss: 0.5655 - val_accuracy: 0.7542 - lr: 8.0000e-06
# Epoch 37/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.5329 - accuracy: 0.7574 - val_loss: 0.5648 - val_accuracy: 0.7542 - lr: 8.0000e-06
# Epoch 38/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.5306 - accuracy: 0.7553 - val_loss: 0.5627 - val_accuracy: 0.7542 - lr: 8.0000e-06
# Epoch 39/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.5287 - accuracy: 0.7574 - val_loss: 0.5615 - val_accuracy: 0.7542 - lr: 8.0000e-06
# Epoch 40/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.5268 - accuracy: 0.7574 - val_loss: 0.5560 - val_accuracy: 0.7542 - lr: 8.0000e-06
# Epoch 41/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.5246 - accuracy: 0.7574 - val_loss: 0.5551 - val_accuracy: 0.7542 - lr: 8.0000e-06
# Epoch 42/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.5228 - accuracy: 0.7574 - val_loss: 0.5530 - val_accuracy: 0.7542 - lr: 8.0000e-06
# Epoch 43/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.5210 - accuracy: 0.7574 - val_loss: 0.5510 - val_accuracy: 0.7542 - lr: 8.0000e-06
# Epoch 44/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.5195 - accuracy: 0.7574 - val_loss: 0.5507 - val_accuracy: 0.7458 - lr: 8.0000e-06
# Epoch 45/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.5180 - accuracy: 0.7574 - val_loss: 0.5491 - val_accuracy: 0.7458 - lr: 8.0000e-06
# Epoch 46/1100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.
1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4782 - accuracy: 0.7702 - val_loss: 0.5212 - val_accuracy: 0.7373 - lr: 8.0000e-06
# Epoch 185/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4777 - accuracy: 0.7723 - val_loss: 0.5200 - val_accuracy: 0.7458 - lr: 8.0000e-06
# Epoch 186/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4776 - accuracy: 0.7723 - val_loss: 0.5203 - val_accuracy: 0.7373 - lr: 8.0000e-06
# Epoch 187/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4776 - accuracy: 0.7787 - val_loss: 0.5190 - val_accuracy: 0.7373 - lr: 8.0000e-06
# Epoch 188/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4777 - accuracy: 0.7745 - val_loss: 0.5206 - val_accuracy: 0.7288 - lr: 8.0000e-06
# Epoch 189/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4775 - accuracy: 0.7766 - val_loss: 0.5188 - val_accuracy: 0.7373 - lr: 8.0000e-06
# Epoch 190/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4774 - accuracy: 0.7809 - val_loss: 0.5175 - val_accuracy: 0.7373 - lr: 8.0000e-06
# Epoch 191/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4773 - accuracy: 0.7809 - val_loss: 0.5173 - val_accuracy: 0.7373 - lr: 8.0000e-06
# Epoch 192/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4773 - accuracy: 0.7809 - val_loss: 0.5179 - val_accuracy: 0.7373 - lr: 8.0000e-06
# Epoch 193/1100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4771 - accuracy: 0.7787 - val_loss: 0.5198 - val_accuracy: 0.7288 - lr: 8.0000e-06
# Epoch 194/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4770 - accuracy: 0.7787 - val_loss: 0.5191 - val_accuracy: 0.7288 - lr: 8.0000e-06
# Epoch 195/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4769 - accuracy: 0.7787 - val_loss: 0.5191 - val_accuracy: 0.7288 - lr: 8.0000e-06
# Epoch 196/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4771 - accuracy: 0.7787 - val_loss: 0.5205 - val_accuracy: 0.7288 - lr: 8.0000e-06
# Epoch 197/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4769 - accuracy: 0.7766 - val_loss: 0.5200 - val_accuracy: 0.7288 - lr: 8.0000e-06
# Epoch 198/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4769 - accuracy: 0.7809 - val_loss: 0.5191 - val_accuracy: 0.7288 - lr: 8.0000e-06
# Epoch 199/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4767 - accuracy: 0.7787 - val_loss: 0.5191 - val_accuracy: 0.7288 - lr: 8.0000e-06
# Epoch 200/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4766 - accuracy: 0.7787 - val_loss: 0.5210 - val_accuracy: 0.7288 - lr: 8.0000e-06
# Epoch 201/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4765 - accuracy: 0.7787 - val_loss: 0.5198 - val_accuracy: 0.7288 - lr: 8.0000e-06
# Epoch 202/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4764 - accuracy: 0.7787 - val_loss: 0.5191 - val_accuracy: 0.7288 - lr: 8.0000e-06
# Epoch 203/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4764 - accuracy: 0.7787 - val_loss: 0.5191 - val_accuracy: 0.7288 - lr: 8.0000e-06
# Epoch 204/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4764 - accuracy: 0.7787 - val_loss: 0.5170 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 205/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4763 - accuracy: 0.7809 - val_loss: 0.5175 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 206/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4762 - accuracy: 0.7809 - val_loss: 0.5179 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 207/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4761 - accuracy: 0.7787 - val_loss: 0.5186 - val_accuracy: 0.7288 - lr: 8.0000e-06
# Epoch 208/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4760 - accuracy: 0.7787 - val_loss: 0.5183 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 209/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4761 - accuracy: 0.7809 - val_loss: 0.5176 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 210/1100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4759 - accuracy: 0.7809 - val_loss: 0.5187 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 211/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4758 - accuracy: 0.7787 - val_loss: 0.5198 - val_accuracy: 0.7288 - lr: 8.0000e-06
# Epoch 212/1100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4758 - accuracy: 0.7766 - val_loss: 0.5186 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 213/1100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4760 - accuracy: 0.7809 - val_loss: 0.5188 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 214/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4760 - accuracy: 0.7745 - val_loss: 0.5200 - val_accuracy: 0.7288 - lr: 8.0000e-06
# Epoch 215/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4757 - accuracy: 0.7787 - val_loss: 0.5193 - val_accuracy: 0.7288 - lr: 8.0000e-06
# Epoch 216/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4756 - accuracy: 0.7787 - val_loss: 0.5189 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 217/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4756 - accuracy: 0.7787 - val_loss: 0.5189 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 218/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4756 - accuracy: 0.7809 - val_loss: 0.5183 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 219/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4754 - accuracy: 0.7787 - val_loss: 0.5183 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 220/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4755 - accuracy: 0.7766 - val_loss: 0.5190 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 221/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4752 - accuracy: 0.7787 - val_loss: 0.5180 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 222/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4755 - accuracy: 0.7809 - val_loss: 0.5156 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 223/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4752 - accuracy: 0.7809 - val_loss: 0.5184 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 224/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4750 - accuracy: 0.7809 - val_loss: 0.5178 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 225/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4751 - accuracy: 0.7787 - val_loss: 0.5187 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 226/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4749 - accuracy: 0.7787 - val_loss: 0.5178 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 227/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4749 - accuracy: 0.7766 - val_loss: 0.5192 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 228/1100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4750 - accuracy: 0.7787 - val_loss: 0.5177 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 229/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4748 - accuracy: 0.7787 - val_loss: 0.5189 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 230/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4749 - accuracy: 0.7766 - val_loss: 0.5185 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 231/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4747 - accuracy: 0.7766 - val_loss: 0.5202 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 232/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4746 - accuracy: 0.7766 - val_loss: 0.5183 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 233/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4745 - accuracy: 0.7787 - val_loss: 0.5201 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 234/1100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4745 - accuracy: 0.7745 - val_loss: 0.5203 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 235/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4746 - accuracy: 0.7745 - val_loss: 0.5214 - val_accuracy: 0.7288 - lr: 8.0000e-06
# Epoch 236/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4744 - accuracy: 0.7745 - val_loss: 0.5200 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 237/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4743 - accuracy: 0.7766 - val_loss: 0.5175 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 238/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4743 - accuracy: 0.7766 - val_loss: 0.5182 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 239/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4742 - accuracy: 0.7787 - val_loss: 0.5171 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 240/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4741 - accuracy: 0.7766 - val_loss: 0.5180 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 241/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4740 - accuracy: 0.7766 - val_loss: 0.5183 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 242/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4741 - accuracy: 0.7787 - val_loss: 0.5173 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 243/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4739 - accuracy: 0.7809 - val_loss: 0.5171 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 244/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4739 - accuracy: 0.7787 - val_loss: 0.5176 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 245/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4740 - accuracy: 0.7766 - val_loss: 0.5172 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 246/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4738 - accuracy: 0.7766 - val_loss: 0.5176 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 247/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4739 - accuracy: 0.7787 - val_loss: 0.5175 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 248/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4740 - accuracy: 0.7809 - val_loss: 0.5183 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 249/1100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4737 - accuracy: 0.7766 - val_loss: 0.5174 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 250/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4736 - accuracy: 0.7809 - val_loss: 0.5170 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 251/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4736 - accuracy: 0.7766 - val_loss: 0.5184 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 252/1100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4736 - accuracy: 0.7787 - val_loss: 0.5158 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 253/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4739 - accuracy: 0.7766 - val_loss: 0.5170 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 254/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4733 - accuracy: 0.7766 - val_loss: 0.5173 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 255/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4733 - accuracy: 0.7787 - val_loss: 0.5181 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 256/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4732 - accuracy: 0.7766 - val_loss: 0.5179 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 257/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4734 - accuracy: 0.7766 - val_loss: 0.5197 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 258/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4732 - accuracy: 0.7787 - val_loss: 0.5182 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 259/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4732 - accuracy: 0.7787 - val_loss: 0.5186 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 260/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4731 - accuracy: 0.7766 - val_loss: 0.5202 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 261/1100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4732 - accuracy: 0.7787 - val_loss: 0.5180 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 262/1100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4731 - accuracy: 0.7787 - val_loss: 0.5200 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 263/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4733 - accuracy: 0.7745 - val_loss: 0.5212 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 264/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4728 - accuracy: 0.7766 - val_loss: 0.5185 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 265/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4728 - accuracy: 0.7787 - val_loss: 0.5180 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 266/1100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4728 - accuracy: 0.7787 - val_loss: 0.5173 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 267/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4727 - accuracy: 0.7787 - val_loss: 0.5174 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 268/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4726 - accuracy: 0.7766 - val_loss: 0.5164 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 269/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4726 - accuracy: 0.7766 - val_loss: 0.5167 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 270/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4726 - accuracy: 0.7787 - val_loss: 0.5176 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 271/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4726 - accuracy: 0.7766 - val_loss: 0.5185 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 272/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4726 - accuracy: 0.7766 - val_loss: 0.5166 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 273/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4724 - accuracy: 0.7766 - val_loss: 0.5164 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 274/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4724 - accuracy: 0.7787 - val_loss: 0.5157 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 275/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4723 - accuracy: 0.7787 - val_loss: 0.5180 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 276/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4723 - accuracy: 0.7787 - val_loss: 0.5175 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 277/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4723 - accuracy: 0.7766 - val_loss: 0.5175 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 278/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4723 - accuracy: 0.7809 - val_loss: 0.5171 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 279/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4722 - accuracy: 0.7787 - val_loss: 0.5182 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 280/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4722 - accuracy: 0.7787 - val_loss: 0.5176 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 281/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4722 - accuracy: 0.7766 - val_loss: 0.5161 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 282/1100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4722 - accuracy: 0.7787 - val_loss: 0.5190 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 283/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4722 - accuracy: 0.7787 - val_loss: 0.5196 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 284/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4719 - accuracy: 0.7766 - val_loss: 0.5178 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 285/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4720 - accuracy: 0.7787 - val_loss: 0.5169 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 286/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4719 - accuracy: 0.7809 - val_loss: 0.5160 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 287/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4719 - accuracy: 0.7766 - val_loss: 0.5182 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 288/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4717 - accuracy: 0.7766 - val_loss: 0.5184 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 289/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4717 - accuracy: 0.7787 - val_loss: 0.5180 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 290/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4718 - accuracy: 0.7766 - val_loss: 0.5166 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 291/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4717 - accuracy: 0.7809 - val_loss: 0.5170 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 292/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4719 - accuracy: 0.7787 - val_loss: 0.5159 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 293/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4715 - accuracy: 0.7809 - val_loss: 0.5173 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 294/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4715 - accuracy: 0.7787 - val_loss: 0.5176 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 295/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4715 - accuracy: 0.7809 - val_loss: 0.5172 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 296/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4716 - accuracy: 0.7787 - val_loss: 0.5187 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 297/1100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4713 - accuracy: 0.7809 - val_loss: 0.5166 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 298/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4713 - accuracy: 0.7787 - val_loss: 0.5168 - val_accuracy: 0.7203 - lr: 8.0000e-06
# Epoch 299/1100
# ...
# Epoch 1004/1100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4495 - accuracy: 0.7957 - val_loss: 0.5029 - val_accuracy: 0.7542 - lr: 8.0000e-06
# Epoch 1005/1100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4497 - accuracy: 0.7957 - val_loss: 0.5061 - val_accuracy: 0.7458 - lr: 8.0000e-06
# Epoch 1006/1100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4496 - accuracy: 0.7957 - val_loss: 0.5049 - val_accuracy: 0.7458 - lr: 8.0000e-06
# Epoch 1007/1100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4495 - accuracy: 0.7979 - val_loss: 0.5054 - val_accuracy: 0.7458 - lr: 8.0000e-06
# Epoch 1008/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4495 - accuracy: 0.7957 - val_loss: 0.5052 - val_accuracy: 0.7458 - lr: 8.0000e-06
# Epoch 1009/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4495 - accuracy: 0.7979 - val_loss: 0.5047 - val_accuracy: 0.7458 - lr: 8.0000e-06
# Epoch 1010/1100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4494 - accuracy: 0.7979 - val_loss: 0.5045 - val_accuracy: 0.7458 - lr: 8.0000e-06
# Epoch
1100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4483 - accuracy: 0.7957 - val_loss: 0.5021 - val_accuracy: 0.7542 - lr: 8.0000e-06
# Epoch 1059/1100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4484 - accuracy: 0.7936 - val_loss: 0.5001 - val_accuracy: 0.7542 - lr: 8.0000e-06
# Epoch 1060/1100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4483 - accuracy: 0.7957 - val_loss: 0.5004 - val_accuracy: 0.7542 - lr: 8.0000e-06
# Epoch 1061/1100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4486 - accuracy: 0.7957 - val_loss: 0.5033 - val_accuracy: 0.7542 - lr: 8.0000e-06
# Epoch 1062/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4482 - accuracy: 0.7957 - val_loss: 0.5025 - val_accuracy: 0.7542 - lr: 8.0000e-06
# Epoch 1063/1100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4482 - accuracy: 0.7957 - val_loss: 0.5025 - val_accuracy: 0.7542 - lr: 8.0000e-06
# Epoch 1064/1100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4484 - accuracy: 0.7979 - val_loss: 0.5029 - val_accuracy: 0.7542 - lr: 8.0000e-06
# Epoch 1065/1100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4482 - accuracy: 0.7957 - val_loss: 0.5011 - val_accuracy: 0.7542 - lr: 8.0000e-06
# Epoch 1066/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4484 - accuracy: 0.7957 - val_loss: 0.5039 - val_accuracy: 0.7458 - lr: 8.0000e-06
# Epoch 1067/1100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4481 - accuracy: 0.7957 - val_loss: 0.5019 - val_accuracy: 0.7542 - lr: 8.0000e-06
# Epoch 1068/1100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4482 - accuracy: 0.7979 - val_loss: 0.5033 - val_accuracy: 0.7542 - lr: 8.0000e-06
# Epoch 1069/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4481 - accuracy: 0.7957 - val_loss: 0.5031 - val_accuracy: 0.7542 - lr: 8.0000e-06
# Epoch 1070/1100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4480 - accuracy: 0.7957 - val_loss: 0.5008 - val_accuracy: 0.7542 - lr: 8.0000e-06
# Epoch 1071/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4480 - accuracy: 0.7957 - val_loss: 0.5026 - val_accuracy: 0.7542 - lr: 8.0000e-06
# Epoch 1072/1100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4482 - accuracy: 0.7957 - val_loss: 0.5011 - val_accuracy: 0.7542 - lr: 8.0000e-06
# Epoch 1073/1100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4480 - accuracy: 0.7957 - val_loss: 0.5033 - val_accuracy: 0.7542 - lr: 8.0000e-06
# Epoch 1074/1100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4480 - accuracy: 0.7957 - val_loss: 0.5033 - val_accuracy: 0.7542 - lr: 8.0000e-06
# Epoch 1075/1100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4479 - accuracy: 0.7957 - val_loss: 0.5016 - val_accuracy: 0.7542 - lr: 8.0000e-06
# Epoch 1076/1100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4478 - accuracy: 0.7979 - val_loss: 0.5024 - val_accuracy: 0.7542 - lr: 8.0000e-06
# Epoch 1077/1100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4480 - accuracy: 0.7957 - val_loss: 0.5025 - val_accuracy: 0.7542 - lr: 8.0000e-06
# Epoch 1078/1100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4478 - accuracy: 0.7979 - val_loss: 0.5015 - val_accuracy: 0.7542 - lr: 8.0000e-06
# Epoch 1079/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4479 - accuracy: 0.7979 - val_loss: 0.5023 - val_accuracy: 0.7542 - lr: 8.0000e-06
# Epoch 1080/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4480 - accuracy: 0.8000 - val_loss: 0.5054 - val_accuracy: 0.7458 - lr: 8.0000e-06
# Epoch 1081/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4479 - accuracy: 0.7957 - val_loss: 0.5024 - val_accuracy: 0.7542 - lr: 8.0000e-06
# Epoch 1082/1100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4477 - accuracy: 0.7979 - val_loss: 0.5032 - val_accuracy: 0.7542 - lr: 8.0000e-06
# Epoch 1083/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4479 - accuracy: 0.8000 - val_loss: 0.5042 - val_accuracy: 0.7458 - lr: 8.0000e-06
# Epoch 1084/1100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4477 - accuracy: 0.8000 - val_loss: 0.5013 - val_accuracy: 0.7542 - lr: 8.0000e-06
# Epoch 1085/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4477 - accuracy: 0.7979 - val_loss: 0.5017 - val_accuracy: 0.7542 - lr: 8.0000e-06
# Epoch 1086/1100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4479 - accuracy: 0.7979 - val_loss: 0.5027 - val_accuracy: 0.7542 - lr: 8.0000e-06
# Epoch 1087/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4477 - accuracy: 0.7957 - val_loss: 0.5022 - val_accuracy: 0.7542 - lr: 8.0000e-06
# Epoch 1088/1100
# 30/30 [==============================] - 0s 1ms/step - loss: 0.4476 - accuracy: 0.7979 - val_loss: 0.5006 - val_accuracy: 0.7542 - lr: 8.0000e-06
# Epoch 1089/1100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4477 - accuracy: 0.7957 - val_loss: 0.4986 - val_accuracy: 0.7542 - lr: 8.0000e-06
# Epoch 1090/1100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4476 - accuracy: 0.7979 - val_loss: 0.5004 - val_accuracy: 0.7542 - lr: 8.0000e-06
# Epoch 1091/1100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4477 - accuracy: 0.7957 - val_loss: 0.5024 - val_accuracy: 0.7542 - lr: 8.0000e-06
# Epoch 1092/1100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4475 - accuracy: 0.7979 - val_loss: 0.5018 - val_accuracy: 0.7542 - lr: 8.0000e-06
# Epoch 1093/1100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4476 - accuracy: 0.7957 - val_loss: 0.5034 - val_accuracy: 0.7458 - lr: 8.0000e-06
# Epoch 1094/1100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4478 - accuracy: 0.7957 - val_loss: 0.4995 - val_accuracy: 0.7542 - lr: 8.0000e-06
# Epoch 1095/1100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4474 - accuracy: 0.7979 - val_loss: 0.5016 - val_accuracy: 0.7542 - lr: 8.0000e-06
# Epoch 1096/1100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4475 - accuracy: 0.7979 - val_loss: 0.5005 - val_accuracy: 0.7542 - lr: 8.0000e-06
# Epoch 1097/1100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4474 - accuracy: 0.7979 - val_loss: 0.5034 - val_accuracy: 0.7458 - lr: 8.0000e-06
# Epoch 1098/1100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4474 - accuracy: 0.7979 - val_loss: 0.5021 - val_accuracy: 0.7542 - lr: 8.0000e-06
# Epoch 1099/1100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4474 - accuracy: 0.7957 - val_loss: 0.5028 - val_accuracy: 0.7542 - lr: 8.0000e-06
# Epoch 1100/1100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4473 - accuracy: 0.7957 - val_loss: 0.5030 - val_accuracy: 0.7458 - lr: 8.0000e-06
# 5/5 [==============================] - 0s 750us/step
# Test Accuracy: 0.7786
# Test F1 Score: 0.7801
# Test Precision: 0.7746
# Test Recall: 0.7857
# Test ROC AUC Score: 0.8571
