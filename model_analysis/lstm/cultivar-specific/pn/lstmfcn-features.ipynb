# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import accuracy_score, roc_auc_score, recall_score, precision_score, f1_score
from sklearn.metrics import confusion_matrix, precision_recall_fscore_support
import seaborn as sns
from collections import Counter
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau
import sys
sys.path.append(r'C:\Users\Mud\Desktop\2ndPaper\lstm')
from model.lstmfcn import generate_lstmfcn
from model.fcn import generate_fcn
from model.lstm import generate_lstm
from utils.class_weight import compute_class_weight
import tensorflow as tf
import random as python_random

# %%
# load the data
X_test_time = np.load(r'C:\Users\Mud\Desktop\2ndPaper\lstm\cultivar-specific\data\pn\X_test_pn.npy')
X_train_time = np.load(r'C:\Users\Mud\Desktop\2ndPaper\lstm\cultivar-specific\data\pn\X_train_pn.npy')
y_test = np.load(r'C:\Users\Mud\Desktop\2ndPaper\lstm\cultivar-specific\data\pn\y_test_pn.npy')
y_train = np.load(r'C:\Users\Mud\Desktop\2ndPaper\lstm\cultivar-specific\data\pn\y_train_pn.npy')
X_test_features = np.load(r'C:\Users\Mud\Desktop\2ndPaper\traditional_ml\weka\data\pn\X_test_pn.npy', allow_pickle=True)
X_train_features = np.load(r'C:\Users\Mud\Desktop\2ndPaper\traditional_ml\weka\data\pn\X_train_pn.npy', allow_pickle=True)

# # load fake data
#X_train = np.load('./fake/train/X_train.npy')
#y_train = np.load('./fake/train/y_train.npy')
#X_test = np.load('./fake/test/X_test.npy')
#y_test = np.load('./fake/test/y_test.npy')


print('X_train of time series shape:', X_train_time.shape)
print('X_test of time series shape:', X_test_time.shape)
print('X_train of features shape:', X_train_features.shape)
print('X_test of features shape:', X_test_features.shape)
print('y_train shape:', y_train.shape)
print('y_test shape:', y_test.shape)
# Out:
# X_train of time series shape: (588, 600)
# X_test of time series shape: (140, 600)
# X_train of features shape: (588,)
# X_test of features shape: (140,)
# y_train shape: (588,)
# y_test shape: (140,)

# %%
def reset_random_seeds(seed=42):
   np.random.seed(seed)
   python_random.seed(seed)
   tf.random.set_seed(seed)

reset_random_seeds()

# %%
# normalize the data to have same starting pt for all time series
# input shape: (n_samples, n_timepoints), want each samples - its mean of 0-30th timepts
def normalize_curves_mean_method(unnormalized_datas):
    normalized_datas = []
    for unnormalized_data in unnormalized_datas:
        mean = np.mean(unnormalized_data[:30])
        normalized_data = unnormalized_data - mean
        normalized_datas.append(normalized_data)
    normalized_datas = np.array(normalized_datas)
    assert normalized_datas.shape == unnormalized_datas.shape
    return normalized_datas

# normalize the data using z-score, have mean 0 and std 1
def normalize_curves_zscore(unnormalized_datas):
    normalized_datas = []
    for unnormalized_data in unnormalized_datas:
        mean = np.mean(unnormalized_data)
        std = np.std(unnormalized_data)
        normalized_data = (unnormalized_data - mean) / std
        normalized_datas.append(normalized_data)
    normalized_datas = np.array(normalized_datas)
    assert normalized_datas.shape == unnormalized_datas.shape
    return normalized_datas


# apply ln() to the time series data
def apply_ln_to_curves(datas):
    ln_datas = []
    for data in datas:
        ln_data = np.log(data)
        ln_datas.append(ln_data)
    ln_datas = np.array(ln_datas)
    assert ln_datas.shape == datas.shape
    return ln_datas


# split the time series data into wanted time points
def split_time_series(datas, start, end):
    datas = datas[:, start:end]
    return datas


# plot the time series data, randomly picked n samples, different colors represent different classes
def plot_random_time_series(datas, n, labels):
    for i in range(n):
        idx = np.random.randint(datas.shape[0])
        plt.plot(datas[idx], color = 'blue' if labels[idx] == 1 else 'red', alpha = 0.2)
    plt.show()


X_train_time = normalize_curves_mean_method(X_train_time)
X_test_time = normalize_curves_mean_method(X_test_time)
plot_random_time_series(X_train_time, 100, y_train)

# %%
# normalize the features data
X_train_features = pd.DataFrame.from_records(X_train_features.flatten())
X_test_features = pd.DataFrame.from_records(X_test_features.flatten())
print(X_train_features.head(1))

scaler = StandardScaler()
features = X_train_features.columns
X_train_features[features] = scaler.fit_transform(X_train_features[features])
X_test_features[features] = scaler.transform(X_test_features[features])
print(X_train_features.head(1))
# Out:
#            pc0       pc1        pc2  rising_waveform  falling_waveform  \
# 0  1623.889397  125.7129 -182.72856         1.714598          1.150378
#
#    peak_temperature  cultivar
# 0        462.941497         4
#         pc0       pc1       pc2  rising_waveform  falling_waveform  \
# 0  1.277664  0.360917 -1.330187         1.173085          1.085382
#
#    peak_temperature  cultivar
# 0          1.173085       0.0

# %%
# normalize the time series data
# compute mean & std of the training set, then normalize the whole dataset using z-normalization
mean = np.mean(X_train_time)
std = np.std(X_train_time)
X_train_time = (X_train_time - mean) / std
X_test_time = (X_test_time - mean) / std

# %%
# Ensure data is shaped correctly
X_train_time = X_train_time.reshape(-1, 1, 600)  # Convert to (samples, 1, timesteps)
X_test_time = X_test_time.reshape(-1, 1, 600)
y_train = y_train.reshape(-1, 1)  # Ensure labels are in shape (samples, 1)
y_test = y_test.reshape(-1, 1)
X_train_features = X_train_features.values
X_test_features = X_test_features.values

print('X_train shape of time series:', X_train_time.shape)
print('y_train shape:', y_train.shape)
print('X_test shape of time series:', X_test_time.shape)
print('y_test shape:', y_test.shape)
print('X_train shape of features:', X_train_features.shape)
print('X_test shape of features:', X_test_features.shape)
# Out:
# X_train shape of time series: (588, 1, 600)
# y_train shape: (588, 1)
# X_test shape of time series: (140, 1, 600)
# y_test shape: (140, 1)
# X_train shape of features: (588, 7)
# X_test shape of features: (140, 7)

# %%
# Train final model on full training data# Initialize model
final_model = generate_lstmfcn(feature_input_accept=True, dropout=0.0)
class_weights = compute_class_weight(y_train)
print('class_weights:', class_weights)
reduce_lr = ReduceLROnPlateau(monitor='loss', patience=15, mode='auto',
    factor=1. / np.cbrt(2), cooldown=0, min_lr=1e-6, verbose=2)
final_model.compile(optimizer=Adam(learning_rate=5e-6), loss='binary_crossentropy', metrics=['accuracy'])

# split the data into training and validation set
X_train_time, X_val_time, X_train_features, X_val_features, y_train, y_val = train_test_split(
    X_train_time, X_train_features, y_train, test_size=0.2, random_state=42)
print('X_train shape of time series:', X_train_time.shape)
print('y_train shape:', y_train.shape)
print('X_val shape of time series:', X_val_time.shape)
print('y_val shape:', y_val.shape)
print('X_train shape of features:', X_train_features.shape)
print('X_val shape of features:', X_val_features.shape)

# Train model
history = final_model.fit(
    [X_train_time, X_train_features], y_train,
    validation_data=([X_val_time, X_val_features], y_val),
    callbacks=[reduce_lr],
    epochs=200, batch_size=16, class_weight={0: class_weights[0], 1: class_weights[1]},
    verbose=1
)

# Predict on test set
y_pred_prob = final_model.predict([X_test_time, X_test_features])
y_pred = (y_pred_prob > 0.5).astype(int)

# Calculate metrics
accuracy = accuracy_score(y_test, y_pred)
precision, recall, f1, _ = precision_recall_fscore_support(y_test, y_pred, average='binary')
roc_auc = roc_auc_score(y_test, y_pred_prob)
conf_matrix = confusion_matrix(y_test, y_pred)

# plot the metrics
print(f"Test Accuracy: {accuracy:.4f}")
print(f"Test F1 Score: {f1:.4f}")
print(f"Test Precision: {precision:.4f}")
print(f"Test Recall: {recall:.4f}")
print(f"Test ROC AUC Score: {roc_auc:.4f}")
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Dead', 'Alive'], yticklabels=['Dead', 'Alive'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()


# plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.figure(figsize=(10, 7))
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.figure(figsize=(10, 7))
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# class_weights: [1.60655738 0.72592593]
# X_train shape of time series: (470, 1, 600)
# y_train shape: (470, 1)
# X_val shape of time series: (118, 1, 600)
# y_val shape: (118, 1)
# X_train shape of features: (470, 7)
# X_val shape of features: (118, 7)
# Epoch 1/200
# 30/30 [==============================] - 13s 169ms/step - loss: 0.9355 - accuracy: 0.7021 - val_loss: 0.7904 - val_accuracy: 0.6356 - lr: 5.0000e-06
# Epoch 2/200
# 30/30 [==============================] - 3s 97ms/step - loss: 0.8623 - accuracy: 0.7021 - val_loss: 0.7303 - val_accuracy: 0.6356 - lr: 5.0000e-06
# Epoch 3/200
# 30/30 [==============================] - 3s 98ms/step - loss: 0.8023 - accuracy: 0.7021 - val_loss: 0.6938 - val_accuracy: 0.6356 - lr: 5.0000e-06
# Epoch 4/200
# 30/30 [==============================] - 3s 102ms/step - loss: 0.7495 - accuracy: 0.7021 - val_loss: 0.6630 - val_accuracy: 0.6356 - lr: 5.0000e-06
# Epoch 5/200
# 30/30 [==============================] - 3s 98ms/step - loss: 0.7049 - accuracy: 0.7021 - val_loss: 0.6349 - val_accuracy: 0.6356 - lr: 5.0000e-06
# Epoch 6/200
# 30/30 [==============================] - 3s 95ms/step - loss: 0.6734 - accuracy: 0.7085 - val_loss: 0.6152 - val_accuracy: 0.6525 - lr: 5.0000e-06
# Epoch 7/200
# 30/30 [==============================] - 3s 94ms/step - loss: 0.6447 - accuracy: 0.7255 - val_loss: 0.5975 - val_accuracy: 0.7203 - lr: 5.0000e-06
# Epoch 8/200
# 30/30 [==============================] - 3s 96ms/step - loss: 0.6274 - accuracy: 0.7447 - val_loss: 0.5835 - val_accuracy: 0.7288 - lr: 5.0000e-06
# Epoch 9/200
# 30/30 [==============================] - 3s 96ms/step - loss: 0.6037 - accuracy: 0.7596 - val_loss: 0.5722 - val_accuracy: 0.7458 - lr: 5.0000e-06
# Epoch 10/200
# 30/30 [==============================] - 3s 94ms/step - loss: 0.5948 - accuracy: 0.7702 - val_loss: 0.5625 - val_accuracy: 0.7373 - lr: 5.0000e-06
# Epoch 11/200
# 30/30 [==============================] - 3s 96ms/step - loss: 0.5822 - accuracy: 0.7574 - val_loss: 0.5544 - val_accuracy: 0.7542 - lr: 5.0000e-06
# Epoch 12/200
# 30/30 [==============================] - 3s 93ms/step - loss: 0.5671 - accuracy: 0.7702 - val_loss: 0.5495 - val_accuracy: 0.7542 - lr: 5.0000e-06
# Epoch 13/200
# 30/30 [==============================] - 3s 94ms/step - loss: 0.5721 - accuracy: 0.7574 - val_loss: 0.5465 - val_accuracy: 0.7458 - lr: 5.0000e-06
# Epoch 14/200
# 30/30 [==============================] - 3s 97ms/step - loss: 0.5611 - accuracy: 0.7787 - val_loss: 0.5434 - val_accuracy: 0.7627 - lr: 5.0000e-06
# Epoch 15/200
# 30/30 [==============================] - 3s 96ms/step - loss: 0.5524 - accuracy: 0.7596 - val_loss: 0.5403 - val_accuracy: 0.7712 - lr: 5.0000e-06
# Epoch 16/200
# 30/30 [==============================] - 3s 96ms/step - loss: 0.5490 - accuracy: 0.7745 - val_loss: 0.5389 - val_accuracy: 0.7542 - lr: 5.0000e-06
# Epoch 17/200
# 30/30 [==============================] - 3s 98ms/step - loss: 0.5549 - accuracy: 0.7617 - val_loss: 0.5373 - val_accuracy: 0.7627 - lr: 5.0000e-06
# Epoch 18/200
# 30/30 [==============================] - 3s 96ms/step - loss: 0.5477 - accuracy: 0.7745 - val_loss: 0.5382 - val_accuracy: 0.7712 - lr: 5.0000e-06
# Epoch 19/200
# 30/30 [==============================] - 3s 100ms/step - loss: 0.5461 - accuracy: 0.7809 - val_loss: 0.5345 - val_accuracy: 0.7712 - lr: 5.0000e-06
# Epoch 20/200
# 30/30 [==============================] - 3s 105ms/step - loss: 0.5296 - accuracy: 0.7766 - val_loss: 0.5350 - val_accuracy: 0.7712 - lr: 5.0000e-06
# Epoch
- val_accuracy: 0.7797 - lr: 3.1498e-06
# Epoch 128/200
# 30/30 [==============================] - 4s 122ms/step - loss: 0.4977 - accuracy: 0.7809 - val_loss: 0.5068 - val_accuracy: 0.7797 - lr: 2.5000e-06
# Epoch 129/200
# 30/30 [==============================] - 4s 118ms/step - loss: 0.5160 - accuracy: 0.7617 - val_loss: 0.5038 - val_accuracy: 0.7797 - lr: 2.5000e-06
# Epoch 130/200
# 30/30 [==============================] - 4s 121ms/step - loss: 0.4928 - accuracy: 0.7702 - val_loss: 0.5043 - val_accuracy: 0.7797 - lr: 2.5000e-06
# Epoch 131/200
# 30/30 [==============================] - 4s 122ms/step - loss: 0.5015 - accuracy: 0.7809 - val_loss: 0.5058 - val_accuracy: 0.7797 - lr: 2.5000e-06
# Epoch 132/200
# 30/30 [==============================] - 4s 124ms/step - loss: 0.5065 - accuracy: 0.7489 - val_loss: 0.5076 - val_accuracy: 0.7797 - lr: 2.5000e-06
# Epoch 133/200
# 30/30 [==============================] - 4s 118ms/step - loss: 0.4964 - accuracy: 0.7745 - val_loss: 0.5068 - val_accuracy: 0.7797 - lr: 2.5000e-06
# Epoch 134/200
# 30/30 [==============================] - 4s 119ms/step - loss: 0.4965 - accuracy: 0.7723 - val_loss: 0.5054 - val_accuracy: 0.7797 - lr: 2.5000e-06
# Epoch 135/200
# 30/30 [==============================] - 4s 122ms/step - loss: 0.5051 - accuracy: 0.7553 - val_loss: 0.5044 - val_accuracy: 0.7797 - lr: 2.5000e-06
# Epoch 136/200
# 30/30 [==============================] - 4s 125ms/step - loss: 0.4895 - accuracy: 0.7681 - val_loss: 0.5063 - val_accuracy: 0.7797 - lr: 2.5000e-06
# Epoch 137/200
# 30/30 [==============================] - 4s 121ms/step - loss: 0.5010 - accuracy: 0.7574 - val_loss: 0.5071 - val_accuracy: 0.7797 - lr: 2.5000e-06
# Epoch 138/200
# 30/30 [==============================] - 4s 121ms/step - loss: 0.4880 - accuracy: 0.7809 - val_loss: 0.5035 - val_accuracy: 0.7797 - lr: 2.5000e-06
# Epoch 139/200
# 30/30 [==============================] - 4s 124ms/step - loss: 0.5028 - accuracy: 0.7787 - val_loss: 0.5021 - val_accuracy: 0.7881 - lr: 2.5000e-06
# Epoch 140/200
# 30/30 [==============================] - 4s 122ms/step - loss: 0.4958 - accuracy: 0.7745 - val_loss: 0.5021 - val_accuracy: 0.7881 - lr: 2.5000e-06
# Epoch 141/200
# 30/30 [==============================] - 4s 123ms/step - loss: 0.4965 - accuracy: 0.7851 - val_loss: 0.5034 - val_accuracy: 0.7881 - lr: 2.5000e-06
# Epoch 142/200
# 30/30 [==============================] - ETA: 0s - loss: 0.4936 - accuracy: 0.7851
# Epoch 142: ReduceLROnPlateau reducing learning rate to 1.9842512648338455e-06.
# 30/30 [==============================] - 4s 122ms/step - loss: 0.4936 - accuracy: 0.7851 - val_loss: 0.5041 - val_accuracy: 0.7881 - lr: 2.5000e-06
# Epoch 143/200
# 30/30 [==============================] - 3s 104ms/step - loss: 0.4897 - accuracy: 0.7851 - val_loss: 0.5045 - val_accuracy: 0.7797 - lr: 1.9843e-06
# Epoch 144/200
# 30/30 [==============================] - 3s 96ms/step - loss: 0.5116 - accuracy: 0.7532 - val_loss: 0.5039 - val_accuracy: 0.7797 - lr: 1.9843e-06
# Epoch 145/200
# 30/30 [==============================] - 3s 94ms/step - loss: 0.4908 - accuracy: 0.7702 - val_loss: 0.5040 - val_accuracy: 0.7881 - lr: 1.9843e-06
# Epoch 146/200
# 30/30 [==============================] - 3s 91ms/step - loss: 0.4979 - accuracy: 0.7553 - val_loss: 0.5020 - val_accuracy: 0.7881 - lr: 1.9843e-06
# Epoch 147/200
# 30/30 [==============================] - 3s 91ms/step - loss: 0.4876 - accuracy: 0.7787 - val_loss: 0.5032 - val_accuracy: 0.7881 - lr: 1.9843e-06
# Epoch 148/200
# 30/30 [==============================] - 3s 91ms/step - loss: 0.4984 - accuracy: 0.7681 - val_loss: 0.5034 - val_accuracy: 0.7797 - lr: 1.9843e-06
# Epoch 149/200
# 30/30 [==============================] - 3s 90ms/step - loss: 0.5014 - accuracy: 0.7511 - val_loss: 0.5037 - val_accuracy: 0.7797 - lr: 1.9843e-06
# Epoch 150/200
# 30/30 [==============================] - 3s 90ms/step - loss: 0.4980 - accuracy: 0.7702 - val_loss: 0.5019 - val_accuracy: 0.7881 - lr: 1.9843e-06
# Epoch 151/200
# 30/30 [==============================] - 3s 93ms/step - loss: 0.4907 - accuracy: 0.7702 - val_loss: 0.5028 - val_accuracy: 0.7881 - lr: 1.9843e-06
# Epoch 152/200
# 30/30 [==============================] - 3s 91ms/step - loss: 0.4908 - accuracy: 0.7681 - val_loss: 0.5032 - val_accuracy: 0.7797 - lr: 1.9843e-06
# Epoch 153/200
# 30/30 [==============================] - 3s 92ms/step - loss: 0.4828 - accuracy: 0.7957 - val_loss: 0.5034 - val_accuracy: 0.7797 - lr: 1.9843e-06
# Epoch 154/200
# 30/30 [==============================] - 3s 91ms/step - loss: 0.4993 - accuracy: 0.7723 - val_loss: 0.5048 - val_accuracy: 0.7797 - lr: 1.9843e-06
# Epoch 155/200
# 30/30 [==============================] - 3s 91ms/step - loss: 0.4943 - accuracy: 0.7532 - val_loss: 0.5032 - val_accuracy: 0.7797 - lr: 1.9843e-06
# Epoch 156/200
# 30/30 [==============================] - 3s 90ms/step - loss: 0.5093 - accuracy: 0.7532 - val_loss: 0.5020 - val_accuracy: 0.7881 - lr: 1.9843e-06
# Epoch 157/200
# 30/30 [==============================] - 3s 93ms/step - loss: 0.4900 - accuracy: 0.7681 - val_loss: 0.5009 - val_accuracy: 0.7881 - lr: 1.9843e-06
# Epoch 158/200
# 30/30 [==============================] - 3s 89ms/step - loss: 0.4954 - accuracy: 0.7809 - val_loss: 0.5033 - val_accuracy: 0.7797 - lr: 1.9843e-06
# Epoch 159/200
# 30/30 [==============================] - 3s 84ms/step - loss: 0.5080 - accuracy: 0.7596 - val_loss: 0.5029 - val_accuracy: 0.7881 - lr: 1.9843e-06
# Epoch 160/200
# 30/30 [==============================] - 2s 71ms/step - loss: 0.5070 - accuracy: 0.7681 - val_loss: 0.5026 - val_accuracy: 0.7881 - lr: 1.9843e-06
# Epoch 161/200
# 30/30 [==============================] - 2s 69ms/step - loss: 0.4877 - accuracy: 0.7702 - val_loss: 0.5024 - val_accuracy: 0.7881 - lr: 1.9843e-06
# Epoch 162/200
# 30/30 [==============================] - 2s 68ms/step - loss: 0.5041 - accuracy: 0.7596 - val_loss: 0.5033 - val_accuracy: 0.7797 - lr: 1.9843e-06
# Epoch 163/200
# 30/30 [==============================] - 2s 68ms/step - loss: 0.5025 - accuracy: 0.7723 - val_loss: 0.5020 - val_accuracy: 0.7881 - lr: 1.9843e-06
# Epoch 164/200
# 30/30 [==============================] - 2s 68ms/step - loss: 0.4920 - accuracy: 0.7830 - val_loss: 0.5021 - val_accuracy: 0.7881 - lr: 1.9843e-06
# Epoch 165/200
# 30/30 [==============================] - 2s 67ms/step - loss: 0.4974 - accuracy: 0.7553 - val_loss: 0.5043 - val_accuracy: 0.7797 - lr: 1.9843e-06
# Epoch 166/200
# 30/30 [==============================] - 2s 65ms/step - loss: 0.4954 - accuracy: 0.7745 - val_loss: 0.5023 - val_accuracy: 0.7881 - lr: 1.9843e-06
# Epoch 167/200
# 30/30 [==============================] - 2s 68ms/step - loss: 0.4867 - accuracy: 0.7702 - val_loss: 0.5043 - val_accuracy: 0.7797 - lr: 1.9843e-06
# Epoch 168/200
# 29/30 [============================>.] - ETA: 0s - loss: 0.4958 - accuracy: 0.7608
# Epoch 168: ReduceLROnPlateau reducing learning rate to 1.5749012089766657e-06.
# 30/30 [==============================] - 2s 67ms/step - loss: 0.4957 - accuracy: 0.7574 - val_loss: 0.5067 - val_accuracy: 0.7797 - lr: 1.9843e-06
# Epoch 169/200
# 30/30 [==============================] - 2s 69ms/step - loss: 0.4934 - accuracy: 0.7660 - val_loss: 0.5054 - val_accuracy: 0.7797 - lr: 1.5749e-06
# Epoch 170/200
# 30/30 [==============================] - 2s 68ms/step - loss: 0.4991 - accuracy: 0.7702 - val_loss: 0.5047 - val_accuracy: 0.7797 - lr: 1.5749e-06
# Epoch 171/200
# 30/30 [==============================] - 2s 68ms/step - loss: 0.4992 - accuracy: 0.7723 - val_loss: 0.5034 - val_accuracy: 0.7797 - lr: 1.5749e-06
# Epoch 172/200
# 30/30 [==============================] - 2s 66ms/step - loss: 0.4833 - accuracy: 0.7766 - val_loss: 0.5034 - val_accuracy: 0.7881 - lr: 1.5749e-06
# Epoch 173/200
# 30/30 [==============================] - 2s 69ms/step - loss: 0.4968 - accuracy: 0.7745 - val_loss: 0.5018 - val_accuracy: 0.7881 - lr: 1.5749e-06
# Epoch 174/200
# 30/30 [==============================] - 2s 69ms/step - loss: 0.4983 - accuracy: 0.7596 - val_loss: 0.5020 - val_accuracy: 0.7881 - lr: 1.5749e-06
# Epoch 175/200
# 30/30 [==============================] - 2s 68ms/step - loss: 0.4941 - accuracy: 0.7553 - val_loss: 0.5023 - val_accuracy: 0.7881 - lr: 1.5749e-06
# Epoch 176/200
# 30/30 [==============================] - 2s 67ms/step - loss: 0.4920 - accuracy: 0.7660 - val_loss: 0.5032 - val_accuracy: 0.7797 - lr: 1.5749e-06
# Epoch 177/200
# 30/30 [==============================] - 2s 68ms/step - loss: 0.5042 - accuracy: 0.7617 - val_loss: 0.5026 - val_accuracy: 0.7881 - lr: 1.5749e-06
# Epoch 178/200
# 30/30 [==============================] - 2s 67ms/step - loss: 0.4916 - accuracy: 0.7723 - val_loss: 0.5040 - val_accuracy: 0.7797 - lr: 1.5749e-06
# Epoch 179/200
# 30/30 [==============================] - 2s 67ms/step - loss: 0.4895 - accuracy: 0.7766 - val_loss: 0.5018 - val_accuracy: 0.7881 - lr: 1.5749e-06
# Epoch 180/200
# 30/30 [==============================] - 2s 68ms/step - loss: 0.5014 - accuracy: 0.7574 - val_loss: 0.5019 - val_accuracy: 0.7881 - lr: 1.5749e-06
# Epoch 181/200
# 30/30 [==============================] - 2s 68ms/step - loss: 0.4897 - accuracy: 0.7787 - val_loss: 0.5016 - val_accuracy: 0.7881 - lr: 1.5749e-06
# Epoch 182/200
# 30/30 [==============================] - 2s 67ms/step - loss: 0.4892 - accuracy: 0.7681 - val_loss: 0.5030 - val_accuracy: 0.7881 - lr: 1.5749e-06
# Epoch 183/200
# 29/30 [============================>.] - ETA: 0s - loss: 0.4907 - accuracy: 0.7866
# Epoch 183: ReduceLROnPlateau reducing learning rate to 1.2499999599010794e-06.
# 30/30 [==============================] - 2s 67ms/step - loss: 0.4923 - accuracy: 0.7851 - val_loss: 0.5033 - val_accuracy: 0.7881 - lr: 1.5749e-06
# Epoch 184/200
# 30/30 [==============================] - 2s 68ms/step - loss: 0.4946 - accuracy: 0.7660 - val_loss: 0.5033 - val_accuracy: 0.7881 - lr: 1.2500e-06
# Epoch 185/200
# 30/30 [==============================] - 2s 68ms/step - loss: 0.4997 - accuracy: 0.7915 - val_loss: 0.5014 - val_accuracy: 0.7881 - lr: 1.2500e-06
# Epoch 186/200
# 30/30 [==============================] - 2s 67ms/step - loss: 0.5007 - accuracy: 0.7723 - val_loss: 0.5002 - val_accuracy: 0.7881 - lr: 1.2500e-06
# Epoch 187/200
# 30/30 [==============================] - 2s 67ms/step - loss: 0.4855 - accuracy: 0.7872 - val_loss: 0.5017 - val_accuracy: 0.7881 - lr: 1.2500e-06
# Epoch 188/200
# 30/30 [==============================] - 2s 68ms/step - loss: 0.4830 - accuracy: 0.7766 - val_loss: 0.5012 - val_accuracy: 0.7881 - lr: 1.2500e-06
# Epoch 189/200
# 30/30 [==============================] - 2s 67ms/step - loss: 0.4872 - accuracy: 0.7766 - val_loss: 0.5015 - val_accuracy: 0.7881 - lr: 1.2500e-06
# Epoch 190/200
# 30/30 [==============================] - 2s 69ms/step - loss: 0.4900 - accuracy: 0.7745 - val_loss: 0.5019 - val_accuracy: 0.7881 - lr: 1.2500e-06
# Epoch 191/200
# 30/30 [==============================] - 2s 68ms/step - loss: 0.4942 - accuracy: 0.7638 - val_loss: 0.5022 - val_accuracy: 0.7881 - lr: 1.2500e-06
# Epoch 192/200
# 30/30 [==============================] - 2s 67ms/step - loss: 0.4938 - accuracy: 0.7723 - val_loss: 0.5017 - val_accuracy: 0.7881 - lr: 1.2500e-06
# Epoch 193/200
# 30/30 [==============================] - 2s 68ms/step - loss: 0.4853 - accuracy: 0.7787 - val_loss: 0.5037 - val_accuracy: 0.7797 - lr: 1.2500e-06
# Epoch 194/200
# 30/30 [==============================] - 2s 68ms/step - loss: 0.4800 - accuracy: 0.7872 - val_loss: 0.5044 - val_accuracy: 0.7797 - lr: 1.2500e-06
# Epoch 195/200
# 30/30 [==============================] - 2s 67ms/step - loss: 0.4879 - accuracy: 0.7723 - val_loss: 0.5036 - val_accuracy: 0.7797 - lr: 1.2500e-06
# Epoch 196/200
# 30/30 [==============================] - 2s 68ms/step - loss: 0.4878 - accuracy: 0.7723 - val_loss: 0.5036 - val_accuracy: 0.7797 - lr: 1.2500e-06
# Epoch 197/200
# 30/30 [==============================] - 2s 67ms/step - loss: 0.4886 - accuracy: 0.7638 - val_loss: 0.5044 - val_accuracy: 0.7797 - lr: 1.2500e-06
# Epoch 198/200
# 30/30 [==============================] - 2s 67ms/step - loss: 0.5050 - accuracy: 0.7617 - val_loss: 0.5026 - val_accuracy: 0.7881 - lr: 1.2500e-06
# Epoch 199/200
# 30/30 [==============================] - 2s 67ms/step - loss: 0.4956 - accuracy: 0.7681 - val_loss: 0.5020 - val_accuracy: 0.7881 - lr: 1.2500e-06
# Epoch 200/200
# 30/30 [==============================] - 2s 68ms/step - loss: 0.4978 - accuracy: 0.7638 - val_loss: 0.5024 - val_accuracy: 0.7881 - lr: 1.2500e-06
# 5/5 [==============================] - 0s 13ms/step
# Test Accuracy: 0.7714
# Test F1 Score: 0.7714
# Test Precision: 0.7714
# Test Recall: 0.7714
# Test ROC AUC Score: 0.8471
