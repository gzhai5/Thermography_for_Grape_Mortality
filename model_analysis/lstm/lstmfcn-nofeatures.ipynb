# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import accuracy_score, roc_auc_score, recall_score, precision_score, f1_score
from sklearn.metrics import confusion_matrix, precision_recall_fscore_support
import seaborn as sns
from collections import Counter
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau
from model.lstmfcn import generate_lstmfcn
from model.fcn import generate_fcn
from model.lstm import generate_lstm
from utils.class_weight import compute_class_weight
import tensorflow as tf
import random as python_random

# %%
# # load the data
X_test = np.load('../data-preprocess/data-split/data/mean-time-series/test/X_test.npy')
y_test = np.load('../data-preprocess/data-split/data/features/test/y_test.npy')
X_train = np.load('../data-preprocess/data-split/data/mean-time-series/train/X_train.npy')
y_train = np.load('../data-preprocess/data-split/data/features/train/y_train.npy')

# # load fake data
#X_train = np.load('./fake/train/X_train.npy')
#y_train = np.load('./fake/train/y_train.npy')
#X_test = np.load('./fake/test/X_test.npy')
#y_test = np.load('./fake/test/y_test.npy')


print('X_train shape:', X_train.shape)
print('y_train shape:', y_train.shape)
print('X_test shape:', X_test.shape)
print('y_test shape:', y_test.shape)
# Out:
# X_train shape: (2223, 600)
# y_train shape: (2223,)
# X_test shape: (560, 600)
# y_test shape: (560,)

# %%
def reset_random_seeds(seed=42):
   np.random.seed(seed)
   python_random.seed(seed)
   tf.random.set_seed(seed)

reset_random_seeds()

# %%
# normalize the data to have same starting pt for all time series
# input shape: (n_samples, n_timepoints), want each samples - its mean of 0-30th timepts
def normalize_curves_mean_method(unnormalized_datas):
    normalized_datas = []
    for unnormalized_data in unnormalized_datas:
        mean = np.mean(unnormalized_data[:30])
        normalized_data = unnormalized_data - mean
        normalized_datas.append(normalized_data)
    normalized_datas = np.array(normalized_datas)
    assert normalized_datas.shape == unnormalized_datas.shape
    return normalized_datas

# normalize the data using z-score, have mean 0 and std 1
def normalize_curves_zscore(unnormalized_datas):
    normalized_datas = []
    for unnormalized_data in unnormalized_datas:
        mean = np.mean(unnormalized_data)
        std = np.std(unnormalized_data)
        normalized_data = (unnormalized_data - mean) / std
        normalized_datas.append(normalized_data)
    normalized_datas = np.array(normalized_datas)
    assert normalized_datas.shape == unnormalized_datas.shape
    return normalized_datas


# apply ln() to the time series data
def apply_ln_to_curves(datas):
    ln_datas = []
    for data in datas:
        ln_data = np.log(data)
        ln_datas.append(ln_data)
    ln_datas = np.array(ln_datas)
    assert ln_datas.shape == datas.shape
    return ln_datas


# split the time series data into wanted time points
def split_time_series(datas, start, end):
    datas = datas[:, start:end]
    return datas


# plot the time series data, randomly picked n samples, different colors represent different classes
def plot_random_time_series(datas, n, labels):
    for i in range(n):
        idx = np.random.randint(datas.shape[0])
        plt.plot(datas[idx], color = 'blue' if labels[idx] == 1 else 'red', alpha = 0.2)
    plt.show()


X_train = normalize_curves_mean_method(X_train)
X_test = normalize_curves_mean_method(X_test)
plot_random_time_series(X_train, 100, y_train)
# X_train = normalize_curves_zscore(X_train)
# X_test = normalize_curves_zscore(X_test)
print('X_train shape:', X_train.shape)
print('X_train range:', np.min(X_train), np.max(X_train))
print('X_test shape:', X_test.shape)
print('X_test range:', np.min(X_test), np.max(X_test))
# Out:
# X_train shape: (2223, 600)
# X_train range: -27.382237339377753 930.523356009071
# X_test shape: (560, 600)
# X_test range: -33.20770975056621 708.0417989417983

# %%
# upsample the one class in the training set by given factor
# add some level of noise to the time series data with maintaining mean & std
# class_label: 1 is alive, 0 is dead
def data_augmentation(X_train, y_train, n_times, class_label=1, random_seed=42):
    np.random.seed(random_seed)
    X_train_augmented = X_train.copy()
    y_train_augmented = y_train.copy()
    for i in range(len(y_train)):
        if y_train[i] == class_label:
            for _ in range(n_times):
                X_train_augmented = np.concatenate((X_train_augmented, [X_train[i] + np.random.normal(0, 0.1, X_train[i].shape)]), axis=0)
                y_train_augmented = np.concatenate((y_train_augmented, [y_train[i]]), axis=0)
    return X_train_augmented, y_train_augmented



print('Before, Class ratio:', Counter(y_train))
#X_train, y_train = data_augmentation(X_train, y_train, 10, class_label=0)
#X_train, y_train = data_augmentation(X_train, y_train, 4, class_label=1)
print('After, Class ratio:', Counter(y_train))
# Out:
# Before, Class ratio: Counter({1: 1529, 0: 694})
# After, Class ratio: Counter({1: 1529, 0: 694})

# %%
# compute mean & std of the training set, then normalize the whole dataset using z-normalization
mean = np.mean(X_train)
std = np.std(X_train)
X_train = (X_train - mean) / std
X_test = (X_test - mean) / std

# %%
# Ensure data is shaped correctly
X_train = X_train.reshape(-1, 1, 600)  # Convert to (samples, 1, timesteps)
X_test = X_test.reshape(-1, 1, 600)
y_train = y_train.reshape(-1, 1)  # Ensure labels are in shape (samples, 1)
y_test = y_test.reshape(-1, 1)

print('X_train shape:', X_train.shape)
print('y_train shape:', y_train.shape)
print('X_test shape:', X_test.shape)
print('y_test shape:', y_test.shape)
# Out:
# X_train shape: (2223, 1, 600)
# y_train shape: (2223, 1)
# X_test shape: (560, 1, 600)
# y_test shape: (560, 1)

# %%
# Train final model on full training data# Initialize model
final_model = generate_lstmfcn(dropout=0.0)
class_weights = compute_class_weight(y_train)
print('class_weights:', class_weights)
reduce_lr = ReduceLROnPlateau(monitor='loss', patience=15, mode='auto',
    factor=1. / np.cbrt(2), cooldown=0, min_lr=1e-6, verbose=2)
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=20, verbose=1, mode='min', restore_best_weights=True)
final_model.compile(optimizer=Adam(learning_rate=5e-6), loss='binary_crossentropy', metrics=['accuracy'])

# split the data into training and validation set
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# Train model
history = final_model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    callbacks=[reduce_lr],
    shuffle=True,
    epochs=200, batch_size=16, class_weight={0: class_weights[0], 1: class_weights[1]},
    verbose=1
)

# Predict on test set
y_pred_prob = final_model.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)

# Calculate metrics
accuracy = accuracy_score(y_test, y_pred)
precision, recall, f1, _ = precision_recall_fscore_support(y_test, y_pred, average='binary')
roc_auc = roc_auc_score(y_test, y_pred_prob)
conf_matrix = confusion_matrix(y_test, y_pred)

# plot the metrics
print(f"Test Accuracy: {accuracy:.4f}")
print(f"Test F1 Score: {f1:.4f}")
print(f"Test Precision: {precision:.4f}")
print(f"Test Recall: {recall:.4f}")
print(f"Test ROC AUC Score: {roc_auc:.4f}")
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Dead', 'Alive'], yticklabels=['Dead', 'Alive'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()


# plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.figure(figsize=(10, 7))
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.figure(figsize=(10, 7))
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# class_weights: [1.60158501 0.72694572]
# Epoch 1/200
# 112/112 [==============================] - 12s 79ms/step - loss: 0.7008 - accuracy: 0.6957 - val_loss: 0.6471 - val_accuracy: 0.7056 - lr: 5.0000e-06
# Epoch 2/200
# 112/112 [==============================] - 9s 82ms/step - loss: 0.6255 - accuracy: 0.7373 - val_loss: 0.6306 - val_accuracy: 0.6629 - lr: 5.0000e-06
# Epoch 3/200
# 112/112 [==============================] - 9s 81ms/step - loss: 0.6012 - accuracy: 0.7070 - val_loss: 0.6175 - val_accuracy: 0.6787 - lr: 5.0000e-06
# Epoch 4/200
# 112/112 [==============================] - 9s 82ms/step - loss: 0.5927 - accuracy: 0.7070 - val_loss: 0.6114 - val_accuracy: 0.6899 - lr: 5.0000e-06
# Epoch 5/200
# 112/112 [==============================] - 9s 81ms/step - loss: 0.5869 - accuracy: 0.7132 - val_loss: 0.5925 - val_accuracy: 0.6966 - lr: 5.0000e-06
# Epoch 6/200
# 112/112 [==============================] - 9s 81ms/step - loss: 0.5899 - accuracy: 0.7042 - val_loss: 0.5859 - val_accuracy: 0.7034 - lr: 5.0000e-06
# Epoch 7/200
# 112/112 [==============================] - 9s 82ms/step - loss: 0.5839 - accuracy: 0.6963 - val_loss: 0.5899 - val_accuracy: 0.6989 - lr: 5.0000e-06
# Epoch 8/200
# 112/112 [==============================] - 9s 83ms/step - loss: 0.5876 - accuracy: 0.6985 - val_loss: 0.5923 - val_accuracy: 0.6966 - lr: 5.0000e-06
# Epoch 9/200
# 112/112 [==============================] - 9s 82ms/step - loss: 0.5878 - accuracy: 0.7019 - val_loss: 0.5830 - val_accuracy: 0.7011 - lr: 5.0000e-06
# Epoch 10/200
# 112/112 [==============================] - 9s 81ms/step - loss: 0.5795 - accuracy: 0.7019 - val_loss: 0.5912 - val_accuracy: 0.6854 - lr: 5.0000e-06
# Epoch 11/200
# 112/112 [==============================] - 9s 82ms/step - loss: 0.5800 - accuracy: 0.7058 - val_loss: 0.5947 - val_accuracy: 0.6854 - lr: 5.0000e-06
# Epoch 12/200
# 112/112 [==============================] - 9s 82ms/step - loss: 0.5751 - accuracy: 0.7070 - val_loss: 0.5875 - val_accuracy: 0.6966 - lr: 5.0000e-06
# Epoch 13/200
# 112/112 [==============================] - 9s 82ms/step - loss: 0.5758 - accuracy: 0.7177 - val_loss: 0.5826 - val_accuracy: 0.6989 - lr: 5.0000e-06
# Epoch 14/200
# 112/112 [==============================] - 9s 82ms/step - loss: 0.5809 - accuracy: 0.7132 - val_loss: 0.5885 - val_accuracy: 0.6921 - lr: 5.0000e-06
# Epoch 15/200
# 112/112 [==============================] - 9s 81ms/step - loss: 0.5788 - accuracy: 0.7103 - val_loss: 0.5893 - val_accuracy: 0.6944 - lr: 5.0000e-06
# Epoch 16/200
# 112/112 [==============================] - 9s 79ms/step - loss: 0.5755 - accuracy: 0.7137 - val_loss: 0.5791 - val_accuracy: 0.7011 - lr: 5.0000e-06
# Epoch 17/200
# 112/112 [==============================] - 9s 78ms/step - loss: 0.5735 - accuracy: 0.7132 - val_loss: 0.5817 - val_accuracy: 0.7011 - lr: 5.0000e-06
# Epoch 18/200
# 112/112 [==============================] - 9s 81ms/step - loss: 0.5739 - accuracy: 0.7250 - val_loss: 0.5750 - val_accuracy: 0.7034 - lr: 5.0000e-06
# Epoch 19/200
# 112/112 [==============================] - 9s 82ms/step - loss: 0.5769 - accuracy: 0.7160 - val_loss: 0.5711 - val_accuracy: 0.7056 - lr: 5.0000e-06
# Epoch 20/200
# 112/112 [==============================] - 9s 81ms/step - loss: 0.5747 - accuracy: 0.7137 - val_loss: 0.5789 - val_accuracy: 0.7056 - lr: 5.0000e-06
# Epoch 21/200
# 112/112 [==============================] - 9s 81ms/step - loss: 0.5696 - accuracy: 0.7193 - val_loss: 0.5838 - val_accuracy: 0.7056 - lr: 5.0000e-06
# Epoch 22/200
# 112/112 [==============================] - 9s 83ms/step - loss: 0.5724 - accuracy: 0.7154 - val_loss: 0.5858 - val_accuracy: 0.6966 - lr: 5.0000e-06
# Epoch 23/200
# 112/112 [==============================] - 9s 81ms/step - loss: 0.5709 - accuracy: 0.7222 - val_loss: 0.5731 - val_accuracy: 0.7056 - lr: 5.0000e-06
# Epoch 24/200
# 112/112 [==============================] - 9s 81ms/step - loss: 0.5702 - accuracy: 0.7098 - val_loss: 0.5702 - val_accuracy: 0.7079 - lr: 5.0000e-06
# Epoch 25/200
# 112/112 [==============================] - 9s 82ms/step - loss: 0.5760 - accuracy: 0.7109 - val_loss: 0.5803 - val_accuracy: 0.7034 - lr: 5.0000e-06
# Epoch 26/200
# 112/112 [==============================] - 9s 82ms/step - loss: 0.5737 - accuracy: 0.7278 - val_loss: 0.5734 - val_accuracy: 0.7079 - lr: 5.0000e-06
# Epoch 27/200
# 112/112 [==============================] - 9s 81ms/step - loss: 0.5724 - accuracy: 0.7177 - val_loss: 0.5771 - val_accuracy: 0.7056 - lr: 5.0000e-06
# Epoch 28/200
# 112/112 [==============================] - 9s 82ms/step - loss: 0.5662 - accuracy: 0.7137 - val_loss: 0.5795 - val_accuracy: 0.7034 - lr: 5.0000e-06
# Epoch 29/200
# 112/112 [==============================] - 9s 82ms/step - loss: 0.5684 - accuracy: 0.7165 - val_loss: 0.5664 - val_accuracy: 0.7034 - lr: 5.0000e-06
# Epoch 30/200
# 112/112 [==============================] - 9s 81ms/step - loss: 0.5693 - accuracy: 0.7216 - val_loss: 0.5683 - val_accuracy: 0.7079 - lr: 5.0000e-06
# Epoch 31/200
# 112/112 [==============================] - 9s 81ms/step - loss: 0.5713 - accuracy: 0.7261 - val_loss: 0.5640 - val_accuracy: 0.7034 - lr: 5.0000e-06
# Epoch 32/200
# 112/112 [==============================] - 9s 81ms/step - loss: 0.5671 - accuracy: 0.7283 - val_loss: 0.5626 - val_accuracy: 0.7034 - lr: 5.0000e-06
# Epoch 33/200
# 112/112 [==============================] - 9s 82ms/step - loss: 0.5706 - accuracy: 0.7199 - val_loss: 0.5670 - val_accuracy: 0.7056 - lr: 5.0000e-06
# Epoch 34/200
# 112/112 [==============================] - 9s 81ms/step - loss: 0.5608 - accuracy: 0.7289 - val_loss: 0.5783 - val_accuracy: 0.6989 - lr: 5.0000e-06
# Epoch 35/200
# 112/112 [==============================] - 9s 81ms/step - loss: 0.5657 - accuracy: 0.7216 - val_loss: 0.5748 - val_accuracy: 0.7011 - lr: 5.0000e-06
# Epoch 36/200
# 112/112 [==============================] - 9s 80ms/step - loss: 0.5618 - accuracy: 0.7244 - val_loss: 0.5761 - val_accuracy: 0.6989 - lr: 5.0000e-06
# Epoch 37/200
# 112/112 [==============================] - 9s 80ms/step - loss: 0.5743 - accuracy: 0.7261 - val_loss: 0.5653 - val_accuracy: 0.7056 - lr: 5.0000e-06
# Epoch 38/200
# 112/112 [==============================] - 9s 81ms/step - loss: 0.5687 - accuracy: 0.7261 - val_loss: 0.5730 - val_accuracy: 0.7034 - lr: 5.0000e-06
# Epoch 39/200
# 112/112 [==============================] - 9s 80ms/step - loss: 0.5658 - accuracy: 0.7227 - val_loss: 0.5791 - val_accuracy: 0.6966 - lr: 5.0000e-06
# Epoch 40/200
# 112/112 [==============================] - 9s 81ms/step - loss: 0.5680 - accuracy: 0.7255 - val_loss: 0.5714 - val_accuracy: 0.7034 - lr: 5.0000e-06
# Epoch 41/200
# 112/112 [==============================] - 9s 80ms/step - loss: 0.5644 - accuracy: 0.7261 - val_loss: 0.5640 - val_accuracy: 0.7079 - lr: 5.0000e-06
# Epoch 42/200
# 112/112 [==============================] - 9s 80ms/step - loss: 0.5636 - accuracy: 0.7323 - val_loss: 0.5628 - val_accuracy: 0.7101 - lr: 5.0000e-06
# Epoch 43/200
# 112/112 [==============================] - 9s 80ms/step - loss: 0.5661 - accuracy: 0.7250 - val_loss: 0.5620 - val_accuracy: 0.7079 - lr: 5.0000e-06
# Epoch 44/200
# 112/112 [==============================] - 9s 80ms/step - loss: 0.5640 - accuracy: 0.7300 - val_loss: 0.5771 - val_accuracy: 0.7011 - lr: 5.0000e-06
# Epoch 45/200
# 112/112 [==============================] - 9s 79ms/step - loss: 0.5603 - accuracy: 0.7379 - val_loss: 0.5647 - val_accuracy: 0.7056 - lr: 5.0000e-06
# Epoch 46/200
# 112/112 [==============================] - 9s 77ms/step - loss: 0.5637 - accuracy: 0.7255 - val_loss: 0.5625 - val_accuracy: 0.7056 - lr: 5.0000e-06
# Epoch 47/200
# 112/112 [==============================] - 9s 77ms/step - loss: 0.5631 - accuracy: 0.7227 - val_loss: 0.5622 - val_accuracy: 0.7056 - lr: 5.0000e-06
# Epoch 48/200
# 112/112 [==============================] - 9s 80ms/step - loss: 0.5666 - accuracy: 0.7227 - val_loss: 0.5640 - val_accuracy: 0.7056 - lr: 5.0000e-06
# Epoch 49/200
# 112/112 [==============================] - 9s 80ms/step - loss: 0.5613 - accuracy: 0.7216 - val_loss: 0.5689 - val_accuracy: 0.7056 - lr: 5.0000e-06
# Epoch 50/200
# 112/112 [==============================] - 9s 80ms/step - loss: 0.5642 - accuracy: 0.7300 - val_loss: 0.5667 - val_accuracy: 0.7034 - lr: 5.0000e-06
# Epoch 51/200
# 112/112 [==============================] - 9s 80ms/step - loss: 0.5568 - accuracy: 0.7390 - val_loss: 0.5681 - val_accuracy: 0.7079 - lr: 5.0000e-06
# Epoch 52/200
# 112/112 [==============================] - 9s 80ms/step - loss: 0.5612 - accuracy: 0.7289 - val_loss: 0.5604 - val_accuracy: 0.7101 - lr: 5.0000e-06
# Epoch 53/200
# 112/112 [==============================] - 9s 79ms/step - loss: 0.5580 - accuracy: 0.7255 - val_loss: 0.5521 - val_accuracy: 0.7169 - lr: 5.0000e-06
# Epoch 54/200
# 112/112 [==============================] - 9s 80ms/step - loss: 0.5612 - accuracy: 0.7312 - val_loss: 0.5514 - val_accuracy: 0.7213 - lr: 5.0000e-06
# Epoch 55/200
# 112/112 [==============================] - 9s 80ms/step - loss: 0.5617 - accuracy: 0.7238 - val_loss: 0.5647 - val_accuracy: 0.7079 - lr: 5.0000e-06
# Epoch 56/200
# 112/112 [==============================] - 9s 80ms/step - loss: 0.5536 - accuracy: 0.7340 - val_loss: 0.5568 - val_accuracy: 0.7124 - lr: 5.0000e-06
# Epoch 57/200
# 112/112 [==============================] - 9s 79ms/step - loss: 0.5571 - accuracy: 0.7283 - val_loss: 0.5637 - val_accuracy: 0.7079 - lr: 5.0000e-06
# Epoch 58/200
# 112/112 [==============================] - 9s 79ms/step - loss: 0.5552 - accuracy: 0.7345 - val_loss: 0.5657 - val_accuracy: 0.7034 - lr: 5.0000e-06
# Epoch 59/200
# 112/112 [==============================] - 9s 80ms/step - loss: 0.5570 - accuracy: 0.7407 - val_loss: 0.5706 - val_accuracy: 0.7034 - lr: 5.0000e-06
# Epoch 60/200
# 112/112 [==============================] - 9s 79ms/step - loss: 0.5605 - accuracy: 0.7334 - val_loss: 0.5607 - val_accuracy: 0.7101 - lr: 5.0000e-06
# Epoch 61/200
# 112/112 [==============================] - 9s 80ms/step - loss: 0.5595 - accuracy: 0.7278 - val_loss: 0.5502 - val_accuracy: 0.7169 - lr: 5.0000e-06
# Epoch 62/200
# 112/112 [==============================] - 9s 79ms/step - loss: 0.5542 - accuracy: 0.7385 - val_loss: 0.5540 - val_accuracy: 0.7169 - lr: 5.0000e-06
# Epoch 63/200
# 112/112 [==============================] - 9s 79ms/step - loss: 0.5604 - accuracy: 0.7345 - val_loss: 0.5558 - val_accuracy: 0.7169 - lr: 5.0000e-06
# Epoch 64/200
# 112/112 [==============================] - 9s 79ms/step - loss: 0.5546 - accuracy: 0.7373 - val_loss: 0.5595 - val_accuracy: 0.7169 - lr: 5.0000e-06
# Epoch 65/200
# 112/112 [==============================] - 9s 79ms/step - loss: 0.5538 - accuracy: 0.7385 - val_loss: 0.5554 - val_accuracy: 0.7146 - lr: 5.0000e-06
# Epoch 66/200
# 112/112 [==============================] - 9s 79ms/step - loss: 0.5579 - accuracy: 0.7323 - val_loss: 0.5487 - val_accuracy: 0.7191 - lr: 5.0000e-06
# Epoch 67/200
# 112/112 [==============================] - 9s 79ms/step - loss: 0.5594 - accuracy: 0.7222 - val_loss: 0.5506 - val_accuracy: 0.7191 - lr: 5.0000e-06
# Epoch 68/200
# 112/112 [==============================] - 9s 79ms/step - loss: 0.5621 - accuracy: 0.7295 - val_loss: 0.5506 - val_accuracy: 0.7191 - lr: 5.0000e-06
# Epoch 69/200
# 112/112 [==============================] - 9s 79ms/step - loss: 0.5600 - accuracy: 0.7272 - val_loss: 0.5574 - val_accuracy: 0.7146 - lr: 5.0000e-06
# Epoch 70/200
# 112/112 [==============================] - 9s 80ms/step - loss: 0.5549 - accuracy: 0.7385 - val_loss: 0.5561 - val_accuracy: 0.7169 - lr: 5.0000e-06
# Epoch 71/200
# 111/112 [============================>.] - ETA: 0s - loss: 0.5569 - accuracy: 0.7342
# Epoch 71: ReduceLROnPlateau reducing learning rate to 3.968502529667691e-06.
# 112/112 [==============================] - 9s 79ms/step - loss: 0.5574 - accuracy: 0.7334 - val_loss: 0.5433 - val_accuracy: 0.7258 - lr: 5.0000e-06
# Epoch 72/200
# 112/112 [==============================] - 9s 79ms/step - loss: 0.5581 - accuracy: 0.7373 - val_loss: 0.5613 - val_accuracy: 0.7056 - lr: 3.9685e-06
# Epoch 73/200
# 112/112 [==============================] - 9s 77ms/step - loss: 0.5553 - accuracy: 0.7334 - val_loss: 0.5521 - val_accuracy: 0.7169 - lr: 3.9685e-06
# Epoch 74/200
# 112/112 [==============================] - 9s 78ms/step - loss: 0.5524 - accuracy: 0.7362 - val_loss: 0.5478 - val_accuracy: 0.7191 - lr: 3.9685e-06
# Epoch 75/200
# 112/112 [==============================] - 9s 79ms/step - loss: 0.5558 - accuracy: 0.7373 - val_loss: 0.5548 - val_accuracy: 0.7169 - lr: 3.9685e-06
# Epoch 76/200
# 112/112 [==============================] - 9s 78ms/step - loss: 0.5552 - accuracy: 0.7407 - val_loss: 0.5563 - val_accuracy: 0.7169 - lr: 3.9685e-06
# Epoch 77/200
# 112/112 [==============================] - 9s 78ms/step - loss: 0.5546 - accuracy: 0.7317 - val_loss: 0.5614 - val_accuracy: 0.7079 - lr: 3.9685e-06
# Epoch 78/200
# 112/112 [==============================] - 9s 76ms/step - loss: 0.5532 - accuracy: 0.7295 - val_loss: 0.5532 - val_accuracy: 0.7169 - lr: 3.9685e-06
# Epoch 79/200
# 112/112 [==============================] - 9s 77ms/step - loss: 0.5547 - accuracy: 0.7362 - val_loss: 0.5553 - val_accuracy: 0.7169 - lr: 3.9685e-06
# Epoch 80/200
# 112/112 [==============================] - 9s 78ms/step - loss: 0.5526 - accuracy: 0.7300 - val_loss: 0.5615 - val_accuracy: 0.7011 - lr: 3.9685e-06
# Epoch 81/200
# 112/112 [==============================] - 9s 79ms/step - loss: 0.5495 - accuracy: 0.7373 - val_loss: 0.5603 - val_accuracy: 0.7124 - lr: 3.9685e-06
# Epoch 82/200
# 112/112 [==============================] - 9s 78ms/step - loss: 0.5498 - accuracy: 0.7396 - val_loss: 0.5582 - val_accuracy: 0.7124 - lr: 3.9685e-06
# Epoch 83/200
# 112/112 [==============================] - 9s 79ms/step - loss: 0.5543 - accuracy: 0.7345 - val_loss: 0.5519 - val_accuracy: 0.7169 - lr: 3.9685e-06
# Epoch 84/200
# 112/112 [==============================] - 9s 79ms/step - loss: 0.5529 - accuracy: 0.7418 - val_loss: 0.5465 - val_accuracy: 0.7236 - lr: 3.9685e-06
# Epoch 85/200
# 112/112 [==============================] - 9s 80ms/step - loss: 0.5520 - accuracy: 0.7385 - val_loss: 0.5590 - val_accuracy: 0.7056 - lr: 3.9685e-06
# Epoch 86/200
# 112/112 [==============================] - 9s 79ms/step - loss: 0.5576 - accuracy: 0.7362 - val_loss: 0.5510 - val_accuracy: 0.7146 - lr: 3.9685e-06
# Epoch 87/200
# 112/112 [==============================] - 9s 77ms/step - loss: 0.5535 - accuracy: 0.7379 - val_loss: 0.5512 - val_accuracy: 0.7191 - lr: 3.9685e-06
# Epoch 88/200
# 112/112 [==============================] - 9s 77ms/step - loss: 0.5548 - accuracy: 0.7385 - val_loss: 0.5513 - val_accuracy: 0.7169 - lr: 3.9685e-06
# Epoch 89/200
# 112/112 [==============================] - 9s 78ms/step - loss: 0.5564 - accuracy: 0.7272 - val_loss: 0.5502 - val_accuracy: 0.7191 - lr: 3.9685e-06
# Epoch 90/200
# 112/112 [==============================] - 9s 78ms/step - loss: 0.5527 - accuracy: 0.7379 - val_loss: 0.5603 - val_accuracy: 0.7034 - lr: 3.9685e-06
# Epoch 91/200
# 112/112 [==============================] - 9s 77ms/step - loss: 0.5538 - accuracy: 0.7340 - val_loss: 0.5656 - val_accuracy: 0.7011 - lr: 3.9685e-06
# Epoch 92/200
# 112/112 [==============================] - 9s 79ms/step - loss: 0.5566 - accuracy: 0.7334 - val_loss: 0.5617 - val_accuracy: 0.7034 - lr: 3.9685e-06
# Epoch 93/200
# 112/112 [==============================] - 9s 79ms/step - loss: 0.5545 - accuracy: 0.7390 - val_loss: 0.5541 - val_accuracy: 0.7079 - lr: 3.9685e-06
# Epoch 94/200
# 112/112 [==============================] - 9s 79ms/step - loss: 0.5526 - accuracy: 0.7351 - val_loss: 0.5538 - val_accuracy: 0.7124 - lr: 3.9685e-06
# Epoch 95/200
# 112/112 [==============================] - 9s 77ms/step - loss: 0.5499 - accuracy: 0.7441 - val_loss: 0.5601 - val_accuracy: 0.7011 - lr: 3.9685e-06
# Epoch 96/200
# 111/112 [============================>.] - ETA: 0s - loss: 0.5535 - accuracy: 0.7416
# Epoch 96: ReduceLROnPlateau reducing learning rate to 3.1498024179533314e-06.
# 112/112 [==============================] - 9s 77ms/step - loss: 0.5532 - accuracy: 0.7418 - val_loss: 0.5445 - val_accuracy: 0.7213 - lr: 3.9685e-06
# Epoch 97/200
# 112/112 [==============================] - 9s 78ms/step - loss: 0.5529 - accuracy: 0.7300 - val_loss: 0.5552 - val_accuracy: 0.7101 - lr: 3.1498e-06
# Epoch 98/200
# 112/112 [==============================] - 9s 78ms/step - loss: 0.5513 - accuracy: 0.7430 - val_loss: 0.5543 - val_accuracy: 0.7079 - lr: 3.1498e-06
# Epoch 99/200
# 112/112 [==============================] - 9s 77ms/step - loss: 0.5539 - accuracy: 0.7362 - val_loss: 0.5473 - val_accuracy: 0.7169 - lr: 3.1498e-06
# Epoch 100/200
# 112/112 [==============================] - 9s 78ms/step - loss: 0.5515 - accuracy: 0.7385 - val_loss: 0.5608 - val_accuracy: 0.7034 - lr: 3.1498e-06
# Epoch 101/200
# 112/112 [==============================] - 9s 79ms/step - loss: 0.5498 - accuracy: 0.7306 - val_loss: 0.5668 - val_accuracy: 0.7034 - lr: 3.1498e-06
# Epoch 102/200
# 112/112 [==============================] - 9s 78ms/step - loss: 0.5538 - accuracy: 0.7334 - val_loss: 0.5556 - val_accuracy: 0.7079 - lr: 3.1498e-06
# Epoch 103/200
# 112/112 [==============================] - 8s 76ms/step - loss: 0.5540 - accuracy: 0.7328 - val_loss: 0.5546 - val_accuracy: 0.7079 - lr: 3.1498e-06
# Epoch 104/200
# 112/112 [==============================] - 9s 76ms/step - loss: 0.5529 - accuracy: 0.7413 - val_loss: 0.5552 - val_accuracy: 0.7079 - lr: 3.1498e-06
# Epoch 105/200
# 112/112 [==============================] - 9s 76ms/step - loss: 0.5561 - accuracy: 0.7362 - val_loss: 0.5607 - val_accuracy: 0.7056 - lr: 3.1498e-06
# Epoch 106/200
# 112/112 [==============================] - 9s 77ms/step - loss: 0.5489 - accuracy: 0.7396 - val_loss: 0.5523 - val_accuracy: 0.7124 - lr: 3.1498e-06
# Epoch 107/200
# 112/112 [==============================] - 9s 76ms/step - loss: 0.5475 - accuracy: 0.7413 - val_loss: 0.5538 - val_accuracy: 0.7146 - lr: 3.1498e-06
# Epoch 108/200
# 112/112 [==============================] - 9s 77ms/step - loss: 0.5518 - accuracy: 0.7396 - val_loss: 0.5558 - val_accuracy: 0.7124 - lr: 3.1498e-06
# Epoch 109/200
# 112/112 [==============================] - 8s 76ms/step - loss: 0.5458 - accuracy: 0.7430 - val_loss: 0.5535 - val_accuracy: 0.7124 - lr: 3.1498e-06
# Epoch 110/200
# 112/112 [==============================] - 8s 76ms/step - loss: 0.5518 - accuracy: 0.7323 - val_loss: 0.5578 - val_accuracy: 0.7101 - lr: 3.1498e-06
# Epoch 111/200
# 112/112 [==============================] - 9s 76ms/step - loss: 0.5489 - accuracy: 0.7390 - val_loss: 0.5496 - val_accuracy: 0.7124 - lr: 3.1498e-06
# Epoch 112/200
# 112/112 [==============================] - 9s 76ms/step - loss: 0.5517 - accuracy: 0.7407 - val_loss: 0.5551 - val_accuracy: 0.7101 - lr: 3.1498e-06
# Epoch 113/200
# 112/112 [==============================] - 9s 77ms/step - loss: 0.5471 - accuracy: 0.7390 - val_loss: 0.5629 - val_accuracy: 0.7034 - lr: 3.1498e-06
# Epoch 114/200
# 112/112 [==============================] - 9s 76ms/step - loss: 0.5518 - accuracy: 0.7306 - val_loss: 0.5528 - val_accuracy: 0.7101 - lr: 3.1498e-06
# Epoch 115/200
# 112/112 [==============================] - 9s 76ms/step - loss: 0.5526 - accuracy: 0.7441 - val_loss: 0.5555 - val_accuracy: 0.7124 - lr: 3.1498e-06
# Epoch 116/200
# 112/112 [==============================] - 9s 76ms/step - loss: 0.5481 - accuracy: 0.7390 - val_loss: 0.5471 - val_accuracy: 0.7213 - lr: 3.1498e-06
# Epoch 117/200
# 112/112 [==============================] - 9s 78ms/step - loss: 0.5491 - accuracy: 0.7463 - val_loss: 0.5504 - val_accuracy: 0.7101 - lr: 3.1498e-06
# Epoch 118/200
# 112/112 [==============================] - 9s 77ms/step - loss: 0.5495 - accuracy: 0.7418 - val_loss: 0.5454 - val_accuracy: 0.7213 - lr: 3.1498e-06
# Epoch 119/200
# 112/112 [==============================] - 9s 78ms/step - loss: 0.5471 - accuracy: 0.7351 - val_loss: 0.5452 - val_accuracy: 0.7191 - lr: 3.1498e-06
# Epoch 120/200
# 112/112 [==============================] - 9s 77ms/step - loss: 0.5494 - accuracy: 0.7418 - val_loss: 0.5461 - val_accuracy: 0.7191 - lr: 3.1498e-06
# Epoch 121/200
# 112/112 [==============================] - 9s 81ms/step - loss: 0.5484 - accuracy: 0.7396 - val_loss: 0.5503 - val_accuracy: 0.7146 - lr: 3.1498e-06
# Epoch 122/200
# 112/112 [==============================] - 10s 87ms/step - loss: 0.5475 - accuracy: 0.7458 - val_loss: 0.5551 - val_accuracy: 0.7124 - lr: 3.1498e-06
# Epoch 123/200
# 112/112 [==============================] - 9s 82ms/step - loss: 0.5504 - accuracy: 0.7379 - val_loss: 0.5553 - val_accuracy: 0.7101 - lr: 3.1498e-06
# Epoch 124/200
# 111/112 [============================>.] - ETA: 0s - loss: 0.5461 - accuracy: 0.7376
# Epoch 124: ReduceLROnPlateau reducing learning rate to 2.499999919802159e-06.
# 112/112 [==============================] - 9s 81ms/step - loss: 0.5464 - accuracy: 0.7373 - val_loss: 0.5549 - val_accuracy: 0.7079 - lr: 3.1498e-06
# Epoch 125/200
# 112/112 [==============================] - 9s 80ms/step - loss: 0.5504 - accuracy: 0.7373 - val_loss: 0.5544 - val_accuracy: 0.7124 - lr: 2.5000e-06
# Epoch 126/200
# 112/112 [==============================] - 9s 79ms/step - loss: 0.5491 - accuracy: 0.7368 - val_loss: 0.5500 - val_accuracy: 0.7124 - lr: 2.5000e-06
# Epoch 127/200
# 112/112 [==============================] - 9s 79ms/step - loss: 0.5485 - accuracy: 0.7441 - val_loss: 0.5528 - val_accuracy: 0.7146 - lr: 2.5000e-06
# Epoch 128/200
# 112/112 [==============================] - 9s 80ms/step - loss: 0.5452 - accuracy: 0.7407 - val_loss: 0.5562 - val_accuracy: 0.7079 - lr: 2.5000e-06
# Epoch 129/200
# 112/112 [==============================] - 9s 80ms/step - loss: 0.5463 - accuracy: 0.7357 - val_loss: 0.5503 - val_accuracy: 0.7146 - lr: 2.5000e-06
# Epoch 130/200
# 112/112 [==============================] - 9s 79ms/step - loss: 0.5443 - accuracy: 0.7390 - val_loss: 0.5520 - val_accuracy: 0.7124 - lr: 2.5000e-06
# Epoch 131/200
# 112/112 [==============================] - 9s 80ms/step - loss: 0.5487 - accuracy: 0.7430 - val_loss: 0.5542 - val_accuracy: 0.7079 - lr: 2.5000e-06
# Epoch 132/200
# 112/112 [==============================] - 9s 76ms/step - loss: 0.5497 - accuracy: 0.7345 - val_loss: 0.5536 - val_accuracy: 0.7101 - lr: 2.5000e-06
# Epoch 133/200
# 112/112 [==============================] - 8s 74ms/step - loss: 0.5474 - accuracy: 0.7424 - val_loss: 0.5536 - val_accuracy: 0.7124 - lr: 2.5000e-06
# Epoch 134/200
# 112/112 [==============================] - 8s 74ms/step - loss: 0.5475 - accuracy: 0.7424 - val_loss: 0.5587 - val_accuracy: 0.7079 - lr: 2.5000e-06
# Epoch 135/200
# 112/112 [==============================] - 9s 76ms/step - loss: 0.5507 - accuracy: 0.7413 - val_loss: 0.5509 - val_accuracy: 0.7169 - lr: 2.5000e-06
# Epoch 136/200
# 112/112 [==============================] - 9s 78ms/step - loss: 0.5468 - accuracy: 0.7418 - val_loss: 0.5572 - val_accuracy: 0.7079 - lr: 2.5000e-06
# Epoch 137/200
# 112/112 [==============================] - 9s 77ms/step - loss: 0.5458 - accuracy: 0.7390 - val_loss: 0.5475 - val_accuracy: 0.7124 - lr: 2.5000e-06
# Epoch 138/200
# 112/112 [==============================] - 9s 77ms/step - loss: 0.5508 - accuracy: 0.7424 - val_loss: 0.5495 - val_accuracy: 0.7079 - lr: 2.5000e-06
# Epoch 139/200
# 112/112 [==============================] - 9s 77ms/step - loss: 0.5537 - accuracy: 0.7402 - val_loss: 0.5521 - val_accuracy: 0.7124 - lr: 2.5000e-06
# Epoch 140/200
# 112/112 [==============================] - 9s 78ms/step - loss: 0.5495 - accuracy: 0.7345 - val_loss: 0.5579 - val_accuracy: 0.7101 - lr: 2.5000e-06
# Epoch 141/200
# 112/112 [==============================] - 9s 78ms/step - loss: 0.5459 - accuracy: 0.7385 - val_loss: 0.5552 - val_accuracy: 0.7124 - lr: 2.5000e-06
# Epoch 142/200
# 112/112 [==============================] - 9s 81ms/step - loss: 0.5523 - accuracy: 0.7418 - val_loss: 0.5461 - val_accuracy: 0.7146 - lr: 2.5000e-06
# Epoch 143/200
# 112/112 [==============================] - 9s 79ms/step - loss: 0.5453 - accuracy: 0.7463 - val_loss: 0.5488 - val_accuracy: 0.7124 - lr: 2.5000e-06
# Epoch 144/200
# 112/112 [==============================] - 9s 80ms/step - loss: 0.5451 - accuracy: 0.7424 - val_loss: 0.5599 - val_accuracy: 0.7056 - lr: 2.5000e-06
# Epoch 145/200
# 111/112 [============================>.] - ETA: 0s - loss: 0.5471 - accuracy: 0.7387
# Epoch 145: ReduceLROnPlateau reducing learning rate to 1.9842512648338455e-06.
# 112/112 [==============================] - 9s 82ms/step - loss: 0.5471 - accuracy: 0.7385 - val_loss: 0.5536 - val_accuracy: 0.7146 - lr: 2.5000e-06
# Epoch 146/200
# 112/112 [==============================] - 9s 80ms/step - loss: 0.5465 - accuracy: 0.7413 - val_loss: 0.5532 - val_accuracy: 0.7169 - lr: 1.9843e-06
# Epoch 147/200
# 112/112 [==============================] - 9s 80ms/step - loss: 0.5489 - accuracy: 0.7340 - val_loss: 0.5487 - val_accuracy: 0.7124 - lr: 1.9843e-06
# Epoch 148/200
# 112/112 [==============================] - 9s 79ms/step - loss: 0.5459 - accuracy: 0.7418 - val_loss: 0.5506 - val_accuracy: 0.7124 - lr: 1.9843e-06
# Epoch 149/200
# 112/112 [==============================] - 9s 79ms/step - loss: 0.5498 - accuracy: 0.7390 - val_loss: 0.5509 - val_accuracy: 0.7101 - lr: 1.9843e-06
# Epoch 150/200
# 112/112 [==============================] - 9s 79ms/step - loss: 0.5491 - accuracy: 0.7289 - val_loss: 0.5541 - val_accuracy: 0.7146 - lr: 1.9843e-06
# Epoch 151/200
# 112/112 [==============================] - 9s 79ms/step - loss: 0.5537 - accuracy: 0.7407 - val_loss: 0.5427 - val_accuracy: 0.7169 - lr: 1.9843e-06
# Epoch 152/200
# 112/112 [==============================] - 9s 79ms/step - loss: 0.5478 - accuracy: 0.7452 - val_loss: 0.5500 - val_accuracy: 0.7124 - lr: 1.9843e-06
# Epoch 153/200
# 112/112 [==============================] - 9s 78ms/step - loss: 0.5477 - accuracy: 0.7407 - val_loss: 0.5505 - val_accuracy: 0.7124 - lr: 1.9843e-06
# Epoch 154/200
# 112/112 [==============================] - 9s 79ms/step - loss: 0.5452 - accuracy: 0.7514 - val_loss: 0.5537 - val_accuracy: 0.7101 - lr: 1.9843e-06
# Epoch 155/200
# 112/112 [==============================] - 9s 80ms/step - loss: 0.5507 - accuracy: 0.7345 - val_loss: 0.5505 - val_accuracy: 0.7124 - lr: 1.9843e-06
# Epoch 156/200
# 112/112 [==============================] - 9s 79ms/step - loss: 0.5462 - accuracy: 0.7418 - val_loss: 0.5527 - val_accuracy: 0.7101 - lr: 1.9843e-06
# Epoch 157/200
# 112/112 [==============================] - 9s 78ms/step - loss: 0.5464 - accuracy: 0.7396 - val_loss: 0.5505 - val_accuracy: 0.7124 - lr: 1.9843e-06
# Epoch 158/200
# 112/112 [==============================] - 9s 80ms/step - loss: 0.5460 - accuracy: 0.7430 - val_loss: 0.5512 - val_accuracy: 0.7124 - lr: 1.9843e-06
# Epoch 159/200
# 112/112 [==============================] - 9s 79ms/step - loss: 0.5463 - accuracy: 0.7452 - val_loss: 0.5511 - val_accuracy: 0.7124 - lr: 1.9843e-06
# Epoch 160/200
# 111/112 [============================>.] - ETA: 0s - loss: 0.5458 - accuracy: 0.7404
# Epoch 160: ReduceLROnPlateau reducing learning rate to 1.5749012089766657e-06.
# 112/112 [==============================] - 9s 81ms/step - loss: 0.5459 - accuracy: 0.7407 - val_loss: 0.5496 - val_accuracy: 0.7169 - lr: 1.9843e-06
# Epoch 161/200
# 112/112 [==============================] - 9s 79ms/step - loss: 0.5471 - accuracy: 0.7362 - val_loss: 0.5514 - val_accuracy: 0.7146 - lr: 1.5749e-06
# Epoch 162/200
# 112/112 [==============================] - 6s 53ms/step - loss: 0.5470 - accuracy: 0.7373 - val_loss: 0.5557 - val_accuracy: 0.7101 - lr: 1.5749e-06
# Epoch 163/200
# 112/112 [==============================] - 6s 53ms/step - loss: 0.5506 - accuracy: 0.7357 - val_loss: 0.5528 - val_accuracy: 0.7079 - lr: 1.5749e-06
# Epoch 164/200
# 112/112 [==============================] - 6s 50ms/step - loss: 0.5468 - accuracy: 0.7441 - val_loss: 0.5579 - val_accuracy: 0.7079 - lr: 1.5749e-06
# Epoch 165/200
# 112/112 [==============================] - 6s 53ms/step - loss: 0.5440 - accuracy: 0.7407 - val_loss: 0.5533 - val_accuracy: 0.7169 - lr: 1.5749e-06
# Epoch 166/200
# 112/112 [==============================] - 6s 52ms/step - loss: 0.5453 - accuracy: 0.7402 - val_loss: 0.5486 - val_accuracy: 0.7124 - lr: 1.5749e-06
# Epoch 167/200
# 112/112 [==============================] - 6s 51ms/step - loss: 0.5460 - accuracy: 0.7390 - val_loss: 0.5497 - val_accuracy: 0.7169 - lr: 1.5749e-06
# Epoch 168/200
# 112/112 [==============================] - 6s 52ms/step - loss: 0.5453 - accuracy: 0.7390 - val_loss: 0.5485 - val_accuracy: 0.7101 - lr: 1.5749e-06
# Epoch 169/200
# 112/112 [==============================] - 6s 51ms/step - loss: 0.5477 - accuracy: 0.7435 - val_loss: 0.5489 - val_accuracy: 0.7056 - lr: 1.5749e-06
# Epoch 170/200
# 112/112 [==============================] - 6s 52ms/step - loss: 0.5436 - accuracy: 0.7379 - val_loss: 0.5544 - val_accuracy: 0.7101 - lr: 1.5749e-06
# Epoch 171/200
# 112/112 [==============================] - 6s 51ms/step - loss: 0.5475 - accuracy: 0.7447 - val_loss: 0.5490 - val_accuracy: 0.7191 - lr: 1.5749e-06
# Epoch 172/200
# 112/112 [==============================] - 6s 51ms/step - loss: 0.5502 - accuracy: 0.7413 - val_loss: 0.5474 - val_accuracy: 0.7124 - lr: 1.5749e-06
# Epoch 173/200
# 112/112 [==============================] - 6s 51ms/step - loss: 0.5457 - accuracy: 0.7345 - val_loss: 0.5533 - val_accuracy: 0.7079 - lr: 1.5749e-06
# Epoch 174/200
# 112/112 [==============================] - 6s 52ms/step - loss: 0.5469 - accuracy: 0.7441 - val_loss: 0.5529 - val_accuracy: 0.7079 - lr: 1.5749e-06
# Epoch 175/200
# 112/112 [==============================] - 6s 52ms/step - loss: 0.5463 - accuracy: 0.7340 - val_loss: 0.5532 - val_accuracy: 0.7079 - lr: 1.5749e-06
# Epoch 176/200
# 112/112 [==============================] - 6s 51ms/step - loss: 0.5434 - accuracy: 0.7379 - val_loss: 0.5514 - val_accuracy: 0.7101 - lr: 1.5749e-06
# Epoch 177/200
# 112/112 [==============================] - 6s 51ms/step - loss: 0.5428 - accuracy: 0.7413 - val_loss: 0.5545 - val_accuracy: 0.7079 - lr: 1.5749e-06
# Epoch 178/200
# 112/112 [==============================] - 6s 52ms/step - loss: 0.5480 - accuracy: 0.7334 - val_loss: 0.5522 - val_accuracy: 0.7146 - lr: 1.5749e-06
# Epoch 179/200
# 112/112 [==============================] - 6s 52ms/step - loss: 0.5444 - accuracy: 0.7345 - val_loss: 0.5524 - val_accuracy: 0.7124 - lr: 1.5749e-06
# Epoch 180/200
# 112/112 [==============================] - 6s 52ms/step - loss: 0.5469 - accuracy: 0.7385 - val_loss: 0.5526 - val_accuracy: 0.7124 - lr: 1.5749e-06
# Epoch 181/200
# 112/112 [==============================] - 6s 52ms/step - loss: 0.5453 - accuracy: 0.7396 - val_loss: 0.5525 - val_accuracy: 0.7101 - lr: 1.5749e-06
# Epoch 182/200
# 112/112 [==============================] - 6s 52ms/step - loss: 0.5445 - accuracy: 0.7480 - val_loss: 0.5534 - val_accuracy: 0.7124 - lr: 1.5749e-06
# Epoch 183/200
# 112/112 [==============================] - 6s 51ms/step - loss: 0.5479 - accuracy: 0.7379 - val_loss: 0.5556 - val_accuracy: 0.7124 - lr: 1.5749e-06
# Epoch 184/200
# 112/112 [==============================] - 6s 51ms/step - loss: 0.5453 - accuracy: 0.7424 - val_loss: 0.5536 - val_accuracy: 0.7146 - lr: 1.5749e-06
# Epoch 185/200
# 112/112 [==============================] - 6s 52ms/step - loss: 0.5486 - accuracy: 0.7402 - val_loss: 0.5514 - val_accuracy: 0.7124 - lr: 1.5749e-06
# Epoch 186/200
# 112/112 [==============================] - 6s 53ms/step - loss: 0.5471 - accuracy: 0.7379 - val_loss: 0.5459 - val_accuracy: 0.7169 - lr: 1.5749e-06
# Epoch 187/200
# 112/112 [==============================] - 6s 53ms/step - loss: 0.5428 - accuracy: 0.7458 - val_loss: 0.5497 - val_accuracy: 0.7124 - lr: 1.5749e-06
# Epoch 188/200
# 112/112 [==============================] - 6s 52ms/step - loss: 0.5477 - accuracy: 0.7407 - val_loss: 0.5494 - val_accuracy: 0.7101 - lr: 1.5749e-06
# Epoch 189/200
# 112/112 [==============================] - 6s 52ms/step - loss: 0.5455 - accuracy: 0.7418 - val_loss: 0.5498 - val_accuracy: 0.7124 - lr: 1.5749e-06
# Epoch 190/200
# 112/112 [==============================] - 6s 52ms/step - loss: 0.5466 - accuracy: 0.7435 - val_loss: 0.5515 - val_accuracy: 0.7101 - lr: 1.5749e-06
# Epoch 191/200
# 112/112 [==============================] - 6s 51ms/step - loss: 0.5447 - accuracy: 0.7379 - val_loss: 0.5512 - val_accuracy: 0.7101 - lr: 1.5749e-06
# Epoch 192/200
# 112/112 [==============================] - 6s 51ms/step - loss: 0.5424 - accuracy: 0.7402 - val_loss: 0.5516 - val_accuracy: 0.7101 - lr: 1.5749e-06
# Epoch 193/200
# 112/112 [==============================] - 6s 51ms/step - loss: 0.5472 - accuracy: 0.7351 - val_loss: 0.5488 - val_accuracy: 0.7146 - lr: 1.5749e-06
# Epoch 194/200
# 112/112 [==============================] - 6s 51ms/step - loss: 0.5431 - accuracy: 0.7452 - val_loss: 0.5521 - val_accuracy: 0.7101 - lr: 1.5749e-06
# Epoch 195/200
# 112/112 [==============================] - 6s 52ms/step - loss: 0.5448 - accuracy: 0.7514 - val_loss: 0.5531 - val_accuracy: 0.7079 - lr: 1.5749e-06
# Epoch 196/200
# 112/112 [==============================] - 6s 52ms/step - loss: 0.5413 - accuracy: 0.7492 - val_loss: 0.5555 - val_accuracy: 0.7079 - lr: 1.5749e-06
# Epoch 197/200
# 112/112 [==============================] - 6s 52ms/step - loss: 0.5441 - accuracy: 0.7385 - val_loss: 0.5520 - val_accuracy: 0.7079 - lr: 1.5749e-06
# Epoch 198/200
# 112/112 [==============================] - 6s 52ms/step - loss: 0.5446 - accuracy: 0.7390 - val_loss: 0.5487 - val_accuracy: 0.7124 - lr: 1.5749e-06
# Epoch 199/200
# 112/112 [==============================] - 6s 52ms/step - loss: 0.5466 - accuracy: 0.7441 - val_loss: 0.5468 - val_accuracy: 0.7124 - lr: 1.5749e-06
# Epoch 200/200
# 112/112 [==============================] - 6s 52ms/step - loss: 0.5504 - accuracy: 0.7351 - val_loss: 0.5487 - val_accuracy: 0.7124 - lr: 1.5749e-06
# 18/18 [==============================] - 0s 16ms/step
# Test Accuracy: 0.7232
# Test F1 Score: 0.7332
# Test Precision: 0.7076
# Test Recall: 0.7607
# Test ROC AUC Score: 0.8022
