# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import accuracy_score, roc_auc_score, recall_score, precision_score, f1_score
from sklearn.metrics import confusion_matrix, precision_recall_fscore_support
import seaborn as sns
from collections import Counter
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau
from model.lstmfcn import generate_lstmfcn
from model.fcn import generate_fcn
from model.lstm import generate_lstm
from utils.class_weight import compute_class_weight
import tensorflow as tf
import random as python_random

# %%
# # load the data
X_test = np.load('../data-preprocess/data-split/data/mean-time-series/test/X_test.npy')
y_test = np.load('../data-preprocess/data-split/data/features/test/y_test.npy')
X_train = np.load('../data-preprocess/data-split/data/mean-time-series/train/X_train.npy')
y_train = np.load('../data-preprocess/data-split/data/features/train/y_train.npy')

# # load fake data
#X_train = np.load('./fake/train/X_train.npy')
#y_train = np.load('./fake/train/y_train.npy')
#X_test = np.load('./fake/test/X_test.npy')
#y_test = np.load('./fake/test/y_test.npy')


print('X_train shape:', X_train.shape)
print('y_train shape:', y_train.shape)
print('X_test shape:', X_test.shape)
print('y_test shape:', y_test.shape)
# Out:
# X_train shape: (2223, 600)
# y_train shape: (2223,)
# X_test shape: (560, 600)
# y_test shape: (560,)

# %%
def reset_random_seeds(seed=42):
   np.random.seed(seed)
   python_random.seed(seed)
   tf.random.set_seed(seed)

reset_random_seeds()

# %%
# normalize the data to have same starting pt for all time series
# input shape: (n_samples, n_timepoints), want each samples - its mean of 0-30th timepts
def normalize_curves_mean_method(unnormalized_datas):
    normalized_datas = []
    for unnormalized_data in unnormalized_datas:
        mean = np.mean(unnormalized_data[:30])
        normalized_data = unnormalized_data - mean
        normalized_datas.append(normalized_data)
    normalized_datas = np.array(normalized_datas)
    assert normalized_datas.shape == unnormalized_datas.shape
    return normalized_datas

# normalize the data using z-score, have mean 0 and std 1
def normalize_curves_zscore(unnormalized_datas):
    normalized_datas = []
    for unnormalized_data in unnormalized_datas:
        mean = np.mean(unnormalized_data)
        std = np.std(unnormalized_data)
        normalized_data = (unnormalized_data - mean) / std
        normalized_datas.append(normalized_data)
    normalized_datas = np.array(normalized_datas)
    assert normalized_datas.shape == unnormalized_datas.shape
    return normalized_datas


# apply ln() to the time series data
def apply_ln_to_curves(datas):
    ln_datas = []
    for data in datas:
        ln_data = np.log(data)
        ln_datas.append(ln_data)
    ln_datas = np.array(ln_datas)
    assert ln_datas.shape == datas.shape
    return ln_datas


# split the time series data into wanted time points
def split_time_series(datas, start, end):
    datas = datas[:, start:end]
    return datas


# plot the time series data, randomly picked n samples, different colors represent different classes
def plot_random_time_series(datas, n, labels):
    for i in range(n):
        idx = np.random.randint(datas.shape[0])
        plt.plot(datas[idx], color = 'blue' if labels[idx] == 1 else 'red', alpha = 0.2)
    plt.show()


X_train = normalize_curves_mean_method(X_train)
X_test = normalize_curves_mean_method(X_test)
plot_random_time_series(X_train, 100, y_train)
# X_train = normalize_curves_zscore(X_train)
# X_test = normalize_curves_zscore(X_test)
print('X_train shape:', X_train.shape)
print('X_train range:', np.min(X_train), np.max(X_train))
print('X_test shape:', X_test.shape)
print('X_test range:', np.min(X_test), np.max(X_test))
# Out:
# X_train shape: (2223, 600)
# X_train range: -27.382237339377753 930.523356009071
# X_test shape: (560, 600)
# X_test range: -33.20770975056621 708.0417989417983

# %%
# upsample the one class in the training set by given factor
# add some level of noise to the time series data with maintaining mean & std
# class_label: 1 is alive, 0 is dead
def data_augmentation(X_train, y_train, n_times, class_label=1, random_seed=42):
    np.random.seed(random_seed)
    X_train_augmented = X_train.copy()
    y_train_augmented = y_train.copy()
    for i in range(len(y_train)):
        if y_train[i] == class_label:
            for _ in range(n_times):
                X_train_augmented = np.concatenate((X_train_augmented, [X_train[i] + np.random.normal(0, 0.1, X_train[i].shape)]), axis=0)
                y_train_augmented = np.concatenate((y_train_augmented, [y_train[i]]), axis=0)
    return X_train_augmented, y_train_augmented



print('Before, Class ratio:', Counter(y_train))
#X_train, y_train = data_augmentation(X_train, y_train, 10, class_label=0)
#X_train, y_train = data_augmentation(X_train, y_train, 4, class_label=1)
print('After, Class ratio:', Counter(y_train))
# Out:
# Before, Class ratio: Counter({1: 1529, 0: 694})
# After, Class ratio: Counter({1: 1529, 0: 694})

# %%
# compute mean & std of the training set, then normalize the whole dataset using z-normalization
mean = np.mean(X_train)
std = np.std(X_train)
X_train = (X_train - mean) / std
X_test = (X_test - mean) / std

# %%
# Ensure data is shaped correctly
X_train = X_train.reshape(-1, 1, 600)  # Convert to (samples, 1, timesteps)
X_test = X_test.reshape(-1, 1, 600)
y_train = y_train.reshape(-1, 1)  # Ensure labels are in shape (samples, 1)
y_test = y_test.reshape(-1, 1)

print('X_train shape:', X_train.shape)
print('y_train shape:', y_train.shape)
print('X_test shape:', X_test.shape)
print('y_test shape:', y_test.shape)
# Out:
# X_train shape: (2223, 1, 600)
# y_train shape: (2223, 1)
# X_test shape: (560, 1, 600)
# y_test shape: (560, 1)

# %%
# Train final model on full training data
final_model = generate_lstm(dropout=0.5)
class_weights = compute_class_weight(y_train)
print('class_weights:', class_weights)
reduce_lr = ReduceLROnPlateau(monitor='loss', patience=15, mode='auto',
    factor=1. / np.cbrt(2), cooldown=0, min_lr=5e-7, verbose=2)
final_model.compile(optimizer=Adam(learning_rate=8e-6), loss='binary_crossentropy', metrics=['accuracy'])

# split the data into training and validation set
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# Train model
history = final_model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    callbacks=[reduce_lr],
    epochs=1100, batch_size=16, class_weight={0: class_weights[0], 1: class_weights[1]},
    verbose=1
)

# Predict on test set
y_pred_prob = final_model.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)

# Calculate metrics
accuracy = accuracy_score(y_test, y_pred)
precision, recall, f1, _ = precision_recall_fscore_support(y_test, y_pred, average='binary')
roc_auc = roc_auc_score(y_test, y_pred_prob)
conf_matrix = confusion_matrix(y_test, y_pred)

# plot the metrics
print(f"Test Accuracy: {accuracy:.4f}")
print(f"Test F1 Score: {f1:.4f}")
print(f"Test Precision: {precision:.4f}")
print(f"Test Recall: {recall:.4f}")
print(f"Test ROC AUC Score: {roc_auc:.4f}")
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Dead', 'Alive'], yticklabels=['Dead', 'Alive'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()


# plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.figure(figsize=(10, 7))
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.figure(figsize=(10, 7))
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# class_weights: [1.60158501 0.72694572]
# Epoch 1/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5760 - loss: 0.6392 - val_accuracy: 0.6180 - val_loss: 0.6459 - learning_rate: 8.0000e-06
# Epoch 2/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step - accuracy: 0.6357 - loss: 0.6258 - val_accuracy: 0.6629 - val_loss: 0.6244 - learning_rate: 8.0000e-06
# Epoch 3/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - accuracy: 0.6529 - loss: 0.6232 - val_accuracy: 0.6831 - val_loss: 0.6089 - learning_rate: 8.0000e-06
# Epoch 4/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step - accuracy: 0.6716 - loss: 0.6118 - val_accuracy: 0.6966 - val_loss: 0.5983 - learning_rate: 8.0000e-06
# Epoch 5/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - accuracy: 0.7116 - loss: 0.5984 - val_accuracy: 0.6966 - val_loss: 0.5924 - learning_rate: 8.0000e-06
# Epoch 6/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step - accuracy: 0.6959 - loss: 0.6013 - val_accuracy: 0.6944 - val_loss: 0.5889 - learning_rate: 8.0000e-06
# Epoch 7/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step - accuracy: 0.6889 - loss: 0.6045 - val_accuracy: 0.6966 - val_loss: 0.5831 - learning_rate: 8.0000e-06
# Epoch 8/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step - accuracy: 0.7244 - loss: 0.5901 - val_accuracy: 0.7056 - val_loss: 0.5794 - learning_rate: 8.0000e-06
# Epoch 9/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 741us/step - accuracy: 0.7115 - loss: 0.5967 - val_accuracy: 0.7034 - val_loss: 0.5787 - learning_rate: 8.0000e-06
# Epoch 10/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step - accuracy: 0.6947 - loss: 0.5910 - val_accuracy: 0.7034 - val_loss: 0.5760 - learning_rate: 8.0000e-06
# Epoch 11/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 784us/step - accuracy: 0.7182 - loss: 0.5934 - val_accuracy: 0.7034 - val_loss: 0.5735 - learning_rate: 8.0000e-06
# Epoch 12/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - accuracy: 0.7050 - loss: 0.5948 - val_accuracy: 0.7034 - val_loss: 0.5736 - learning_rate: 8.0000e-06
# Epoch 13/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step - accuracy: 0.7041 - loss: 0.5873 - val_accuracy: 0.7079 - val_loss: 0.5711 - learning_rate: 8.0000e-06
# Epoch 14/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 911us/step - accuracy: 0.7184 - loss: 0.5866 - val_accuracy: 0.7034 - val_loss: 0.5743 - learning_rate: 8.0000e-06
# Epoch 15/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 797us/step - accuracy: 0.7233 - loss: 0.5907 - val_accuracy: 0.7034 - val_loss: 0.5728 - learning_rate: 8.0000e-06
# Epoch 16/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 824us/step - accuracy: 0.7220 - loss: 0.5874 - val_accuracy: 0.7034 - val_loss: 0.5728 - learning_rate: 8.0000e-06
# Epoch 17/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 802us/step - accuracy: 0.7218 - loss: 0.5927 - val_accuracy: 0.7056 - val_loss: 0.5715 - learning_rate: 8.0000e-06
# Epoch 18/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 766us/step - accuracy: 0.7302 - loss: 0.5762 - val_accuracy: 0.7124 - val_loss: 0.5699 - learning_rate: 8.0000e-06
# Epoch 19/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 742us/step - accuracy: 0.7333 - loss: 0.5705 - val_accuracy: 0.7056 - val_loss: 0.5718 - learning_rate: 8.0000e-06
# Epoch 20/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 788us/step - accuracy: 0.7213 - loss: 0.5843 - val_accuracy: 0.7124 - val_loss: 0.5665 - learning_rate: 8.0000e-06
# Epoch 21/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step - accuracy: 0.7176 - loss: 0.5829 - val_accuracy: 0.7101 - val_loss: 0.5704 - learning_rate: 8.0000e-06
# Epoch 22/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 797us/step - accuracy: 0.7263 - loss: 0.5857 - val_accuracy: 0.7146 - val_loss: 0.5682 - learning_rate: 8.0000e-06
# Epoch 23/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 776us/step - accuracy: 0.7280 - loss: 0.5757 - val_accuracy: 0.7079 - val_loss: 0.5705 - learning_rate: 8.0000e-06
# Epoch 24/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step - accuracy: 0.7161 - loss: 0.5927 - val_accuracy: 0.7146 - val_loss: 0.5670 - learning_rate: 8.0000e-06
# Epoch 25/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step - accuracy: 0.7285 - loss: 0.5756 - val_accuracy: 0.7213 - val_loss: 0.5656 - learning_rate: 8.0000e-06
# Epoch 26/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 732us/step - accuracy: 0.7183 - loss: 0.5757 - val_accuracy: 0.7146 - val_loss: 0.5688 - learning_rate: 8.0000e-06
# Epoch 27/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 895us/step - accuracy: 0.7384 - loss: 0.5837 - val_accuracy: 0.7213 - val_loss: 0.5667 - learning_rate: 8.0000e-06
# Epoch 28/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 793us/step - accuracy: 0.7366 - loss: 0.5703 - val_accuracy: 0.7191 - val_loss: 0.5667 - learning_rate: 8.0000e-06
# Epoch 29/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 833us/step - accuracy: 0.7226 - loss: 0.5764 - val_accuracy: 0.7124 - val_loss: 0.5704 - learning_rate: 8.0000e-06
# Epoch 30/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 806us/step - accuracy: 0.7262 - loss: 0.5694 - val_accuracy: 0.7236 - val_loss: 0.5641 - learning_rate: 8.0000e-06
# Epoch 31/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 815us/step - accuracy: 0.7382 - loss: 0.5835 - val_accuracy: 0.7213 - val_loss: 0.5661 - learning_rate: 8.0000e-06
# Epoch 32/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step - accuracy: 0.7285 - loss: 0.5618 - val_accuracy: 0.7236 - val_loss: 0.5628 - learning_rate: 8.0000e-06
# Epoch 33/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 842us/step - accuracy: 0.7292 - loss: 0.5868 - val_accuracy: 0.7213 - val_loss: 0.5660 - learning_rate: 8.0000e-06
# Epoch 34/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - accuracy: 0.7312 - loss: 0.5730 - val_accuracy: 0.7191 - val_loss: 0.5659 - learning_rate: 8.0000e-06
# Epoch 35/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - accuracy: 0.7172 - loss: 0.5749 - val_accuracy: 0.7191 - val_loss: 0.5670 - learning_rate: 8.0000e-06
# Epoch 36/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step - accuracy: 0.7352 - loss: 0.5611 - val_accuracy: 0.7191 - val_loss: 0.5643 - learning_rate: 8.0000e-06
# Epoch 37/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step - accuracy: 0.7371 - loss: 0.5739 - val_accuracy: 0.7146 - val_loss: 0.5656 - learning_rate: 8.0000e-06
# Epoch 38/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 759us/step - accuracy: 0.7359 - loss: 0.5644 - val_accuracy: 0.7146 - val_loss: 0.5673 - learning_rate: 8.0000e-06
# Epoch 39/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 735us/step - accuracy: 0.7282 - loss: 0.5675 - val_accuracy: 0.7213 - val_loss: 0.5626 - learning_rate: 8.0000e-06
# Epoch 40/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step - accuracy: 0.7270 - loss: 0.5643 - val_accuracy: 0.7169 - val_loss: 0.5652 - learning_rate: 8.0000e-06
# Epoch 41/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 722us/step - accuracy: 0.7300 - loss: 0.5699 - val_accuracy: 0.7169 - val_loss: 0.5638 - learning_rate: 8.0000e-06
# Epoch 42/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - accuracy: 0.7379 - loss: 0.5675 - val_accuracy: 0.7169 - val_loss: 0.5661 - learning_rate: 8.0000e-06
# Epoch 43/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 918us/step - accuracy: 0.7428 - loss: 0.5725 - val_accuracy: 0.7169 - val_loss: 0.5638 - learning_rate: 8.0000e-06
# Epoch 44/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step - accuracy: 0.7357 - loss: 0.5692 - val_accuracy: 0.7169 - val_loss: 0.5630 - learning_rate: 8.0000e-06
# Epoch 45/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 757us/step - accuracy: 0.7242 - loss: 0.5678 - val_accuracy: 0.7101 - val_loss: 0.5678 - learning_rate: 8.0000e-06
# Epoch 46/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step - accuracy: 0.7239 - loss: 0.5723 - val_accuracy: 0.7146 - val_loss: 0.5650 - learning_rate: 8.0000e-06
# Epoch 47/1100
#  96/112 ━━━━━━━━━━━━━━━━━━━━ 0s 529us/step - accuracy: 0.7383 - loss: 0.5725
# Epoch 47: ReduceLROnPlateau reducing learning rate to 6.34960419184159e-06.
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - accuracy: 0.7370 - loss: 0.5738 - val_accuracy: 0.7146 - val_loss: 0.5648 - learning_rate: 8.0000e-06
# Epoch 48/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - accuracy: 0.7310 - loss: 0.5734 - val_accuracy: 0.7169 - val_loss: 0.5637 - learning_rate: 6.3496e-06
# Epoch 49/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step - accuracy: 0.7362 - loss: 0.5724 - val_accuracy: 0.7146 - val_loss: 0.5650 - learning_rate: 6.3496e-06
# Epoch 50/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 727us/step - accuracy: 0.7419 - loss: 0.5661 - val_accuracy: 0.7146 - val_loss: 0.5646 - learning_rate: 6.3496e-06
# Epoch 51/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 839us/step - accuracy: 0.7324 - loss: 0.5669 - val_accuracy: 0.7146 - val_loss: 0.5658 - learning_rate: 6.3496e-06
# Epoch 52/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 894us/step - accuracy: 0.7353 - loss: 0.5727 - val_accuracy: 0.7146 - val_loss: 0.5651 - learning_rate: 6.3496e-06
# Epoch 53/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 938us/step - accuracy: 0.7457 - loss: 0.5648 - val_accuracy: 0.7169 - val_loss: 0.5639 - learning_rate: 6.3496e-06
# Epoch 54/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 797us/step - accuracy: 0.7303 - loss: 0.5702 - val_accuracy: 0.7146 - val_loss: 0.5651 - learning_rate: 6.3496e-06
# Epoch 55/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 757us/step - accuracy: 0.7314 - loss: 0.5640 - val_accuracy: 0.7169 - val_loss: 0.5602 - learning_rate: 6.3496e-06
# Epoch 56/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step - accuracy: 0.7299 - loss: 0.5730 - val_accuracy: 0.7191 - val_loss: 0.5620 - learning_rate: 6.3496e-06
# Epoch 57/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 766us/step - accuracy: 0.7306 - loss: 0.5677 - val_accuracy: 0.7169 - val_loss: 0.5645 - learning_rate: 6.3496e-06
# Epoch 58/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step - accuracy: 0.7284 - loss: 0.5699 - val_accuracy: 0.7169 - val_loss: 0.5639 - learning_rate: 6.3496e-06
# Epoch 59/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step - accuracy: 0.7443 - loss: 0.5743 - val_accuracy: 0.7169 - val_loss: 0.5627 - learning_rate: 6.3496e-06
# Epoch 60/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - accuracy: 0.7329 - loss: 0.5670 - val_accuracy: 0.7169 - val_loss: 0.5633 - learning_rate: 6.3496e-06
# Epoch 61/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step - accuracy: 0.7485 - loss: 0.5635 - val_accuracy: 0.7169 - val_loss: 0.5625 - learning_rate: 6.3496e-06
# Epoch 62/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step - accuracy: 0.7546 - loss: 0.5645 - val_accuracy: 0.7169 - val_loss: 0.5630 - learning_rate: 6.3496e-06
# Epoch 63/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step - accuracy: 0.7325 - loss: 0.5651 - val_accuracy: 0.7169 - val_loss: 0.5604 - learning_rate: 6.3496e-06
# Epoch 64/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 757us/step - accuracy: 0.7369 - loss: 0.5603 - val_accuracy: 0.7169 - val_loss: 0.5639 - learning_rate: 6.3496e-06
# Epoch 65/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 794us/step - accuracy: 0.7474 - loss: 0.5601 - val_accuracy: 0.7169 - val_loss: 0.5641 - learning_rate: 6.3496e-06
# Epoch 66/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step - accuracy: 0.7426 - loss: 0.5664 - val_accuracy: 0.7169 - val_loss: 0.5633 - learning_rate: 6.3496e-06
# Epoch 67/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 757us/step - accuracy: 0.7377 - loss: 0.5566 - val_accuracy: 0.7146 - val_loss: 0.5625 - learning_rate: 6.3496e-06
# Epoch 68/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 732us/step - accuracy: 0.7342 - loss: 0.5759 - val_accuracy: 0.7146 - val_loss: 0.5644 - learning_rate: 6.3496e-06
# Epoch 69/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 875us/step - accuracy: 0.7366 - loss: 0.5641 - val_accuracy: 0.7146 - val_loss: 0.5643 - learning_rate: 6.3496e-06
# Epoch 70/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 766us/step - accuracy: 0.7178 - loss: 0.5610 - val_accuracy: 0.7146 - val_loss: 0.5626 - learning_rate: 6.3496e-06
# Epoch 71/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step - accuracy: 0.7395 - loss: 0.5693 - val_accuracy: 0.7146 - val_loss: 0.5651 - learning_rate: 6.3496e-06
# Epoch 72/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 769us/step - accuracy: 0.7312 - loss: 0.5654 - val_accuracy: 0.7146 - val_loss: 0.5664 - learning_rate: 6.3496e-06
# Epoch 73/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 807us/step - accuracy: 0.7409 - loss: 0.5593 - val_accuracy: 0.7169 - val_loss: 0.5617 - learning_rate: 6.3496e-06
# Epoch 74/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 766us/step - accuracy: 0.7466 - loss: 0.5612 - val_accuracy: 0.7124 - val_loss: 0.5635 - learning_rate: 6.3496e-06
# Epoch 75/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step - accuracy: 0.7351 - loss: 0.5557 - val_accuracy: 0.7124 - val_loss: 0.5627 - learning_rate: 6.3496e-06
# Epoch 76/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step - accuracy: 0.7424 - loss: 0.5800 - val_accuracy: 0.7146 - val_loss: 0.5604 - learning_rate: 6.3496e-06
# Epoch 77/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step - accuracy: 0.7193 - loss: 0.5795 - val_accuracy: 0.7101 - val_loss: 0.5644 - learning_rate: 6.3496e-06
# Epoch 78/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step - accuracy: 0.7395 - loss: 0.5539 - val_accuracy: 0.7124 - val_loss: 0.5627 - learning_rate: 6.3496e-06
# Epoch 79/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step - accuracy: 0.7423 - loss: 0.5463 - val_accuracy: 0.7146 - val_loss: 0.5618 - learning_rate: 6.3496e-06
# Epoch 80/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step - accuracy: 0.7415 - loss: 0.5651 - val_accuracy: 0.7124 - val_loss: 0.5628 - learning_rate: 6.3496e-06
# Epoch 81/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step - accuracy: 0.7345 - loss: 0.5593 - val_accuracy: 0.7146 - val_loss: 0.5620 - learning_rate: 6.3496e-06
# Epoch 82/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 784us/step - accuracy: 0.7313 - loss: 0.5691 - val_accuracy: 0.7146 - val_loss: 0.5606 - learning_rate: 6.3496e-06
# Epoch 83/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step - accuracy: 0.7435 - loss: 0.5621 - val_accuracy: 0.7124 - val_loss: 0.5618 - learning_rate: 6.3496e-06
# Epoch 84/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - accuracy: 0.7445 - loss: 0.5590 - val_accuracy: 0.7146 - val_loss: 0.5592 - learning_rate: 6.3496e-06
# Epoch 85/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step - accuracy: 0.7469 - loss: 0.5655 - val_accuracy: 0.7146 - val_loss: 0.5591 - learning_rate: 6.3496e-06
# Epoch 86/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 759us/step - accuracy: 0.7496 - loss: 0.5612 - val_accuracy: 0.7124 - val_loss: 0.5622 - learning_rate: 6.3496e-06
# Epoch 87/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step - accuracy: 0.7402 - loss: 0.5686 - val_accuracy: 0.7079 - val_loss: 0.5630 - learning_rate: 6.3496e-06
# Epoch 88/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 779us/step - accuracy: 0.7427 - loss: 0.5616 - val_accuracy: 0.7124 - val_loss: 0.5662 - learning_rate: 6.3496e-06
# Epoch 89/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 806us/step - accuracy: 0.7431 - loss: 0.5649 - val_accuracy: 0.7146 - val_loss: 0.5676 - learning_rate: 6.3496e-06
# Epoch 90/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 766us/step - accuracy: 0.7429 - loss: 0.5591 - val_accuracy: 0.7079 - val_loss: 0.5639 - learning_rate: 6.3496e-06
# Epoch 91/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - accuracy: 0.7442 - loss: 0.5643 - val_accuracy: 0.7079 - val_loss: 0.5645 - learning_rate: 6.3496e-06
# Epoch 92/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - accuracy: 0.7332 - loss: 0.5661 - val_accuracy: 0.7101 - val_loss: 0.5625 - learning_rate: 6.3496e-06
# Epoch 93/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step - accuracy: 0.7388 - loss: 0.5606 - val_accuracy: 0.7101 - val_loss: 0.5617 - learning_rate: 6.3496e-06
# Epoch 94/1100
#  86/112 ━━━━━━━━━━━━━━━━━━━━ 0s 593us/step - accuracy: 0.7439 - loss: 0.5626
# Epoch 94: ReduceLROnPlateau reducing learning rate to 5.039684085285258e-06.
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 828us/step - accuracy: 0.7410 - loss: 0.5648 - val_accuracy: 0.7101 - val_loss: 0.5625 - learning_rate: 6.3496e-06
# Epoch 95/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - accuracy: 0.7265 - loss: 0.5673 - val_accuracy: 0.7079 - val_loss: 0.5645 - learning_rate: 5.0397e-06
# Epoch 96/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 757us/step - accuracy: 0.7382 - loss: 0.5618 - val_accuracy: 0.7101 - val_loss: 0.5642 - learning_rate: 5.0397e-06
# Epoch 97/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 812us/step - accuracy: 0.7438 - loss: 0.5675 - val_accuracy: 0.7101 - val_loss: 0.5610 - learning_rate: 5.0397e-06
# Epoch 98/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 741us/step - accuracy: 0.7434 - loss: 0.5597 - val_accuracy: 0.7079 - val_loss: 0.5632 - learning_rate: 5.0397e-06
# Epoch 99/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step - accuracy: 0.7438 - loss: 0.5522 - val_accuracy: 0.7101 - val_loss: 0.5652 - learning_rate: 5.0397e-06
# Epoch 100/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - accuracy: 0.7333 - loss: 0.5565 - val_accuracy: 0.7101 - val_loss: 0.5650 - learning_rate: 5.0397e-06
# Epoch 101/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 824us/step - accuracy: 0.7295 - loss: 0.5703 - val_accuracy: 0.7101 - val_loss: 0.5631 - learning_rate: 5.0397e-06
# Epoch 102/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step - accuracy: 0.7313 - loss: 0.5565 - val_accuracy: 0.7101 - val_loss: 0.5644 - learning_rate: 5.0397e-06
# Epoch 103/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step - accuracy: 0.7430 - loss: 0.5633 - val_accuracy: 0.7079 - val_loss: 0.5604 - learning_rate: 5.0397e-06
# Epoch 104/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 757us/step - accuracy: 0.7487 - loss: 0.5667 - val_accuracy: 0.7101 - val_loss: 0.5652 - learning_rate: 5.0397e-06
# Epoch 105/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 712us/step - accuracy: 0.7354 - loss: 0.5593 - val_accuracy: 0.7079 - val_loss: 0.5634 - learning_rate: 5.0397e-06
# Epoch 106/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 820us/step - accuracy: 0.7393 - loss: 0.5630 - val_accuracy: 0.7101 - val_loss: 0.5646 - learning_rate: 5.0397e-06
# Epoch 107/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step - accuracy: 0.7484 - loss: 0.5557 - val_accuracy: 0.7101 - val_loss: 0.5643 - learning_rate: 5.0397e-06
# Epoch 108/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step - accuracy: 0.7431 - loss: 0.5683 - val_accuracy: 0.7101 - val_loss: 0.5641 - learning_rate: 5.0397e-06
# Epoch 109/1100
#  94/112 ━━━━━━━━━━━━━━━━━━━━ 0s 548us/step - accuracy: 0.7295 - loss: 0.5681
# Epoch 109: ReduceLROnPlateau reducing learning rate to 4.000000088243381e-06.
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 802us/step - accuracy: 0.7290 - loss: 0.5697 - val_accuracy: 0.7124 - val_loss: 0.5611 - learning_rate: 5.0397e-06
# Epoch 110/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 766us/step - accuracy: 0.7379 - loss: 0.5615 - val_accuracy: 0.7124 - val_loss: 0.5616 - learning_rate: 4.0000e-06
# Epoch 111/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step - accuracy: 0.7378 - loss: 0.5668 - val_accuracy: 0.7101 - val_loss: 0.5604 - learning_rate: 4.0000e-06
# Epoch 112/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step - accuracy: 0.7413 - loss: 0.5659 - val_accuracy: 0.7079 - val_loss: 0.5598 - learning_rate: 4.0000e-06
# Epoch 113/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 784us/step - accuracy: 0.7251 - loss: 0.5637 - val_accuracy: 0.7124 - val_loss: 0.5616 - learning_rate: 4.0000e-06
# Epoch 114/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 864us/step - accuracy: 0.7479 - loss: 0.5727 - val_accuracy: 0.7079 - val_loss: 0.5615 - learning_rate: 4.0000e-06
# Epoch 115/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step - accuracy: 0.7432 - loss: 0.5630 - val_accuracy: 0.7101 - val_loss: 0.5635 - learning_rate: 4.0000e-06
# Epoch 116/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 777us/step - accuracy: 0.7349 - loss: 0.5585 - val_accuracy: 0.7101 - val_loss: 0.5627 - learning_rate: 4.0000e-06
# Epoch 117/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 815us/step - accuracy: 0.7461 - loss: 0.5665 - val_accuracy: 0.7079 - val_loss: 0.5593 - learning_rate: 4.0000e-06
# Epoch 118/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - accuracy: 0.7442 - loss: 0.5554 - val_accuracy: 0.7079 - val_loss: 0.5583 - learning_rate: 4.0000e-06
# Epoch 119/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 732us/step - accuracy: 0.7300 - loss: 0.5642 - val_accuracy: 0.7101 - val_loss: 0.5576 - learning_rate: 4.0000e-06
# Epoch 120/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 778us/step - accuracy: 0.7494 - loss: 0.5589 - val_accuracy: 0.7079 - val_loss: 0.5601 - learning_rate: 4.0000e-06
# Epoch 121/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - accuracy: 0.7384 - loss: 0.5595 - val_accuracy: 0.7056 - val_loss: 0.5613 - learning_rate: 4.0000e-06
# Epoch 122/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 732us/step - accuracy: 0.7467 - loss: 0.5628 - val_accuracy: 0.7124 - val_loss: 0.5639 - learning_rate: 4.0000e-06
# Epoch 123/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 784us/step - accuracy: 0.7428 - loss: 0.5566 - val_accuracy: 0.7079 - val_loss: 0.5617 - learning_rate: 4.0000e-06
# Epoch 124/1100
#  96/112 ━━━━━━━━━━━━━━━━━━━━ 0s 526us/step - accuracy: 0.7414 - loss: 0.5746
# Epoch 124: ReduceLROnPlateau reducing learning rate to 3.174802095920795e-06.
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step - accuracy: 0.7401 - loss: 0.5750 - val_accuracy: 0.7056 - val_loss: 0.5608 - learning_rate: 4.0000e-06
# Epoch 125/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step - accuracy: 0.7450 - loss: 0.5641 - val_accuracy: 0.7079 - val_loss: 0.5604 - learning_rate: 3.1748e-06
# Epoch 126/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 712us/step - accuracy: 0.7503 - loss: 0.5702 - val_accuracy: 0.7079 - val_loss: 0.5612 - learning_rate: 3.1748e-06
# Epoch 127/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step - accuracy: 0.7504 - loss: 0.5488 - val_accuracy: 0.7124 - val_loss: 0.5632 - learning_rate: 3.1748e-06
# Epoch 128/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step - accuracy: 0.7434 - loss: 0.5625 - val_accuracy: 0.7101 - val_loss: 0.5631 - learning_rate: 3.1748e-06
# Epoch 129/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step - accuracy: 0.7381 - loss: 0.5494 - val_accuracy: 0.7124 - val_loss: 0.5634 - learning_rate: 3.1748e-06
# Epoch 130/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 820us/step - accuracy: 0.7413 - loss: 0.5559 - val_accuracy: 0.7124 - val_loss: 0.5626 - learning_rate: 3.1748e-06
# Epoch 131/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 712us/step - accuracy: 0.7426 - loss: 0.5676 - val_accuracy: 0.7124 - val_loss: 0.5624 - learning_rate: 3.1748e-06
# Epoch 132/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step - accuracy: 0.7416 - loss: 0.5553 - val_accuracy: 0.7079 - val_loss: 0.5621 - learning_rate: 3.1748e-06
# Epoch 133/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 728us/step - accuracy: 0.7489 - loss: 0.5608 - val_accuracy: 0.7101 - val_loss: 0.5625 - learning_rate: 3.1748e-06
# Epoch 134/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step - accuracy: 0.7483 - loss: 0.5454 - val_accuracy: 0.7124 - val_loss: 0.5629 - learning_rate: 3.1748e-06
# Epoch 135/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 772us/step - accuracy: 0.7412 - loss: 0.5652 - val_accuracy: 0.7079 - val_loss: 0.5614 - learning_rate: 3.1748e-06
# Epoch 136/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step - accuracy: 0.7439 - loss: 0.5625 - val_accuracy: 0.7079 - val_loss: 0.5614 - learning_rate: 3.1748e-06
# Epoch 137/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step - accuracy: 0.7409 - loss: 0.5651 - val_accuracy: 0.7079 - val_loss: 0.5605 - learning_rate: 3.1748e-06
# Epoch 138/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - accuracy: 0.7373 - loss: 0.5714 - val_accuracy: 0.7079 - val_loss: 0.5587 - learning_rate: 3.1748e-06
# Epoch 139/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 779us/step - accuracy: 0.7509 - loss: 0.5586 - val_accuracy: 0.7079 - val_loss: 0.5609 - learning_rate: 3.1748e-06
# Epoch 140/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 716us/step - accuracy: 0.7417 - loss: 0.5592 - val_accuracy: 0.7101 - val_loss: 0.5617 - learning_rate: 3.1748e-06
# Epoch 141/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 716us/step - accuracy: 0.7405 - loss: 0.5566 - val_accuracy: 0.7056 - val_loss: 0.5603 - learning_rate: 3.1748e-06
# Epoch 142/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step - accuracy: 0.7438 - loss: 0.5501 - val_accuracy: 0.7124 - val_loss: 0.5626 - learning_rate: 3.1748e-06
# Epoch 143/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 724us/step - accuracy: 0.7470 - loss: 0.5699 - val_accuracy: 0.7056 - val_loss: 0.5604 - learning_rate: 3.1748e-06
# Epoch 144/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 733us/step - accuracy: 0.7294 - loss: 0.5553 - val_accuracy: 0.7079 - val_loss: 0.5599 - learning_rate: 3.1748e-06
# Epoch 145/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 767us/step - accuracy: 0.7394 - loss: 0.5702 - val_accuracy: 0.7079 - val_loss: 0.5597 - learning_rate: 3.1748e-06
# Epoch 146/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 856us/step - accuracy: 0.7463 - loss: 0.5603 - val_accuracy: 0.7079 - val_loss: 0.5594 - learning_rate: 3.1748e-06
# Epoch 147/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step - accuracy: 0.7266 - loss: 0.5657 - val_accuracy: 0.7079 - val_loss: 0.5601 - learning_rate: 3.1748e-06
# Epoch 148/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 758us/step - accuracy: 0.7449 - loss: 0.5626 - val_accuracy: 0.7079 - val_loss: 0.5597 - learning_rate: 3.1748e-06
# Epoch 149/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step - accuracy: 0.7368 - loss: 0.5671 - val_accuracy: 0.7079 - val_loss: 0.5601 - learning_rate: 3.1748e-06
# Epoch 150/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 797us/step - accuracy: 0.7495 - loss: 0.5579 - val_accuracy: 0.7101 - val_loss: 0.5624 - learning_rate: 3.1748e-06
# Epoch 151/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 784us/step - accuracy: 0.7397 - loss: 0.5639 - val_accuracy: 0.7101 - val_loss: 0.5626 - learning_rate: 3.1748e-06
# Epoch 152/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 795us/step - accuracy: 0.7457 - loss: 0.5586 - val_accuracy: 0.7079 - val_loss: 0.5615 - learning_rate: 3.1748e-06
# Epoch 153/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 804us/step - accuracy: 0.7380 - loss: 0.5641 - val_accuracy: 0.7079 - val_loss: 0.5612 - learning_rate: 3.1748e-06
# Epoch 154/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 757us/step - accuracy: 0.7518 - loss: 0.5554 - val_accuracy: 0.7056 - val_loss: 0.5608 - learning_rate: 3.1748e-06
# Epoch 155/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step - accuracy: 0.7425 - loss: 0.5614 - val_accuracy: 0.7056 - val_loss: 0.5601 - learning_rate: 3.1748e-06
# Epoch 156/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 819us/step - accuracy: 0.7343 - loss: 0.5719 - val_accuracy: 0.7056 - val_loss: 0.5617 - learning_rate: 3.1748e-06
# Epoch 157/1100
#  93/112 ━━━━━━━━━━━━━━━━━━━━ 0s 543us/step - accuracy: 0.7409 - loss: 0.5632
# Epoch 157: ReduceLROnPlateau reducing learning rate to 2.519842042642629e-06.
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step - accuracy: 0.7396 - loss: 0.5644 - val_accuracy: 0.7056 - val_loss: 0.5604 - learning_rate: 3.1748e-06
# Epoch 158/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step - accuracy: 0.7385 - loss: 0.5467 - val_accuracy: 0.7056 - val_loss: 0.5602 - learning_rate: 2.5198e-06
# Epoch 159/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step - accuracy: 0.7314 - loss: 0.5608 - val_accuracy: 0.7056 - val_loss: 0.5608 - learning_rate: 2.5198e-06
# Epoch 160/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 846us/step - accuracy: 0.7340 - loss: 0.5595 - val_accuracy: 0.7056 - val_loss: 0.5608 - learning_rate: 2.5198e-06
# Epoch 161/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step - accuracy: 0.7502 - loss: 0.5609 - val_accuracy: 0.7056 - val_loss: 0.5613 - learning_rate: 2.5198e-06
# Epoch 162/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step - accuracy: 0.7463 - loss: 0.5586 - val_accuracy: 0.7056 - val_loss: 0.5613 - learning_rate: 2.5198e-06
# Epoch 163/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 712us/step - accuracy: 0.7528 - loss: 0.5534 - val_accuracy: 0.7079 - val_loss: 0.5622 - learning_rate: 2.5198e-06
# Epoch 164/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step - accuracy: 0.7471 - loss: 0.5617 - val_accuracy: 0.7056 - val_loss: 0.5615 - learning_rate: 2.5198e-06
# Epoch 165/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step - accuracy: 0.7298 - loss: 0.5571 - val_accuracy: 0.7079 - val_loss: 0.5621 - learning_rate: 2.5198e-06
# Epoch 166/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 833us/step - accuracy: 0.7388 - loss: 0.5582 - val_accuracy: 0.7079 - val_loss: 0.5626 - learning_rate: 2.5198e-06
# Epoch 167/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 824us/step - accuracy: 0.7413 - loss: 0.5607 - val_accuracy: 0.7079 - val_loss: 0.5621 - learning_rate: 2.5198e-06
# Epoch 168/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 776us/step - accuracy: 0.7404 - loss: 0.5574 - val_accuracy: 0.7101 - val_loss: 0.5637 - learning_rate: 2.5198e-06
# Epoch 169/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 766us/step - accuracy: 0.7426 - loss: 0.5518 - val_accuracy: 0.7124 - val_loss: 0.5645 - learning_rate: 2.5198e-06
# Epoch 170/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step - accuracy: 0.7349 - loss: 0.5488 - val_accuracy: 0.7101 - val_loss: 0.5637 - learning_rate: 2.5198e-06
# Epoch 171/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step - accuracy: 0.7334 - loss: 0.5547 - val_accuracy: 0.7056 - val_loss: 0.5613 - learning_rate: 2.5198e-06
# Epoch 172/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 724us/step - accuracy: 0.7306 - loss: 0.5666 - val_accuracy: 0.7079 - val_loss: 0.5620 - learning_rate: 2.5198e-06
# Epoch 173/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 716us/step - accuracy: 0.7373 - loss: 0.5573 - val_accuracy: 0.7056 - val_loss: 0.5613 - learning_rate: 2.5198e-06
# Epoch 174/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 711us/step - accuracy: 0.7324 - loss: 0.5665 - val_accuracy: 0.7079 - val_loss: 0.5618 - learning_rate: 2.5198e-06
# Epoch 175/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 806us/step - accuracy: 0.7431 - loss: 0.5545 - val_accuracy: 0.7079 - val_loss: 0.5634 - learning_rate: 2.5198e-06
# Epoch 176/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step - accuracy: 0.7321 - loss: 0.5576 - val_accuracy: 0.7079 - val_loss: 0.5626 - learning_rate: 2.5198e-06
# Epoch 177/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 766us/step - accuracy: 0.7415 - loss: 0.5538 - val_accuracy: 0.7056 - val_loss: 0.5619 - learning_rate: 2.5198e-06
# Epoch 178/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step - accuracy: 0.7407 - loss: 0.5581 - val_accuracy: 0.7079 - val_loss: 0.5625 - learning_rate: 2.5198e-06
# Epoch 179/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step - accuracy: 0.7432 - loss: 0.5599 - val_accuracy: 0.7079 - val_loss: 0.5603 - learning_rate: 2.5198e-06
# Epoch 180/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - accuracy: 0.7361 - loss: 0.5622 - val_accuracy: 0.7079 - val_loss: 0.5606 - learning_rate: 2.5198e-06
# Epoch 181/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step - accuracy: 0.7485 - loss: 0.5557 - val_accuracy: 0.7079 - val_loss: 0.5613 - learning_rate: 2.5198e-06
# Epoch 182/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 758us/step - accuracy: 0.7252 - loss: 0.5673 - val_accuracy: 0.7079 - val_loss: 0.5600 - learning_rate: 2.5198e-06
# Epoch 183/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step - accuracy: 0.7537 - loss: 0.5542 - val_accuracy: 0.7056 - val_loss: 0.5615 - learning_rate: 2.5198e-06
# Epoch 184/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step - accuracy: 0.7414 - loss: 0.5594 - val_accuracy: 0.7056 - val_loss: 0.5604 - learning_rate: 2.5198e-06
# Epoch 185/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step - accuracy: 0.7466 - loss: 0.5561 - val_accuracy: 0.7056 - val_loss: 0.5610 - learning_rate: 2.5198e-06
# Epoch 186/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step - accuracy: 0.7400 - loss: 0.5614 - val_accuracy: 0.7079 - val_loss: 0.5622 - learning_rate: 2.5198e-06
# Epoch 187/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step - accuracy: 0.7316 - loss: 0.5566 - val_accuracy: 0.7079 - val_loss: 0.5630 - learning_rate: 2.5198e-06
# Epoch 188/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 942us/step - accuracy: 0.7376 - loss: 0.5550 - val_accuracy: 0.7079 - val_loss: 0.5621 - learning_rate: 2.5198e-06
# Epoch 189/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - accuracy: 0.7420 - loss: 0.5597 - val_accuracy: 0.7079 - val_loss: 0.5622 - learning_rate: 2.5198e-06
# Epoch 190/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 741us/step - accuracy: 0.7577 - loss: 0.5542 - val_accuracy: 0.7079 - val_loss: 0.5613 - learning_rate: 2.5198e-06
# Epoch 191/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 732us/step - accuracy: 0.7425 - loss: 0.5525 - val_accuracy: 0.7056 - val_loss: 0.5603 - learning_rate: 2.5198e-06
# Epoch 192/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step - accuracy: 0.7468 - loss: 0.5547 - val_accuracy: 0.7056 - val_loss: 0.5603 - learning_rate: 2.5198e-06
# Epoch 193/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 741us/step - accuracy: 0.7421 - loss: 0.5464 - val_accuracy: 0.7056 - val_loss: 0.5606 - learning_rate: 2.5198e-06
# Epoch 194/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step - accuracy: 0.7372 - loss: 0.5457 - val_accuracy: 0.7079 - val_loss: 0.5591 - learning_rate: 2.5198e-06
# Epoch 195/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - accuracy: 0.7456 - loss: 0.5543 - val_accuracy: 0.7056 - val_loss: 0.5599 - learning_rate: 2.5198e-06
# Epoch 196/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 779us/step - accuracy: 0.7486 - loss: 0.5656 - val_accuracy: 0.7056 - val_loss: 0.5607 - learning_rate: 2.5198e-06
# Epoch 197/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step - accuracy: 0.7427 - loss: 0.5611 - val_accuracy: 0.7056 - val_loss: 0.5614 - learning_rate: 2.5198e-06
# Epoch 198/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 809us/step - accuracy: 0.7448 - loss: 0.5650 - val_accuracy: 0.7056 - val_loss: 0.5612 - learning_rate: 2.5198e-06
# Epoch 199/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 785us/step - accuracy: 0.7380 - loss: 0.5626 - val_accuracy: 0.7079 - val_loss: 0.5622 - learning_rate: 2.5198e-06
# Epoch 200/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step - accuracy: 0.7445 - loss: 0.5524 - val_accuracy: 0.7079 - val_loss: 0.5643 - learning_rate: 2.5198e-06
# Epoch 201/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step - accuracy: 0.7363 - loss: 0.5543 - val_accuracy: 0.7056 - val_loss: 0.5612 - learning_rate: 2.5198e-06
# Epoch 202/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 758us/step - accuracy: 0.7356 - loss: 0.5510 - val_accuracy: 0.7079 - val_loss: 0.5620 - learning_rate: 2.5198e-06
# Epoch 203/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 767us/step - accuracy: 0.7455 - loss: 0.5623 - val_accuracy: 0.7079 - val_loss: 0.5616 - learning_rate: 2.5198e-06
# Epoch 204/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step - accuracy: 0.7374 - loss: 0.5617 - val_accuracy: 0.7079 - val_loss: 0.5626 - learning_rate: 2.5198e-06
# Epoch 205/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step - accuracy: 0.7375 - loss: 0.5533 - val_accuracy: 0.7079 - val_loss: 0.5625 - learning_rate: 2.5198e-06
# Epoch 206/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step - accuracy: 0.7376 - loss: 0.5550 - val_accuracy: 0.7079 - val_loss: 0.5631 - learning_rate: 2.5198e-06
# Epoch 207/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 779us/step - accuracy: 0.7438 - loss: 0.5499 - val_accuracy: 0.7079 - val_loss: 0.5615 - learning_rate: 2.5198e-06
# Epoch 208/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 767us/step - accuracy: 0.7410 - loss: 0.5427 - val_accuracy: 0.7079 - val_loss: 0.5631 - learning_rate: 2.5198e-06
# Epoch 209/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 768us/step - accuracy: 0.7419 - loss: 0.5577 - val_accuracy: 0.7056 - val_loss: 0.5608 - learning_rate: 2.5198e-06
# Epoch 210/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 767us/step - accuracy: 0.7351 - loss: 0.5661 - val_accuracy: 0.7056 - val_loss: 0.5606 - learning_rate: 2.5198e-06
# Epoch 211/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 776us/step - accuracy: 0.7421 - loss: 0.5577 - val_accuracy: 0.7079 - val_loss: 0.5617 - learning_rate: 2.5198e-06
# Epoch 212/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step - accuracy: 0.7373 - loss: 0.5538 - val_accuracy: 0.7079 - val_loss: 0.5627 - learning_rate: 2.5198e-06
# Epoch 213/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step - accuracy: 0.7447 - loss: 0.5526 - val_accuracy: 0.7079 - val_loss: 0.5632 - learning_rate: 2.5198e-06
# Epoch 214/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 788us/step - accuracy: 0.7495 - loss: 0.5534 - val_accuracy: 0.7079 - val_loss: 0.5629 - learning_rate: 2.5198e-06
# Epoch 215/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7393 - loss: 0.5652 - val_accuracy: 0.7056 - val_loss: 0.5613 - learning_rate: 2.5198e-06
# Epoch 216/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7482 - loss: 0.5601 - val_accuracy: 0.7079 - val_loss: 0.5598 - learning_rate: 2.5198e-06
# Epoch 217/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7429 - loss: 0.5728 - val_accuracy: 0.7079 - val_loss: 0.5595 - learning_rate: 2.5198e-06
# Epoch 218/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7383 - loss: 0.5558 - val_accuracy: 0.7056 - val_loss: 0.5608 - learning_rate: 2.5198e-06
# Epoch 219/1100
# 103/112 ━━━━━━━━━━━━━━━━━━━━ 0s 985us/step - accuracy: 0.7433 - loss: 0.5515
# Epoch 219: ReduceLROnPlateau reducing learning rate to 2.0000000441216903e-06.
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7423 - loss: 0.5528 - val_accuracy: 0.7056 - val_loss: 0.5611 - learning_rate: 2.5198e-06
# Epoch 220/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7420 - loss: 0.5642 - val_accuracy: 0.7056 - val_loss: 0.5609 - learning_rate: 2.0000e-06
# Epoch 221/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7400 - loss: 0.5603 - val_accuracy: 0.7079 - val_loss: 0.5607 - learning_rate: 2.0000e-06
# Epoch 222/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7383 - loss: 0.5525 - val_accuracy: 0.7079 - val_loss: 0.5606 - learning_rate: 2.0000e-06
# Epoch 223/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7446 - loss: 0.5589 - val_accuracy: 0.7079 - val_loss: 0.5604 - learning_rate: 2.0000e-06
# Epoch 224/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7507 - loss: 0.5597 - val_accuracy: 0.7079 - val_loss: 0.5601 - learning_rate: 2.0000e-06
# Epoch 225/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7427 - loss: 0.5668 - val_accuracy: 0.7079 - val_loss: 0.5602 - learning_rate: 2.0000e-06
# Epoch 226/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7407 - loss: 0.5633 - val_accuracy: 0.7079 - val_loss: 0.5610 - learning_rate: 2.0000e-06
# Epoch 227/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7432 - loss: 0.5553 - val_accuracy: 0.7079 - val_loss: 0.5605 - learning_rate: 2.0000e-06
# Epoch 228/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7451 - loss: 0.5613 - val_accuracy: 0.7079 - val_loss: 0.5602 - learning_rate: 2.0000e-06
# Epoch 229/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7412 - loss: 0.5565 - val_accuracy: 0.7079 - val_loss: 0.5618 - learning_rate: 2.0000e-06
# Epoch 230/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7564 - loss: 0.5517 - val_accuracy: 0.7056 - val_loss: 0.5625 - learning_rate: 2.0000e-06
# Epoch 231/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7516 - loss: 0.5493 - val_accuracy: 0.7079 - val_loss: 0.5617 - learning_rate: 2.0000e-06
# Epoch 232/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7397 - loss: 0.5750 - val_accuracy: 0.7079 - val_loss: 0.5616 - learning_rate: 2.0000e-06
# Epoch 233/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7278 - loss: 0.5566 - val_accuracy: 0.7079 - val_loss: 0.5603 - learning_rate: 2.0000e-06
# Epoch 234/1100
#  96/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7381 - loss: 0.5619
# Epoch 234: ReduceLROnPlateau reducing learning rate to 1.5874010479603974e-06.
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7372 - loss: 0.5631 - val_accuracy: 0.7079 - val_loss: 0.5616 - learning_rate: 2.0000e-06
# Epoch 235/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7399 - loss: 0.5572 - val_accuracy: 0.7079 - val_loss: 0.5614 - learning_rate: 1.5874e-06
# Epoch 236/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7450 - loss: 0.5557 - val_accuracy: 0.7079 - val_loss: 0.5613 - learning_rate: 1.5874e-06
# Epoch 237/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7354 - loss: 0.5570 - val_accuracy: 0.7079 - val_loss: 0.5619 - learning_rate: 1.5874e-06
# Epoch 238/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7456 - loss: 0.5577 - val_accuracy: 0.7079 - val_loss: 0.5617 - learning_rate: 1.5874e-06
# Epoch 239/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7439 - loss: 0.5679 - val_accuracy: 0.7101 - val_loss: 0.5631 - learning_rate: 1.5874e-06
# Epoch 240/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7449 - loss: 0.5563 - val_accuracy: 0.7079 - val_loss: 0.5624 - learning_rate: 1.5874e-06
# Epoch 241/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7381 - loss: 0.5595 - val_accuracy: 0.7079 - val_loss: 0.5614 - learning_rate: 1.5874e-06
# Epoch 242/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7398 - loss: 0.5693 - val_accuracy: 0.7079 - val_loss: 0.5616 - learning_rate: 1.5874e-06
# Epoch 243/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7493 - loss: 0.5500 - val_accuracy: 0.7079 - val_loss: 0.5609 - learning_rate: 1.5874e-06
# Epoch 244/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7417 - loss: 0.5592 - val_accuracy: 0.7079 - val_loss: 0.5613 - learning_rate: 1.5874e-06
# Epoch 245/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7463 - loss: 0.5577 - val_accuracy: 0.7079 - val_loss: 0.5610 - learning_rate: 1.5874e-06
# Epoch 246/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7317 - loss: 0.5581 - val_accuracy: 0.7079 - val_loss: 0.5610 - learning_rate: 1.5874e-06
# Epoch 247/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7378 - loss: 0.5583 - val_accuracy: 0.7079 - val_loss: 0.5612 - learning_rate: 1.5874e-06
# Epoch 248/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7409 - loss: 0.5510 - val_accuracy: 0.7079 - val_loss: 0.5612 - learning_rate: 1.5874e-06
# Epoch 249/1100
#  94/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7451 - loss: 0.5590
# Epoch 249: ReduceLROnPlateau reducing learning rate to 1.2599210213213145e-06.
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7435 - loss: 0.5609 - val_accuracy: 0.7079 - val_loss: 0.5611 - learning_rate: 1.5874e-06
# Epoch 250/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7355 - loss: 0.5570 - val_accuracy: 0.7079 - val_loss: 0.5611 - learning_rate: 1.2599e-06
# Epoch 251/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7407 - loss: 0.5653 - val_accuracy: 0.7079 - val_loss: 0.5613 - learning_rate: 1.2599e-06
# Epoch 252/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7410 - loss: 0.5572 - val_accuracy: 0.7079 - val_loss: 0.5620 - learning_rate: 1.2599e-06
# Epoch 253/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7249 - loss: 0.5537 - val_accuracy: 0.7079 - val_loss: 0.5613 - learning_rate: 1.2599e-06
# Epoch 254/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7499 - loss: 0.5607 - val_accuracy: 0.7079 - val_loss: 0.5617 - learning_rate: 1.2599e-06
# Epoch 255/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7329 - loss: 0.5617 - val_accuracy: 0.7079 - val_loss: 0.5616 - learning_rate: 1.2599e-06
# Epoch 256/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7265 - loss: 0.5718 - val_accuracy: 0.7079 - val_loss: 0.5612 - learning_rate: 1.2599e-06
# Epoch 257/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7282 - loss: 0.5654 - val_accuracy: 0.7079 - val_loss: 0.5609 - learning_rate: 1.2599e-06
# Epoch 258/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7447 - loss: 0.5625 - val_accuracy: 0.7079 - val_loss: 0.5604 - learning_rate: 1.2599e-06
# Epoch 259/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7440 - loss: 0.5490 - val_accuracy: 0.7079 - val_loss: 0.5602 - learning_rate: 1.2599e-06
# Epoch 260/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7378 - loss: 0.5649 - val_accuracy: 0.7079 - val_loss: 0.5602 - learning_rate: 1.2599e-06
# Epoch 261/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7412 - loss: 0.5601 - val_accuracy: 0.7079 - val_loss: 0.5607 - learning_rate: 1.2599e-06
# Epoch 262/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7543 - loss: 0.5544 - val_accuracy: 0.7079 - val_loss: 0.5605 - learning_rate: 1.2599e-06
# Epoch 263/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7398 - loss: 0.5579 - val_accuracy: 0.7079 - val_loss: 0.5608 - learning_rate: 1.2599e-06
# Epoch 264/1100
# 105/112 ━━━━━━━━━━━━━━━━━━━━ 0s 966us/step - accuracy: 0.7365 - loss: 0.5582
# Epoch 264: ReduceLROnPlateau reducing learning rate to 1.0000000220608452e-06.
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7362 - loss: 0.5591 - val_accuracy: 0.7079 - val_loss: 0.5613 - learning_rate: 1.2599e-06
# Epoch 265/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7357 - loss: 0.5486 - val_accuracy: 0.7079 - val_loss: 0.5607 - learning_rate: 1.0000e-06
# Epoch 266/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7465 - loss: 0.5604 - val_accuracy: 0.7079 - val_loss: 0.5612 - learning_rate: 1.0000e-06
# Epoch 267/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7404 - loss: 0.5565 - val_accuracy: 0.7101 - val_loss: 0.5615 - learning_rate: 1.0000e-06
# Epoch 268/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7379 - loss: 0.5571 - val_accuracy: 0.7101 - val_loss: 0.5617 - learning_rate: 1.0000e-06
# Epoch 269/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7259 - loss: 0.5604 - val_accuracy: 0.7101 - val_loss: 0.5613 - learning_rate: 1.0000e-06
# Epoch 270/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7500 - loss: 0.5626 - val_accuracy: 0.7101 - val_loss: 0.5612 - learning_rate: 1.0000e-06
# Epoch 271/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7456 - loss: 0.5620 - val_accuracy: 0.7101 - val_loss: 0.5617 - learning_rate: 1.0000e-06
# Epoch 272/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7482 - loss: 0.5635 - val_accuracy: 0.7101 - val_loss: 0.5618 - learning_rate: 1.0000e-06
# Epoch 273/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7340 - loss: 0.5690 - val_accuracy: 0.7101 - val_loss: 0.5615 - learning_rate: 1.0000e-06
# Epoch 274/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7448 - loss: 0.5592 - val_accuracy: 0.7079 - val_loss: 0.5611 - learning_rate: 1.0000e-06
# Epoch 275/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7455 - loss: 0.5676 - val_accuracy: 0.7079 - val_loss: 0.5610 - learning_rate: 1.0000e-06
# Epoch 276/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7494 - loss: 0.5502 - val_accuracy: 0.7101 - val_loss: 0.5613 - learning_rate: 1.0000e-06
# Epoch 277/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7407 - loss: 0.5598 - val_accuracy: 0.7079 - val_loss: 0.5610 - learning_rate: 1.0000e-06
# Epoch 278/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7563 - loss: 0.5508 - val_accuracy: 0.7079 - val_loss: 0.5608 - learning_rate: 1.0000e-06
# Epoch 279/1100
# 101/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7507 - loss: 0.5526
# Epoch 279: ReduceLROnPlateau reducing learning rate to 7.937005239801987e-07.
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7499 - loss: 0.5543 - val_accuracy: 0.7079 - val_loss: 0.5609 - learning_rate: 1.0000e-06
# Epoch 280/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7461 - loss: 0.5558 - val_accuracy: 0.7079 - val_loss: 0.5607 - learning_rate: 7.9370e-07
# Epoch 281/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7398 - loss: 0.5578 - val_accuracy: 0.7079 - val_loss: 0.5603 - learning_rate: 7.9370e-07
# Epoch 282/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7584 - loss: 0.5638 - val_accuracy: 0.7079 - val_loss: 0.5604 - learning_rate: 7.9370e-07
# Epoch 283/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7440 - loss: 0.5546 - val_accuracy: 0.7079 - val_loss: 0.5601 - learning_rate: 7.9370e-07
# Epoch 284/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7514 - loss: 0.5550 - val_accuracy: 0.7079 - val_loss: 0.5601 - learning_rate: 7.9370e-07
# Epoch 285/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7444 - loss: 0.5572 - val_accuracy: 0.7079 - val_loss: 0.5604 - learning_rate: 7.9370e-07
# Epoch 286/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7322 - loss: 0.5630 - val_accuracy: 0.7079 - val_loss: 0.5600 - learning_rate: 7.9370e-07
# Epoch 287/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7481 - loss: 0.5466 - val_accuracy: 0.7079 - val_loss: 0.5593 - learning_rate: 7.9370e-07
# Epoch 288/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7444 - loss: 0.5664 - val_accuracy: 0.7079 - val_loss: 0.5601 - learning_rate: 7.9370e-07
# Epoch 289/1100
# ...
# Epoch 1003/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7446 - loss: 0.5493 - val_accuracy: 0.7101 - val_loss: 0.5580 - learning_rate: 5.0000e-07
# Epoch 1004/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7488 - loss: 0.5457 - val_accuracy: 0.7101 - val_loss: 0.5582 - learning_rate: 5.0000e-07
# Epoch 1005/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7321 - loss: 0.5571 - val_accuracy: 0.7101 - val_loss: 0.5581 - learning_rate: 5.0000e-07
# Epoch 1006/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7378 - loss: 0.5554 - val_accuracy: 0.7101 - val_loss: 0.5579 - learning_rate: 5.0000e-07
# Epoch 1007/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7358 - loss: 0.5605 - val_accuracy: 0.7101 - val_loss: 0.5576 - learning_rate: 5.0000e-07
# Epoch 1008/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7524 - loss: 0.5546 - val_accuracy: 0.7101 - val_loss: 0.5577 - learning_rate: 5.0000e-07
# Epoch 1009/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7476 - loss: 0.5450 - val_accuracy: 0.7101 - val_loss: 0.5576 - learning_rate: 5.0000e-07
# Epoch 1010/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7525 - loss: 0.5515 - val_accuracy: 0.7101 - val_loss: 0.5576 - learning_rate: 5.0000e-07
# Epoch 1011/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7477 - loss: 0.5581 - val_accuracy: 0.7101 - val_loss: 0.5578 - learning_rate: 5.0000e-07
# Epoch 1012/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7473 - loss: 0.5496 - val_accuracy: 0.7101 - val_loss: 0.5578 - learning_rate: 5.0000e-07
# Epoch 1013/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7489 - loss: 0.5543 - val_accuracy: 0.7101 - val_loss: 0.5578 - learning_rate: 5.0000e-07
# Epoch 1014/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7342 - loss: 0.5636 - val_accuracy: 0.7101 - val_loss: 0.5575 - learning_rate: 5.0000e-07
# Epoch 1015/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7506 - loss: 0.5573 - val_accuracy: 0.7101 - val_loss: 0.5577 - learning_rate: 5.0000e-07
# Epoch 1016/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7493 - loss: 0.5386 - val_accuracy: 0.7101 - val_loss: 0.5577 - learning_rate: 5.0000e-07
# Epoch 1017/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7480 - loss: 0.5560 - val_accuracy: 0.7101 - val_loss: 0.5580 - learning_rate: 5.0000e-07
# Epoch 1018/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7461 - loss: 0.5611 - val_accuracy: 0.7101 - val_loss: 0.5579 - learning_rate: 5.0000e-07
# Epoch 1019/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7513 - loss: 0.5683 - val_accuracy: 0.7101 - val_loss: 0.5583 - learning_rate: 5.0000e-07
# Epoch 1020/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7369 - loss: 0.5564 - val_accuracy: 0.7101 - val_loss: 0.5584 - learning_rate: 5.0000e-07
# Epoch 1021/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7486 - loss: 0.5628 - val_accuracy: 0.7101 - val_loss: 0.5582 - learning_rate: 5.0000e-07
# Epoch 1022/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7494 - loss: 0.5445 - val_accuracy: 0.7101 - val_loss: 0.5582 - learning_rate: 5.0000e-07
# Epoch 1023/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7643 - loss: 0.5410 - val_accuracy: 0.7101 - val_loss: 0.5579 - learning_rate: 5.0000e-07
# Epoch 1024/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7393 - loss: 0.5519 - val_accuracy: 0.7101 - val_loss: 0.5572 - learning_rate: 5.0000e-07
# Epoch 1025/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7507 - loss: 0.5570 - val_accuracy: 0.7124 - val_loss: 0.5570 - learning_rate: 5.0000e-07
# Epoch 1026/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7463 - loss: 0.5550 - val_accuracy: 0.7101 - val_loss: 0.5571 - learning_rate: 5.0000e-07
# Epoch 1027/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7470 - loss: 0.5612 - val_accuracy: 0.7101 - val_loss: 0.5573 - learning_rate: 5.0000e-07
# Epoch 1028/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7485 - loss: 0.5524 - val_accuracy: 0.7101 - val_loss: 0.5571 - learning_rate: 5.0000e-07
# Epoch 1029/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7413 - loss: 0.5528 - val_accuracy: 0.7101 - val_loss: 0.5571 - learning_rate: 5.0000e-07
# Epoch 1030/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7398 - loss: 0.5491 - val_accuracy: 0.7101 - val_loss: 0.5571 - learning_rate: 5.0000e-07
# Epoch 1031/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7444 - loss: 0.5547 - val_accuracy: 0.7124 - val_loss: 0.5571 - learning_rate: 5.0000e-07
# Epoch 1032/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7543 - loss: 0.5599 - val_accuracy: 0.7101 - val_loss: 0.5572 - learning_rate: 5.0000e-07
# Epoch 1033/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7425 - loss: 0.5501 - val_accuracy: 0.7124 - val_loss: 0.5569 - learning_rate: 5.0000e-07
# Epoch 1034/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7510 - loss: 0.5516 - val_accuracy: 0.7101 - val_loss: 0.5574 - learning_rate: 5.0000e-07
# Epoch 1035/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7494 - loss: 0.5488 - val_accuracy: 0.7101 - val_loss: 0.5573 - learning_rate: 5.0000e-07
# Epoch 1036/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7447 - loss: 0.5512 - val_accuracy: 0.7101 - val_loss: 0.5573 - learning_rate: 5.0000e-07
# Epoch 1037/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7524 - loss: 0.5662 - val_accuracy: 0.7101 - val_loss: 0.5577 - learning_rate: 5.0000e-07
# Epoch 1038/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7363 - loss: 0.5601 - val_accuracy: 0.7101 - val_loss: 0.5578 - learning_rate: 5.0000e-07
# Epoch 1039/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7387 - loss: 0.5569 - val_accuracy: 0.7101 - val_loss: 0.5577 - learning_rate: 5.0000e-07
# Epoch 1040/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7418 - loss: 0.5518 - val_accuracy: 0.7101 - val_loss: 0.5581 - learning_rate: 5.0000e-07
# Epoch 1041/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7538 - loss: 0.5519 - val_accuracy: 0.7101 - val_loss: 0.5582 - learning_rate: 5.0000e-07
# Epoch 1042/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7405 - loss: 0.5573 - val_accuracy: 0.7101 - val_loss: 0.5582 - learning_rate: 5.0000e-07
# Epoch 1043/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7408 - loss: 0.5564 - val_accuracy: 0.7101 - val_loss: 0.5579 - learning_rate: 5.0000e-07
# Epoch 1044/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7434 - loss: 0.5525 - val_accuracy: 0.7101 - val_loss: 0.5577 - learning_rate: 5.0000e-07
# Epoch 1045/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7485 - loss: 0.5514 - val_accuracy: 0.7101 - val_loss: 0.5575 - learning_rate: 5.0000e-07
# Epoch 1046/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7385 - loss: 0.5706 - val_accuracy: 0.7124 - val_loss: 0.5575 - learning_rate: 5.0000e-07
# Epoch 1047/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7407 - loss: 0.5525 - val_accuracy: 0.7124 - val_loss: 0.5574 - learning_rate: 5.0000e-07
# Epoch 1048/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7522 - loss: 0.5502 - val_accuracy: 0.7101 - val_loss: 0.5576 - learning_rate: 5.0000e-07
# Epoch 1049/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7419 - loss: 0.5545 - val_accuracy: 0.7101 - val_loss: 0.5580 - learning_rate: 5.0000e-07
# Epoch 1050/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7542 - loss: 0.5560 - val_accuracy: 0.7101 - val_loss: 0.5577 - learning_rate: 5.0000e-07
# Epoch 1051/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7363 - loss: 0.5538 - val_accuracy: 0.7101 - val_loss: 0.5577 - learning_rate: 5.0000e-07
# Epoch 1052/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7481 - loss: 0.5565 - val_accuracy: 0.7101 - val_loss: 0.5577 - learning_rate: 5.0000e-07
# Epoch 1053/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7491 - loss: 0.5620 - val_accuracy: 0.7101 - val_loss: 0.5577 - learning_rate: 5.0000e-07
# Epoch 1054/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7470 - loss: 0.5547 - val_accuracy: 0.7101 - val_loss: 0.5577 - learning_rate: 5.0000e-07
# Epoch 1055/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7421 - loss: 0.5435 - val_accuracy: 0.7101 - val_loss: 0.5580 - learning_rate: 5.0000e-07
# Epoch 1056/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7602 - loss: 0.5493 - val_accuracy: 0.7101 - val_loss: 0.5579 - learning_rate: 5.0000e-07
# Epoch 1057/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7480 - loss: 0.5544 - val_accuracy: 0.7101 - val_loss: 0.5583 - learning_rate: 5.0000e-07
# Epoch 1058/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7334 - loss: 0.5487 - val_accuracy: 0.7101 - val_loss: 0.5584 - learning_rate: 5.0000e-07
# Epoch 1059/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7433 - loss: 0.5531 - val_accuracy: 0.7101 - val_loss: 0.5584 - learning_rate: 5.0000e-07
# Epoch 1060/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7384 - loss: 0.5492 - val_accuracy: 0.7101 - val_loss: 0.5588 - learning_rate: 5.0000e-07
# Epoch 1061/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7406 - loss: 0.5516 - val_accuracy: 0.7101 - val_loss: 0.5589 - learning_rate: 5.0000e-07
# Epoch 1062/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7399 - loss: 0.5497 - val_accuracy: 0.7101 - val_loss: 0.5590 - learning_rate: 5.0000e-07
# Epoch 1063/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7308 - loss: 0.5654 - val_accuracy: 0.7101 - val_loss: 0.5586 - learning_rate: 5.0000e-07
# Epoch 1064/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7497 - loss: 0.5475 - val_accuracy: 0.7101 - val_loss: 0.5584 - learning_rate: 5.0000e-07
# Epoch 1065/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7529 - loss: 0.5527 - val_accuracy: 0.7101 - val_loss: 0.5585 - learning_rate: 5.0000e-07
# Epoch 1066/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7440 - loss: 0.5561 - val_accuracy: 0.7101 - val_loss: 0.5585 - learning_rate: 5.0000e-07
# Epoch 1067/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7320 - loss: 0.5654 - val_accuracy: 0.7101 - val_loss: 0.5585 - learning_rate: 5.0000e-07
# Epoch 1068/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7591 - loss: 0.5491 - val_accuracy: 0.7101 - val_loss: 0.5590 - learning_rate: 5.0000e-07
# Epoch 1069/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7567 - loss: 0.5636 - val_accuracy: 0.7101 - val_loss: 0.5588 - learning_rate: 5.0000e-07
# Epoch 1070/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7339 - loss: 0.5582 - val_accuracy: 0.7101 - val_loss: 0.5586 - learning_rate: 5.0000e-07
# Epoch 1071/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7377 - loss: 0.5652 - val_accuracy: 0.7101 - val_loss: 0.5585 - learning_rate: 5.0000e-07
# Epoch 1072/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7466 - loss: 0.5627 - val_accuracy: 0.7101 - val_loss: 0.5586 - learning_rate: 5.0000e-07
# Epoch 1073/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7422 - loss: 0.5596 - val_accuracy: 0.7101 - val_loss: 0.5584 - learning_rate: 5.0000e-07
# Epoch 1074/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7457 - loss: 0.5528 - val_accuracy: 0.7101 - val_loss: 0.5587 - learning_rate: 5.0000e-07
# Epoch 1075/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7283 - loss: 0.5596 - val_accuracy: 0.7101 - val_loss: 0.5589 - learning_rate: 5.0000e-07
# Epoch 1076/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.7523 - loss: 0.5515 - val_accuracy: 0.7101 - val_loss: 0.5588 - learning_rate: 5.0000e-07
# Epoch 1077/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7513 - loss: 0.5491 - val_accuracy: 0.7101 - val_loss: 0.5588 - learning_rate: 5.0000e-07
# Epoch 1078/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7304 - loss: 0.5491 - val_accuracy: 0.7101 - val_loss: 0.5584 - learning_rate: 5.0000e-07
# Epoch 1079/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7454 - loss: 0.5540 - val_accuracy: 0.7101 - val_loss: 0.5581 - learning_rate: 5.0000e-07
# Epoch 1080/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7481 - loss: 0.5526 - val_accuracy: 0.7101 - val_loss: 0.5582 - learning_rate: 5.0000e-07
# Epoch 1081/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7461 - loss: 0.5539 - val_accuracy: 0.7124 - val_loss: 0.5581 - learning_rate: 5.0000e-07
# Epoch 1082/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7392 - loss: 0.5557 - val_accuracy: 0.7124 - val_loss: 0.5579 - learning_rate: 5.0000e-07
# Epoch 1083/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7523 - loss: 0.5518 - val_accuracy: 0.7124 - val_loss: 0.5577 - learning_rate: 5.0000e-07
# Epoch 1084/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7411 - loss: 0.5547 - val_accuracy: 0.7124 - val_loss: 0.5577 - learning_rate: 5.0000e-07
# Epoch 1085/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7385 - loss: 0.5484 - val_accuracy: 0.7124 - val_loss: 0.5578 - learning_rate: 5.0000e-07
# Epoch 1086/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7384 - loss: 0.5461 - val_accuracy: 0.7124 - val_loss: 0.5572 - learning_rate: 5.0000e-07
# Epoch 1087/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7507 - loss: 0.5627 - val_accuracy: 0.7124 - val_loss: 0.5572 - learning_rate: 5.0000e-07
# Epoch 1088/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7484 - loss: 0.5539 - val_accuracy: 0.7124 - val_loss: 0.5572 - learning_rate: 5.0000e-07
# Epoch 1089/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7351 - loss: 0.5488 - val_accuracy: 0.7124 - val_loss: 0.5570 - learning_rate: 5.0000e-07
# Epoch 1090/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7418 - loss: 0.5582 - val_accuracy: 0.7124 - val_loss: 0.5575 - learning_rate: 5.0000e-07
# Epoch 1091/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7512 - loss: 0.5491 - val_accuracy: 0.7124 - val_loss: 0.5576 - learning_rate: 5.0000e-07
# Epoch 1092/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7483 - loss: 0.5519 - val_accuracy: 0.7124 - val_loss: 0.5572 - learning_rate: 5.0000e-07
# Epoch 1093/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7388 - loss: 0.5521 - val_accuracy: 0.7124 - val_loss: 0.5575 - learning_rate: 5.0000e-07
# Epoch 1094/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7493 - loss: 0.5579 - val_accuracy: 0.7124 - val_loss: 0.5575 - learning_rate: 5.0000e-07
# Epoch 1095/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7542 - loss: 0.5566 - val_accuracy: 0.7124 - val_loss: 0.5575 - learning_rate: 5.0000e-07
# Epoch 1096/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7468 - loss: 0.5551 - val_accuracy: 0.7124 - val_loss: 0.5576 - learning_rate: 5.0000e-07
# Epoch 1097/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7330 - loss: 0.5608 - val_accuracy: 0.7124 - val_loss: 0.5574 - learning_rate: 5.0000e-07
# Epoch 1098/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7602 - loss: 0.5476 - val_accuracy: 0.7146 - val_loss: 0.5569 - learning_rate: 5.0000e-07
# Epoch 1099/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7505 - loss: 0.5494 - val_accuracy: 0.7124 - val_loss: 0.5572 - learning_rate: 5.0000e-07
# Epoch 1100/1100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7481 - loss: 0.5596 - val_accuracy: 0.7146 - val_loss: 0.5567 - learning_rate: 5.0000e-07
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step
# Test Accuracy: 0.7321
# Test F1 Score: 0.7432
# Test Precision: 0.7138
# Test Recall: 0.7750
# Test ROC AUC Score: 0.8054
