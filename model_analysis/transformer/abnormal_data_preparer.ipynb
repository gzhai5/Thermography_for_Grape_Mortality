# %%
import numpy as np
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import cv2
import json
import imageio
import os
import pandas as pd
import random
import torch
import matplotlib.pyplot as plt
from datasets import Dataset
from utils.preprocessing import process_example
from pympler import asizeof
from collections import Counter
from data_augumentation.augument import augumentate
import mplcursors
from abnormals import abnormal_samples_21

# %%
# normalize the data to have same starting pt for all time series
# input shape: (n_samples, n_timepoints, width, height), want each samples - its mean of 0-30th timepts
def normalize_curves_mean_method(unnormalized_data):
    mean = np.mean(unnormalized_data[:30, :, :], axis=0, keepdims=True)
    normalized_data = np.maximum(unnormalized_data - mean, 0)
    assert normalized_data.shape == unnormalized_data.shape, 'Shape mismatch after normalization'
    return normalized_data

# %%
target_size = 21
target_cultivar = 'RIES'


round_numbers = [5, 6]
 # npy data path -> {'label': 0/1, 'cultivar': 'cultivar_name'}
total_video_map = {}



for round_number in round_numbers:
    roi_data_folder = f'C:/Users/Mud/Desktop/2ndPaper/roi_data/size-{target_size}/round_{round_number}/abnormal/'
    data_status_csv = f'C:/Users/Mud/Desktop/2ndPaper/roi_data/csv/stat_all_data_extend_mean_normalization_pca_round_{round_number}.csv'

   
    # Load the data status
    data_status = pd.read_csv(data_status_csv)
    data_status_this_round = data_status[data_status['dev_stage'] == round_number]


    # Load the data and append without flattening
    for index, row in data_status_this_round.iterrows():
        filename = row['filename']
        cultivar = row['cultivar']
        mortality = row['mortality']
        treatment = row['treatment']
        npy_data_path = f'{roi_data_folder}[ROI]{filename}'
        try:
            video_data = np.load(npy_data_path)

            if cultivar == target_cultivar:

                if 1 <= treatment < 5:
                    if mortality:
                        total_video_map[npy_data_path] = {'label': 1, 'cultivar': cultivar}
                    else:
                        total_video_map[npy_data_path] = {'label': 0, 'cultivar': cultivar}
                    print(f'Loaded {filename} with shape {video_data.shape}')
        except FileNotFoundError:
            print(f'File not found: {npy_data_path}, possibly an good data and not interesting for us')
# Out:
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B01_N06.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B02_N02.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B02_N05.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B02_N06.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B02_N08.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B02_N09.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B03_N01.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B03_N03.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B03_N04.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B03_N05.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B03_N06.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B03_N07.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B03_N08.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B04_N01.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B04_N02.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B04_N03.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B04_N06.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B04_N07.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B05_N07.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B05_N08.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B05_N09.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B06_N01.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B06_N02.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B06_N03.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B06_N04.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B06_N05.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B06_N06.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B06_N07.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B06_N08.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B06_N09.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B07_N01.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B07_N03.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B07_N04.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B07_N05.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B07_N06.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B07_N07.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B07_N08.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B08_N01.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B08_N03.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B08_N04.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B08_N05.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B08_N06.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B08_N07.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B08_N08.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B08_N09.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B09_N01.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B09_N02.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B09_N03.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B09_N04.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B09_N05.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B09_N06.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B09_N07.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B09_N08.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B09_N09.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B10_N01.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B10_N02.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B10_N03.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B10_N05.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B10_N06.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B10_N07.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B10_N08.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B10_N09.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B11_N01.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B11_N02.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B11_N03.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B11_N04.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B11_N05.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B11_N06.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B11_N07.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B11_N08.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B11_N09.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B12_N01.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B12_N02.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B12_N03.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B12_N04.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B12_N05.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B12_N06.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B12_N07.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B12_N08.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B12_N09.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B13_N02.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B13_N03.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B13_N04.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B13_N05.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B13_N06.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B13_N07.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B13_N08.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B13_N09.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B14_N01.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B14_N02.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B14_N03.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B14_N04.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B14_N05.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B14_N06.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B14_N08.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B14_N09.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B15_N01.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B15_N02.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B15_N03.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B15_N04.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B15_N07.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B15_N09.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B16_N01.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B16_N02.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B16_N03.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B16_N04.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B16_N05.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B16_N06.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B16_N07.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B16_N08.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B16_N09.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B17_N01.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B17_N02.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B17_N03.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B17_N04.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B17_N05.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B17_N06.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B17_N07.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B17_N08.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B17_N09.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B18_N01.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B18_N02.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B18_N03.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B18_N04.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B18_N05.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B18_N06.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B18_N07.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B18_N09.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B19_N01.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B19_N03.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B19_N04.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B19_N05.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B19_N06.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B19_N07.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B20_N01.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B20_N02.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B20_N03.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B20_N04.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B20_N05.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B20_N06.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B20_N07.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B20_N08.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B20_N09.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B21_N01.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B21_N02.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B21_N03.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B21_N04.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B21_N05.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B21_N06.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B21_N07.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B21_N08.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B21_N09.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B22_N01.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B22_N03.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B22_N04.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B22_N05.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B22_N06.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B22_N07.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B22_N09.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B23_N01.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B23_N02.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B23_N03.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B23_N04.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B23_N05.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B23_N06.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B23_N07.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B23_N08.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B23_N09.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B24_N01.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B24_N02.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B24_N03.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B24_N05.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B24_N06.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B24_N07.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B24_N08.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B25_N02.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B25_N03.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B25_N04.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B25_N05.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B25_N06.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B25_N07.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B25_N09.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B26_N01.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B26_N02.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B26_N03.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B26_N05.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B26_N06.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B26_N07.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B26_N08.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B27_N01.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B27_N02.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B27_N03.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B27_N04.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B27_N07.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B27_N08.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B27_N09.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B28_N01.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B28_N02.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B28_N04.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B28_N05.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B28_N07.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B28_N08.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B28_N09.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B29_N01.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B29_N02.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B29_N03.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B29_N04.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B29_N05.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B29_N06.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B29_N07.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B29_N08.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B29_N09.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B30_N02.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B30_N04.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B30_N05.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B30_N06.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B30_N08.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.0_B30_N09.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B31_N01.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B31_N02.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B31_N03.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B31_N04.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B31_N05.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B31_N06.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B31_N07.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B31_N08.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B31_N09.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B32_N02.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B32_N03.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B32_N04.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B32_N05.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B32_N06.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B32_N07.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B32_N08.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B32_N09.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B33_N02.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B33_N03.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B33_N04.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B33_N05.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B33_N06.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B33_N07.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B33_N08.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B33_N09.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B34_N01.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B34_N02.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B34_N03.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B34_N04.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B34_N05.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B34_N06.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B34_N07.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B34_N08.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B34_N09.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B35_N01.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B35_N02.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B35_N03.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B35_N04.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B35_N05.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B35_N06.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B35_N07.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B35_N08.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B35_N09.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B36_N01.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B36_N02.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B36_N03.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B36_N04.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B36_N05.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B36_N06.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B36_N07.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B36_N08.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B36_N09.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B37_N01.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B37_N02.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B37_N03.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B37_N04.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B37_N05.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B37_N06.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B37_N07.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B37_N09.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B38_N01.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B38_N02.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B38_N03.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B38_N04.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B38_N05.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B38_N06.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B38_N08.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B38_N09.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B39_N01.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B39_N02.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B39_N03.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B39_N04.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B39_N05.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B39_N06.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B39_N07.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B39_N08.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B39_N09.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B40_N01.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B40_N02.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B40_N03.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B40_N04.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B40_N05.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B40_N06.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B40_N07.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B40_N08.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B40_N09.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B41_N01.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B41_N02.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B41_N03.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B41_N04.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B41_N05.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B41_N06.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B41_N07.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B41_N08.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_5/abnormal/[ROI]CF5.1F_B41_N09.npy, possibly an good data and not interesting for us
# ...
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B35_N07.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B35_N09.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B36_N02.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B36_N04.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B36_N05.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B36_N06.npy, possibly an good data and not interesting for us
# Loaded Ries6.1F_B37_N01.npy with shape (600, 21, 21)
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B37_N02.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B37_N03.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B37_N04.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B37_N05.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B37_N06.npy, possibly an good data and not interesting for us
# Loaded Ries6.1F_B37_N07.npy with shape (600, 21, 21)
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B37_N08.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B37_N09.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B38_N01.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B38_N03.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B38_N04.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B38_N05.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B38_N06.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B38_N07.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B38_N08.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B39_N01.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B39_N02.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B39_N03.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B39_N04.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B39_N05.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B39_N06.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B39_N07.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B39_N08.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B39_N09.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B40_N05.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B40_N06.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B40_N09.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B41_N03.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B41_N05.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B41_N06.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B41_N07.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B41_N08.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B41_N09.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B42_N02.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B42_N04.npy, possibly an good data and not interesting for us
# Loaded Ries6.1F_B42_N05.npy with shape (600, 21, 21)
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B42_N07.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B42_N08.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B42_N09.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B43_N01.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B43_N02.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B43_N03.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B43_N04.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B43_N05.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B43_N06.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B43_N07.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B43_N08.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B43_N09.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B44_N01.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B44_N02.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B44_N04.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B44_N05.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B44_N06.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B44_N07.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B44_N09.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B45_N01.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B45_N02.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B45_N03.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B45_N04.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B45_N05.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B45_N06.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B45_N07.npy, possibly an good data and not interesting for us
# Loaded Ries6.1F_B45_N08.npy with shape (600, 21, 21)
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.1F_B45_N09.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.5F_B46_N01.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.5F_B46_N02.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.5F_B46_N03.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.5F_B46_N04.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.5F_B46_N06.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.5F_B46_N07.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.5F_B46_N08.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.5F_B46_N09.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.5F_B47_N01.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.5F_B47_N02.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.5F_B47_N04.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.5F_B47_N05.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.5F_B47_N06.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.5F_B47_N07.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.5F_B47_N08.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.5F_B47_N09.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.5F_B48_N01.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.5F_B48_N02.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.5F_B48_N03.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.5F_B48_N04.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.5F_B48_N05.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.5F_B48_N06.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.5F_B48_N07.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.5F_B48_N08.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.5F_B48_N09.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.5F_B49_N01.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.5F_B49_N02.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.5F_B49_N03.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.5F_B49_N04.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.5F_B49_N05.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.5F_B49_N06.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.5F_B49_N07.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.5F_B49_N08.npy, possibly an good data and not interesting for us
# File not found: C:/Users/Mud/Desktop/2ndPaper/roi_data/size-21/round_6/abnormal/[ROI]Ries6.5F_B49_N09.npy, possibly an good data and not interesting for us

# %%
print('shape of total_video_map:', len(total_video_map.values()))
# Out:
# shape of total_video_map: 38

# %%
# cultivar-specific data
video_paths = list(total_video_map.keys())
labels = [total_video_map[path]['label'] for path in video_paths]
X = pd.DataFrame(index=video_paths)  # empty DataFrame with video paths as index
y = pd.Series(labels, index=video_paths)
test_videos, test_labels = X, y
test_video_to_label_map = test_labels.to_dict()

print('Test:', test_videos.shape, test_labels.shape)

# Count class distribution
print("\nClass distribution:")
print("\nTest:")
print(test_labels.value_counts())
# Out:
# Test: (38, 0) (38,)
#
# Class distribution:
#
# Test:
# 1    24
# 0    14
# Name: count, dtype: int64

# %%
# %matplotlib widget

def normalize_curve_mean_method1(input_data):
    mean = np.mean(input_data[:30])
    normalized_data = np.maximum(input_data - mean, 0)
    return normalized_data


def visualizer(label_map, random_state=42, random_pick_num=-1):
    video_paths = list(label_map.keys())
    total_samples = len(video_paths)

    # Randomly sample video paths
    random.seed(random_state)
    if random_pick_num == -1:
        random_pick_num = total_samples
    sampled_paths = random.sample(video_paths, min(random_pick_num, total_samples))

    plt.figure(figsize=(10, 5))
    lines = []
    for video_path in sampled_paths:
        video_array = np.load(video_path)
        video_curve = np.mean(video_array, axis=(1, 2))
        video_curve = normalize_curve_mean_method1(video_curve)
        label = label_map[video_path]
        line, = plt.plot(
            video_curve,
            color={0: 'blue', 1: 'red'}.get(label),
            alpha=0.5
        )
        line._video_path = video_path  # Attach metadata
        lines.append(line)

    plt.xlabel('Frame')
    plt.ylabel('Mean Value')
    plt.title('Time-Series Curves of Randomly Picked Videos')

    # Add hover annotations
    cursor = mplcursors.cursor(lines, hover=True)
    @cursor.connect("add")
    def on_add(sel):
        sel.annotation.set(text=f"{os.path.basename(sel.artist._video_path)}")

    plt.tight_layout()
    plt.show()

# %%
visualizer(test_video_to_label_map, random_state=42, random_pick_num=-1)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
min_max_dict = {
    "CF": [0.0, 832.1333333333332],
    "CON": [0.0, 758.1333333333332],
    "PN": [0.0, 1003.8666666666668],
    "RIES": [0.0, 1132.3999999999996],
}
global_min, global_max = min_max_dict[target_cultivar][0], min_max_dict[target_cultivar][1]
print(f'Global min: {global_min}, Global max: {global_max}')

def prepare_data(video_to_label_map, data_type='train'):
    # Compute global min and max across all videos
    pixel_values = [np.load(path) for path in video_to_label_map]
    pixel_values = [normalize_curves_mean_method(video) for video in pixel_values]

    # Normalize and convert videos
    data = []
    for video, (video_path, label) in zip(pixel_values, video_to_label_map.items()):
        normalized = ((video - global_min) / (global_max - global_min) * 255).astype(np.uint8)
        rgb_video = np.stack([cv2.cvtColor(frame, cv2.COLOR_GRAY2RGB) for frame in normalized], axis=0)
        data.append({'video': rgb_video, 'labels': label})

    # find the max/min val of all pixels in the video
    mins, maxs = [], []
    for video in data:
        rgb_video = video['video']
        mins.append(rgb_video.min())
        maxs.append(rgb_video.max())
    print(f'Min of all videos: {min(mins)}, Max of all videos: {max(maxs)}')
    return data

test_video_dict_list = prepare_data(test_video_to_label_map, data_type='test')
# Out:
# Global min: 0.0, Global max: 1132.3999999999996
# Min of all videos: 0, Max of all videos: 200

# %%
def visualizer2(video_dict_list, random_state=42, random_pick_num=-1):
    total_samples = len(video_dict_list)

    # Randomly select indices
    random.seed(random_state)
    if random_pick_num == -1:
        random_pick_num = total_samples
    indices = random.sample(range(total_samples), min(random_pick_num, total_samples))

    plt.figure(figsize=(10, 5))
    for idx in indices:
        video_dict = video_dict_list[idx]['video']
        label = video_dict_list[idx]['labels']
        video_curve = np.mean(video_dict_list[idx]['video'], axis=(1, 2, 3))
        plt.plot(video_curve, color={0: 'blue', 1: 'red'}.get(label), alpha=0.5, label=f'dead' if label == 0 else 'alive')
    plt.xlabel('Frame')
    plt.ylabel('Mean Value')
    plt.title('Time-Series Curves of Randomly Picked Videos')

    # Deduplicate legend entries
    handles, labels_unique = plt.gca().get_legend_handles_labels()
    by_label = dict(zip(labels_unique, handles))
    plt.legend(by_label.values(), by_label.keys(), title="Labels", bbox_to_anchor=(1.05, 1), loc='upper left')

    plt.tight_layout()
    plt.show()

visualizer2(test_video_dict_list, random_state=42)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
mins, maxs = [], []
for video_dict in test_video_dict_list:
    data = video_dict['video']
    data = np.concatenate(data, axis=0)
    mins.append(data.min())
    maxs.append(data.max())
print(f'Min of all videos: {min(mins)}, Max of all videos: {max(maxs)}')
# Out:
# Min of all videos: 0, Max of all videos: 200

# %%
def downsample_video(video_dict, target_total_frames=600):
    if target_total_frames == 600:
        return video_dict['video']
    video = video_dict['video']
    total_frames = video.shape[0]
    # Downsample by taking every nth frame
    step = total_frames // target_total_frames
    video = video[::step][:target_total_frames]
    return video

def find_max_min(video_dict):
    data = [video_dict['video']]
    data = np.concatenate(data, axis=0)
    print(f'Min of all videos: {data.min()}, Max of all videos: {data.max()}')

def find_max_min1(processed):
    data = processed['pixel_values']
    print(f'Min of all videos: {data.min()}, Max of all videos: {data.max()}')

def create_pytorch_ds_and_store(video_dict_list, save_dir, type):
    os.makedirs(save_dir, exist_ok=True)
    metadata = []

    # Downsample videos
    for video_dict in tqdm(video_dict_list, desc=f"Downsampling {type} data"):
        video_dict['video'] = downsample_video(video_dict, target_total_frames=60)


    # Create Dataset object
    for i, video_dict in enumerate(tqdm(video_dict_list, desc=f"Processing {type} data using image-processer and saving")):
        # find_max_min(video_dict)
        processed = process_example(video_dict)
        processed["pixel_values"] = processed["pixel_values"].squeeze(0) # remove batch dimension [1, T, C, H, W] → [T, C, H, W]
        # find_max_min1(processed)
        file_path = os.path.join(save_dir, f"sample_{i}.pt")
        torch.save({
            "pixel_values": processed["pixel_values"],  # [600, 3, 224, 224]
            "labels": processed["labels"]
        }, file_path)
        metadata.append({ "path": file_path })
        

    with open(os.path.join(save_dir, "metadata.json"), "w") as f:
        json.dump(metadata, f)



test_dataset = create_pytorch_ds_and_store(test_video_dict_list, save_dir=f'./refined_data_{target_size}/{target_cultivar}/frame-60/abnormal/test', type='test')
# Out:
# Downsampling test data: 100%|██████████| 38/38 [00:00<?, ?it/s]
# Processing test data using image-processer and saving: 100%|██████████| 38/38 [00:23<00:00,  1.65it/s]

# %%
class VideoDiskDataset(torch.utils.data.Dataset):
    def __init__(self, metadata_path):
        with open(metadata_path, "r") as f:
            self.metadata = json.load(f)

    def __len__(self):
        return len(self.metadata)

    def __getitem__(self, idx):
        item = torch.load(self.metadata[idx]["path"])
        return {
            "pixel_values": item["pixel_values"],  # shape: [T, 3, 224, 224]
            "labels": item["labels"]
        }

test_dataset  = VideoDiskDataset(f'./refined_data_{target_size}/{target_cultivar}/frame-60/abnormal/test/metadata.json')

# %%
def visualizer3(dataset, random_state=42, random_pick_num=-1):
    total_samples = len(dataset)

    # Randomly select sample indices
    random.seed(random_state)
    if random_pick_num == -1:
        random_pick_num = total_samples
    indices = random.sample(range(total_samples), min(random_pick_num, total_samples))

    plt.figure(figsize=(10, 5))

    for idx in indices:
        sample = dataset[idx]
        pixel_values = sample['pixel_values']  # shape: [T, C, H, W]
        label = sample['labels']

        # Convert to numpy and calculate mean intensity per frame
        video_np = pixel_values.numpy()  # [T, C, H, W]
        video_mean_curve = np.mean(video_np, axis=(1, 2, 3))  # [T]

        # Plot the curve
        plt.plot(
            video_mean_curve,
            color={0: 'blue', 1: 'red'}.get(label, 'gray'),
            alpha=0.5,
            label='dead' if label == 0 else 'alive'
        )

    plt.xlabel('Frame')
    plt.ylabel('Mean Pixel Intensity')
    plt.title('Mean Intensity Curves of Random Samples')

    # Deduplicate legend
    handles, labels_uniq = plt.gca().get_legend_handles_labels()
    by_label = dict(zip(labels_uniq, handles))
    plt.legend(by_label.values(), by_label.keys(), title="Labels", bbox_to_anchor=(1.05, 1), loc='upper left')

    plt.tight_layout()
    plt.show()

visualizer3(test_dataset, random_state=42)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
