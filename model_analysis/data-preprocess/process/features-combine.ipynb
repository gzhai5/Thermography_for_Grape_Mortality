# %%
import numpy as np

# %%
exp4_data = np.load('../data/features/exp_4_total_data.npy', allow_pickle=True).item()
exp5_data = np.load('../data/features/exp_5_total_data.npy', allow_pickle=True).item()

print('exp#4 data shape:', len(exp4_data))
print('exp#5 data shape:', len(exp5_data))
# Out:
# exp#4 data shape: 1404
# exp#5 data shape: 1379

# %%
total_data = exp4_data | exp5_data

print('total data shape:', len(total_data))
# Out:
# total data shape: 2783

# %%
np.save('../data/features/total_data.npy', total_data)

# %%
# !cp ../data/roi-video/total_cultivar.npy ../data/features/total_cultivar.npy
# !cp ../data/roi-video/total_label.npy ../data/features/total_label.npy
# Out:
# 'cp' �����ڲ����ⲿ���Ҳ���ǿ����еĳ���
# ���������ļ���
# 'cp' �����ڲ����ⲿ���Ҳ���ǿ����еĳ���
# ���������ļ���
