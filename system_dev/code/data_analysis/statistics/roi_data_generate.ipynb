# %%
import pandas as pd
import numpy as np

# %%
orginal_csv_files = [
    '../roi_data_cf_2.csv',
    '../roi_data_cf_3.csv',
    '../roi_data_cf_4.csv',
    '../roi_data_cf_5.csv',
    '../roi_data_cf_6.csv',
    '../roi_data_con_2.csv',
    '../roi_data_con_3.csv',
    '../roi_data_con_4.csv',
    '../roi_data_con_5.csv',
    '../roi_data_con_6.csv',
    '../roi_data_pn_2.csv',
    '../roi_data_pn_3.csv',
    '../roi_data_pn_4.csv',
    '../roi_data_pn_5.csv',
    '../roi_data_pn_6.csv',
    '../roi_data_ries_2.csv',
    '../roi_data_ries_3.csv',
    '../roi_data_ries_4.csv',
    '../roi_data_ries_5.csv',
    '../roi_data_ries_6.csv',
]

# %%
# mean temperature before heating
def get_starting_temperature(curves: np.ndarray):
    return np.mean(curves[0:30])

# peak temperature after heating
def get_peak_temperature(curves: np.ndarray):
    return np.max(curves[30:300])

# difference between peak temperature and starting temperature
def get_rising_waveform_feature(starting_temperature: float, peak_temperature: float):
    return peak_temperature - starting_temperature

# difference between peak temperature and end temperature
def get_falling_waveform_feature(curves: np.ndarray):
    return np.max(curves[30:300]) - np.min(curves[300:600])

def get_rising_waveform_std(curves: np.ndarray):
    return np.std(curves[30:300])

def get_falling_waveform_std(curves: np.ndarray):
    return np.std(curves[300:600])

def extract_frames(data: np.ndarray, y: int, x: int, radius: int) -> np.ndarray:
    extracted_frames = []
    for frame in data:
        # Extract a (raidus*2+1)^2 region around the center for each frame
        extracted_frame = frame[y-radius:y+radius+1, x-radius:x+radius+1]
        extracted_frames.append(extracted_frame)
    return np.array(extracted_frames)

# use the mean of the first 30 frames as the lowest standard
def normalize_curves_mean_method(curves: np.ndarray):
    mean = np.mean(curves[0:30])
    return curves - mean

# use the min of the first 30 frames as the lowest standard
def normalize_curves_min_method(curves: np.ndarray):
    min_value = np.min(curves[0:30])
    return curves - min_value

# %%
# curves: 600 image frames, 30fps
# heat at 1s, cool at 10s, end at 20s
# 0-29: nothing, 30-299: heating, 300-599: cooling


df_new = pd.read_csv('./csv/stat_all_data.csv')

# traverse all rows, for each row, get the npy file, extract the roi data, and store the data
for index, row in df_new.iterrows():
    filename = row['filename']
    round_number = row['dev_stage']
    x_pt = row['x_coordinate']
    y_pt = row['y_coordinate']

    raw_data = np.load(f'/Volumes/My Book Duo/Bud Thermography Data/round_{round_number}/{filename}')
    roi_data = extract_frames(raw_data, y_pt, x_pt, 10)

    print('processing', filename)
    print('round_number', round_number)
    print('shape of raw_data:', raw_data.shape)
    print('shape of roi_data:', roi_data.shape)

    # save the roi data
    np.save(f'../roi_data/round_{round_number}/[ROI]{filename}', roi_data)
    print(f'saved ./roi_data/round_{round_number}/[ROI]{filename}.npy')
    print('-------------------------------------------------')
# Out:
# processing CF_2.0_B01_N01.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B01_N01.npy.npy
# -------------------------------------------------
# processing CF_2.0_B01_N02.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B01_N02.npy.npy
# -------------------------------------------------
# processing CF_2.0_B01_N03.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B01_N03.npy.npy
# -------------------------------------------------
# processing CF_2.0_B01_N04.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B01_N04.npy.npy
# -------------------------------------------------
# processing CF_2.0_B01_N05.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B01_N05.npy.npy
# -------------------------------------------------
# processing CF_2.0_B01_N06.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B01_N06.npy.npy
# -------------------------------------------------
# processing CF_2.0_B01_N07.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B01_N07.npy.npy
# -------------------------------------------------
# processing CF_2.0_B01_N08.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B01_N08.npy.npy
# -------------------------------------------------
# processing CF_2.0_B01_N09.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B01_N09.npy.npy
# -------------------------------------------------
# processing CF_2.0_B02_N01.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B02_N01.npy.npy
# -------------------------------------------------
# processing CF_2.0_B02_N02.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B02_N02.npy.npy
# -------------------------------------------------
# processing CF_2.0_B02_N03.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B02_N03.npy.npy
# -------------------------------------------------
# processing CF_2.0_B02_N04.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B02_N04.npy.npy
# -------------------------------------------------
# processing CF_2.0_B02_N05.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B02_N05.npy.npy
# -------------------------------------------------
# processing CF_2.0_B02_N06.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B02_N06.npy.npy
# -------------------------------------------------
# processing CF_2.0_B02_N07.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B02_N07.npy.npy
# -------------------------------------------------
# processing CF_2.0_B02_N08.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B02_N08.npy.npy
# -------------------------------------------------
# processing CF_2.0_B02_N09.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B02_N09.npy.npy
# -------------------------------------------------
# processing CF_2.0_B03_N02.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B03_N02.npy.npy
# -------------------------------------------------
# processing CF_2.0_B03_N03.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B03_N03.npy.npy
# -------------------------------------------------
# processing CF_2.0_B03_N05.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B03_N05.npy.npy
# -------------------------------------------------
# processing CF_2.0_B03_N06.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B03_N06.npy.npy
# -------------------------------------------------
# processing CF_2.0_B03_N07.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B03_N07.npy.npy
# -------------------------------------------------
# processing CF_2.0_B03_N08.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B03_N08.npy.npy
# -------------------------------------------------
# processing CF_2.0_B03_N09.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B03_N09.npy.npy
# -------------------------------------------------
# processing CF_2.0_B04_N01.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B04_N01.npy.npy
# -------------------------------------------------
# processing CF_2.0_B04_N02.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B04_N02.npy.npy
# -------------------------------------------------
# processing CF_2.0_B04_N03.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B04_N03.npy.npy
# -------------------------------------------------
# processing CF_2.0_B04_N04.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B04_N04.npy.npy
# -------------------------------------------------
# processing CF_2.0_B04_N05.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B04_N05.npy.npy
# -------------------------------------------------
# processing CF_2.0_B04_N06.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B04_N06.npy.npy
# -------------------------------------------------
# processing CF_2.0_B04_N07.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B04_N07.npy.npy
# -------------------------------------------------
# processing CF_2.0_B05_N01.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B05_N01.npy.npy
# -------------------------------------------------
# processing CF_2.0_B05_N02.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B05_N02.npy.npy
# -------------------------------------------------
# processing CF_2.0_B05_N03.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B05_N03.npy.npy
# -------------------------------------------------
# processing CF_2.0_B05_N04.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B05_N04.npy.npy
# -------------------------------------------------
# processing CF_2.0_B05_N05.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B05_N05.npy.npy
# -------------------------------------------------
# processing CF_2.0_B05_N06.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B05_N06.npy.npy
# -------------------------------------------------
# processing CF_2.0_B05_N07.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B05_N07.npy.npy
# -------------------------------------------------
# processing CF_2.0_B05_N09.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B05_N09.npy.npy
# -------------------------------------------------
# processing CF_2.0_B06_N02.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B06_N02.npy.npy
# -------------------------------------------------
# processing CF_2.0_B06_N03.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B06_N03.npy.npy
# -------------------------------------------------
# processing CF_2.0_B06_N04.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B06_N04.npy.npy
# -------------------------------------------------
# processing CF_2.0_B06_N05.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B06_N05.npy.npy
# -------------------------------------------------
# processing CF_2.0_B06_N06.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B06_N06.npy.npy
# -------------------------------------------------
# processing CF_2.0_B06_N07.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B06_N07.npy.npy
# -------------------------------------------------
# processing CF_2.0_B06_N08.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B06_N08.npy.npy
# -------------------------------------------------
# processing CF_2.0_B07_N01.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B07_N01.npy.npy
# -------------------------------------------------
# processing CF_2.0_B07_N02.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B07_N02.npy.npy
# -------------------------------------------------
# processing CF_2.0_B07_N03.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B07_N03.npy.npy
# -------------------------------------------------
# processing CF_2.0_B07_N04.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B07_N04.npy.npy
# -------------------------------------------------
# processing CF_2.0_B07_N05.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B07_N05.npy.npy
# -------------------------------------------------
# processing CF_2.0_B07_N07.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B07_N07.npy.npy
# -------------------------------------------------
# processing CF_2.0_B07_N08.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B07_N08.npy.npy
# -------------------------------------------------
# processing CF_2.0_B07_N09.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B07_N09.npy.npy
# -------------------------------------------------
# processing CF_2.0_B08_N01.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B08_N01.npy.npy
# -------------------------------------------------
# processing CF_2.0_B08_N02.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B08_N02.npy.npy
# -------------------------------------------------
# processing CF_2.0_B08_N03.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B08_N03.npy.npy
# -------------------------------------------------
# processing CF_2.0_B08_N04.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B08_N04.npy.npy
# -------------------------------------------------
# processing CF_2.0_B08_N05.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B08_N05.npy.npy
# -------------------------------------------------
# processing CF_2.0_B08_N06.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B08_N06.npy.npy
# -------------------------------------------------
# processing CF_2.0_B08_N07.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B08_N07.npy.npy
# -------------------------------------------------
# processing CF_2.0_B08_N09.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B08_N09.npy.npy
# -------------------------------------------------
# processing CF_2.0_B09_N01.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B09_N01.npy.npy
# -------------------------------------------------
# processing CF_2.0_B09_N02.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B09_N02.npy.npy
# -------------------------------------------------
# processing CF_2.0_B09_N03.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B09_N03.npy.npy
# -------------------------------------------------
# processing CF_2.0_B09_N04.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B09_N04.npy.npy
# -------------------------------------------------
# processing CF_2.0_B09_N05.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B09_N05.npy.npy
# -------------------------------------------------
# processing CF_2.0_B09_N06.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B09_N06.npy.npy
# -------------------------------------------------
# processing CF_2.0_B09_N07.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B09_N07.npy.npy
# -------------------------------------------------
# processing CF_2.0_B09_N09.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B09_N09.npy.npy
# -------------------------------------------------
# processing CF_2.0_B10_N01.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B10_N01.npy.npy
# -------------------------------------------------
# processing CF_2.0_B10_N02.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B10_N02.npy.npy
# -------------------------------------------------
# processing CF_2.0_B10_N03.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B10_N03.npy.npy
# -------------------------------------------------
# processing CF_2.0_B10_N04.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B10_N04.npy.npy
# -------------------------------------------------
# processing CF_2.0_B10_N05.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B10_N05.npy.npy
# -------------------------------------------------
# processing CF_2.0_B10_N06.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B10_N06.npy.npy
# -------------------------------------------------
# processing CF_2.0_B10_N07.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B10_N07.npy.npy
# -------------------------------------------------
# processing CF_2.0_B10_N08.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B10_N08.npy.npy
# -------------------------------------------------
# processing CF_2.0_B10_N09.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B10_N09.npy.npy
# -------------------------------------------------
# processing CF_2.0_B11_N01.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B11_N01.npy.npy
# -------------------------------------------------
# processing CF_2.0_B11_N03.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B11_N03.npy.npy
# -------------------------------------------------
# processing CF_2.0_B11_N04.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B11_N04.npy.npy
# -------------------------------------------------
# processing CF_2.0_B11_N05.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B11_N05.npy.npy
# -------------------------------------------------
# processing CF_2.0_B11_N06.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B11_N06.npy.npy
# -------------------------------------------------
# processing CF_2.0_B11_N07.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B11_N07.npy.npy
# -------------------------------------------------
# processing CF_2.0_B11_N08.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B11_N08.npy.npy
# -------------------------------------------------
# processing CF_2.0_B11_N09.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B11_N09.npy.npy
# -------------------------------------------------
# processing CF_2.0_B12_N03.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B12_N03.npy.npy
# -------------------------------------------------
# processing CF_2.0_B12_N04.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B12_N04.npy.npy
# -------------------------------------------------
# processing CF_2.0_B12_N07.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B12_N07.npy.npy
# -------------------------------------------------
# processing CF_2.0_B12_N08.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B12_N08.npy.npy
# -------------------------------------------------
# processing CF_2.0_B12_N09.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B12_N09.npy.npy
# -------------------------------------------------
# processing CF_2.0_B13_N04.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B13_N04.npy.npy
# -------------------------------------------------
# processing CF_2.0_B13_N05.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B13_N05.npy.npy
# -------------------------------------------------
# processing CF_2.0_B13_N06.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B13_N06.npy.npy
# -------------------------------------------------
# processing CF_2.0_B13_N07.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B13_N07.npy.npy
# -------------------------------------------------
# processing CF_2.0_B13_N08.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B13_N08.npy.npy
# -------------------------------------------------
# processing CF_2.0_B13_N09.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B13_N09.npy.npy
# -------------------------------------------------
# processing CF_2.0_B14_N01.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B14_N01.npy.npy
# -------------------------------------------------
# processing CF_2.0_B14_N02.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B14_N02.npy.npy
# -------------------------------------------------
# processing CF_2.0_B14_N03.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B14_N03.npy.npy
# -------------------------------------------------
# processing CF_2.0_B14_N04.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B14_N04.npy.npy
# -------------------------------------------------
# processing CF_2.0_B14_N05.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B14_N05.npy.npy
# -------------------------------------------------
# processing CF_2.0_B14_N06.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B14_N06.npy.npy
# -------------------------------------------------
# processing CF_2.0_B14_N07.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B14_N07.npy.npy
# -------------------------------------------------
# processing CF_2.0_B14_N08.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B14_N08.npy.npy
# -------------------------------------------------
# processing CF_2.0_B14_N09.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B14_N09.npy.npy
# -------------------------------------------------
# processing CF_2.0_B15_N01.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B15_N01.npy.npy
# -------------------------------------------------
# processing CF_2.0_B15_N02.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B15_N02.npy.npy
# -------------------------------------------------
# processing CF_2.0_B15_N03.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B15_N03.npy.npy
# -------------------------------------------------
# processing CF_2.0_B15_N05.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B15_N05.npy.npy
# -------------------------------------------------
# processing CF_2.0_B15_N06.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B15_N06.npy.npy
# -------------------------------------------------
# processing CF_2.0_B15_N08.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B15_N08.npy.npy
# -------------------------------------------------
# processing CF_2.0_B15_N09.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B15_N09.npy.npy
# -------------------------------------------------
# processing CF_2.0_B16_N01.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B16_N01.npy.npy
# -------------------------------------------------
# processing CF_2.0_B16_N02.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B16_N02.npy.npy
# -------------------------------------------------
# processing CF_2.0_B16_N03.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B16_N03.npy.npy
# -------------------------------------------------
# processing CF_2.0_B16_N04.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B16_N04.npy.npy
# -------------------------------------------------
# processing CF_2.0_B16_N05.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B16_N05.npy.npy
# -------------------------------------------------
# processing CF_2.0_B16_N06.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B16_N06.npy.npy
# -------------------------------------------------
# processing CF_2.0_B16_N07.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B16_N07.npy.npy
# -------------------------------------------------
# processing CF_2.0_B17_N01.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B17_N01.npy.npy
# -------------------------------------------------
# processing CF_2.0_B17_N02.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B17_N02.npy.npy
# -------------------------------------------------
# processing CF_2.0_B17_N04.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B17_N04.npy.npy
# -------------------------------------------------
# processing CF_2.0_B17_N05.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B17_N05.npy.npy
# -------------------------------------------------
# processing CF_2.0_B17_N06.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B17_N06.npy.npy
# -------------------------------------------------
# processing CF_2.0_B17_N07.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B17_N07.npy.npy
# -------------------------------------------------
# processing CF_2.0_B17_N08.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B17_N08.npy.npy
# -------------------------------------------------
# processing CF_2.0_B17_N09.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B17_N09.npy.npy
# -------------------------------------------------
# processing CF_2.0_B18_N01.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B18_N01.npy.npy
# -------------------------------------------------
# processing CF_2.0_B18_N02.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B18_N02.npy.npy
# -------------------------------------------------
# processing CF_2.0_B18_N05.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B18_N05.npy.npy
# -------------------------------------------------
# processing CF_2.0_B18_N06.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B18_N06.npy.npy
# -------------------------------------------------
# processing CF_2.0_B18_N07.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B18_N07.npy.npy
# -------------------------------------------------
# processing CF_2.0_B18_N08.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B18_N08.npy.npy
# -------------------------------------------------
# processing CF_2.0_B18_N09.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B18_N09.npy.npy
# -------------------------------------------------
# processing CF_2.0_B19_N01.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B19_N01.npy.npy
# -------------------------------------------------
# processing CF_2.0_B19_N02.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B19_N02.npy.npy
# -------------------------------------------------
# processing CF_2.0_B19_N04.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B19_N04.npy.npy
# -------------------------------------------------
# processing CF_2.0_B19_N05.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B19_N05.npy.npy
# -------------------------------------------------
# processing CF_2.0_B19_N06.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B19_N06.npy.npy
# -------------------------------------------------
# processing CF_2.0_B19_N07.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B19_N07.npy.npy
# -------------------------------------------------
# processing CF_2.0_B20_N01.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B20_N01.npy.npy
# -------------------------------------------------
# processing CF_2.0_B20_N02.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B20_N02.npy.npy
# -------------------------------------------------
# processing CF_2.0_B20_N03.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B20_N03.npy.npy
# -------------------------------------------------
# processing CF_2.0_B20_N04.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B20_N04.npy.npy
# -------------------------------------------------
# processing CF_2.0_B20_N05.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B20_N05.npy.npy
# -------------------------------------------------
# processing CF_2.0_B20_N06.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B20_N06.npy.npy
# -------------------------------------------------
# processing CF_2.0_B20_N07.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B20_N07.npy.npy
# -------------------------------------------------
# processing CF_2.0_B20_N08.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B20_N08.npy.npy
# -------------------------------------------------
# processing CF_2.0_B20_N09.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B20_N09.npy.npy
# -------------------------------------------------
# processing CF_2.0_B21_N01.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B21_N01.npy.npy
# -------------------------------------------------
# processing CF_2.0_B21_N02.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B21_N02.npy.npy
# -------------------------------------------------
# processing CF_2.0_B21_N03.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B21_N03.npy.npy
# -------------------------------------------------
# processing CF_2.0_B21_N04.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B21_N04.npy.npy
# -------------------------------------------------
# processing CF_2.0_B21_N05.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B21_N05.npy.npy
# -------------------------------------------------
# processing CF_2.0_B21_N06.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B21_N06.npy.npy
# -------------------------------------------------
# processing CF_2.0_B21_N07.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B21_N07.npy.npy
# -------------------------------------------------
# processing CF_2.0_B21_N08.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B21_N08.npy.npy
# -------------------------------------------------
# processing CF_2.0_B21_N09.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B21_N09.npy.npy
# -------------------------------------------------
# processing CF_2.0_B22_N01.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B22_N01.npy.npy
# -------------------------------------------------
# processing CF_2.0_B22_N02.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B22_N02.npy.npy
# -------------------------------------------------
# processing CF_2.0_B22_N04.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B22_N04.npy.npy
# -------------------------------------------------
# processing CF_2.0_B22_N05.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B22_N05.npy.npy
# -------------------------------------------------
# processing CF_2.0_B22_N06.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B22_N06.npy.npy
# -------------------------------------------------
# processing CF_2.0_B22_N07.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B22_N07.npy.npy
# -------------------------------------------------
# processing CF_2.0_B22_N08.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B22_N08.npy.npy
# -------------------------------------------------
# processing CF_2.0_B23_N01.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B23_N01.npy.npy
# -------------------------------------------------
# processing CF_2.0_B23_N02.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B23_N02.npy.npy
# -------------------------------------------------
# processing CF_2.0_B23_N03.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B23_N03.npy.npy
# -------------------------------------------------
# processing CF_2.0_B23_N04.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B23_N04.npy.npy
# -------------------------------------------------
# processing CF_2.0_B23_N06.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B23_N06.npy.npy
# -------------------------------------------------
# processing CF_2.0_B23_N08.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B23_N08.npy.npy
# -------------------------------------------------
# processing CF_2.0_B23_N09.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B23_N09.npy.npy
# -------------------------------------------------
# processing CF_2.0_B24_N01.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B24_N01.npy.npy
# -------------------------------------------------
# processing CF_2.0_B24_N03.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B24_N03.npy.npy
# -------------------------------------------------
# processing CF_2.0_B24_N04.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B24_N04.npy.npy
# -------------------------------------------------
# processing CF_2.0_B24_N05.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B24_N05.npy.npy
# -------------------------------------------------
# processing CF_2.0_B24_N06.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B24_N06.npy.npy
# -------------------------------------------------
# processing CF_2.0_B24_N07.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B24_N07.npy.npy
# -------------------------------------------------
# processing CF_2.0_B24_N08.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B24_N08.npy.npy
# -------------------------------------------------
# processing CF_2.0_B24_N09.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B24_N09.npy.npy
# -------------------------------------------------
# processing CF_2.0_B25_N01.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B25_N01.npy.npy
# -------------------------------------------------
# processing CF_2.0_B25_N02.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B25_N02.npy.npy
# -------------------------------------------------
# processing CF_2.0_B25_N03.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B25_N03.npy.npy
# -------------------------------------------------
# processing CF_2.0_B25_N04.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B25_N04.npy.npy
# -------------------------------------------------
# processing CF_2.0_B25_N05.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B25_N05.npy.npy
# -------------------------------------------------
# processing CF_2.0_B25_N06.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B25_N06.npy.npy
# -------------------------------------------------
# processing CF_2.0_B25_N07.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B25_N07.npy.npy
# -------------------------------------------------
# processing CF_2.0_B25_N08.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B25_N08.npy.npy
# -------------------------------------------------
# processing CF_2.0_B25_N09.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B25_N09.npy.npy
# -------------------------------------------------
# processing CF_2.0_B26_N03.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B26_N03.npy.npy
# -------------------------------------------------
# processing CF_2.0_B26_N04.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B26_N04.npy.npy
# -------------------------------------------------
# processing CF_2.0_B26_N05.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B26_N05.npy.npy
# -------------------------------------------------
# processing CF_2.0_B26_N06.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B26_N06.npy.npy
# -------------------------------------------------
# processing CF_2.0_B26_N07.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B26_N07.npy.npy
# -------------------------------------------------
# processing CF_2.0_B26_N08.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B26_N08.npy.npy
# -------------------------------------------------
# processing CF_2.0_B26_N09.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B26_N09.npy.npy
# -------------------------------------------------
# processing CF_2.0_B27_N01.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B27_N01.npy.npy
# -------------------------------------------------
# processing CF_2.0_B27_N04.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B27_N04.npy.npy
# -------------------------------------------------
# processing CF_2.0_B27_N05.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B27_N05.npy.npy
# -------------------------------------------------
# processing CF_2.0_B27_N06.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B27_N06.npy.npy
# -------------------------------------------------
# processing CF_2.0_B27_N07.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B27_N07.npy.npy
# -------------------------------------------------
# processing CF_2.0_B27_N08.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B27_N08.npy.npy
# -------------------------------------------------
# processing CF_2.0_B27_N09.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B27_N09.npy.npy
# -------------------------------------------------
# processing CF_2.0_B28_N01.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B28_N01.npy.npy
# -------------------------------------------------
# processing CF_2.0_B28_N02.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B28_N02.npy.npy
# -------------------------------------------------
# processing CF_2.0_B28_N04.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B28_N04.npy.npy
# -------------------------------------------------
# processing CF_2.0_B28_N05.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B28_N05.npy.npy
# -------------------------------------------------
# processing CF_2.0_B28_N06.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B28_N06.npy.npy
# -------------------------------------------------
# processing CF_2.0_B28_N07.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B28_N07.npy.npy
# -------------------------------------------------
# processing CF_2.0_B28_N08.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B28_N08.npy.npy
# -------------------------------------------------
# processing CF_2.0_B28_N09.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B28_N09.npy.npy
# -------------------------------------------------
# processing CF_2.0_B29_N02.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B29_N02.npy.npy
# -------------------------------------------------
# processing CF_2.0_B29_N03.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B29_N03.npy.npy
# -------------------------------------------------
# processing CF_2.0_B29_N04.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B29_N04.npy.npy
# -------------------------------------------------
# processing CF_2.0_B29_N05.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B29_N05.npy.npy
# -------------------------------------------------
# processing CF_2.0_B29_N06.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B29_N06.npy.npy
# -------------------------------------------------
# processing CF_2.0_B29_N07.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B29_N07.npy.npy
# -------------------------------------------------
# processing CF_2.0_B29_N08.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B29_N08.npy.npy
# -------------------------------------------------
# processing CF_2.0_B29_N09.npy
# round_number 2
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_2/[ROI]CF_2.0_B29_N09.npy.npy
# -------------------------------------------------
# processing CF_2.0_B30_N01.npy
# round_number 2
# ...
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.1F_B40_N06.npy.npy
# -------------------------------------------------
# processing Ries6.1F_B40_N09.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.1F_B40_N09.npy.npy
# -------------------------------------------------
# processing Ries6.1F_B41_N03.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.1F_B41_N03.npy.npy
# -------------------------------------------------
# processing Ries6.1F_B41_N05.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.1F_B41_N05.npy.npy
# -------------------------------------------------
# processing Ries6.1F_B41_N06.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.1F_B41_N06.npy.npy
# -------------------------------------------------
# processing Ries6.1F_B41_N07.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.1F_B41_N07.npy.npy
# -------------------------------------------------
# processing Ries6.1F_B41_N08.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.1F_B41_N08.npy.npy
# -------------------------------------------------
# processing Ries6.1F_B41_N09.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.1F_B41_N09.npy.npy
# -------------------------------------------------
# processing Ries6.1F_B42_N02.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.1F_B42_N02.npy.npy
# -------------------------------------------------
# processing Ries6.1F_B42_N04.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.1F_B42_N04.npy.npy
# -------------------------------------------------
# processing Ries6.1F_B42_N05.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.1F_B42_N05.npy.npy
# -------------------------------------------------
# processing Ries6.1F_B42_N07.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.1F_B42_N07.npy.npy
# -------------------------------------------------
# processing Ries6.1F_B42_N08.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.1F_B42_N08.npy.npy
# -------------------------------------------------
# processing Ries6.1F_B42_N09.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.1F_B42_N09.npy.npy
# -------------------------------------------------
# processing Ries6.1F_B43_N01.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.1F_B43_N01.npy.npy
# -------------------------------------------------
# processing Ries6.1F_B43_N02.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.1F_B43_N02.npy.npy
# -------------------------------------------------
# processing Ries6.1F_B43_N03.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.1F_B43_N03.npy.npy
# -------------------------------------------------
# processing Ries6.1F_B43_N04.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.1F_B43_N04.npy.npy
# -------------------------------------------------
# processing Ries6.1F_B43_N05.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.1F_B43_N05.npy.npy
# -------------------------------------------------
# processing Ries6.1F_B43_N06.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.1F_B43_N06.npy.npy
# -------------------------------------------------
# processing Ries6.1F_B43_N07.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.1F_B43_N07.npy.npy
# -------------------------------------------------
# processing Ries6.1F_B43_N08.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.1F_B43_N08.npy.npy
# -------------------------------------------------
# processing Ries6.1F_B43_N09.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.1F_B43_N09.npy.npy
# -------------------------------------------------
# processing Ries6.1F_B44_N01.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.1F_B44_N01.npy.npy
# -------------------------------------------------
# processing Ries6.1F_B44_N02.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.1F_B44_N02.npy.npy
# -------------------------------------------------
# processing Ries6.1F_B44_N04.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.1F_B44_N04.npy.npy
# -------------------------------------------------
# processing Ries6.1F_B44_N05.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.1F_B44_N05.npy.npy
# -------------------------------------------------
# processing Ries6.1F_B44_N06.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.1F_B44_N06.npy.npy
# -------------------------------------------------
# processing Ries6.1F_B44_N07.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.1F_B44_N07.npy.npy
# -------------------------------------------------
# processing Ries6.1F_B44_N09.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.1F_B44_N09.npy.npy
# -------------------------------------------------
# processing Ries6.1F_B45_N01.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.1F_B45_N01.npy.npy
# -------------------------------------------------
# processing Ries6.1F_B45_N02.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.1F_B45_N02.npy.npy
# -------------------------------------------------
# processing Ries6.1F_B45_N03.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.1F_B45_N03.npy.npy
# -------------------------------------------------
# processing Ries6.1F_B45_N04.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.1F_B45_N04.npy.npy
# -------------------------------------------------
# processing Ries6.1F_B45_N05.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.1F_B45_N05.npy.npy
# -------------------------------------------------
# processing Ries6.1F_B45_N06.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.1F_B45_N06.npy.npy
# -------------------------------------------------
# processing Ries6.1F_B45_N07.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.1F_B45_N07.npy.npy
# -------------------------------------------------
# processing Ries6.1F_B45_N08.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.1F_B45_N08.npy.npy
# -------------------------------------------------
# processing Ries6.1F_B45_N09.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.1F_B45_N09.npy.npy
# -------------------------------------------------
# processing Ries6.5F_B46_N01.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.5F_B46_N01.npy.npy
# -------------------------------------------------
# processing Ries6.5F_B46_N02.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.5F_B46_N02.npy.npy
# -------------------------------------------------
# processing Ries6.5F_B46_N03.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.5F_B46_N03.npy.npy
# -------------------------------------------------
# processing Ries6.5F_B46_N04.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.5F_B46_N04.npy.npy
# -------------------------------------------------
# processing Ries6.5F_B46_N06.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.5F_B46_N06.npy.npy
# -------------------------------------------------
# processing Ries6.5F_B46_N07.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.5F_B46_N07.npy.npy
# -------------------------------------------------
# processing Ries6.5F_B46_N08.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.5F_B46_N08.npy.npy
# -------------------------------------------------
# processing Ries6.5F_B46_N09.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.5F_B46_N09.npy.npy
# -------------------------------------------------
# processing Ries6.5F_B47_N01.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.5F_B47_N01.npy.npy
# -------------------------------------------------
# processing Ries6.5F_B47_N02.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.5F_B47_N02.npy.npy
# -------------------------------------------------
# processing Ries6.5F_B47_N04.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.5F_B47_N04.npy.npy
# -------------------------------------------------
# processing Ries6.5F_B47_N05.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.5F_B47_N05.npy.npy
# -------------------------------------------------
# processing Ries6.5F_B47_N06.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.5F_B47_N06.npy.npy
# -------------------------------------------------
# processing Ries6.5F_B47_N07.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.5F_B47_N07.npy.npy
# -------------------------------------------------
# processing Ries6.5F_B47_N08.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.5F_B47_N08.npy.npy
# -------------------------------------------------
# processing Ries6.5F_B47_N09.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.5F_B47_N09.npy.npy
# -------------------------------------------------
# processing Ries6.5F_B48_N01.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.5F_B48_N01.npy.npy
# -------------------------------------------------
# processing Ries6.5F_B48_N02.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.5F_B48_N02.npy.npy
# -------------------------------------------------
# processing Ries6.5F_B48_N03.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.5F_B48_N03.npy.npy
# -------------------------------------------------
# processing Ries6.5F_B48_N04.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.5F_B48_N04.npy.npy
# -------------------------------------------------
# processing Ries6.5F_B48_N05.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.5F_B48_N05.npy.npy
# -------------------------------------------------
# processing Ries6.5F_B48_N06.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.5F_B48_N06.npy.npy
# -------------------------------------------------
# processing Ries6.5F_B48_N07.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.5F_B48_N07.npy.npy
# -------------------------------------------------
# processing Ries6.5F_B48_N08.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.5F_B48_N08.npy.npy
# -------------------------------------------------
# processing Ries6.5F_B48_N09.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.5F_B48_N09.npy.npy
# -------------------------------------------------
# processing Ries6.5F_B49_N01.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.5F_B49_N01.npy.npy
# -------------------------------------------------
# processing Ries6.5F_B49_N02.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.5F_B49_N02.npy.npy
# -------------------------------------------------
# processing Ries6.5F_B49_N03.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.5F_B49_N03.npy.npy
# -------------------------------------------------
# processing Ries6.5F_B49_N04.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.5F_B49_N04.npy.npy
# -------------------------------------------------
# processing Ries6.5F_B49_N05.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.5F_B49_N05.npy.npy
# -------------------------------------------------
# processing Ries6.5F_B49_N06.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.5F_B49_N06.npy.npy
# -------------------------------------------------
# processing Ries6.5F_B49_N07.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.5F_B49_N07.npy.npy
# -------------------------------------------------
# processing Ries6.5F_B49_N08.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.5F_B49_N08.npy.npy
# -------------------------------------------------
# processing Ries6.5F_B49_N09.npy
# round_number 6
# shape of raw_data: (600, 480, 640)
# shape of roi_data: (600, 21, 21)
# saved ./roi_data/round_6/[ROI]Ries6.5F_B49_N09.npy.npy
# -------------------------------------------------
